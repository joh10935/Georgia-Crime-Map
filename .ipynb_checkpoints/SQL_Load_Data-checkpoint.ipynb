# %% [markdown]
# ### Imports

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import pprint
import pymongo

# %%
from sqlalchemy import create_engine, func
import psycopg2
import os
import requests

# %% [markdown]
# ### Initializations

# %%
api_key = "eVDzrjlfZg8aVJnAy1jNIovawgD9jxyEoBnhCda3"

# %%
# Create base url and get json data
base_url = f"https://api.usa.gov/crime/fbi/sapi//api/agencies?API_KEY={api_key}"
response = requests.get(base_url).json()

# %%
#db initializations
engine = create_engine(f'postgresql://postgres:password@localhost/GACRIME')

# %%
# Show only Georgia results
GA_data = response["GA"]
GA_data
# Out:
# {'GA0160300': {'ori': 'GA0160300',
#   'agency_name': 'Portal Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': False,
#   'latitude': 32.393408,
#   'longitude': -81.74381,
#   'nibrs_start_date': None},
#  'GA0680900': {'ori': 'GA0680900',
#   'agency_name': 'Alto Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BANKS; HABERSHAM',
#   'nibrs': True,
#   'latitude': 34.635108,
#   'longitude': -83.526406,
#   'nibrs_start_date': '01/01/2019'},
#  'GA0410100': {'ori': 'GA0410100',
#   'agency_name': 'Trenton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DADE',
#   'nibrs': False,
#   'latitude': 34.852424,
#   'longitude': -85.506201,
#   'nibrs_start_date': None},
#  'GA0080300': {'ori': 'GA0080300',
#   'agency_name': 'Kingston Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARTOW',
#   'nibrs': True,
#   'latitude': 34.240917,
#   'longitude': -84.838188,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP3300': {'ori': 'GAGSP3300',
#   'agency_name': 'State Patrol: Milledgeville',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 33.059504,
#   'longitude': -83.255452,
#   'nibrs_start_date': None},
#  'GA060459E': {'ori': 'GA060459E',
#   'agency_name': 'Morris Brown College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': False,
#   'latitude': 33.75472,
#   'longitude': -84.40874,
#   'nibrs_start_date': None},
#  'GA0330100': {'ori': 'GA0330100',
#   'agency_name': 'Austell Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGLAS; COBB',
#   'nibrs': True,
#   'latitude': 33.93994,
#   'longitude': -84.574166,
#   'nibrs_start_date': '01/01/2020'},
#  'GA1210300': {'ori': 'GA1210300',
#   'agency_name': 'Hephzibah Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RICHMOND',
#   'nibrs': False,
#   'latitude': 33.361487,
#   'longitude': -82.074998,
#   'nibrs_start_date': None},
#  'GA0020000': {'ori': 'GA0020000',
#   'agency_name': "Atkinson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ATKINSON',
#   'nibrs': True,
#   'latitude': 31.296677,
#   'longitude': -82.878067,
#   'nibrs_start_date': '10/01/2019'},
#  'GAGSP1000': {'ori': 'GAGSP1000',
#   'agency_name': 'State Patrol: Americus',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': False,
#   'latitude': 32.037216,
#   'longitude': -84.14207,
#   'nibrs_start_date': None},
#  'GA1300100': {'ori': 'GA1300100',
#   'agency_name': 'Talbotton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TALBOT',
#   'nibrs': False,
#   'latitude': 32.704603,
#   'longitude': -84.530029,
#   'nibrs_start_date': None},
#  'GA0090100': {'ori': 'GA0090100',
#   'agency_name': 'Fitzgerald Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BEN HILL',
#   'nibrs': True,
#   'latitude': 31.740775,
#   'longitude': -83.14719,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0960000': {'ori': 'GA0960000',
#   'agency_name': "Macon County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MACON',
#   'nibrs': False,
#   'latitude': 32.366216,
#   'longitude': -84.052162,
#   'nibrs_start_date': None},
#  'GA1290100': {'ori': 'GA1290100',
#   'agency_name': 'Americus Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': True,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': '08/01/2019'},
#  'GA0880000': {'ori': 'GA0880000',
#   'agency_name': "Lee County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LEE',
#   'nibrs': True,
#   'latitude': 31.818419,
#   'longitude': -84.146681,
#   'nibrs_start_date': '04/01/2019'},
#  'GA0310500': {'ori': 'GA0310500',
#   'agency_name': 'Riverdale Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': True,
#   'latitude': 33.572205,
#   'longitude': -84.415726,
#   'nibrs_start_date': '06/01/2019'},
#  'GA0100000': {'ori': 'GA0100000',
#   'agency_name': "Berrien County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BERRIEN',
#   'nibrs': True,
#   'latitude': 31.191711,
#   'longitude': -83.27352,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1370100': {'ori': 'GA1370100',
#   'agency_name': 'Tifton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TIFT',
#   'nibrs': False,
#   'latitude': 31.449644,
#   'longitude': -83.509926,
#   'nibrs_start_date': None},
#  'GA0950200': {'ori': 'GA0950200',
#   'agency_name': 'McIntosh County Schools',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MCINTOSH',
#   'nibrs': False,
#   'latitude': 31.482978,
#   'longitude': -81.370199,
#   'nibrs_start_date': None},
#  'GA0780400': {'ori': 'GA0780400',
#   'agency_name': 'Arcade Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JACKSON',
#   'nibrs': True,
#   'latitude': 34.134157,
#   'longitude': -83.565133,
#   'nibrs_start_date': '12/01/2019'},
#  'GA0810000': {'ori': 'GA0810000',
#   'agency_name': "Jefferson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': True,
#   'latitude': 33.051874,
#   'longitude': -82.41905,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0331300': {'ori': 'GA0331300',
#   'agency_name': 'Cobb County Board of Education',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.916363,
#   'longitude': -84.546295,
#   'nibrs_start_date': '10/01/2019'},
#  'GAGSP4500': {'ori': 'GAGSP4500',
#   'agency_name': 'State Patrol: Statesboro',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': False,
#   'latitude': 32.411438,
#   'longitude': -81.80494,
#   'nibrs_start_date': None},
#  'GAGSP2200': {'ori': 'GAGSP2200',
#   'agency_name': 'State Patrol: Waycross',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WARE',
#   'nibrs': False,
#   'latitude': 31.050881,
#   'longitude': -82.421507,
#   'nibrs_start_date': None},
#  'GA0560100': {'ori': 'GA0560100',
#   'agency_name': 'Fayetteville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.412717,
#   'longitude': -84.493941,
#   'nibrs_start_date': '08/01/2019'},
#  'GA0650000': {'ori': 'GA0650000',
#   'agency_name': "Grady County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GRADY',
#   'nibrs': True,
#   'latitude': 30.875891,
#   'longitude': -84.245066,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1060100': {'ori': 'GA1060100',
#   'agency_name': 'Columbus Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MUSCOGEE',
#   'nibrs': False,
#   'latitude': 32.464756,
#   'longitude': -84.98599,
#   'nibrs_start_date': None},
#  'GA0720100': {'ori': 'GA0720100',
#   'agency_name': 'Pine Mountain Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MERIWETHER; HARRIS',
#   'nibrs': True,
#   'latitude': 32.731549,
#   'longitude': -84.912432,
#   'nibrs_start_date': '01/01/2019'},
#  'GA0445100': {'ori': 'GA0445100',
#   'agency_name': 'DeKalb County School System',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': True,
#   'latitude': 33.800564,
#   'longitude': -84.20196,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0170000': {'ori': 'GA0170000',
#   'agency_name': "Burke  County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BURKE',
#   'nibrs': True,
#   'latitude': 33.050819,
#   'longitude': -82.011571,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1360300': {'ori': 'GA1360300',
#   'agency_name': 'Coolidge Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'THOMAS',
#   'nibrs': True,
#   'latitude': 30.864606,
#   'longitude': -83.91982,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1140000': {'ori': 'GA1140000',
#   'agency_name': "Pike County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIKE',
#   'nibrs': True,
#   'latitude': 33.090768,
#   'longitude': -84.386627,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1530100': {'ori': 'GA1530100',
#   'agency_name': 'Alamo Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHEELER',
#   'nibrs': True,
#   'latitude': 32.109276,
#   'longitude': -82.738701,
#   'nibrs_start_date': '07/01/2019'},
#  'GA1220100': {'ori': 'GA1220100',
#   'agency_name': 'Conyers Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ROCKDALE',
#   'nibrs': False,
#   'latitude': 33.65794,
#   'longitude': -84.01751,
#   'nibrs_start_date': None},
#  'GA0250100': {'ori': 'GA0250100',
#   'agency_name': 'Chatham County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': False,
#   'latitude': 32.060173,
#   'longitude': -81.166336,
#   'nibrs_start_date': None},
#  'GA0640200': {'ori': 'GA0640200',
#   'agency_name': 'Fairmount Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GORDON',
#   'nibrs': False,
#   'latitude': 34.509667,
#   'longitude': -84.873862,
#   'nibrs_start_date': None},
#  'GA0252400': {'ori': 'GA0252400',
#   'agency_name': 'Savannah Technical College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': True,
#   'latitude': 31.980523,
#   'longitude': -81.08519,
#   'nibrs_start_date': '01/01/2019'},
#  'GA1130200': {'ori': 'GA1130200',
#   'agency_name': 'Patterson Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIERCE',
#   'nibrs': False,
#   'latitude': 31.353988,
#   'longitude': -82.210427,
#   'nibrs_start_date': None},
#  'GA0710500': {'ori': 'GA0710500',
#   'agency_name': 'West Georgia Technical College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HARALSON',
#   'nibrs': True,
#   'latitude': 33.795165,
#   'longitude': -85.220062,
#   'nibrs_start_date': '03/01/2019'},
#  'GA0160400': {'ori': 'GA0160400',
#   'agency_name': 'Georgia Southern University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': True,
#   'latitude': 32.393408,
#   'longitude': -81.74381,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0330000': {'ori': 'GA0330000',
#   'agency_name': "Cobb County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.952282,
#   'longitude': -84.5482,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1210400': {'ori': 'GA1210400',
#   'agency_name': 'Georgia Regents University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RICHMOND',
#   'nibrs': True,
#   'latitude': 33.47503,
#   'longitude': -81.98768,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP3200': {'ori': 'GAGSP3200',
#   'agency_name': 'State Patrol: Athens',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLARKE',
#   'nibrs': False,
#   'latitude': 33.952185,
#   'longitude': -83.367152,
#   'nibrs_start_date': None},
#  'GA1190500': {'ori': 'GA1190500',
#   'agency_name': 'Sky Valley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RABUN',
#   'nibrs': False,
#   'latitude': 34.883026,
#   'longitude': -83.404735,
#   'nibrs_start_date': None},
#  'GA1300200': {'ori': 'GA1300200',
#   'agency_name': 'Woodland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TALBOT',
#   'nibrs': True,
#   'latitude': 32.704603,
#   'longitude': -84.530029,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0240200': {'ori': 'GA0240200',
#   'agency_name': 'Homeland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHARLTON',
#   'nibrs': False,
#   'latitude': 30.856588,
#   'longitude': -82.02113,
#   'nibrs_start_date': None},
#  'GA0500000': {'ori': 'GA0500000',
#   'agency_name': "Echols County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ECHOLS',
#   'nibrs': True,
#   'latitude': 30.7085,
#   'longitude': -82.836132,
#   'nibrs_start_date': '11/01/2018'},
#  'GA0800100': {'ori': 'GA0800100',
#   'agency_name': 'Hazlehurst Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFF DAVIS',
#   'nibrs': True,
#   'latitude': 31.867207,
#   'longitude': -82.599304,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0530700': {'ori': 'GA0530700',
#   'agency_name': 'East Georgia State College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL',
#   'nibrs': False,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': None},
#  'GA0490000': {'ori': 'GA0490000',
#   'agency_name': "Early County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EARLY',
#   'nibrs': True,
#   'latitude': 31.324191,
#   'longitude': -84.906723,
#   'nibrs_start_date': '10/01/2019'},
#  'GA139039E': {'ori': 'GA139039E',
#   'agency_name': 'Young Harris College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TOWNS',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1380000': {'ori': 'GA1380000',
#   'agency_name': "Toombs County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TOOMBS',
#   'nibrs': False,
#   'latitude': 32.20298,
#   'longitude': -82.34015,
#   'nibrs_start_date': None},
#  'GA0570000': {'ori': 'GA0570000',
#   'agency_name': "Floyd County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FLOYD',
#   'nibrs': True,
#   'latitude': 34.280457,
#   'longitude': -85.1429,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0310400': {'ori': 'GA0310400',
#   'agency_name': 'Jonesboro Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': False,
#   'latitude': 33.516556,
#   'longitude': -84.353935,
#   'nibrs_start_date': None},
#  'GA0010100': {'ori': 'GA0010100',
#   'agency_name': 'Baxley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'APPLING',
#   'nibrs': True,
#   'latitude': 31.739712,
#   'longitude': -82.290103,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0440900': {'ori': 'GA0440900',
#   'agency_name': 'Stone Mountain Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': True,
#   'latitude': 33.80639,
#   'longitude': -84.170364,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1370200': {'ori': 'GA1370200',
#   'agency_name': 'Omega Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COLQUITT; TIFT',
#   'nibrs': True,
#   'latitude': 31.457003,
#   'longitude': -83.525931,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0480100': {'ori': 'GA0480100',
#   'agency_name': 'Douglasville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGLAS',
#   'nibrs': True,
#   'latitude': 33.699317,
#   'longitude': -84.765944,
#   'nibrs_start_date': '07/01/2019'},
#  'GA1290200': {'ori': 'GA1290200',
#   'agency_name': 'Leslie Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': True,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0950100': {'ori': 'GA0950100',
#   'agency_name': 'Darien Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MCINTOSH',
#   'nibrs': True,
#   'latitude': 31.482978,
#   'longitude': -81.370199,
#   'nibrs_start_date': '02/01/2020'},
#  'GA0780500': {'ori': 'GA0780500',
#   'agency_name': 'Hoschton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JACKSON',
#   'nibrs': False,
#   'latitude': 34.134157,
#   'longitude': -83.565133,
#   'nibrs_start_date': None},
#  'GA1230000': {'ori': 'GA1230000',
#   'agency_name': "Schley County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SCHLEY',
#   'nibrs': True,
#   'latitude': 32.263441,
#   'longitude': -84.322724,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0331200': {'ori': 'GA0331200',
#   'agency_name': 'Kennesaw State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.93994,
#   'longitude': -84.574166,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP4400': {'ori': 'GAGSP4400',
#   'agency_name': 'State Patrol: Forsyth',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONROE',
#   'nibrs': False,
#   'latitude': 33.017435,
#   'longitude': -83.922938,
#   'nibrs_start_date': None},
#  'GAGSP2100': {'ori': 'GAGSP2100',
#   'agency_name': 'State Patrol: Sylvania',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SCREVEN',
#   'nibrs': False,
#   'latitude': 32.748623,
#   'longitude': -81.65879,
#   'nibrs_start_date': None},
#  'GA0560200': {'ori': 'GA0560200',
#   'agency_name': 'Peachtree City Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.412717,
#   'longitude': -84.493941,
#   'nibrs_start_date': '11/01/2019'},
#  'GA1060000': {'ori': 'GA1060000',
#   'agency_name': "Muscogee  County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MUSCOGEE',
#   'nibrs': True,
#   'latitude': 32.510197,
#   'longitude': -84.874946,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0690600': {'ori': 'GA0690600',
#   'agency_name': 'Hall County Marshal',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HALL',
#   'nibrs': True,
#   'latitude': 34.317588,
#   'longitude': -83.818497,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0650100': {'ori': 'GA0650100',
#   'agency_name': 'Cairo Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GRADY',
#   'nibrs': True,
#   'latitude': 30.875891,
#   'longitude': -84.245066,
#   'nibrs_start_date': '04/01/2019'},
#  'GA1360400': {'ori': 'GA1360400',
#   'agency_name': 'Meigs Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MITCHELL; THOMAS',
#   'nibrs': False,
#   'latitude': 30.864606,
#   'longitude': -83.91982,
#   'nibrs_start_date': None},
#  'GA0420000': {'ori': 'GA0420000',
#   'agency_name': "Dawson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DAWSON',
#   'nibrs': False,
#   'latitude': 34.422028,
#   'longitude': -84.12007,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1140100': {'ori': 'GA1140100',
#   'agency_name': 'Zebulon Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIKE',
#   'nibrs': True,
#   'latitude': 33.090768,
#   'longitude': -84.386627,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0720000': {'ori': 'GA0720000',
#   'agency_name': "Harris County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HARRIS',
#   'nibrs': True,
#   'latitude': 32.731549,
#   'longitude': -84.912432,
#   'nibrs_start_date': '12/01/2019'},
#  'GA0470300': {'ori': 'GA0470300',
#   'agency_name': 'Albany State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGHERTY',
#   'nibrs': False,
#   'latitude': 31.572027,
#   'longitude': -84.144394,
#   'nibrs_start_date': None},
#  'GA0290900': {'ori': 'GA0290900',
#   'agency_name': 'Athens Technical College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLARKE',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '01/01/2019'},
#  'GA1530000': {'ori': 'GA1530000',
#   'agency_name': "Wheeler County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHEELER',
#   'nibrs': False,
#   'latitude': 32.14889,
#   'longitude': -82.78266,
#   'nibrs_start_date': None},
#  'GA1050200': {'ori': 'GA1050200',
#   'agency_name': 'Eton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MURRAY',
#   'nibrs': True,
#   'latitude': 34.797097,
#   'longitude': -84.73799,
#   'nibrs_start_date': '08/01/2019'},
#  'GA0250000': {'ori': 'GA0250000',
#   'agency_name': "Chatham County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': False,
#   'latitude': 31.980523,
#   'longitude': -81.08519,
#   'nibrs_start_date': None},
#  'GA0160500': {'ori': 'GA0160500',
#   'agency_name': 'Register Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': False,
#   'latitude': 32.367367,
#   'longitude': -81.88627,
#   'nibrs_start_date': None},
#  'GA0970000': {'ori': 'GA0970000',
#   'agency_name': "Madison County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MADISON',
#   'nibrs': True,
#   'latitude': 34.128484,
#   'longitude': -83.203644,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0320100': {'ori': 'GA0320100',
#   'agency_name': 'Homerville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLINCH',
#   'nibrs': False,
#   'latitude': 30.917653,
#   'longitude': -82.702614,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0630200': {'ori': 'GA0630200',
#   'agency_name': 'Glynn County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GLYNN',
#   'nibrs': True,
#   'latitude': 31.212746,
#   'longitude': -81.496517,
#   'nibrs_start_date': '05/01/2019'},
#  'GA057069E': {'ori': 'GA057069E',
#   'agency_name': 'Berry College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FLOYD',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '06/01/2019'},
#  'GAGSP3100': {'ori': 'GAGSP3100',
#   'agency_name': 'State Patrol: Valdosta',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LOWNDES',
#   'nibrs': False,
#   'latitude': 30.833127,
#   'longitude': -83.268992,
#   'nibrs_start_date': None},
#  'GA1000000': {'ori': 'GA1000000',
#   'agency_name': "Miller County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MILLER',
#   'nibrs': False,
#   'latitude': 31.17431,
#   'longitude': -84.73826,
#   'nibrs_start_date': None},
#  'GA1190400': {'ori': 'GA1190400',
#   'agency_name': 'Dillard Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RABUN',
#   'nibrs': True,
#   'latitude': 34.883026,
#   'longitude': -83.404735,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1340600': {'ori': 'GA1340600',
#   'agency_name': 'Jacksonville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TELFAIR',
#   'nibrs': False,
#   'latitude': 31.913639,
#   'longitude': -82.931062,
#   'nibrs_start_date': None},
#  'GA0110000': {'ori': 'GA0110000',
#   'agency_name': "Bibb County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BIBB',
#   'nibrs': True,
#   'latitude': 32.831833,
#   'longitude': -83.64161,
#   'nibrs_start_date': '02/01/2019'},
#  'GA0960200': {'ori': 'GA0960200',
#   'agency_name': 'Ideal Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MACON',
#   'nibrs': False,
#   'latitude': 32.366216,
#   'longitude': -84.052162,
#   'nibrs_start_date': None},
#  'GA0010000': {'ori': 'GA0010000',
#   'agency_name': "Appling County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'APPLING',
#   'nibrs': True,
#   'latitude': 31.782509,
#   'longitude': -82.35828,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0310300': {'ori': 'GA0310300',
#   'agency_name': 'Morrow Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': True,
#   'latitude': 33.582436,
#   'longitude': -84.33722,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0570100': {'ori': 'GA0570100',
#   'agency_name': 'Floyd County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FLOYD',
#   'nibrs': True,
#   'latitude': 34.169235,
#   'longitude': -85.21126,
#   'nibrs_start_date': '01/01/2020'},
#  'GA1500600': {'ori': 'GA1500600',
#   'agency_name': 'Washington County Board of Education',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WASHINGTON',
#   'nibrs': True,
#   'latitude': 32.971848,
#   'longitude': -82.798112,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0100200': {'ori': 'GA0100200',
#   'agency_name': 'Alapaha Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BERRIEN',
#   'nibrs': True,
#   'latitude': 31.274308,
#   'longitude': -83.231906,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0790000': {'ori': 'GA0790000',
#   'agency_name': "Jasper County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JASPER',
#   'nibrs': True,
#   'latitude': 33.318128,
#   'longitude': -83.689505,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0440800': {'ori': 'GA0440800',
#   'agency_name': 'Pine Lake Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': False,
#   'latitude': 33.770661,
#   'longitude': -84.226343,
#   'nibrs_start_date': None},
#  'GA0780200': {'ori': 'GA0780200',
#   'agency_name': 'Jefferson Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JACKSON',
#   'nibrs': True,
#   'latitude': 34.11839,
#   'longitude': -83.57744,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0480000': {'ori': 'GA0480000',
#   'agency_name': "Douglas County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGLAS',
#   'nibrs': True,
#   'latitude': 33.748375,
#   'longitude': -84.7535,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1290300': {'ori': 'GA1290300',
#   'agency_name': 'Plains Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': False,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': None},
#  'GA0220600': {'ori': 'GA0220600',
#   'agency_name': 'University of West Georgia',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CARROLL',
#   'nibrs': True,
#   'latitude': 33.571545,
#   'longitude': -85.094604,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0820000': {'ori': 'GA0820000',
#   'agency_name': "Jenkins County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JENKINS',
#   'nibrs': True,
#   'latitude': 32.794563,
#   'longitude': -81.971524,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0560300': {'ori': 'GA0560300',
#   'agency_name': 'Tyrone Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.478733,
#   'longitude': -84.594215,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP4300': {'ori': 'GAGSP4300',
#   'agency_name': 'State Patrol: Calhoun',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GORDON',
#   'nibrs': False,
#   'latitude': 34.460278,
#   'longitude': -84.91662,
#   'nibrs_start_date': None},
#  'GAGSP2000': {'ori': 'GAGSP2000',
#   'agency_name': 'State Patrol: Dublin',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LAURENS',
#   'nibrs': False,
#   'latitude': 32.39322,
#   'longitude': -82.926317,
#   'nibrs_start_date': None},
#  'GA0600900': {'ori': 'GA0600900',
#   'agency_name': 'Georgia State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.754486,
#   'longitude': -84.38908,
#   'nibrs_start_date': '05/01/2019'},
#  'GA1540100': {'ori': 'GA1540100',
#   'agency_name': 'Cleveland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHITE',
#   'nibrs': True,
#   'latitude': 34.643776,
#   'longitude': -83.743417,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1150000': {'ori': 'GA1150000',
#   'agency_name': "Polk County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'POLK',
#   'nibrs': True,
#   'latitude': 33.996015,
#   'longitude': -85.188338,
#   'nibrs_start_date': '12/01/2018'},
#  'GAAPD0000': {'ori': 'GAAPD0000',
#   'agency_name': 'Atlanta Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB; FULTON',
#   'nibrs': True,
#   'latitude': 33.74819,
#   'longitude': -84.39517,
#   'nibrs_start_date': '10/01/2020'},
#  'GA0470200': {'ori': 'GA0470200',
#   'agency_name': 'Dougherty County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGHERTY',
#   'nibrs': True,
#   'latitude': 31.532588,
#   'longitude': -84.20904,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1360100': {'ori': 'GA1360100',
#   'agency_name': 'Thomasville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'THOMAS',
#   'nibrs': True,
#   'latitude': 30.864606,
#   'longitude': -83.91982,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0447200': {'ori': 'GA0447200',
#   'agency_name': 'Brookhaven Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0070300': {'ori': 'GA0070300',
#   'agency_name': 'Statham Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARROW',
#   'nibrs': False,
#   'latitude': 33.992009,
#   'longitude': -83.712303,
#   'nibrs_start_date': None},
#  'GA0606200': {'ori': 'GA0606200',
#   'agency_name': 'Morehouse School of Medicine',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': False,
#   'latitude': 33.743107,
#   'longitude': -84.41023,
#   'nibrs_start_date': None},
#  'GA0080100': {'ori': 'GA0080100',
#   'agency_name': 'Cartersville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARTOW',
#   'nibrs': True,
#   'latitude': 34.240917,
#   'longitude': -84.838188,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0250300': {'ori': 'GA0250300',
#   'agency_name': 'Savannah-Chatham Metropolitan Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': False,
#   'latitude': 32.075733,
#   'longitude': -81.088394,
#   'nibrs_start_date': None},
#  'GA0810200': {'ori': 'GA0810200',
#   'agency_name': 'Wadley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.051874,
#   'longitude': -82.41905,
#   'nibrs_start_date': None},
#  'GA1050100': {'ori': 'GA1050100',
#   'agency_name': 'Chatsworth Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MURRAY',
#   'nibrs': True,
#   'latitude': 34.797097,
#   'longitude': -84.73799,
#   'nibrs_start_date': '02/01/2019'},
#  'GA0640000': {'ori': 'GA0640000',
#   'agency_name': "Gordon County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GORDON',
#   'nibrs': True,
#   'latitude': 34.509667,
#   'longitude': -84.873862,
#   'nibrs_start_date': '12/01/2018'},
#  'GAGSP3000': {'ori': 'GAGSP3000',
#   'agency_name': 'State Patrol: Cordele',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CRISP',
#   'nibrs': False,
#   'latitude': 31.914753,
#   'longitude': -83.753338,
#   'nibrs_start_date': None},
#  'GA1000100': {'ori': 'GA1000100',
#   'agency_name': 'Colquitt Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MILLER',
#   'nibrs': False,
#   'latitude': 31.162908,
#   'longitude': -84.730386,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0320000': {'ori': 'GA0320000',
#   'agency_name': "Clinch County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLINCH',
#   'nibrs': True,
#   'latitude': 31.039433,
#   'longitude': -82.749954,
#   'nibrs_start_date': '07/01/2020'},
#  'GA0080200': {'ori': 'GA0080200',
#   'agency_name': 'Adairsville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARTOW',
#   'nibrs': True,
#   'latitude': 34.368633,
#   'longitude': -84.93449,
#   'nibrs_start_date': '11/01/2018'},
#  'GA0630300': {'ori': 'GA0630300',
#   'agency_name': 'College of Coastal Georgia',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GLYNN',
#   'nibrs': True,
#   'latitude': 31.212746,
#   'longitude': -81.496517,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1190300': {'ori': 'GA1190300',
# ...
#   'agency_type_name': 'Other State Agency',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.759632,
#   'longitude': -84.382416,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1130000': {'ori': 'GA1130000',
#   'agency_name': "Pierce County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIERCE',
#   'nibrs': True,
#   'latitude': 31.302244,
#   'longitude': -82.23383,
#   'nibrs_start_date': '06/01/2018'},
#  'GA120059E': {'ori': 'GA120059E',
#   'agency_name': 'Andrew College ',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RANDOLPH',
#   'nibrs': False,
#   'latitude': 31.771894,
#   'longitude': -84.79704,
#   'nibrs_start_date': None},
#  'GA0970300': {'ori': 'GA0970300',
#   'agency_name': 'Danielsville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MADISON',
#   'nibrs': True,
#   'latitude': 34.128484,
#   'longitude': -83.203644,
#   'nibrs_start_date': '07/01/2019'},
#  'GA0410000': {'ori': 'GA0410000',
#   'agency_name': "Dade County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DADE',
#   'nibrs': False,
#   'latitude': 34.852424,
#   'longitude': -85.506201,
#   'nibrs_start_date': None},
#  'GA0070000': {'ori': 'GA0070000',
#   'agency_name': "Barrow County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARROW',
#   'nibrs': True,
#   'latitude': 33.992009,
#   'longitude': -83.712303,
#   'nibrs_start_date': '01/01/2018'},
#  'GA0840000': {'ori': 'GA0840000',
#   'agency_name': "Jones County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JONES',
#   'nibrs': True,
#   'latitude': 33.020226,
#   'longitude': -83.562339,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0330200': {'ori': 'GA0330200',
#   'agency_name': 'Cobb County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.958862,
#   'longitude': -84.54633,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1340100': {'ori': 'GA1340100',
#   'agency_name': 'McRae Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHEELER; TELFAIR',
#   'nibrs': True,
#   'latitude': 31.913639,
#   'longitude': -82.931062,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0670800': {'ori': 'GA0670800',
#   'agency_name': 'Snellville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GWINNETT',
#   'nibrs': True,
#   'latitude': 33.83367,
#   'longitude': -84.00958,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0760200': {'ori': 'GA0760200',
#   'agency_name': 'Warner Robins Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PEACH; HOUSTON',
#   'nibrs': True,
#   'latitude': 32.458381,
#   'longitude': -83.662856,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0280100': {'ori': 'GA0280100',
#   'agency_name': 'Canton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHEROKEE',
#   'nibrs': True,
#   'latitude': 34.23541,
#   'longitude': -84.490005,
#   'nibrs_start_date': '11/01/2020'},
#  'GAGSP1900': {'ori': 'GAGSP1900',
#   'agency_name': 'State Patrol: Swainsboro',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL',
#   'nibrs': False,
#   'latitude': 32.5911,
#   'longitude': -82.299763,
#   'nibrs_start_date': None},
#  'GA1200000': {'ori': 'GA1200000',
#   'agency_name': "Randolph County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RANDOLPH',
#   'nibrs': False,
#   'latitude': 31.762651,
#   'longitude': -84.752311,
#   'nibrs_start_date': None},
#  'GA0530500': {'ori': 'GA0530500',
#   'agency_name': 'Stillmore Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL',
#   'nibrs': False,
#   'latitude': 32.5911,
#   'longitude': -82.299763,
#   'nibrs_start_date': None},
#  'GA1550200': {'ori': 'GA1550200',
#   'agency_name': 'Tunnel Hill Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHITFIELD',
#   'nibrs': True,
#   'latitude': 34.801726,
#   'longitude': -84.968541,
#   'nibrs_start_date': '02/01/2020'},
#  'GA0830200': {'ori': 'GA0830200',
#   'agency_name': 'Adrian Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL; JOHNSON',
#   'nibrs': False,
#   'latitude': 32.689831,
#   'longitude': -82.661354,
#   'nibrs_start_date': None},
#  'GA0610300': {'ori': 'GA0610300',
#   'agency_name': 'East Ellijay Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GILMER',
#   'nibrs': True,
#   'latitude': 34.690541,
#   'longitude': -84.453984,
#   'nibrs_start_date': '12/01/2019'},
#  'GA0750400': {'ori': 'GA0750400',
#   'agency_name': 'Locust Grove Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HENRY',
#   'nibrs': False,
#   'latitude': 33.452881,
#   'longitude': -84.15444,
#   'nibrs_start_date': None},
#  'GA0310600': {'ori': 'GA0310600',
#   'agency_name': 'Lake City Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': True,
#   'latitude': 33.60693,
#   'longitude': -84.34333,
#   'nibrs_start_date': '09/01/2018'},
#  'GA1290000': {'ori': 'GA1290000',
#   'agency_name': "Sumter County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': True,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': '01/01/2018'},
#  'GA1070000': {'ori': 'GA1070000',
#   'agency_name': "Newton County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'NEWTON',
#   'nibrs': True,
#   'latitude': 33.544065,
#   'longitude': -83.855192,
#   'nibrs_start_date': '10/01/2018'},
#  'GA0050300': {'ori': 'GA0050300',
#   'agency_name': 'Georgia College and State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': True,
#   'latitude': 33.059504,
#   'longitude': -83.255452,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0560000': {'ori': 'GA0560000',
#   'agency_name': "Fayette County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.446476,
#   'longitude': -84.45227,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0990000': {'ori': 'GA0990000',
#   'agency_name': "Meriwether County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MERIWETHER',
#   'nibrs': True,
#   'latitude': 33.03022,
#   'longitude': -84.663279,
#   'nibrs_start_date': '01/01/2019'},
#  'GA0602700': {'ori': 'GA0602700',
#   'agency_name': 'Fulton County Marshal',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.752655,
#   'longitude': -84.38997,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0600400': {'ori': 'GA0600400',
#   'agency_name': 'Alpharetta Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.790034,
#   'longitude': -84.468182,
#   'nibrs_start_date': '03/01/2019'},
#  'GA1280100': {'ori': 'GA1280100',
#   'agency_name': 'Lumpkin Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'STEWART',
#   'nibrs': False,
#   'latitude': 32.073225,
#   'longitude': -84.834912,
#   'nibrs_start_date': None},
#  'GA1410000': {'ori': 'GA1410000',
#   'agency_name': "Troup County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TROUP',
#   'nibrs': False,
#   'latitude': 32.989746,
#   'longitude': -85.00395,
#   'nibrs_start_date': None},
#  'GA0690400': {'ori': 'GA0690400',
#   'agency_name': 'Oakwood Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HALL',
#   'nibrs': True,
#   'latitude': 34.317588,
#   'longitude': -83.818497,
#   'nibrs_start_date': '11/01/2019'},
#  'GA0130000': {'ori': 'GA0130000',
#   'agency_name': "Brantley County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BRANTLEY',
#   'nibrs': True,
#   'latitude': 31.197334,
#   'longitude': -81.982978,
#   'nibrs_start_date': '10/01/2019'},
#  'GAGSP0800': {'ori': 'GAGSP0800',
#   'agency_name': 'State Patrol: Madison',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MORGAN',
#   'nibrs': False,
#   'latitude': 33.593732,
#   'longitude': -83.492324,
#   'nibrs_start_date': None},
#  'GA0340100': {'ori': 'GA0340100',
#   'agency_name': 'Douglas Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COFFEE',
#   'nibrs': True,
#   'latitude': 31.511168,
#   'longitude': -82.852135,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0470500': {'ori': 'GA0470500',
#   'agency_name': 'Dougherty County Board of Education',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGHERTY',
#   'nibrs': True,
#   'latitude': 31.532588,
#   'longitude': -84.20904,
#   'nibrs_start_date': '07/01/2019'},
#  'GA1350000': {'ori': 'GA1350000',
#   'agency_name': "Terrell County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TERRELL',
#   'nibrs': False,
#   'latitude': 31.777191,
#   'longitude': -84.439446,
#   'nibrs_start_date': None},
#  'GA0250600': {'ori': 'GA0250600',
#   'agency_name': 'Tybee Island Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': True,
#   'latitude': 31.980523,
#   'longitude': -81.08519,
#   'nibrs_start_date': '05/01/2019'},
#  'GA0900000': {'ori': 'GA0900000',
#   'agency_name': "Lincoln County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LINCOLN',
#   'nibrs': False,
#   'latitude': 33.792151,
#   'longitude': -82.448299,
#   'nibrs_start_date': None},
#  'GA0550200': {'ori': 'GA0550200',
#   'agency_name': 'Blue Ridge Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FANNIN',
#   'nibrs': False,
#   'latitude': 34.866226,
#   'longitude': -84.32594,
#   'nibrs_start_date': None},
#  'GA0770100': {'ori': 'GA0770100',
#   'agency_name': 'Ocilla Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'IRWIN',
#   'nibrs': True,
#   'latitude': 31.591131,
#   'longitude': -83.25055,
#   'nibrs_start_date': '07/01/2019'},
#  'GA0810500': {'ori': 'GA0810500',
#   'agency_name': 'Stapleton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': True,
#   'latitude': 33.051874,
#   'longitude': -82.41905,
#   'nibrs_start_date': '07/01/2020'},
#  'GA0120200': {'ori': 'GA0120200',
#   'agency_name': 'Middle Georgia State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BLECKLEY',
#   'nibrs': True,
#   'latitude': 32.435403,
#   'longitude': -83.331717,
#   'nibrs_start_date': '01/01/2019'}}

# %%
# Connect to database
client = pymongo.MongoClient('mongodb://localhost:27017')
db = client.CrimeAgencyData

# Deletes any existing database to prevent data from duplicating each time script is executed
client.drop_database('CrimeAgencyData')

agency_data = []

# Loop through the GA_data
for x in GA_data:
    agency_data = [
        {
            "ORI" : GA_data[x]["ori"],
            "Agency Name" : GA_data[x]["agency_name"],
            "County" : GA_data[x]["county_name"],
            "Latitude" : GA_data[x]["latitude"],
            "Longitude" : GA_data[x]["longitude"]
        }
    ]
    
    
    # Add entry to the database
    db.destination.insert_many(agency_data)
    
    agency_data.append(agency_data)
    pprint.pprint(agency_data)
# Out:
# [{'Agency Name': 'Portal Police Department',
#   'County': 'BULLOCH',
#   'Latitude': 32.393408,
#   'Longitude': -81.74381,
#   'ORI': 'GA0160300',
#   '_id': ObjectId('6333e73f4607824e8e9f2f4a')},
#  <Recursion on list with id=2458959900288>]
# [{'Agency Name': 'Alto Police Department',
#   'County': 'BANKS; HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   'ORI': 'GA0680900',
#   '_id': ObjectId('6333e73f4607824e8e9f2f4b')},
#  <Recursion on list with id=2458961521920>]
# [{'Agency Name': 'Trenton Police Department',
#   'County': 'DADE',
#   'Latitude': 34.852424,
#   'Longitude': -85.506201,
#   'ORI': 'GA0410100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f4c')},
#  <Recursion on list with id=2458955144704>]
# [{'Agency Name': 'Kingston Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080300',
#   '_id': ObjectId('6333e73f4607824e8e9f2f4d')},
#  <Recursion on list with id=2458955403648>]
# [{'Agency Name': 'State Patrol: Milledgeville',
#   'County': 'BALDWIN',
#   'Latitude': 33.059504,
#   'Longitude': -83.255452,
#   'ORI': 'GAGSP3300',
#   '_id': ObjectId('6333e73f4607824e8e9f2f4e')},
#  <Recursion on list with id=2458952187520>]
# [{'Agency Name': 'Morris Brown College',
#   'County': 'FULTON',
#   'Latitude': 33.75472,
#   'Longitude': -84.40874,
#   'ORI': 'GA060459E',
#   '_id': ObjectId('6333e73f4607824e8e9f2f4f')},
#  <Recursion on list with id=2458955145152>]
# [{'Agency Name': 'Austell Police Department',
#   'County': 'DOUGLAS; COBB',
#   'Latitude': 33.93994,
#   'Longitude': -84.574166,
#   'ORI': 'GA0330100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f50')},
#  <Recursion on list with id=2458955401280>]
# [{'Agency Name': 'Hephzibah Police Department',
#   'County': 'RICHMOND',
#   'Latitude': 33.361487,
#   'Longitude': -82.074998,
#   'ORI': 'GA1210300',
#   '_id': ObjectId('6333e73f4607824e8e9f2f51')},
#  <Recursion on list with id=2458872134912>]
# [{'Agency Name': "Atkinson County Sheriff's Office",
#   'County': 'ATKINSON',
#   'Latitude': 31.296677,
#   'Longitude': -82.878067,
#   'ORI': 'GA0020000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f52')},
#  <Recursion on list with id=2458955154304>]
# [{'Agency Name': 'State Patrol: Americus',
#   'County': 'SUMTER',
#   'Latitude': 32.037216,
#   'Longitude': -84.14207,
#   'ORI': 'GAGSP1000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f53')},
#  <Recursion on list with id=2458955156928>]
# [{'Agency Name': 'Talbotton Police Department',
#   'County': 'TALBOT',
#   'Latitude': 32.704603,
#   'Longitude': -84.530029,
#   'ORI': 'GA1300100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f54')},
#  <Recursion on list with id=2458955154240>]
# [{'Agency Name': 'Fitzgerald Police Department',
#   'County': 'BEN HILL',
#   'Latitude': 31.740775,
#   'Longitude': -83.14719,
#   'ORI': 'GA0090100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f55')},
#  <Recursion on list with id=2458955154048>]
# [{'Agency Name': "Macon County Sheriff's Office",
#   'County': 'MACON',
#   'Latitude': 32.366216,
#   'Longitude': -84.052162,
#   'ORI': 'GA0960000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f56')},
#  <Recursion on list with id=2458955400896>]
# [{'Agency Name': 'Americus Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f57')},
#  <Recursion on list with id=2458961787072>]
# [{'Agency Name': "Lee County Sheriff's Office",
#   'County': 'LEE',
#   'Latitude': 31.818419,
#   'Longitude': -84.146681,
#   'ORI': 'GA0880000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f58')},
#  <Recursion on list with id=2458955153664>]
# [{'Agency Name': 'Riverdale Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.572205,
#   'Longitude': -84.415726,
#   'ORI': 'GA0310500',
#   '_id': ObjectId('6333e73f4607824e8e9f2f59')},
#  <Recursion on list with id=2458955144512>]
# [{'Agency Name': "Berrien County Sheriff's Office",
#   'County': 'BERRIEN',
#   'Latitude': 31.191711,
#   'Longitude': -83.27352,
#   'ORI': 'GA0100000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f5a')},
#  <Recursion on list with id=2458955400576>]
# [{'Agency Name': 'Tifton Police Department',
#   'County': 'TIFT',
#   'Latitude': 31.449644,
#   'Longitude': -83.509926,
#   'ORI': 'GA1370100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f5b')},
#  <Recursion on list with id=2458961752512>]
# [{'Agency Name': 'McIntosh County Schools',
#   'County': 'MCINTOSH',
#   'Latitude': 31.482978,
#   'Longitude': -81.370199,
#   'ORI': 'GA0950200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f5c')},
#  <Recursion on list with id=2458961788160>]
# [{'Agency Name': 'Arcade Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   'ORI': 'GA0780400',
#   '_id': ObjectId('6333e73f4607824e8e9f2f5d')},
#  <Recursion on list with id=2458953830656>]
# [{'Agency Name': "Jefferson County Sheriff's Office",
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f5e')},
#  <Recursion on list with id=2458955153536>]
# [{'Agency Name': 'Cobb County Board of Education',
#   'County': 'COBB',
#   'Latitude': 33.916363,
#   'Longitude': -84.546295,
#   'ORI': 'GA0331300',
#   '_id': ObjectId('6333e73f4607824e8e9f2f5f')},
#  <Recursion on list with id=2458955401792>]
# [{'Agency Name': 'State Patrol: Statesboro',
#   'County': 'BULLOCH',
#   'Latitude': 32.411438,
#   'Longitude': -81.80494,
#   'ORI': 'GAGSP4500',
#   '_id': ObjectId('6333e73f4607824e8e9f2f60')},
#  <Recursion on list with id=2458961754368>]
# [{'Agency Name': 'State Patrol: Waycross',
#   'County': 'WARE',
#   'Latitude': 31.050881,
#   'Longitude': -82.421507,
#   'ORI': 'GAGSP2200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f61')},
#  <Recursion on list with id=2458961755456>]
# [{'Agency Name': 'Fayetteville Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.412717,
#   'Longitude': -84.493941,
#   'ORI': 'GA0560100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f62')},
#  <Recursion on list with id=2458961753344>]
# [{'Agency Name': "Grady County Sheriff's Office",
#   'County': 'GRADY',
#   'Latitude': 30.875891,
#   'Longitude': -84.245066,
#   'ORI': 'GA0650000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f63')},
#  <Recursion on list with id=2458961785856>]
# [{'Agency Name': 'Columbus Police Department',
#   'County': 'MUSCOGEE',
#   'Latitude': 32.464756,
#   'Longitude': -84.98599,
#   'ORI': 'GA1060100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f64')},
#  <Recursion on list with id=2458961799680>]
# [{'Agency Name': 'Pine Mountain Police Department',
#   'County': 'MERIWETHER; HARRIS',
#   'Latitude': 32.731549,
#   'Longitude': -84.912432,
#   'ORI': 'GA0720100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f65')},
#  <Recursion on list with id=2458955122432>]
# [{'Agency Name': 'DeKalb County School System',
#   'County': 'DEKALB',
#   'Latitude': 33.800564,
#   'Longitude': -84.20196,
#   'ORI': 'GA0445100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f66')},
#  <Recursion on list with id=2458958136960>]
# [{'Agency Name': "Burke  County Sheriff's Office",
#   'County': 'BURKE',
#   'Latitude': 33.050819,
#   'Longitude': -82.011571,
#   'ORI': 'GA0170000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f67')},
#  <Recursion on list with id=2458955909504>]
# [{'Agency Name': 'Coolidge Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360300',
#   '_id': ObjectId('6333e73f4607824e8e9f2f68')},
#  <Recursion on list with id=2458961782528>]
# [{'Agency Name': "Pike County Sheriff's Office",
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   'ORI': 'GA1140000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f69')},
#  <Recursion on list with id=2458961816512>]
# [{'Agency Name': 'Alamo Police Department',
#   'County': 'WHEELER',
#   'Latitude': 32.109276,
#   'Longitude': -82.738701,
#   'ORI': 'GA1530100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f6a')},
#  <Recursion on list with id=2458961815424>]
# [{'Agency Name': 'Conyers Police Department',
#   'County': 'ROCKDALE',
#   'Latitude': 33.65794,
#   'Longitude': -84.01751,
#   'ORI': 'GA1220100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f6b')},
#  <Recursion on list with id=2458961633856>]
# [{'Agency Name': 'Chatham County Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 32.060173,
#   'Longitude': -81.166336,
#   'ORI': 'GA0250100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f6c')},
#  <Recursion on list with id=2458961814400>]
# [{'Agency Name': 'Fairmount Police Department',
#   'County': 'GORDON',
#   'Latitude': 34.509667,
#   'Longitude': -84.873862,
#   'ORI': 'GA0640200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f6d')},
#  <Recursion on list with id=2458955400512>]
# [{'Agency Name': 'Savannah Technical College',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0252400',
#   '_id': ObjectId('6333e73f4607824e8e9f2f6e')},
#  <Recursion on list with id=2458961819712>]
# [{'Agency Name': 'Patterson Police Department',
#   'County': 'PIERCE',
#   'Latitude': 31.353988,
#   'Longitude': -82.210427,
#   'ORI': 'GA1130200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f6f')},
#  <Recursion on list with id=2458961820864>]
# [{'Agency Name': 'West Georgia Technical College',
#   'County': 'HARALSON',
#   'Latitude': 33.795165,
#   'Longitude': -85.220062,
#   'ORI': 'GA0710500',
#   '_id': ObjectId('6333e73f4607824e8e9f2f70')},
#  <Recursion on list with id=2458961784576>]
# [{'Agency Name': 'Georgia Southern University',
#   'County': 'BULLOCH',
#   'Latitude': 32.393408,
#   'Longitude': -81.74381,
#   'ORI': 'GA0160400',
#   '_id': ObjectId('6333e73f4607824e8e9f2f71')},
#  <Recursion on list with id=2458961797568>]
# [{'Agency Name': "Cobb County Sheriff's Office",
#   'County': 'COBB',
#   'Latitude': 33.952282,
#   'Longitude': -84.5482,
#   'ORI': 'GA0330000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f72')},
#  <Recursion on list with id=2458961836672>]
# [{'Agency Name': 'Georgia Regents University',
#   'County': 'RICHMOND',
#   'Latitude': 33.47503,
#   'Longitude': -81.98768,
#   'ORI': 'GA1210400',
#   '_id': ObjectId('6333e73f4607824e8e9f2f73')},
#  <Recursion on list with id=2458961834496>]
# [{'Agency Name': 'State Patrol: Athens',
#   'County': 'CLARKE',
#   'Latitude': 33.952185,
#   'Longitude': -83.367152,
#   'ORI': 'GAGSP3200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f74')},
#  <Recursion on list with id=2458961783424>]
# [{'Agency Name': 'Sky Valley Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190500',
#   '_id': ObjectId('6333e73f4607824e8e9f2f75')},
#  <Recursion on list with id=2458961798656>]
# [{'Agency Name': 'Woodland Police Department',
#   'County': 'TALBOT',
#   'Latitude': 32.704603,
#   'Longitude': -84.530029,
#   'ORI': 'GA1300200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f76')},
#  <Recursion on list with id=2458961826112>]
# [{'Agency Name': 'Homeland Police Department',
#   'County': 'CHARLTON',
#   'Latitude': 30.856588,
#   'Longitude': -82.02113,
#   'ORI': 'GA0240200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f77')},
#  <Recursion on list with id=2458961818624>]
# [{'Agency Name': "Echols County Sheriff's Office",
#   'County': 'ECHOLS',
#   'Latitude': 30.7085,
#   'Longitude': -82.836132,
#   'ORI': 'GA0500000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f78')},
#  <Recursion on list with id=2458961788800>]
# [{'Agency Name': 'Hazlehurst Police Department',
#   'County': 'JEFF DAVIS',
#   'Latitude': 31.867207,
#   'Longitude': -82.599304,
#   'ORI': 'GA0800100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f79')},
#  <Recursion on list with id=2458961781440>]
# [{'Agency Name': 'East Georgia State College',
#   'County': 'EMANUEL',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0530700',
#   '_id': ObjectId('6333e73f4607824e8e9f2f7a')},
#  <Recursion on list with id=2458961843200>]
# [{'Agency Name': "Early County Sheriff's Office",
#   'County': 'EARLY',
#   'Latitude': 31.324191,
#   'Longitude': -84.906723,
#   'ORI': 'GA0490000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f7b')},
#  <Recursion on list with id=2458961845248>]
# [{'Agency Name': 'Young Harris College',
#   'County': 'TOWNS',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA139039E',
#   '_id': ObjectId('6333e73f4607824e8e9f2f7c')},
#  <Recursion on list with id=2458961829120>]
# [{'Agency Name': "Toombs County Sheriff's Office",
#   'County': 'TOOMBS',
#   'Latitude': 32.20298,
#   'Longitude': -82.34015,
#   'ORI': 'GA1380000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f7d')},
#  <Recursion on list with id=2458961851520>]
# [{'Agency Name': "Floyd County Sheriff's Office",
#   'County': 'FLOYD',
#   'Latitude': 34.280457,
#   'Longitude': -85.1429,
#   'ORI': 'GA0570000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f7e')},
#  <Recursion on list with id=2458961828224>]
# [{'Agency Name': 'Jonesboro Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.516556,
#   'Longitude': -84.353935,
#   'ORI': 'GA0310400',
#   '_id': ObjectId('6333e73f4607824e8e9f2f7f')},
#  <Recursion on list with id=2458961835648>]
# [{'Agency Name': 'Baxley Police Department',
#   'County': 'APPLING',
#   'Latitude': 31.739712,
#   'Longitude': -82.290103,
#   'ORI': 'GA0010100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f80')},
#  <Recursion on list with id=2458961853632>]
# [{'Agency Name': 'Stone Mountain Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.80639,
#   'Longitude': -84.170364,
#   'ORI': 'GA0440900',
#   '_id': ObjectId('6333e73f4607824e8e9f2f81')},
#  <Recursion on list with id=2458961850496>]
# [{'Agency Name': 'Omega Police Department',
#   'County': 'COLQUITT; TIFT',
#   'Latitude': 31.457003,
#   'Longitude': -83.525931,
#   'ORI': 'GA1370200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f82')},
#  <Recursion on list with id=2458961864000>]
# [{'Agency Name': 'Douglasville Police Department',
#   'County': 'DOUGLAS',
#   'Latitude': 33.699317,
#   'Longitude': -84.765944,
#   'ORI': 'GA0480100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f83')},
#  <Recursion on list with id=2458961852416>]
# [{'Agency Name': 'Leslie Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f84')},
#  <Recursion on list with id=2458961862912>]
# [{'Agency Name': 'Darien Police Department',
#   'County': 'MCINTOSH',
#   'Latitude': 31.482978,
#   'Longitude': -81.370199,
#   'ORI': 'GA0950100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f85')},
#  <Recursion on list with id=2458961859008>]
# [{'Agency Name': 'Hoschton Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   'ORI': 'GA0780500',
#   '_id': ObjectId('6333e73f4607824e8e9f2f86')},
#  <Recursion on list with id=2458961836096>]
# [{'Agency Name': "Schley County Sheriff's Office",
#   'County': 'SCHLEY',
#   'Latitude': 32.263441,
#   'Longitude': -84.322724,
#   'ORI': 'GA1230000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f87')},
#  <Recursion on list with id=2458961803008>]
# [{'Agency Name': 'Kennesaw State University',
#   'County': 'COBB',
#   'Latitude': 33.93994,
#   'Longitude': -84.574166,
#   'ORI': 'GA0331200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f88')},
#  <Recursion on list with id=2458961861120>]
# [{'Agency Name': 'State Patrol: Forsyth',
#   'County': 'MONROE',
#   'Latitude': 33.017435,
#   'Longitude': -83.922938,
#   'ORI': 'GAGSP4400',
#   '_id': ObjectId('6333e73f4607824e8e9f2f89')},
#  <Recursion on list with id=2458961866112>]
# [{'Agency Name': 'State Patrol: Sylvania',
#   'County': 'SCREVEN',
#   'Latitude': 32.748623,
#   'Longitude': -81.65879,
#   'ORI': 'GAGSP2100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f8a')},
#  <Recursion on list with id=2458961804096>]
# [{'Agency Name': 'Peachtree City Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.412717,
#   'Longitude': -84.493941,
#   'ORI': 'GA0560200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f8b')},
#  <Recursion on list with id=2458961801920>]
# [{'Agency Name': "Muscogee  County Sheriff's Office",
#   'County': 'MUSCOGEE',
#   'Latitude': 32.510197,
#   'Longitude': -84.874946,
#   'ORI': 'GA1060000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f8c')},
#  <Recursion on list with id=2458961865088>]
# [{'Agency Name': 'Hall County Marshal',
#   'County': 'HALL',
#   'Latitude': 34.317588,
#   'Longitude': -83.818497,
#   'ORI': 'GA0690600',
#   '_id': ObjectId('6333e73f4607824e8e9f2f8d')},
#  <Recursion on list with id=2458961886272>]
# [{'Agency Name': 'Cairo Police Department',
#   'County': 'GRADY',
#   'Latitude': 30.875891,
#   'Longitude': -84.245066,
#   'ORI': 'GA0650100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f8e')},
#  <Recursion on list with id=2458961884160>]
# [{'Agency Name': 'Meigs Police Department',
#   'County': 'MITCHELL; THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360400',
#   '_id': ObjectId('6333e73f4607824e8e9f2f8f')},
#  <Recursion on list with id=2458961805184>]
# [{'Agency Name': "Dawson County Sheriff's Office",
#   'County': 'DAWSON',
#   'Latitude': 34.422028,
#   'Longitude': -84.12007,
#   'ORI': 'GA0420000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f90')},
#  <Recursion on list with id=2458961897024>]
# [{'Agency Name': 'Zebulon Police Department',
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   'ORI': 'GA1140100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f91')},
#  <Recursion on list with id=2458961895936>]
# [{'Agency Name': "Harris County Sheriff's Office",
#   'County': 'HARRIS',
#   'Latitude': 32.731549,
#   'Longitude': -84.912432,
#   'ORI': 'GA0720000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f92')},
#  <Recursion on list with id=2458961899136>]
# [{'Agency Name': 'Albany State University',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.572027,
#   'Longitude': -84.144394,
#   'ORI': 'GA0470300',
#   '_id': ObjectId('6333e73f4607824e8e9f2f93')},
#  <Recursion on list with id=2458961885184>]
# [{'Agency Name': 'Athens Technical College',
#   'County': 'CLARKE',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0290900',
#   '_id': ObjectId('6333e73f4607824e8e9f2f94')},
#  <Recursion on list with id=2458961827136>]
# [{'Agency Name': "Wheeler County Sheriff's Office",
#   'County': 'WHEELER',
#   'Latitude': 32.14889,
#   'Longitude': -82.78266,
#   'ORI': 'GA1530000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f95')},
#  <Recursion on list with id=2458961805184>]
# [{'Agency Name': 'Eton Police Department',
#   'County': 'MURRAY',
#   'Latitude': 34.797097,
#   'Longitude': -84.73799,
#   'ORI': 'GA1050200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f96')},
#  <Recursion on list with id=2458961804096>]
# [{'Agency Name': "Chatham County Sheriff's Office",
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0250000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f97')},
#  <Recursion on list with id=2458961803008>]
# [{'Agency Name': 'Register Police Department',
#   'County': 'BULLOCH',
#   'Latitude': 32.367367,
#   'Longitude': -81.88627,
#   'ORI': 'GA0160500',
#   '_id': ObjectId('6333e73f4607824e8e9f2f98')},
#  <Recursion on list with id=2458961861120>]
# [{'Agency Name': "Madison County Sheriff's Office",
#   'County': 'MADISON',
#   'Latitude': 34.128484,
#   'Longitude': -83.203644,
#   'ORI': 'GA0970000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f99')},
#  <Recursion on list with id=2458961866112>]
# [{'Agency Name': 'Homerville Police Department',
#   'County': 'CLINCH',
#   'Latitude': 30.917653,
#   'Longitude': -82.702614,
#   'ORI': 'GA0320100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f9a')},
#  <Recursion on list with id=2458961859008>]
# [{'Agency Name': 'Glynn County Police Department',
#   'County': 'GLYNN',
#   'Latitude': 31.212746,
#   'Longitude': -81.496517,
#   'ORI': 'GA0630200',
#   '_id': ObjectId('6333e73f4607824e8e9f2f9b')},
#  <Recursion on list with id=2458961862912>]
# [{'Agency Name': 'Berry College',
#   'County': 'FLOYD',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA057069E',
#   '_id': ObjectId('6333e73f4607824e8e9f2f9c')},
#  <Recursion on list with id=2458961852416>]
# [{'Agency Name': 'State Patrol: Valdosta',
#   'County': 'LOWNDES',
#   'Latitude': 30.833127,
#   'Longitude': -83.268992,
#   'ORI': 'GAGSP3100',
#   '_id': ObjectId('6333e73f4607824e8e9f2f9d')},
#  <Recursion on list with id=2458961884160>]
# [{'Agency Name': "Miller County Sheriff's Office",
#   'County': 'MILLER',
#   'Latitude': 31.17431,
#   'Longitude': -84.73826,
#   'ORI': 'GA1000000',
#   '_id': ObjectId('6333e73f4607824e8e9f2f9e')},
#  <Recursion on list with id=2458961850496>]
# [{'Agency Name': 'Dillard Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190400',
#   '_id': ObjectId('6333e73f4607824e8e9f2f9f')},
#  <Recursion on list with id=2458961864000>]
# [{'Agency Name': 'Jacksonville Police Department',
#   'County': 'TELFAIR',
#   'Latitude': 31.913639,
#   'Longitude': -82.931062,
#   'ORI': 'GA1340600',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa0')},
#  <Recursion on list with id=2458961801920>]
# [{'Agency Name': "Bibb County Sheriff's Office",
#   'County': 'BIBB',
#   'Latitude': 32.831833,
#   'Longitude': -83.64161,
#   'ORI': 'GA0110000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa1')},
#  <Recursion on list with id=2458961853632>]
# [{'Agency Name': 'Ideal Police Department',
#   'County': 'MACON',
#   'Latitude': 32.366216,
#   'Longitude': -84.052162,
#   'ORI': 'GA0960200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa2')},
#  <Recursion on list with id=2458961829120>]
# [{'Agency Name': "Appling County Sheriff's Office",
#   'County': 'APPLING',
#   'Latitude': 31.782509,
#   'Longitude': -82.35828,
#   'ORI': 'GA0010000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa3')},
#  <Recursion on list with id=2458961845248>]
# [{'Agency Name': 'Morrow Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.582436,
#   'Longitude': -84.33722,
#   'ORI': 'GA0310300',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa4')},
#  <Recursion on list with id=2458961826112>]
# [{'Agency Name': 'Floyd County Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.169235,
#   'Longitude': -85.21126,
#   'ORI': 'GA0570100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa5')},
#  <Recursion on list with id=2458961836096>]
# [{'Agency Name': 'Washington County Board of Education',
#   'County': 'WASHINGTON',
#   'Latitude': 32.971848,
#   'Longitude': -82.798112,
#   'ORI': 'GA1500600',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa6')},
#  <Recursion on list with id=2458961843200>]
# [{'Agency Name': 'Alapaha Police Department',
#   'County': 'BERRIEN',
#   'Latitude': 31.274308,
#   'Longitude': -83.231906,
#   'ORI': 'GA0100200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa7')},
#  <Recursion on list with id=2458961886272>]
# [{'Agency Name': "Jasper County Sheriff's Office",
#   'County': 'JASPER',
#   'Latitude': 33.318128,
#   'Longitude': -83.689505,
#   'ORI': 'GA0790000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa8')},
#  <Recursion on list with id=2458961862400>]
# [{'Agency Name': 'Pine Lake Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.770661,
#   'Longitude': -84.226343,
#   'ORI': 'GA0440800',
#   '_id': ObjectId('6333e73f4607824e8e9f2fa9')},
#  <Recursion on list with id=2458961783424>]
# [{'Agency Name': 'Jefferson Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.11839,
#   'Longitude': -83.57744,
#   'ORI': 'GA0780200',
#   '_id': ObjectId('6333e73f4607824e8e9f2faa')},
#  <Recursion on list with id=2458961797568>]
# [{'Agency Name': "Douglas County Sheriff's Office",
#   'County': 'DOUGLAS',
#   'Latitude': 33.748375,
#   'Longitude': -84.7535,
#   'ORI': 'GA0480000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fab')},
#  <Recursion on list with id=2458961828224>]
# [{'Agency Name': 'Plains Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290300',
#   '_id': ObjectId('6333e73f4607824e8e9f2fac')},
#  <Recursion on list with id=2458961865088>]
# [{'Agency Name': 'University of West Georgia',
#   'County': 'CARROLL',
#   'Latitude': 33.571545,
#   'Longitude': -85.094604,
#   'ORI': 'GA0220600',
#   '_id': ObjectId('6333e73f4607824e8e9f2fad')},
#  <Recursion on list with id=2458961818624>]
# [{'Agency Name': "Jenkins County Sheriff's Office",
#   'County': 'JENKINS',
#   'Latitude': 32.794563,
#   'Longitude': -81.971524,
#   'ORI': 'GA0820000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fae')},
#  <Recursion on list with id=2458961788800>]
# [{'Agency Name': 'Tyrone Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.478733,
#   'Longitude': -84.594215,
#   'ORI': 'GA0560300',
#   '_id': ObjectId('6333e73f4607824e8e9f2faf')},
#  <Recursion on list with id=2458955400512>]
# [{'Agency Name': 'State Patrol: Calhoun',
#   'County': 'GORDON',
#   'Latitude': 34.460278,
#   'Longitude': -84.91662,
#   'ORI': 'GAGSP4300',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb0')},
#  <Recursion on list with id=2458961798656>]
# [{'Agency Name': 'State Patrol: Dublin',
#   'County': 'LAURENS',
#   'Latitude': 32.39322,
#   'Longitude': -82.926317,
#   'ORI': 'GAGSP2000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb1')},
#  <Recursion on list with id=2458961851520>]
# [{'Agency Name': 'Georgia State University',
#   'County': 'FULTON',
#   'Latitude': 33.754486,
#   'Longitude': -84.38908,
#   'ORI': 'GA0600900',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb2')},
#  <Recursion on list with id=2458961633856>]
# [{'Agency Name': 'Cleveland Police Department',
#   'County': 'WHITE',
#   'Latitude': 34.643776,
#   'Longitude': -83.743417,
#   'ORI': 'GA1540100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb3')},
#  <Recursion on list with id=2458961782528>]
# [{'Agency Name': "Polk County Sheriff's Office",
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb4')},
#  <Recursion on list with id=2458961836672>]
# [{'Agency Name': 'Atlanta Police Department',
#   'County': 'DEKALB; FULTON',
#   'Latitude': 33.74819,
#   'Longitude': -84.39517,
#   'ORI': 'GAAPD0000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb5')},
#  <Recursion on list with id=2458961819712>]
# [{'Agency Name': 'Dougherty County Police Department',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb6')},
#  <Recursion on list with id=2458961820864>]
# [{'Agency Name': 'Thomasville Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb7')},
#  <Recursion on list with id=2458961781440>]
# [{'Agency Name': 'Brookhaven Police Department',
#   'County': 'DEKALB',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0447200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb8')},
#  <Recursion on list with id=2458961799680>]
# [{'Agency Name': 'Statham Police Department',
#   'County': 'BARROW',
#   'Latitude': 33.992009,
#   'Longitude': -83.712303,
#   'ORI': 'GA0070300',
#   '_id': ObjectId('6333e73f4607824e8e9f2fb9')},
#  <Recursion on list with id=2458961816512>]
# [{'Agency Name': 'Morehouse School of Medicine',
#   'County': 'FULTON',
#   'Latitude': 33.743107,
#   'Longitude': -84.41023,
#   'ORI': 'GA0606200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fba')},
#  <Recursion on list with id=2458955401792>]
# [{'Agency Name': 'Cartersville Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fbb')},
#  <Recursion on list with id=2458961754368>]
# [{'Agency Name': 'Savannah-Chatham Metropolitan Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 32.075733,
#   'Longitude': -81.088394,
#   'ORI': 'GA0250300',
#   '_id': ObjectId('6333e73f4607824e8e9f2fbc')},
#  <Recursion on list with id=2458961814400>]
# [{'Agency Name': 'Wadley Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fbd')},
#  <Recursion on list with id=2458955909504>]
# [{'Agency Name': 'Chatsworth Police Department',
#   'County': 'MURRAY',
#   'Latitude': 34.797097,
#   'Longitude': -84.73799,
#   'ORI': 'GA1050100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fbe')},
#  <Recursion on list with id=2458961755456>]
# [{'Agency Name': "Gordon County Sheriff's Office",
#   'County': 'GORDON',
#   'Latitude': 34.509667,
#   'Longitude': -84.873862,
#   'ORI': 'GA0640000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fbf')},
#  <Recursion on list with id=2458961785856>]
# [{'Agency Name': 'State Patrol: Cordele',
#   'County': 'CRISP',
#   'Latitude': 31.914753,
#   'Longitude': -83.753338,
#   'ORI': 'GAGSP3000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc0')},
#  <Recursion on list with id=2458953830656>]
# [{'Agency Name': 'Colquitt Police Department',
#   'County': 'MILLER',
#   'Latitude': 31.162908,
#   'Longitude': -84.730386,
#   'ORI': 'GA1000100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc1')},
#  <Recursion on list with id=2458955153536>]
# [{'Agency Name': "Clinch County Sheriff's Office",
#   'County': 'CLINCH',
#   'Latitude': 31.039433,
#   'Longitude': -82.749954,
#   'ORI': 'GA0320000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc2')},
#  <Recursion on list with id=2458961753344>]
# [{'Agency Name': 'Adairsville Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.368633,
#   'Longitude': -84.93449,
#   'ORI': 'GA0080200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc3')},
#  <Recursion on list with id=2458961834496>]
# [{'Agency Name': 'College of Coastal Georgia',
#   'County': 'GLYNN',
#   'Latitude': 31.212746,
#   'Longitude': -81.496517,
#   'ORI': 'GA0630300',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc4')},
#  <Recursion on list with id=2458955122432>]
# [{'Agency Name': 'Tallulah Falls Police Department',
#   'County': 'RABUN; HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   'ORI': 'GA1190300',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc5')},
#  <Recursion on list with id=2458955400576>]
# [{'Agency Name': 'Montezuma Police Department',
#   'County': 'MACON',
#   'Latitude': 32.366216,
#   'Longitude': -84.052162,
#   'ORI': 'GA0960100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc6')},
#  <Recursion on list with id=2458955144512>]
# [{'Agency Name': 'Forest Park Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.60854,
#   'Longitude': -84.37918,
#   'ORI': 'GA0310200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc7')},
#  <Recursion on list with id=2458961787072>]
# [{'Agency Name': "Forsyth County Sheriff's Office",
#   'County': 'FORSYTH',
#   'Latitude': 34.225143,
#   'Longitude': -84.127435,
#   'ORI': 'GA0580000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc8')},
#  <Recursion on list with id=2458955156928>]
# [{'Agency Name': 'Rome Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.169235,
#   'Longitude': -85.21126,
#   'ORI': 'GA0570200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fc9')},
#  <Recursion on list with id=2458955154240>]
# [{'Agency Name': 'Lithonia Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.710865,
#   'Longitude': -84.10791,
#   'ORI': 'GA0440700',
#   '_id': ObjectId('6333e73f4607824e8e9f2fca')},
#  <Recursion on list with id=2458961788160>]
# [{'Agency Name': 'Nashville Police Department',
#   'County': 'BERRIEN',
#   'Latitude': 31.274308,
#   'Longitude': -83.231906,
#   'ORI': 'GA0100100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fcb')},
#  <Recursion on list with id=2458961752512>]
# [{'Agency Name': 'South Fulton',
#   'County': 'FULTON',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0607200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fcc')},
#  <Recursion on list with id=2458955400896>]
# [{'Agency Name': 'Monticello Police Department',
#   'County': 'JASPER',
#   'Latitude': 33.318128,
#   'Longitude': -83.689505,
#   'ORI': 'GA0790100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fcd')},
#  <Recursion on list with id=2458955154048>]
# [{'Agency Name': 'Maysville Police Department',
#   'County': 'BANKS; JACKSON',
#   'Latitude': 34.351922,
#   'Longitude': -83.498441,
#   'ORI': 'GA0780300',
#   '_id': ObjectId('6333e73f4607824e8e9f2fce')},
#  <Recursion on list with id=2458955401280>]
# [{'Agency Name': "Tift County Sheriff's Office",
#   'County': 'TIFT',
#   'Latitude': 31.457003,
#   'Longitude': -83.525931,
#   'ORI': 'GA1370000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fcf')},
#  <Recursion on list with id=2458961521920>]
# [{'Agency Name': 'Georgia Southwestern State University',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290400',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd0')},
#  <Recursion on list with id=2458961800768>]
# [{'Agency Name': "Decatur County Sheriff's Office",
#   'County': 'DECATUR',
#   'Latitude': 30.908264,
#   'Longitude': -84.59721,
#   'ORI': 'GA0430000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd1')},
#  <Recursion on list with id=2458872134912>]
# [{'Agency Name': 'Mount Zion Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.582237,
#   'Longitude': -85.080527,
#   'ORI': 'GA0220700',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd2')},
#  <Recursion on list with id=2458961835648>]
# [{'Agency Name': 'Fayette County Marshal',
#   'County': 'FAYETTE',
#   'Latitude': 33.447628,
#   'Longitude': -84.462875,
#   'ORI': 'GA0560400',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd3')},
#  <Recursion on list with id=2458955144704>]
# [{'Agency Name': "White County Sheriff's Office",
#   'County': 'WHITE',
#   'Latitude': 34.618458,
#   'Longitude': -83.75649,
#   'ORI': 'GA1540000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd4')},
#  <Recursion on list with id=2458955153664>]
# [{'Agency Name': 'State Patrol: Savannah',
#   'County': 'CHATHAM',
#   'Latitude': 32.361711,
#   'Longitude': -81.343337,
#   'ORI': 'GAGSP4200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd5')},
#  <Recursion on list with id=2458961887424>]
# [{'Agency Name': 'Cedartown Police Department',
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd6')},
#  <Recursion on list with id=2458961898112>]
# [{'Agency Name': 'Palmetto Police Department',
#   'County': 'COWETA; FULTON',
#   'Latitude': 33.790034,
#   'Longitude': -84.468182,
#   'ORI': 'GA0600800',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd7')},
#  <Recursion on list with id=2458955145152>]
# [{'Agency Name': "Ben Hill County Sheriff's Office",
#   'County': 'BEN HILL',
#   'Latitude': 31.740775,
#   'Longitude': -83.14719,
#   'ORI': 'GA0090000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd8')},
#  <Recursion on list with id=2458961894080>]
# [{'Agency Name': "Chattahoochee County Sheriff's Office",
#   'County': 'CHATTAHOOCHEE',
#   'Latitude': 32.347445,
#   'Longitude': -84.788021,
#   'ORI': 'GA0260000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fd9')},
#  <Recursion on list with id=2458961892032>]
# [{'Agency Name': 'Albany Police Department',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fda')},
#  <Recursion on list with id=2458961860032>]
# [{'Agency Name': 'Boston Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fdb')},
#  <Recursion on list with id=2458961895360>]
# [{'Agency Name': 'Molena Police Department',
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   'ORI': 'GA1140300',
#   '_id': ObjectId('6333e73f4607824e8e9f2fdc')},
#  <Recursion on list with id=2458961893056>]
# [{'Agency Name': 'Dunwoody  Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.770661,
#   'Longitude': -84.226343,
#   'ORI': 'GA0447100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fdd')},
#  <Recursion on list with id=2458962024896>]
# [{'Agency Name': "Rockdale County Sheriff's Office",
#   'County': 'ROCKDALE',
#   'Latitude': 33.685886,
#   'Longitude': -84.05896,
#   'ORI': 'GA1220000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fde')},
#  <Recursion on list with id=2458952187520>]
# [{'Agency Name': 'Louisville Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fdf')},
#  <Recursion on list with id=2458962032192>]
# [{'Agency Name': 'Savannah Fire and Emergency Services Arson Unit',
#   'County': 'CHATHAM',
#   'Latitude': 32.08216,
#   'Longitude': -81.09664,
#   'ORI': 'GA0252500',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe0')},
#  <Recursion on list with id=2458961890688>]
# [{'Agency Name': 'Garden City Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0250200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe1')},
#  <Recursion on list with id=2458955154304>]
# [{'Agency Name': "Murray County Sheriff's Office",
#   'County': 'MURRAY',
#   'Latitude': 34.78274,
#   'Longitude': -84.785446,
#   'ORI': 'GA1050000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe2')},
#  <Recursion on list with id=2458961888512>]
# [{'Agency Name': 'Calhoun Police Department',
#   'County': 'GORDON',
#   'Latitude': 34.50379,
#   'Longitude': -84.95111,
#   'ORI': 'GA0640100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe3')},
#  <Recursion on list with id=2458962035456>]
# [{'Agency Name': 'Midway Police Department',
#   'County': 'LIBERTY',
#   'Latitude': 31.807296,
#   'Longitude': -81.457864,
#   'ORI': 'GA0890200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe4')},
#  <Recursion on list with id=2458962031168>]
# [{'Agency Name': 'Euharlee Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080700',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe5')},
#  <Recursion on list with id=2458961844288>]
# [{'Agency Name': 'Sandy Springs Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.925224,
#   'Longitude': -84.359856,
#   'ORI': 'GA0605600',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe6')},
#  <Recursion on list with id=2458962033408>]
# [{'Agency Name': "Haralson County Sheriff's Office",
#   'County': 'HARALSON',
#   'Latitude': 33.795165,
#   'Longitude': -85.220062,
#   'ORI': 'GA0710000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe7')},
#  <Recursion on list with id=2458962059456>]
# [{'Agency Name': 'Screven Police Department',
#   'County': 'WAYNE',
#   'Latitude': 31.547845,
#   'Longitude': -81.912376,
#   'ORI': 'GA1510200',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe8')},
#  <Recursion on list with id=2458955403648>]
# [{'Agency Name': 'Hiawassee Police Department',
#   'County': 'TOWNS',
#   'Latitude': 34.902662,
#   'Longitude': -83.732215,
#   'ORI': 'GA1390100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fe9')},
#  <Recursion on list with id=2458961815424>]
# [{'Agency Name': 'Madison Police Department',
#   'County': 'MORGAN',
#   'Latitude': 33.593732,
#   'Longitude': -83.492324,
#   'ORI': 'GA1040100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fea')},
#  <Recursion on list with id=2458961784576>]
# [{'Agency Name': 'Monroe Police Department',
#   'County': 'WALTON',
#   'Latitude': 33.782648,
#   'Longitude': -83.734215,
#   'ORI': 'GA1470100',
#   '_id': ObjectId('6333e73f4607824e8e9f2feb')},
#  <Recursion on list with id=2458958136960>]
# [{'Agency Name': 'Cecil',
#   'County': 'COOK',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0370400',
#   '_id': ObjectId('6333e73f4607824e8e9f2fec')},
#  <Recursion on list with id=2458962062720>]
# [{'Agency Name': 'Pembroke Police Department',
#   'County': 'BRYAN',
#   'Latitude': 32.017969,
#   'Longitude': -81.438543,
#   'ORI': 'GA0150100',
#   '_id': ObjectId('6333e73f4607824e8e9f2fed')},
#  <Recursion on list with id=2458962053120>]
# [{'Agency Name': 'State Patrol: Lawrenceville',
#   'County': 'GWINNETT',
#   'Latitude': 33.959099,
#   'Longitude': -84.022949,
#   'ORI': 'GAGSP3700',
#   '_id': ObjectId('6333e73f4607824e8e9f2fee')},
#  <Recursion on list with id=2458962033280>]
# [{'Agency Name': 'Richmond County Marshal',
#   'County': 'RICHMOND',
#   'Latitude': 33.361487,
#   'Longitude': -82.074998,
#   'ORI': 'GA1210700',
#   '_id': ObjectId('6333e73f4607824e8e9f2fef')},
#  <Recursion on list with id=2458962034368>]
# [{'Agency Name': 'Mountain City Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190200',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff0')},
#  <Recursion on list with id=2458962060544>]
# [{'Agency Name': 'State Patrol: Donalsonville',
#   'County': 'SEMINOLE',
#   'Latitude': 30.933894,
#   'Longitude': -84.867592,
#   'ORI': 'GAGSP1400',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff1')},
#  <Recursion on list with id=2458962071232>]
# [{'Agency Name': 'Greensboro Police Department',
#   'County': 'GREENE',
#   'Latitude': 33.573967,
#   'Longitude': -83.17531,
#   'ORI': 'GA0660100',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff2')},
#  <Recursion on list with id=2458962067968>]
# [{'Agency Name': 'Fort Oglethorpe Police Department',
#   'County': 'WALKER; CATOOSA',
#   'Latitude': 34.899393,
#   'Longitude': -85.137353,
#   'ORI': 'GA0230100',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff3')},
#  <Recursion on list with id=2458962054400>]
# [{'Agency Name': 'Franklin Police Department',
#   'County': 'HEARD',
#   'Latitude': 33.290968,
#   'Longitude': -85.139594,
#   'ORI': 'GA0740100',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff4')},
#  <Recursion on list with id=2458962070144>]
# [{'Agency Name': 'Cumming Police Department',
#   'County': 'FORSYTH',
#   'Latitude': 34.204327,
#   'Longitude': -84.13951,
#   'ORI': 'GA0580100',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff5')},
#  <Recursion on list with id=2458962073536>]
# [{'Agency Name': 'Albany Technical College',
#   'County': 'DOUGHERTY',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0471100',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff6')},
#  <Recursion on list with id=2458962052032>]
# [{'Agency Name': 'Clayton County Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.541374,
#   'Longitude': -84.34508,
#   'ORI': 'GA0310100',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff7')},
#  <Recursion on list with id=2458962047168>]
# [{'Agency Name': "Calhoun County Sheriff's Office",
#   'County': 'CALHOUN',
#   'Latitude': 31.521279,
#   'Longitude': -84.62629,
#   'ORI': 'GA0190000',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff8')},
#  <Recursion on list with id=2458962082944>]
# [{'Agency Name': "Worth County Sheriff's Office",
#   'County': 'WORTH',
#   'Latitude': 31.527578,
#   'Longitude': -83.83554,
#   'ORI': 'GA1590000',
#   '_id': ObjectId('6333e73f4607824e8e9f2ff9')},
#  <Recursion on list with id=2458962069056>]
# [{'Agency Name': 'Lookout Mountain Police Department',
#   'County': 'WALKER',
#   'Latitude': 34.978447,
#   'Longitude': -85.35674,
#   'ORI': 'GA1460300',
#   '_id': ObjectId('6333e73f4607824e8e9f2ffa')},
#  <Recursion on list with id=2458961860672>]
# [{'Agency Name': 'Pendergrass  Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   'ORI': 'GA0780900',
#   '_id': ObjectId('6333e73f4607824e8e9f2ffb')},
#  <Recursion on list with id=2458962036544>]
# [{'Agency Name': "Pulaski County Sheriff's Office",
#   'County': 'PULASKI',
#   'Latitude': 32.238794,
#   'Longitude': -83.481855,
#   'ORI': 'GA1160000',
#   '_id': ObjectId('6333e73f4607824e8e9f2ffc')},
#  <Recursion on list with id=2458961804416>]
# [{'Agency Name': 'Valdosta State University',
#   'County': 'LOWNDES',
#   'Latitude': 30.813684,
#   'Longitude': -83.264366,
#   'ORI': 'GA0920500',
#   '_id': ObjectId('6333e73f4607824e8e9f2ffd')},
#  <Recursion on list with id=2458962080832>]
# [{'Agency Name': 'Cave Spring Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.263677,
#   'Longitude': -85.21373,
#   'ORI': 'GA0570300',
#   '_id': ObjectId('6333e73f4607824e8e9f2ffe')},
#  <Recursion on list with id=2458962037376>]
# [{'Agency Name': 'Georgia Institute of Technology',
#   'County': 'FULTON',
#   'Latitude': 33.779533,
#   'Longitude': -84.40235,
#   'ORI': 'GA0601000',
#   '_id': ObjectId('6333e73f4607824e8e9f2fff')},
#  <Recursion on list with id=2458961834752>]
# [{'Agency Name': 'Doraville Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.90096,
#   'Longitude': -84.27897,
#   'ORI': 'GA0440600',
#   '_id': ObjectId('6333e73f4607824e8e9f3000')},
#  <Recursion on list with id=2458958213696>]
# [{'Agency Name': "Tattnall County Sheriff's Office",
#   'County': 'TATTNALL',
#   'Latitude': 32.043768,
#   'Longitude': -82.059208,
#   'ORI': 'GA1320000',
#   '_id': ObjectId('6333e73f4607824e8e9f3001')},
#  <Recursion on list with id=2458961837696>]
# [{'Agency Name': 'Gwinnett County Public Schools',
#   'County': 'GWINNETT',
#   'Latitude': 33.959099,
#   'Longitude': -84.022949,
#   'ORI': 'GA0671000',
#   '_id': ObjectId('6333e73f4607824e8e9f3002')},
#  <Recursion on list with id=2458961894784>]
# [{'Agency Name': 'Temple Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.582237,
#   'Longitude': -85.080527,
#   'ORI': 'GA0220400',
#   '_id': ObjectId('6333e73f4607824e8e9f3003')},
#  <Recursion on list with id=2458961894080>]
# [{'Agency Name': 'Sylvania Police Department',
#   'County': 'SCREVEN',
#   'Latitude': 32.744751,
#   'Longitude': -81.617585,
#   'ORI': 'GA1240100',
#   '_id': ObjectId('6333e73f4607824e8e9f3004')},
#  <Recursion on list with id=2458962048192>]
# [{'Agency Name': 'Lakeland Police Department',
#   'County': 'LANIER',
#   'Latitude': 31.038197,
#   'Longitude': -83.063164,
#   'ORI': 'GA0860100',
#   '_id': ObjectId('6333e73f4607824e8e9f3005')},
#  <Recursion on list with id=2458955145152>]
# [{'Agency Name': 'Bainbridge Police Department',
#   'County': 'DECATUR',
#   'Latitude': 30.878091,
#   'Longitude': -84.577894,
#   'ORI': 'GA0430100',
#   '_id': ObjectId('6333e73f4607824e8e9f3006')},
#  <Recursion on list with id=2458955144704>]
# [{'Agency Name': 'Irwinton Police Department',
#   'County': 'WILKINSON',
#   'Latitude': 32.804312,
#   'Longitude': -83.175497,
#   'ORI': 'GA1580200',
#   '_id': ObjectId('6333e73f4607824e8e9f3007')},
#  <Recursion on list with id=2458961893056>]
# [{'Agency Name': 'Rockmart Police Department',
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150200',
#   '_id': ObjectId('6333e7404607824e8e9f3008')},
#  <Recursion on list with id=2458955400896>]
# [{'Agency Name': 'Warm Springs Police Department',
#   'County': 'MERIWETHER',
#   'Latitude': 33.03022,
#   'Longitude': -84.663279,
#   'ORI': 'GA0990500',
#   '_id': ObjectId('6333e7404607824e8e9f3009')},
#  <Recursion on list with id=2458872134912>]
# [{'Agency Name': 'State Patrol: Thomaston',
#   'County': 'UPSON',
#   'Latitude': 32.881837,
#   'Longitude': -84.292281,
#   'ORI': 'GAGSP2600',
#   '_id': ObjectId('6333e7404607824e8e9f300a')},
#  <Recursion on list with id=2458955154240>]
# [{'Agency Name': 'State Patrol: Cartersville',
#   'County': 'BARTOW',
#   'Latitude': 34.204853,
#   'Longitude': -84.81206,
#   'ORI': 'GAGSP0300',
#   '_id': ObjectId('6333e7404607824e8e9f300b')},
#  <Recursion on list with id=2458961800768>]
# [{'Agency Name': "Union County Sheriff's Office",
#   'County': 'UNION',
#   'Latitude': 34.83377,
#   'Longitude': -83.989573,
#   'ORI': 'GA1440000',
#   '_id': ObjectId('6333e7404607824e8e9f300c')},
#  <Recursion on list with id=2458961521920>]
# [{'Agency Name': "Mitchell County Sheriff's Office",
#   'County': 'MITCHELL',
#   'Latitude': 31.228997,
#   'Longitude': -84.192038,
#   'ORI': 'GA1010000',
#   '_id': ObjectId('6333e7404607824e8e9f300d')},
#  <Recursion on list with id=2458955153664>]
# [{'Agency Name': "Dougherty County Sheriff's Office",
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470000',
#   '_id': ObjectId('6333e7404607824e8e9f300e')},
#  <Recursion on list with id=2458961752512>]
# [{'Agency Name': 'Nelson Police Department',
#   'County': 'CHEROKEE; PICKENS',
#   'Latitude': 34.456625,
#   'Longitude': -84.490263,
#   'ORI': 'GA0280600',
#   '_id': ObjectId('6333e7404607824e8e9f300f')},
#  <Recursion on list with id=2458955156928>]
# [{'Agency Name': "Baker County Sheriff's Office",
#   'County': 'BAKER',
#   'Latitude': 31.31958,
#   'Longitude': -84.454881,
#   'ORI': 'GA0040000',
#   '_id': ObjectId('6333e7404607824e8e9f3010')},
#  <Recursion on list with id=2458955154048>]
# [{'Agency Name': 'Gordon State College',
#   'County': 'LAMAR',
#   'Latitude': 33.044018,
#   'Longitude': -84.15348,
#   'ORI': 'GA0850300',
#   '_id': ObjectId('6333e7404607824e8e9f3011')},
#  <Recursion on list with id=2458961860032>]
# [{'Agency Name': "McDuffie County Sheriff's Office",
#   'County': 'MCDUFFIE',
#   'Latitude': 33.482464,
#   'Longitude': -82.473188,
#   'ORI': 'GA0940000',
#   '_id': ObjectId('6333e7404607824e8e9f3012')},
#  <Recursion on list with id=2458955401280>]
# [{'Agency Name': 'Newnan Police Department',
#   'County': 'COWETA',
#   'Latitude': 33.352897,
#   'Longitude': -84.762138,
#   'ORI': 'GA0380100',
#   '_id': ObjectId('6333e7404607824e8e9f3013')},
#  <Recursion on list with id=2458955400576>]
# [{'Agency Name': 'Wesleyan College',
#   'County': 'BIBB',
#   'Latitude': 32.876038,
#   'Longitude': -83.71381,
#   'ORI': 'GA011119E',
#   '_id': ObjectId('6333e7404607824e8e9f3014')},
#  <Recursion on list with id=2458961887424>]
# [{'Agency Name': "Effingham County Sheriff's Office",
#   'County': 'EFFINGHAM',
# ...
#   '_id': ObjectId('6333e7404607824e8e9f3197')},
#  <Recursion on list with id=2458961986560>]
# [{'Agency Name': "Cherokee County Sheriff's Office",
#   'County': 'CHEROKEE',
#   'Latitude': 34.196648,
#   'Longitude': -84.49234,
#   'ORI': 'GA0280000',
#   '_id': ObjectId('6333e7404607824e8e9f3198')},
#  <Recursion on list with id=2458961844672>]
# [{'Agency Name': 'Cohutta Police Department',
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   'ORI': 'GA1550300',
#   '_id': ObjectId('6333e7404607824e8e9f3199')},
#  <Recursion on list with id=2458961886848>]
# [{'Agency Name': 'Oak Park Police Department',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   'ORI': 'GA0530600',
#   '_id': ObjectId('6333e7404607824e8e9f319a')},
#  <Recursion on list with id=2458961834560>]
# [{'Agency Name': 'Mercer University',
#   'County': 'BIBB',
#   'Latitude': 32.82903,
#   'Longitude': -83.648766,
#   'ORI': 'GA011099E',
#   '_id': ObjectId('6333e7404607824e8e9f319b')},
#  <Recursion on list with id=2458955156928>]
# [{'Agency Name': 'Wrightsville Police Department',
#   'County': 'JOHNSON',
#   'Latitude': 32.72852,
#   'Longitude': -82.731895,
#   'ORI': 'GA0830100',
#   '_id': ObjectId('6333e7404607824e8e9f319c')},
#  <Recursion on list with id=2458961988608>]
# [{'Agency Name': 'Blakely Police Department',
#   'County': 'EARLY',
#   'Latitude': 31.324191,
#   'Longitude': -84.906723,
#   'ORI': 'GA0490100',
#   '_id': ObjectId('6333e7404607824e8e9f319d')},
#  <Recursion on list with id=2458961815488>]
# [{'Agency Name': 'Pickens County Board of Education',
#   'County': 'PICKENS',
#   'Latitude': 34.456625,
#   'Longitude': -84.490263,
#   'ORI': 'GA1120300',
#   '_id': ObjectId('6333e7404607824e8e9f319e')},
#  <Recursion on list with id=2458952623680>]
# [{'Agency Name': 'Henry County Police Department',
#   'County': 'HENRY',
#   'Latitude': 33.452881,
#   'Longitude': -84.15444,
#   'ORI': 'GA0750500',
#   '_id': ObjectId('6333e7404607824e8e9f319f')},
#  <Recursion on list with id=2458961821504>]
# [{'Agency Name': 'Cordele Police Department',
#   'County': 'CRISP',
#   'Latitude': 31.973846,
#   'Longitude': -83.782745,
#   'ORI': 'GA0400100',
#   '_id': ObjectId('6333e7404607824e8e9f31a0')},
#  <Recursion on list with id=2458961800896>]
# [{'Agency Name': "Glascock County Sheriff's Office",
#   'County': 'GLASCOCK',
#   'Latitude': 33.227491,
#   'Longitude': -82.606913,
#   'ORI': 'GA0620000',
#   '_id': ObjectId('6333e7404607824e8e9f31a1')},
#  <Recursion on list with id=2458962439424>]
# [{'Agency Name': 'Trion Police Department',
#   'County': 'CHATTOOGA',
#   'Latitude': 34.54347,
#   'Longitude': -85.312996,
#   'ORI': 'GA0270200',
#   '_id': ObjectId('6333e7404607824e8e9f31a2')},
#  <Recursion on list with id=2458961821568>]
# [{'Agency Name': 'Covington Police Department',
#   'County': 'NEWTON',
#   'Latitude': 33.595737,
#   'Longitude': -83.857635,
#   'ORI': 'GA1070100',
#   '_id': ObjectId('6333e7404607824e8e9f31a3')},
#  <Recursion on list with id=2458961944448>]
# [{'Agency Name': 'Georgia Military College',
#   'County': 'BALDWIN',
#   'Latitude': 33.08015,
#   'Longitude': -83.22491,
#   'ORI': 'GA0050400',
#   '_id': ObjectId('6333e7404607824e8e9f31a4')},
#  <Recursion on list with id=2458961894080>]
# [{'Agency Name': 'Roswell Police Department',
#   'County': 'FULTON',
#   'Latitude': 34.021626,
#   'Longitude': -84.35973,
#   'ORI': 'GA0600500',
#   '_id': ObjectId('6333e7404607824e8e9f31a5')},
#  <Recursion on list with id=2458955145152>]
# [{'Agency Name': 'Hogansville Police Department',
#   'County': 'TROUP',
#   'Latitude': 33.17311,
#   'Longitude': -84.920135,
#   'ORI': 'GA1410100',
#   '_id': ObjectId('6333e7404607824e8e9f31a6')},
#  <Recursion on list with id=2458961835648>]
# [{'Agency Name': 'Richland Police Department',
#   'County': 'STEWART',
#   'Latitude': 32.073225,
#   'Longitude': -84.834912,
#   'ORI': 'GA1280200',
#   '_id': ObjectId('6333e7404607824e8e9f31a7')},
#  <Recursion on list with id=2458961887424>]
# [{'Agency Name': 'State Patrol: Marietta',
#   'County': 'COBB',
#   'Latitude': 33.93994,
#   'Longitude': -84.574166,
#   'ORI': 'GAGSP0900',
#   '_id': ObjectId('6333e7404607824e8e9f31a8')},
#  <Recursion on list with id=2458955400576>]
# [{'Agency Name': 'McCaysville Police Department',
#   'County': 'FANNIN',
#   'Latitude': 34.866497,
#   'Longitude': -84.31744,
#   'ORI': 'GA0550100',
#   '_id': ObjectId('6333e7404607824e8e9f31a9')},
#  <Recursion on list with id=2458961788160>]
# [{'Agency Name': 'Buena Vista Police Department',
#   'County': 'MARION',
#   'Latitude': 32.359538,
#   'Longitude': -84.529561,
#   'ORI': 'GA0980100',
#   '_id': ObjectId('6333e7404607824e8e9f31aa')},
#  <Recursion on list with id=2458961782528>]
# [{'Agency Name': 'Albany-Dougherty Metropolitan Drug Squad',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470600',
#   '_id': ObjectId('6333e7404607824e8e9f31ab')},
#  <Recursion on list with id=2458961891200>]
# [{'Agency Name': 'Suwanee Police Department',
#   'County': 'GWINNETT',
#   'Latitude': 33.959099,
#   'Longitude': -84.022949,
#   'ORI': 'GA0670900',
#   '_id': ObjectId('6333e7404607824e8e9f31ac')},
#  <Recursion on list with id=2458961887424>]
# [{'Agency Name': "Coffee County Sheriff's Office",
#   'County': 'COFFEE',
#   'Latitude': 31.549245,
#   'Longitude': -82.844938,
#   'ORI': 'GA0340000',
#   '_id': ObjectId('6333e7404607824e8e9f31ad')},
#  <Recursion on list with id=2458961894080>]
# [{'Agency Name': "Irwin County Sheriff's Office",
#   'County': 'IRWIN',
#   'Latitude': 31.591131,
#   'Longitude': -83.25055,
#   'ORI': 'GA0770000',
#   '_id': ObjectId('6333e7404607824e8e9f31ae')},
#  <Recursion on list with id=2458955154240>]
# [{'Agency Name': 'Cochran Police Department',
#   'County': 'BLECKLEY',
#   'Latitude': 32.386444,
#   'Longitude': -83.35458,
#   'ORI': 'GA0120100',
#   '_id': ObjectId('6333e7404607824e8e9f31af')},
#  <Recursion on list with id=2458961835648>]
# [{'Agency Name': "Wilcox County Sheriff's Office",
#   'County': 'WILCOX',
#   'Latitude': 31.962717,
#   'Longitude': -83.438262,
#   'ORI': 'GA1560000',
#   '_id': ObjectId('6333e7404607824e8e9f31b0')},
#  <Recursion on list with id=2458961827136>]
# [{'Agency Name': 'Augusta Technical College',
#   'County': 'RICHMOND',
#   'Latitude': 33.419178,
#   'Longitude': -82.051254,
#   'ORI': 'GA1212100',
#   '_id': ObjectId('6333e7404607824e8e9f31b1')},
#  <Recursion on list with id=2458961884544>]
# [{'Agency Name': 'Georgia World Congress',
#   'County': 'FULTON',
#   'Latitude': 33.759632,
#   'Longitude': -84.382416,
#   'ORI': 'GA0603800',
#   '_id': ObjectId('6333e7404607824e8e9f31b2')},
#  <Recursion on list with id=2458961800768>]
# [{'Agency Name': "Pierce County Sheriff's Office",
#   'County': 'PIERCE',
#   'Latitude': 31.302244,
#   'Longitude': -82.23383,
#   'ORI': 'GA1130000',
#   '_id': ObjectId('6333e7404607824e8e9f31b3')},
#  <Recursion on list with id=2458961752512>]
# [{'Agency Name': 'Andrew College ',
#   'County': 'RANDOLPH',
#   'Latitude': 31.771894,
#   'Longitude': -84.79704,
#   'ORI': 'GA120059E',
#   '_id': ObjectId('6333e7404607824e8e9f31b4')},
#  <Recursion on list with id=2458955122432>]
# [{'Agency Name': 'Danielsville Police Department',
#   'County': 'MADISON',
#   'Latitude': 34.128484,
#   'Longitude': -83.203644,
#   'ORI': 'GA0970300',
#   '_id': ObjectId('6333e7404607824e8e9f31b5')},
#  <Recursion on list with id=2458961788160>]
# [{'Agency Name': "Dade County Sheriff's Office",
#   'County': 'DADE',
#   'Latitude': 34.852424,
#   'Longitude': -85.506201,
#   'ORI': 'GA0410000',
#   '_id': ObjectId('6333e7404607824e8e9f31b6')},
#  <Recursion on list with id=2458955145152>]
# [{'Agency Name': "Barrow County Sheriff's Office",
#   'County': 'BARROW',
#   'Latitude': 33.992009,
#   'Longitude': -83.712303,
#   'ORI': 'GA0070000',
#   '_id': ObjectId('6333e7404607824e8e9f31b7')},
#  <Recursion on list with id=2458955154048>]
# [{'Agency Name': "Jones County Sheriff's Office",
#   'County': 'JONES',
#   'Latitude': 33.020226,
#   'Longitude': -83.562339,
#   'ORI': 'GA0840000',
#   '_id': ObjectId('6333e7404607824e8e9f31b8')},
#  <Recursion on list with id=2458961754368>]
# [{'Agency Name': 'Cobb County Police Department',
#   'County': 'COBB',
#   'Latitude': 33.958862,
#   'Longitude': -84.54633,
#   'ORI': 'GA0330200',
#   '_id': ObjectId('6333e7404607824e8e9f31b9')},
#  <Recursion on list with id=2458955153664>]
# [{'Agency Name': 'McRae Police Department',
#   'County': 'WHEELER; TELFAIR',
#   'Latitude': 31.913639,
#   'Longitude': -82.931062,
#   'ORI': 'GA1340100',
#   '_id': ObjectId('6333e7404607824e8e9f31ba')},
#  <Recursion on list with id=2458872134912>]
# [{'Agency Name': 'Snellville Police Department',
#   'County': 'GWINNETT',
#   'Latitude': 33.83367,
#   'Longitude': -84.00958,
#   'ORI': 'GA0670800',
#   '_id': ObjectId('6333e7404607824e8e9f31bb')},
#  <Recursion on list with id=2458961818624>]
# [{'Agency Name': 'Warner Robins Police Department',
#   'County': 'PEACH; HOUSTON',
#   'Latitude': 32.458381,
#   'Longitude': -83.662856,
#   'ORI': 'GA0760200',
#   '_id': ObjectId('6333e7404607824e8e9f31bc')},
#  <Recursion on list with id=2458961816512>]
# [{'Agency Name': 'Canton Police Department',
#   'County': 'CHEROKEE',
#   'Latitude': 34.23541,
#   'Longitude': -84.490005,
#   'ORI': 'GA0280100',
#   '_id': ObjectId('6333e7404607824e8e9f31bd')},
#  <Recursion on list with id=2458955400576>]
# [{'Agency Name': 'State Patrol: Swainsboro',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   'ORI': 'GAGSP1900',
#   '_id': ObjectId('6333e7404607824e8e9f31be')},
#  <Recursion on list with id=2458961753344>]
# [{'Agency Name': "Randolph County Sheriff's Office",
#   'County': 'RANDOLPH',
#   'Latitude': 31.762651,
#   'Longitude': -84.752311,
#   'ORI': 'GA1200000',
#   '_id': ObjectId('6333e7404607824e8e9f31bf')},
#  <Recursion on list with id=2458953830656>]
# [{'Agency Name': 'Stillmore Police Department',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   'ORI': 'GA0530500',
#   '_id': ObjectId('6333e7404607824e8e9f31c0')},
#  <Recursion on list with id=2458959900288>]
# [{'Agency Name': 'Tunnel Hill Police Department',
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   'ORI': 'GA1550200',
#   '_id': ObjectId('6333e7404607824e8e9f31c1')},
#  <Recursion on list with id=2458961862400>]
# [{'Agency Name': 'Adrian Police Department',
#   'County': 'EMANUEL; JOHNSON',
#   'Latitude': 32.689831,
#   'Longitude': -82.661354,
#   'ORI': 'GA0830200',
#   '_id': ObjectId('6333e7404607824e8e9f31c2')},
#  <Recursion on list with id=2458961861120>]
# [{'Agency Name': 'East Ellijay Police Department',
#   'County': 'GILMER',
#   'Latitude': 34.690541,
#   'Longitude': -84.453984,
#   'ORI': 'GA0610300',
#   '_id': ObjectId('6333e7404607824e8e9f31c3')},
#  <Recursion on list with id=2458955153536>]
# [{'Agency Name': 'Locust Grove Police Department',
#   'County': 'HENRY',
#   'Latitude': 33.452881,
#   'Longitude': -84.15444,
#   'ORI': 'GA0750400',
#   '_id': ObjectId('6333e7404607824e8e9f31c4')},
#  <Recursion on list with id=2458961850496>]
# [{'Agency Name': 'Lake City Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.60693,
#   'Longitude': -84.34333,
#   'ORI': 'GA0310600',
#   '_id': ObjectId('6333e7404607824e8e9f31c5')},
#  <Recursion on list with id=2458955401792>]
# [{'Agency Name': "Sumter County Sheriff's Office",
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290000',
#   '_id': ObjectId('6333e7404607824e8e9f31c6')},
#  <Recursion on list with id=2458961798656>]
# [{'Agency Name': "Newton County Sheriff's Office",
#   'County': 'NEWTON',
#   'Latitude': 33.544065,
#   'Longitude': -83.855192,
#   'ORI': 'GA1070000',
#   '_id': ObjectId('6333e7404607824e8e9f31c7')},
#  <Recursion on list with id=2458961965376>]
# [{'Agency Name': 'Georgia College and State University',
#   'County': 'BALDWIN',
#   'Latitude': 33.059504,
#   'Longitude': -83.255452,
#   'ORI': 'GA0050300',
#   '_id': ObjectId('6333e7404607824e8e9f31c8')},
#  <Recursion on list with id=2458961862912>]
# [{'Agency Name': "Fayette County Sheriff's Office",
#   'County': 'FAYETTE',
#   'Latitude': 33.446476,
#   'Longitude': -84.45227,
#   'ORI': 'GA0560000',
#   '_id': ObjectId('6333e7404607824e8e9f31c9')},
#  <Recursion on list with id=2458961782528>]
# [{'Agency Name': "Meriwether County Sheriff's Office",
#   'County': 'MERIWETHER',
#   'Latitude': 33.03022,
#   'Longitude': -84.663279,
#   'ORI': 'GA0990000',
#   '_id': ObjectId('6333e7404607824e8e9f31ca')},
#  <Recursion on list with id=2458961997760>]
# [{'Agency Name': 'Fulton County Marshal',
#   'County': 'FULTON',
#   'Latitude': 33.752655,
#   'Longitude': -84.38997,
#   'ORI': 'GA0602700',
#   '_id': ObjectId('6333e7404607824e8e9f31cb')},
#  <Recursion on list with id=2458961866112>]
# [{'Agency Name': 'Alpharetta Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.790034,
#   'Longitude': -84.468182,
#   'ORI': 'GA0600400',
#   '_id': ObjectId('6333e7404607824e8e9f31cc')},
#  <Recursion on list with id=2458961799680>]
# [{'Agency Name': 'Lumpkin Police Department',
#   'County': 'STEWART',
#   'Latitude': 32.073225,
#   'Longitude': -84.834912,
#   'ORI': 'GA1280100',
#   '_id': ObjectId('6333e7404607824e8e9f31cd')},
#  <Recursion on list with id=2458961852416>]
# [{'Agency Name': "Troup County Sheriff's Office",
#   'County': 'TROUP',
#   'Latitude': 32.989746,
#   'Longitude': -85.00395,
#   'ORI': 'GA1410000',
#   '_id': ObjectId('6333e7404607824e8e9f31ce')},
#  <Recursion on list with id=2458961843200>]
# [{'Agency Name': 'Oakwood Police Department',
#   'County': 'HALL',
#   'Latitude': 34.317588,
#   'Longitude': -83.818497,
#   'ORI': 'GA0690400',
#   '_id': ObjectId('6333e7404607824e8e9f31cf')},
#  <Recursion on list with id=2458961804096>]
# [{'Agency Name': "Brantley County Sheriff's Office",
#   'County': 'BRANTLEY',
#   'Latitude': 31.197334,
#   'Longitude': -81.982978,
#   'ORI': 'GA0130000',
#   '_id': ObjectId('6333e7404607824e8e9f31d0')},
#  <Recursion on list with id=2458955400512>]
# [{'Agency Name': 'State Patrol: Madison',
#   'County': 'MORGAN',
#   'Latitude': 33.593732,
#   'Longitude': -83.492324,
#   'ORI': 'GAGSP0800',
#   '_id': ObjectId('6333e7404607824e8e9f31d1')},
#  <Recursion on list with id=2458961797568>]
# [{'Agency Name': 'Douglas Police Department',
#   'County': 'COFFEE',
#   'Latitude': 31.511168,
#   'Longitude': -82.852135,
#   'ORI': 'GA0340100',
#   '_id': ObjectId('6333e7404607824e8e9f31d2')},
#  <Recursion on list with id=2458955144512>]
# [{'Agency Name': 'Dougherty County Board of Education',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470500',
#   '_id': ObjectId('6333e7404607824e8e9f31d3')},
#  <Recursion on list with id=2458961787072>]
# [{'Agency Name': "Terrell County Sheriff's Office",
#   'County': 'TERRELL',
#   'Latitude': 31.777191,
#   'Longitude': -84.439446,
#   'ORI': 'GA1350000',
#   '_id': ObjectId('6333e7404607824e8e9f31d4')},
#  <Recursion on list with id=2458961892032>]
# [{'Agency Name': 'Tybee Island Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0250600',
#   '_id': ObjectId('6333e7404607824e8e9f31d5')},
#  <Recursion on list with id=2458955909504>]
# [{'Agency Name': "Lincoln County Sheriff's Office",
#   'County': 'LINCOLN',
#   'Latitude': 33.792151,
#   'Longitude': -82.448299,
#   'ORI': 'GA0900000',
#   '_id': ObjectId('6333e7404607824e8e9f31d6')},
#  <Recursion on list with id=2458961788800>]
# [{'Agency Name': 'Blue Ridge Police Department',
#   'County': 'FANNIN',
#   'Latitude': 34.866226,
#   'Longitude': -84.32594,
#   'ORI': 'GA0550200',
#   '_id': ObjectId('6333e7404607824e8e9f31d7')},
#  <Recursion on list with id=2458961829120>]
# [{'Agency Name': 'Ocilla Police Department',
#   'County': 'IRWIN',
#   'Latitude': 31.591131,
#   'Longitude': -83.25055,
#   'ORI': 'GA0770100',
#   '_id': ObjectId('6333e7404607824e8e9f31d8')},
#  <Recursion on list with id=2458961804864>]
# [{'Agency Name': 'Stapleton Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810500',
#   '_id': ObjectId('6333e7404607824e8e9f31d9')},
#  <Recursion on list with id=2458961836096>]
# [{'Agency Name': 'Middle Georgia State University',
#   'County': 'BLECKLEY',
#   'Latitude': 32.435403,
#   'Longitude': -83.331717,
#   'ORI': 'GA0120200',
#   '_id': ObjectId('6333e7404607824e8e9f31da')},
#  <Recursion on list with id=2458961845248>]

# %% [markdown]
# ### Load County Table / Build Dictionary

# %%
countyList = []
countyDF = pd.DataFrame(list(db.destination.find({})))['County']

# split multi-counties into individual
for row in countyDF:

    #split the multi-counties
    counties = row.split('; ')

    for cnty in counties:
        if cnty not in countyList and cnty != '':
            countyList.append(cnty)

# cleanup and store in SQL
countyList.sort()
countyDF = pd.DataFrame(countyList, columns =['county_name'])
countyDF.insert(0, 'countyid', range(1, 1 + len(countyDF)))
countyDF.to_sql(name='County', con=engine, if_exists='replace', index=False)

#put counties in dictionary for lookup
county_dict = dict(zip(countyDF.county_name, countyDF.countyid))
county_dict
# Out:
# {'APPLING': 1,
#  'ATKINSON': 2,
#  'BACON': 3,
#  'BAKER': 4,
#  'BALDWIN': 5,
#  'BANKS': 6,
#  'BARROW': 7,
#  'BARTOW': 8,
#  'BEN HILL': 9,
#  'BERRIEN': 10,
#  'BIBB': 11,
#  'BLECKLEY': 12,
#  'BRANTLEY': 13,
#  'BROOKS': 14,
#  'BRYAN': 15,
#  'BULLOCH': 16,
#  'BURKE': 17,
#  'BUTTS': 18,
#  'CALHOUN': 19,
#  'CAMDEN': 20,
#  'CANDLER': 21,
#  'CARROLL': 22,
#  'CATOOSA': 23,
#  'CHARLTON': 24,
#  'CHATHAM': 25,
#  'CHATTAHOOCHEE': 26,
#  'CHATTOOGA': 27,
#  'CHEROKEE': 28,
#  'CLARKE': 29,
#  'CLAY': 30,
#  'CLAYTON': 31,
#  'CLINCH': 32,
#  'COBB': 33,
#  'COFFEE': 34,
#  'COLQUITT': 35,
#  'COLUMBIA': 36,
#  'COOK': 37,
#  'COWETA': 38,
#  'CRAWFORD': 39,
#  'CRISP': 40,
#  'DADE': 41,
#  'DAWSON': 42,
#  'DECATUR': 43,
#  'DEKALB': 44,
#  'DODGE': 45,
#  'DOOLY': 46,
#  'DOUGHERTY': 47,
#  'DOUGLAS': 48,
#  'EARLY': 49,
#  'ECHOLS': 50,
#  'EFFINGHAM': 51,
#  'ELBERT': 52,
#  'EMANUEL': 53,
#  'EVANS': 54,
#  'FANNIN': 55,
#  'FAYETTE': 56,
#  'FLOYD': 57,
#  'FORSYTH': 58,
#  'FRANKLIN': 59,
#  'FULTON': 60,
#  'GILMER': 61,
#  'GLASCOCK': 62,
#  'GLYNN': 63,
#  'GORDON': 64,
#  'GRADY': 65,
#  'GREENE': 66,
#  'GWINNETT': 67,
#  'HABERSHAM': 68,
#  'HALL': 69,
#  'HANCOCK': 70,
#  'HARALSON': 71,
#  'HARRIS': 72,
#  'HART': 73,
#  'HEARD': 74,
#  'HENRY': 75,
#  'HOUSTON': 76,
#  'IRWIN': 77,
#  'JACKSON': 78,
#  'JASPER': 79,
#  'JEFF DAVIS': 80,
#  'JEFFERSON': 81,
#  'JENKINS': 82,
#  'JOHNSON': 83,
#  'JONES': 84,
#  'LAMAR': 85,
#  'LANIER': 86,
#  'LAURENS': 87,
#  'LEE': 88,
#  'LIBERTY': 89,
#  'LINCOLN': 90,
#  'LONG': 91,
#  'LOWNDES': 92,
#  'LUMPKIN': 93,
#  'MACON': 94,
#  'MADISON': 95,
#  'MARION': 96,
#  'MCDUFFIE': 97,
#  'MCINTOSH': 98,
#  'MERIWETHER': 99,
#  'MILLER': 100,
#  'MITCHELL': 101,
#  'MONROE': 102,
#  'MONTGOMERY': 103,
#  'MORGAN': 104,
#  'MURRAY': 105,
#  'MUSCOGEE': 106,
#  'NEWTON': 107,
#  'OCONEE': 108,
#  'OGLETHORPE': 109,
#  'PAULDING': 110,
#  'PEACH': 111,
#  'PICKENS': 112,
#  'PIERCE': 113,
#  'PIKE': 114,
#  'POLK': 115,
#  'PULASKI': 116,
#  'PUTNAM': 117,
#  'QUITMAN': 118,
#  'RABUN': 119,
#  'RANDOLPH': 120,
#  'RICHMOND': 121,
#  'ROCKDALE': 122,
#  'SCHLEY': 123,
#  'SCREVEN': 124,
#  'SEMINOLE': 125,
#  'SPALDING': 126,
#  'STEPHENS': 127,
#  'STEWART': 128,
#  'SUMTER': 129,
#  'TALBOT': 130,
#  'TALIAFERRO': 131,
#  'TATTNALL': 132,
#  'TAYLOR': 133,
#  'TELFAIR': 134,
#  'TERRELL': 135,
#  'THOMAS': 136,
#  'TIFT': 137,
#  'TOOMBS': 138,
#  'TOWNS': 139,
#  'TREUTLEN': 140,
#  'TROUP': 141,
#  'TURNER': 142,
#  'TWIGGS': 143,
#  'UNION': 144,
#  'UPSON': 145,
#  'WALKER': 146,
#  'WALTON': 147,
#  'WARE': 148,
#  'WARREN': 149,
#  'WASHINGTON': 150,
#  'WAYNE': 151,
#  'WEBSTER': 152,
#  'WHEELER': 153,
#  'WHITE': 154,
#  'WHITFIELD': 155,
#  'WILCOX': 156,
#  'WILKES': 157,
#  'WILKINSON': 158,
#  'WORTH': 159}

# %% [markdown]
# ### Load Agency Table / Build Dictionary

# %%
agencyList = []
DF_raw = pd.DataFrame(list(db.destination.find({})))[['Agency Name','County','ORI','Latitude','Longitude']]
agencyDF = pd.DataFrame(columns=['agency_name','ori','latitude','longitude'])

for index, row in DF_raw.iterrows():
    if row[0] not in agencyList:
        agencyList.append(row[0])
        agencyDF.loc[len(agencyDF.index)] = [row[0], row[2],  row[3],  row[4]]
        
agencyDF = agencyDF.sort_values(by=['agency_name'])
agencyDF.insert(0, 'agencyid', range(1, 1 + len(agencyDF.index)))
agencyDF.to_sql(name='Agency', con=engine, if_exists='replace', index=False)

#put agencies in dictionary for lookup
agency_dict = dict(zip(agencyDF.agency_name, agencyDF.agencyid))
agency_dict
# Out:
# {'Abbeville Police Department': 1,
#  'Abraham Baldwin Agricultural College': 2,
#  'Acworth Police Department': 3,
#  'Adairsville Police Department': 4,
#  'Adel Police Department': 5,
#  'Adrian Police Department': 6,
#  'Agnes Scott College': 7,
#  'Alamo Police Department': 8,
#  'Alapaha Police Department': 9,
#  'Albany Police Department': 10,
#  'Albany State University': 11,
#  'Albany Technical College': 12,
#  'Albany-Dougherty Metropolitan Drug Squad': 13,
#  'Alma Police Department': 14,
#  'Alpharetta Police Department': 15,
#  'Alto Police Department': 16,
#  'Americus Police Department': 17,
#  'Andrew College ': 18,
#  'Appling County Board of Education': 19,
#  "Appling County Sheriff's Office": 20,
#  'Aragon Police Department': 21,
#  'Arcade Police Department': 22,
#  'Arlington Police Department': 23,
#  'Ashburn Police Department': 24,
#  'Athens Technical College': 25,
#  'Athens-Clarke County Police Department': 26,
#  "Atkinson County Sheriff's Office": 27,
#  'Atlanta Metropolitan State College': 28,
#  'Atlanta Police Department': 29,
#  'Atlanta Public Schools': 30,
#  'Atlanta Technical College': 31,
#  'Attapulgus Police Department': 32,
#  'Auburn Police Department': 33,
#  'Augusta Board of Education': 34,
#  'Augusta Technical College': 35,
#  "Augusta-Richmond County Sheriff's Office": 36,
#  'Austell Police Department': 37,
#  'Avondale Estates Police Department': 38,
#  "Bacon County Sheriff's Office": 39,
#  'Bainbridge Police Department': 40,
#  'Bainbridge State College': 41,
#  "Baker County Sheriff's Office": 42,
#  "Baldwin County Sheriff's Office": 43,
#  'Baldwin Police Department': 44,
#  'Ball Ground Police Department': 45,
#  "Banks County Sheriff's Office": 46,
#  'Barnesville Police Department': 47,
#  "Barrow County Sheriff's Office": 48,
#  "Bartow County Sheriff's Office": 49,
#  'Bartow Police Department': 50,
#  'Baxley Police Department': 51,
#  "Ben Hill County Sheriff's Office": 52,
#  'Berlin Police Department': 53,
#  "Berrien County Sheriff's Office": 54,
#  'Berry College': 55,
#  'Bibb County Board of Education': 56,
#  "Bibb County Sheriff's Office": 57,
#  'Blackshear Police Department': 58,
#  'Blairsville Police Department': 59,
#  'Blakely Police Department': 60,
#  "Bleckley County Sheriff's Office": 61,
#  'Bloomingdale Police Department': 62,
#  'Blue Ridge Police Department': 63,
#  'Blythe Police Department': 64,
#  'Boston Police Department': 65,
#  'Bowdon Police Department': 66,
#  "Brantley County Sheriff's Office": 67,
#  'Braselton Police Department': 68,
#  'Braswell  Police Department': 69,
#  'Bremen Police Department': 70,
#  'Brookhaven Police Department': 71,
#  'Brooklet Police Department': 72,
#  "Brooks County Sheriff's Office": 73,
#  'Broxton Police Department': 74,
#  'Brunswick Police Department': 75,
#  "Bryan County Sheriff's Office": 76,
#  'Buchanan Police Department': 77,
#  'Buena Vista Police Department': 78,
#  "Bulloch County Sheriff's Office": 79,
#  "Burke  County Sheriff's Office": 80,
#  'Butler Police Department': 81,
#  "Butts County Sheriff's Office": 82,
#  'Byron Police Department': 83,
#  'Cairo Police Department': 84,
#  "Calhoun County Sheriff's Office": 85,
#  'Calhoun Police Department': 86,
#  "Camden County Sheriff's Office": 87,
#  'Camilla Police Department': 88,
#  "Candler County Sheriff's Office": 89,
#  'Canon Police Department': 90,
#  'Canton Police Department': 91,
#  "Carroll County Sheriff's Office": 92,
#  'Carrollton Police Department': 93,
#  'Cartersville Police Department': 94,
#  "Catoosa County Sheriff's Office": 95,
#  'Cave Spring Police Department': 96,
#  'Cecil': 97,
#  'Cedartown Police Department': 98,
#  'Centerville Police Department': 99,
#  'Chamblee Police Department': 100,
#  "Charlton County Sheriff's Office": 101,
#  'Chatham County Board of Education': 102,
#  'Chatham County Police Department': 103,
#  "Chatham County Sheriff's Office": 104,
#  'Chatsworth Police Department': 105,
#  "Chattahoochee County Sheriff's Office": 106,
#  'Chattahoochee Hills Police Department': 107,
#  'Chattahoochee Technical College': 108,
#  "Chattooga County Sheriff's Office": 109,
#  'Cherokee County Board of Education': 110,
#  'Cherokee County Marshal': 111,
#  "Cherokee County Sheriff's Office": 112,
#  'Chickamauga Police Department': 113,
#  'Clark Atlanta University': 114,
#  "Clarke County Sheriff's Office": 115,
#  'Clarkesville Police Department': 116,
#  'Clarkston Police Department': 117,
#  'Claxton Police Department': 118,
#  "Clay County Sheriff's Office": 119,
#  'Clayton County Police Department': 120,
#  "Clayton County Sheriff's Office": 121,
#  'Clayton Police Department': 122,
#  'Clayton State University': 123,
#  'Cleveland Police Department': 124,
#  "Clinch County Sheriff's Office": 125,
#  'Cobb County Board of Education': 126,
#  'Cobb County Police Department': 127,
#  "Cobb County Sheriff's Office": 128,
#  'Cochran Police Department': 129,
#  "Coffee County Sheriff's Office": 130,
#  'Cohutta Police Department': 131,
#  'College Park Police Department': 132,
#  'College of Coastal Georgia': 133,
#  "Colquitt  County Sheriff's Office": 134,
#  'Colquitt Police Department': 135,
#  "Columbia County Sheriff's Office": 136,
#  'Columbus Police Department': 137,
#  'Columbus State University': 138,
#  'Commerce Police Department': 139,
#  'Conyers Police Department': 140,
#  "Cook County Sheriff's Office": 141,
#  'Coolidge Police Department': 142,
#  'Cordele Police Department': 143,
#  'Cornelia Police Department': 144,
#  'Covington Police Department': 145,
#  "Coweta County Sheriff's Office": 146,
#  "Crawford County Sheriff's Office": 147,
#  "Crisp County Sheriff's Office": 148,
#  'Cumming Police Department': 149,
#  'Cuthbert Police Department': 150,
#  "Dade County Sheriff's Office": 151,
#  'Dallas Police Department': 152,
#  'Dalton Police Department': 153,
#  'Dalton State College': 154,
#  'Danielsville Police Department': 155,
#  'Darien Police Department': 156,
#  'Davisboro Police Department': 157,
#  "Dawson County Sheriff's Office": 158,
#  'Dawson Police Department': 159,
#  'DeKalb County Police Department': 160,
#  'DeKalb County School System': 161,
#  "DeKalb County Sheriff's Office": 162,
#  'Decatur County Schools': 163,
#  "Decatur County Sheriff's Office": 164,
#  'Decatur Police Department': 165,
#  'Demorest Police Department': 166,
#  'Department of Transportation Office of Investigations': 167,
#  'Dillard Police Department': 168,
#  "Dodge County Sheriff's Office": 169,
#  'Doerun Police Department': 170,
#  'Donalsonville Police Department': 171,
#  "Dooly County Sheriff's Office": 172,
#  'Doraville Police Department': 173,
#  'Dougherty County Board of Education': 174,
#  'Dougherty County Police Department': 175,
#  "Dougherty County Sheriff's Office": 176,
#  "Douglas County Sheriff's Office": 177,
#  'Douglas Police Department': 178,
#  'Douglasville Police Department': 179,
#  'Dublin Police Department': 180,
#  'Duluth Police Department': 181,
#  'Dunwoody  Police Department': 182,
#  "Early County Sheriff's Office": 183,
#  'East Dublin Police Department': 184,
#  'East Ellijay Police Department': 185,
#  'East Georgia State College': 186,
#  'East Point Police Department': 187,
#  'Eastman Police Department': 188,
#  'Eatonton Police Department': 189,
#  "Echols County Sheriff's Office": 190,
#  'Edison Police Department': 191,
#  "Effingham County Sheriff's Office": 192,
#  "Elbert County Sheriff's Office": 193,
#  'Elberton Police Department': 194,
#  'Ellaville Police Department': 195,
#  'Ellijay Police Department': 196,
#  "Emanuel County Sheriff's Office": 197,
#  'Emerson Police Department': 198,
#  'Emory University': 199,
#  'Enigma Police Department': 200,
#  'Eton Police Department': 201,
#  'Euharlee Police Department': 202,
#  "Evans County Sheriff's Office": 203,
#  'Fairburn Police Department': 204,
#  'Fairmount Police Department': 205,
#  "Fannin County Sheriff's Office": 206,
#  'Fayette County Marshal': 207,
#  "Fayette County Sheriff's Office": 208,
#  'Fayetteville Police Department': 209,
#  'Fitzgerald Police Department': 210,
#  'Flowery Branch Police Department': 211,
#  'Floyd County Police Department': 212,
#  "Floyd County Sheriff's Office": 213,
#  'Folkston Police Department': 214,
#  'Forest Park Police Department': 215,
#  'Forsyth County Fire Investigation Unit': 216,
#  "Forsyth County Sheriff's Office": 217,
#  'Forsyth Police Department': 218,
#  'Fort Oglethorpe Police Department': 219,
#  'Fort Valley Police Department': 220,
#  'Fort Valley State University': 221,
#  "Franklin County Sheriff's Office": 222,
#  'Franklin Police Department': 223,
#  'Franklin Springs Police Department': 224,
#  'Fulton County Marshal': 225,
#  'Fulton County Police Department': 226,
#  'Fulton County School System': 227,
#  "Fulton County Sheriff's Office": 228,
#  'Gainesville Police Department': 229,
#  'Garden City Police Department': 230,
#  'Georgia Bureau of Investigation: Headquarters': 231,
#  'Georgia College and State University': 232,
#  'Georgia Department of Public Safety': 233,
#  'Georgia Forestry Commission': 234,
#  'Georgia Gwinnett College': 235,
#  'Georgia Institute of Technology': 236,
#  'Georgia Military College': 237,
#  'Georgia Public Safety Training Center': 238,
#  'Georgia Regents University': 239,
#  'Georgia Southern University': 240,
#  'Georgia Southwestern State University': 241,
#  'Georgia State University': 242,
#  'Georgia World Congress': 243,
#  "Gilmer County Sheriff's Office": 244,
#  "Glascock County Sheriff's Office": 245,
#  'Glennville Police Department': 246,
#  'Glynn County Police Department': 247,
#  'Glynn County School System': 248,
#  "Glynn County Sheriff's Office": 249,
#  "Gordon County Sheriff's Office": 250,
#  'Gordon Police Department': 251,
#  'Gordon State College': 252,
#  "Grady County Sheriff's Office": 253,
#  'Graham': 254,
#  'Grantville Police Department': 255,
#  'Gray Police Department': 256,
#  "Greene County Sheriff's Office": 257,
#  'Greensboro Police Department': 258,
#  'Greenville Police Department': 259,
#  'Griffin Police Department': 260,
#  'Grovetown Police Department': 261,
#  'Guyton Police Department': 262,
#  'Gwinnett County Police Department': 263,
#  'Gwinnett County Public Schools': 264,
#  'Gwinnett Technical College': 265,
#  "Habersham County Sheriff's Office": 266,
#  'Hagan Police Department': 267,
#  'Hahira Police Department': 268,
#  'Hall County Marshal': 269,
#  "Hall County Sheriff's Office": 270,
#  'Hampton Police Department': 271,
#  "Hancock County Sheriff's Office": 272,
#  'Hapeville Police Department': 273,
#  "Haralson County Sheriff's Office": 274,
#  'Harlem Police Department': 275,
#  "Harris County Sheriff's Office": 276,
#  "Hart County Sheriff's Office": 277,
#  'Hartwell Police Department': 278,
#  'Hazlehurst Police Department': 279,
#  "Heard County Sheriff's Office": 280,
#  'Helen Police Department': 281,
#  'Henry County Police Department': 282,
#  "Henry County Sheriff's Office": 283,
#  'Hephzibah Police Department': 284,
#  'Hiawassee Police Department': 285,
#  'Hinesville Police Department': 286,
#  'Hiram Police Department': 287,
#  'Hoboken Police Department': 288,
#  'Hogansville Police Department': 289,
#  'Holly Springs Police Department': 290,
#  'Homeland Police Department': 291,
#  'Homerville Police Department': 292,
#  'Hoschton Police Department': 293,
#  "Houston County Sheriff's Office": 294,
#  'Ideal Police Department': 295,
#  "Irwin County Sheriff's Office": 296,
#  'Irwinton Police Department': 297,
#  'Ivey Police Department': 298,
#  "Jackson County Sheriff's Office": 299,
#  'Jackson Police Department': 300,
#  'Jacksonville Police Department': 301,
#  "Jasper County Sheriff's Office": 302,
#  'Jasper Police Department': 303,
#  "Jeff Davis County Sheriff's Office": 304,
#  "Jefferson County Sheriff's Office": 305,
#  'Jefferson Police Department': 306,
#  "Jenkins County Sheriff's Office": 307,
#  'Jesup Police Department': 308,
#  'Johns Creek Police Department': 309,
#  "Johnson County Sheriff's Office": 310,
#  "Jones County Sheriff's Office": 311,
#  'Jonesboro Police Department': 312,
#  'Kennesaw Police Department': 313,
#  'Kennesaw State University': 314,
#  'Kingsland Police Department': 315,
#  'Kingston Police Department': 316,
#  'LaGrange Police Department': 317,
#  'Lafayette Police Department': 318,
#  'Lake City Police Department': 319,
#  'Lake Park Police Department': 320,
#  'Lakeland Police Department': 321,
#  "Lamar County Sheriff's Office": 322,
#  'Lanier County Board of Education': 323,
#  "Lanier County Sheriff's Office": 324,
#  "Laurens County Sheriff's Office": 325,
#  'Lavonia Police Department': 326,
#  'Lawrenceville Police Department': 327,
#  'Leary Police Department': 328,
#  "Lee County Sheriff's Office": 329,
#  'Leesburg Police Department': 330,
#  'Lenox Police Department': 331,
#  'Leslie Police Department': 332,
#  "Liberty County Sheriff's Office": 333,
#  'Lilburn Police Department': 334,
#  "Lincoln County Sheriff's Office": 335,
#  'Lincolnton Police Department': 336,
#  'Lithonia Police Department': 337,
#  'Locust Grove Police Department': 338,
#  'Loganville Police Department': 339,
#  "Long County Sheriff's Office": 340,
#  'Lookout Mountain Police Department': 341,
#  'Louisville Police Department': 342,
#  "Lowndes County Sheriff's Office": 343,
#  'Ludowici Police Department': 344,
#  'Lumber City Police Department': 345,
#  "Lumpkin County Sheriff's Office": 346,
#  'Lumpkin Police Department': 347,
#  'Luthersville Police Department': 348,
#  'Lyons Police Department': 349,
#  "Macon County Sheriff's Office": 350,
#  "Madison County Sheriff's Office": 351,
#  'Madison Police Department': 352,
#  'Manchester Police Department': 353,
#  'Marietta Police Department': 354,
#  "Marion County Sheriff's Office": 355,
#  'Marshallville Police Department': 356,
#  'Maysville Police Department': 357,
#  'McCaysville Police Department': 358,
#  'McDonough Police Department': 359,
#  "McDuffie County Sheriff's Office": 360,
#  'McIntosh County Schools': 361,
#  "McIntosh County Sheriff's Office": 362,
#  'McIntyre Police Department': 363,
#  'McRae Police Department': 364,
#  'Meigs Police Department': 365,
#  'Mercer University': 366,
#  "Meriwether County Sheriff's Office": 367,
#  'Metropolitan Atlanta Rapid Transit Authority': 368,
#  'Metter Police Department': 369,
#  'Middle Georgia State University': 370,
#  'Midville Police Department': 371,
#  'Midway Police Department': 372,
#  'Milan Police Department': 373,
#  'Milledgeville Police Department': 374,
#  'Millen Police Department': 375,
#  "Miller County Sheriff's Office": 376,
#  'Milton Police Department': 377,
#  "Mitchell County Sheriff's Office": 378,
#  'Molena Police Department': 379,
#  "Monroe County Sheriff's Office": 380,
#  'Monroe Police Department': 381,
#  'Montezuma Police Department': 382,
#  "Montgomery County Sheriff's Office": 383,
#  'Monticello Police Department': 384,
#  'Morehouse College': 385,
#  'Morehouse School of Medicine': 386,
#  "Morgan County Sheriff's Office": 387,
#  'Morris Brown College': 388,
#  'Morrow Police Department': 389,
#  'Morven Police Department': 390,
#  'Moultrie Police Department': 391,
#  'Mount Airy Police Department': 392,
#  'Mount Vernon Police Department': 393,
#  'Mount Zion Police Department': 394,
#  'Mountain City Police Department': 395,
#  "Murray County Sheriff's Office": 396,
#  "Muscogee  County Sheriff's Office": 397,
#  'Muscogee City Marshal': 398,
#  'Muscogee County Schools': 399,
#  'Nahunta Police Department': 400,
#  'Nashville Police Department': 401,
#  'Nelson Police Department': 402,
#  'Newington Police Department': 403,
#  'Newnan Police Department': 404,
#  "Newton County Sheriff's Office": 405,
#  'Newton Police Department': 406,
#  'Nicholls Police Department': 407,
#  'Norcross Police Department': 408,
#  'Norman Park Police Department': 409,
#  'North Georgia Technical College': 410,
#  'Oak Park Police Department': 411,
#  'Oakwood Police Department': 412,
#  'Ocilla Police Department': 413,
#  'Oconee  Police Department': 414,
#  "Oconee County Sheriff's Office": 415,
#  "Oglethorpe County Sheriff's Office": 416,
#  'Oglethorpe Police Department': 417,
#  'Oliver Police Department': 418,
#  'Omega Police Department': 419,
#  'Oxford Police Department': 420,
#  'Paine College': 421,
#  'Palmetto Police Department': 422,
#  'Patterson Police Department': 423,
#  'Paulding County Marshal': 424,
#  "Paulding County Sheriff's Office": 425,
#  'Pavo Police Department': 426,
#  "Peach County Sheriff's Office": 427,
#  'Peachtree City Police Department': 428,
#  'Pearson Police Department': 429,
#  'Pelham Police Department': 430,
#  'Pembroke Police Department': 431,
#  'Pendergrass  Police Department': 432,
#  'Perry Police Department': 433,
#  'Pickens County Board of Education': 434,
#  "Pickens County Sheriff's Office": 435,
#  'Piedmont College ': 436,
#  "Pierce County Sheriff's Office": 437,
#  "Pike County Sheriff's Office": 438,
#  'Pine Lake Police Department': 439,
#  'Pine Mountain Police Department': 440,
#  'Pineview Police Department': 441,
#  'Plains Police Department': 442,
#  'Polk County Police Department': 443,
#  "Polk County Sheriff's Office": 444,
#  'Pooler Police Department': 445,
#  'Port Wentworth Police Department': 446,
#  'Portal Police Department': 447,
#  'Porterdale Police Department': 448,
#  'Ports Authority Savannah': 449,
#  'Poulan Police Department': 450,
#  'Powder Springs Police Department': 451,
#  "Pulaski County Sheriff's Office": 452,
#  "Putnam County Sheriff's Office": 453,
#  "Quitman County Sheriff's Office": 454,
#  'Quitman Police Department': 455,
#  "Rabun County Sheriff's Office": 456,
#  "Randolph County Sheriff's Office": 457,
#  'Ray City Police Department': 458,
#  'Register Police Department': 459,
#  'Reidsville Police Department': 460,
#  'Remerton Police Department': 461,
#  'Reynolds Police Department': 462,
#  'Richland Police Department': 463,
#  'Richmond County Marshal': 464,
#  'Richmond Hill Police Department': 465,
#  'Rincon Police Department': 466,
#  'Ringgold Police Department': 467,
#  'Riverdale Police Department': 468,
#  'Roberta Police Department': 469,
#  'Rochelle Police Department': 470,
#  "Rockdale County Sheriff's Office": 471,
#  'Rockmart Police Department': 472,
#  'Rome Police Department': 473,
#  'Roosevelt Institute Facility Police': 474,
#  'Rossville Police Department': 475,
#  'Roswell Police Department': 476,
#  'Royston Police Department': 477,
#  'Sale City Police Department': 478,
#  'Sandersville Police Department': 479,
#  'Sandy Springs Police Department': 480,
#  'Sardis Police Department': 481,
#  'Savannah Fire and Emergency Services Arson Unit': 482,
#  'Savannah State University': 483,
#  'Savannah Technical College': 484,
#  'Savannah-Chatham Metropolitan Police Department': 485,
#  "Schley County Sheriff's Office": 486,
#  "Screven  County Sheriff's Office": 487,
#  'Screven Police Department': 488,
#  "Seminole County Sheriff's Office": 489,
#  'Senoia Police Department': 490,
#  'Shiloh Police Department': 491,
#  'Sky Valley Police Department': 492,
#  'Smyrna Police Department': 493,
#  'Snellville Police Department': 494,
#  'Social Circle Police Department': 495,
#  'Soperton Police Department': 496,
#  'South Fulton': 497,
#  'South Georgia State College': 498,
#  'Southern Crescent Technical College': 499,
#  'Southern Regional Technical College': 500,
#  "Spalding County Sheriff's Office": 501,
#  'Sparks Police Department': 502,
#  'Sparta Police Department': 503,
#  'Spelman College': 504,
#  'Springfield Police Department': 505,
#  'St. Marys Police Department': 506,
#  'Stapleton Police Department': 507,
#  'State Board of Workers Compensation Fraud Investigation Division': 508,
#  'State Patrol: Albany': 509,
#  'State Patrol: Americus': 510,
#  'State Patrol: Athens': 511,
#  'State Patrol: Blue Ridge': 512,
#  'State Patrol: Brunswick': 513,
#  'State Patrol: Calhoun': 514,
#  'State Patrol: Canton': 515,
#  'State Patrol: Cartersville': 516,
#  'State Patrol: Cedartown': 517,
#  'State Patrol: Conyers': 518,
#  'State Patrol: Cordele': 519,
#  'State Patrol: Cuthbert': 520,
#  'State Patrol: Dalton': 521,
#  'State Patrol: Donalsonville': 522,
#  'State Patrol: Douglas': 523,
#  'State Patrol: Dublin': 524,
#  'State Patrol: Forsyth': 525,
#  'State Patrol: Gainesville': 526,
#  'State Patrol: Griffin': 527,
#  'State Patrol: Hapeville': 528,
#  'State Patrol: Helena': 529,
#  'State Patrol: Highway Support Division, Thomaston': 530,
#  'State Patrol: Hinesville': 531,
#  'State Patrol: La Grange': 532,
#  'State Patrol: Lafayette': 533,
#  'State Patrol: Lawrenceville': 534,
#  'State Patrol: Madison': 535,
#  'State Patrol: Manchester': 536,
#  'State Patrol: Marietta': 537,
#  'State Patrol: Metropolitan Traffic Unit, Atlanta': 538,
#  'State Patrol: Milledgeville': 539,
#  'State Patrol: Newnan': 540,
#  'State Patrol: Perry': 541,
#  'State Patrol: Reidsville': 542,
#  'State Patrol: Rome': 543,
#  'State Patrol: Savannah': 544,
#  'State Patrol: Statesboro': 545,
#  'State Patrol: Swainsboro': 546,
#  'State Patrol: Sylvania': 547,
#  'State Patrol: Thomaston': 548,
#  'State Patrol: Thomasville': 549,
#  'State Patrol: Thomson': 550,
#  'State Patrol: Tifton': 551,
#  'State Patrol: Toccoa': 552,
#  'State Patrol: Valdosta': 553,
#  'State Patrol: Villa Rica': 554,
#  'State Patrol: Washington': 555,
#  'State Patrol: Waycross': 556,
#  'Statesboro Police Department': 557,
#  'Statham Police Department': 558,
#  "Stephens County Sheriff's Office": 559,
#  "Stewart County Sheriff's Office": 560,
#  'Stillmore Police Department': 561,
#  'Stone Mountain Park Police': 562,
#  'Stone Mountain Police Department': 563,
#  'Summerville Police Department': 564,
#  "Sumter County Sheriff's Office": 565,
#  'Suwanee Police Department': 566,
#  'Swainsboro Police Department': 567,
#  'Sycamore Police Department': 568,
#  'Sylvania Police Department': 569,
#  'Sylvester Police Department': 570,
#  "Talbot County Sheriff's Office": 571,
#  'Talbotton Police Department': 572,
#  "Taliaferro County Sheriff's Office": 573,
#  'Tallapoosa Police Department': 574,
#  'Tallulah Falls Police Department': 575,
#  "Tattnall County Sheriff's Office": 576,
#  "Taylor County Sheriff's Office": 577,
#  "Telfair County Sheriff's Office": 578,
#  'Temple Police Department': 579,
#  "Terrell County Sheriff's Office": 580,
#  "Thomas County Sheriff's Office": 581,
#  'Thomaston Police Department': 582,
#  'Thomasville Police Department': 583,
#  'Thunderbolt Police Department': 584,
#  "Tift County Sheriff's Office": 585,
#  'Tifton Police Department': 586,
#  'Toccoa Police Department': 587,
#  "Toombs County Sheriff's Office": 588,
#  'Toomsboro Police Department': 589,
#  "Towns County Sheriff's Office": 590,
#  'Trenton Police Department': 591,
#  "Treutlen County Sheriff's Office": 592,
#  'Trion Police Department': 593,
#  'Troup County Marshal': 594,
#  "Troup County Sheriff's Office": 595,
#  'Tunnel Hill Police Department': 596,
#  'Turner County Schools': 597,
#  "Turner County Sheriff's Office": 598,
#  'Twiggs County Board of Education': 599,
#  "Twiggs County Sheriff's Office": 600,
#  'Twin City Police Department': 601,
#  'Tybee Island Police Department': 602,
#  'Tyrone Police Department': 603,
#  'Union City Police Department': 604,
#  "Union County Sheriff's Office": 605,
#  'Union Point Police Department': 606,
#  'University of Georgia': 607,
#  'University of North Georgia': 608,
#  'University of West Georgia': 609,
#  "Upson County Sheriff's Office": 610,
#  'Uvalda Police Department': 611,
#  'Valdosta Police Department': 612,
#  'Valdosta State University': 613,
#  'Vidalia Police Department': 614,
#  'Vienna Police Department': 615,
#  'Villa Rica Police Department': 616,
#  'Wadley Police Department': 617,
#  "Walker County Sheriff's Office": 618,
#  'Walthourville Police Department': 619,
#  "Walton County Sheriff's Office": 620,
#  "Ware County Sheriff's Office": 621,
#  'Warm Springs Police Department': 622,
#  'Warner Robins Police Department': 623,
#  "Warren County Sheriff's Office": 624,
#  'Warrenton Police Department': 625,
#  'Warwick Police Department': 626,
#  'Washington County Board of Education': 627,
#  "Washington County Sheriff's Office": 628,
#  'Watkinsville Police Department': 629,
#  'Waverly Hall Police Department': 630,
#  'Waycross Police Department': 631,
#  "Wayne County Sheriff's Office": 632,
#  'Waynesboro Police Department': 633,
#  "Webster County Sheriff's Office": 634,
#  'Wesleyan College': 635,
#  'West Georgia Technical College': 636,
#  'West Point Police Department': 637,
#  "Wheeler County Sheriff's Office": 638,
#  'Whigham Police Department': 639,
#  "White County Sheriff's Office": 640,
#  'White Police Department': 641,
#  'Whitesburg Police Department': 642,
#  "Whitfield County Sheriff's Office": 643,
#  "Wilcox County Sheriff's Office": 644,
#  "Wilkes County Sheriff's Office": 645,
#  "Wilkinson County Sheriff's Office": 646,
#  'Willacoochee Police Department': 647,
#  'Winder Police Department': 648,
#  'Winterville Police Department': 649,
#  'Woodbury Police Department': 650,
#  'Woodland Police Department': 651,
#  'Woodstock Police Department': 652,
#  "Worth County Sheriff's Office": 653,
#  'Wrens Police Department': 654,
#  'Wrightsville Police Department': 655,
#  'Young Harris College': 656,
#  'Zebulon Police Department': 657}

# %% [markdown]
# ### Load CountyAgency Relationship Table

# %%
DF_raw = pd.DataFrame(list(db.destination.find({})))[['Agency Name','County','ORI','Latitude','Longitude']]
countyagencyDF = pd.DataFrame(columns=['agencyid','countyid'])

for index, row in DF_raw.iterrows():
    
    # split the multi-counties
    if ';' in row.County:
        counties = row.County.split('; ')

        for cnty in counties:
            if cnty != '':
                countyagencyDF.loc[len(countyagencyDF.index)] = [agency_dict.get(row[0]), county_dict.get(cnty)]
    else:
        countyagencyDF.loc[len(countyagencyDF.index)] = [agency_dict.get(row[0]), county_dict.get(row[1])]
        
countyagencyDF = countyagencyDF.sort_values(by=['agencyid','countyid'])
countyagencyDF.insert(0, 'countyagencyid', range(1, 1 + len(countyagencyDF.index)))
countyagencyDF.to_sql(name='CountyAgency', con=engine, if_exists='replace', index=False)
countyagencyDF.head(5)
# Out:
#      countyagencyid  agencyid  countyid
# 619               1       1.0     156.0
# 346               2       2.0     137.0
# 536               3       3.0      33.0
# 127               4       4.0       8.0
# 423               5       5.0      37.0

# %% [markdown]
# ### Load Income Table

# %%
DF_raw = pd.read_csv('data/incomepercapita.csv')
incomeDF = pd.DataFrame(columns=['countyid','percapita_income','data_year'])

for index, row in DF_raw.iterrows():
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[1], 2017]
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[2], 2018]
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[3], 2019]
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[4], 2020]
        
incomeDF = incomeDF.sort_values(by=['countyid','data_year'])
incomeDF.insert(0, 'incomeid', range(1, 1 + len(incomeDF.index)))
incomeDF.to_sql(name='Income', con=engine, if_exists='replace', index=False)
incomeDF.head(5)
# Out:
#    incomeid  countyid  percapita_income  data_year
# 0         1         1             33240       2017
# 1         2         1             33620       2018
# 2         3         1             35558       2019
# 3         4         1             39199       2020
# 4         5         2             28937       2017
