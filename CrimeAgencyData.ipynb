# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import pprint
import pymongo

# %%
api_key = "YOUR API KEY"

# %%
# Create base url and get json data
base_url = f"https://api.usa.gov/crime/fbi/sapi//api/agencies?API_KEY={api_key}"
response = requests.get(base_url).json()

# %%
# Show only Georgia results
GA_data = response["GA"]
GA_data
# Out:
# {'GA0160300': {'ori': 'GA0160300',
#   'agency_name': 'Portal Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': False,
#   'latitude': 32.393408,
#   'longitude': -81.74381,
#   'nibrs_start_date': None},
#  'GA0680900': {'ori': 'GA0680900',
#   'agency_name': 'Alto Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BANKS; HABERSHAM',
#   'nibrs': True,
#   'latitude': 34.635108,
#   'longitude': -83.526406,
#   'nibrs_start_date': '01/01/2019'},
#  'GA0410100': {'ori': 'GA0410100',
#   'agency_name': 'Trenton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DADE',
#   'nibrs': False,
#   'latitude': 34.852424,
#   'longitude': -85.506201,
#   'nibrs_start_date': None},
#  'GA0080300': {'ori': 'GA0080300',
#   'agency_name': 'Kingston Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARTOW',
#   'nibrs': True,
#   'latitude': 34.240917,
#   'longitude': -84.838188,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP3300': {'ori': 'GAGSP3300',
#   'agency_name': 'State Patrol: Milledgeville',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 33.059504,
#   'longitude': -83.255452,
#   'nibrs_start_date': None},
#  'GA060459E': {'ori': 'GA060459E',
#   'agency_name': 'Morris Brown College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': False,
#   'latitude': 33.75472,
#   'longitude': -84.40874,
#   'nibrs_start_date': None},
#  'GA0330100': {'ori': 'GA0330100',
#   'agency_name': 'Austell Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGLAS; COBB',
#   'nibrs': True,
#   'latitude': 33.93994,
#   'longitude': -84.574166,
#   'nibrs_start_date': '01/01/2020'},
#  'GA1210300': {'ori': 'GA1210300',
#   'agency_name': 'Hephzibah Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RICHMOND',
#   'nibrs': False,
#   'latitude': 33.361487,
#   'longitude': -82.074998,
#   'nibrs_start_date': None},
#  'GA0020000': {'ori': 'GA0020000',
#   'agency_name': "Atkinson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ATKINSON',
#   'nibrs': True,
#   'latitude': 31.296677,
#   'longitude': -82.878067,
#   'nibrs_start_date': '10/01/2019'},
#  'GAGSP1000': {'ori': 'GAGSP1000',
#   'agency_name': 'State Patrol: Americus',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': False,
#   'latitude': 32.037216,
#   'longitude': -84.14207,
#   'nibrs_start_date': None},
#  'GA1300100': {'ori': 'GA1300100',
#   'agency_name': 'Talbotton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TALBOT',
#   'nibrs': False,
#   'latitude': 32.704603,
#   'longitude': -84.530029,
#   'nibrs_start_date': None},
#  'GA0090100': {'ori': 'GA0090100',
#   'agency_name': 'Fitzgerald Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BEN HILL',
#   'nibrs': True,
#   'latitude': 31.740775,
#   'longitude': -83.14719,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0960000': {'ori': 'GA0960000',
#   'agency_name': "Macon County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MACON',
#   'nibrs': False,
#   'latitude': 32.366216,
#   'longitude': -84.052162,
#   'nibrs_start_date': None},
#  'GA1290100': {'ori': 'GA1290100',
#   'agency_name': 'Americus Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': True,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': '08/01/2019'},
#  'GA0880000': {'ori': 'GA0880000',
#   'agency_name': "Lee County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LEE',
#   'nibrs': True,
#   'latitude': 31.818419,
#   'longitude': -84.146681,
#   'nibrs_start_date': '04/01/2019'},
#  'GA0310500': {'ori': 'GA0310500',
#   'agency_name': 'Riverdale Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': True,
#   'latitude': 33.572205,
#   'longitude': -84.415726,
#   'nibrs_start_date': '06/01/2019'},
#  'GA0100000': {'ori': 'GA0100000',
#   'agency_name': "Berrien County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BERRIEN',
#   'nibrs': True,
#   'latitude': 31.191711,
#   'longitude': -83.27352,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1370100': {'ori': 'GA1370100',
#   'agency_name': 'Tifton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TIFT',
#   'nibrs': False,
#   'latitude': 31.449644,
#   'longitude': -83.509926,
#   'nibrs_start_date': None},
#  'GA0950200': {'ori': 'GA0950200',
#   'agency_name': 'McIntosh County Schools',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MCINTOSH',
#   'nibrs': False,
#   'latitude': 31.482978,
#   'longitude': -81.370199,
#   'nibrs_start_date': None},
#  'GA0780400': {'ori': 'GA0780400',
#   'agency_name': 'Arcade Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JACKSON',
#   'nibrs': True,
#   'latitude': 34.134157,
#   'longitude': -83.565133,
#   'nibrs_start_date': '12/01/2019'},
#  'GA0810000': {'ori': 'GA0810000',
#   'agency_name': "Jefferson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': True,
#   'latitude': 33.051874,
#   'longitude': -82.41905,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0331300': {'ori': 'GA0331300',
#   'agency_name': 'Cobb County Board of Education',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.916363,
#   'longitude': -84.546295,
#   'nibrs_start_date': '10/01/2019'},
#  'GAGSP4500': {'ori': 'GAGSP4500',
#   'agency_name': 'State Patrol: Statesboro',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': False,
#   'latitude': 32.411438,
#   'longitude': -81.80494,
#   'nibrs_start_date': None},
#  'GAGSP2200': {'ori': 'GAGSP2200',
#   'agency_name': 'State Patrol: Waycross',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WARE',
#   'nibrs': False,
#   'latitude': 31.050881,
#   'longitude': -82.421507,
#   'nibrs_start_date': None},
#  'GA0560100': {'ori': 'GA0560100',
#   'agency_name': 'Fayetteville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.412717,
#   'longitude': -84.493941,
#   'nibrs_start_date': '08/01/2019'},
#  'GA0650000': {'ori': 'GA0650000',
#   'agency_name': "Grady County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GRADY',
#   'nibrs': True,
#   'latitude': 30.875891,
#   'longitude': -84.245066,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1060100': {'ori': 'GA1060100',
#   'agency_name': 'Columbus Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MUSCOGEE',
#   'nibrs': False,
#   'latitude': 32.464756,
#   'longitude': -84.98599,
#   'nibrs_start_date': None},
#  'GA0720100': {'ori': 'GA0720100',
#   'agency_name': 'Pine Mountain Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MERIWETHER; HARRIS',
#   'nibrs': True,
#   'latitude': 32.731549,
#   'longitude': -84.912432,
#   'nibrs_start_date': '01/01/2019'},
#  'GA0445100': {'ori': 'GA0445100',
#   'agency_name': 'DeKalb County School System',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': True,
#   'latitude': 33.800564,
#   'longitude': -84.20196,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0170000': {'ori': 'GA0170000',
#   'agency_name': "Burke  County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BURKE',
#   'nibrs': True,
#   'latitude': 33.050819,
#   'longitude': -82.011571,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1360300': {'ori': 'GA1360300',
#   'agency_name': 'Coolidge Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'THOMAS',
#   'nibrs': True,
#   'latitude': 30.864606,
#   'longitude': -83.91982,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1140000': {'ori': 'GA1140000',
#   'agency_name': "Pike County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIKE',
#   'nibrs': True,
#   'latitude': 33.090768,
#   'longitude': -84.386627,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1530100': {'ori': 'GA1530100',
#   'agency_name': 'Alamo Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHEELER',
#   'nibrs': True,
#   'latitude': 32.109276,
#   'longitude': -82.738701,
#   'nibrs_start_date': '07/01/2019'},
#  'GA1220100': {'ori': 'GA1220100',
#   'agency_name': 'Conyers Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ROCKDALE',
#   'nibrs': False,
#   'latitude': 33.65794,
#   'longitude': -84.01751,
#   'nibrs_start_date': None},
#  'GA0250100': {'ori': 'GA0250100',
#   'agency_name': 'Chatham County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': False,
#   'latitude': 32.060173,
#   'longitude': -81.166336,
#   'nibrs_start_date': None},
#  'GA0640200': {'ori': 'GA0640200',
#   'agency_name': 'Fairmount Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GORDON',
#   'nibrs': False,
#   'latitude': 34.509667,
#   'longitude': -84.873862,
#   'nibrs_start_date': None},
#  'GA0252400': {'ori': 'GA0252400',
#   'agency_name': 'Savannah Technical College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': True,
#   'latitude': 31.980523,
#   'longitude': -81.08519,
#   'nibrs_start_date': '01/01/2019'},
#  'GA1130200': {'ori': 'GA1130200',
#   'agency_name': 'Patterson Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIERCE',
#   'nibrs': False,
#   'latitude': 31.353988,
#   'longitude': -82.210427,
#   'nibrs_start_date': None},
#  'GA0710500': {'ori': 'GA0710500',
#   'agency_name': 'West Georgia Technical College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HARALSON',
#   'nibrs': True,
#   'latitude': 33.795165,
#   'longitude': -85.220062,
#   'nibrs_start_date': '03/01/2019'},
#  'GA0160400': {'ori': 'GA0160400',
#   'agency_name': 'Georgia Southern University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': True,
#   'latitude': 32.393408,
#   'longitude': -81.74381,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0330000': {'ori': 'GA0330000',
#   'agency_name': "Cobb County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.952282,
#   'longitude': -84.5482,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1210400': {'ori': 'GA1210400',
#   'agency_name': 'Georgia Regents University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RICHMOND',
#   'nibrs': True,
#   'latitude': 33.47503,
#   'longitude': -81.98768,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP3200': {'ori': 'GAGSP3200',
#   'agency_name': 'State Patrol: Athens',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLARKE',
#   'nibrs': False,
#   'latitude': 33.952185,
#   'longitude': -83.367152,
#   'nibrs_start_date': None},
#  'GA1190500': {'ori': 'GA1190500',
#   'agency_name': 'Sky Valley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RABUN',
#   'nibrs': False,
#   'latitude': 34.883026,
#   'longitude': -83.404735,
#   'nibrs_start_date': None},
#  'GA1300200': {'ori': 'GA1300200',
#   'agency_name': 'Woodland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TALBOT',
#   'nibrs': True,
#   'latitude': 32.704603,
#   'longitude': -84.530029,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0240200': {'ori': 'GA0240200',
#   'agency_name': 'Homeland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHARLTON',
#   'nibrs': False,
#   'latitude': 30.856588,
#   'longitude': -82.02113,
#   'nibrs_start_date': None},
#  'GA0500000': {'ori': 'GA0500000',
#   'agency_name': "Echols County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ECHOLS',
#   'nibrs': True,
#   'latitude': 30.7085,
#   'longitude': -82.836132,
#   'nibrs_start_date': '11/01/2018'},
#  'GA0800100': {'ori': 'GA0800100',
#   'agency_name': 'Hazlehurst Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFF DAVIS',
#   'nibrs': True,
#   'latitude': 31.867207,
#   'longitude': -82.599304,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0530700': {'ori': 'GA0530700',
#   'agency_name': 'East Georgia State College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL',
#   'nibrs': False,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': None},
#  'GA0490000': {'ori': 'GA0490000',
#   'agency_name': "Early County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EARLY',
#   'nibrs': True,
#   'latitude': 31.324191,
#   'longitude': -84.906723,
#   'nibrs_start_date': '10/01/2019'},
#  'GA139039E': {'ori': 'GA139039E',
#   'agency_name': 'Young Harris College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TOWNS',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1380000': {'ori': 'GA1380000',
#   'agency_name': "Toombs County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TOOMBS',
#   'nibrs': False,
#   'latitude': 32.20298,
#   'longitude': -82.34015,
#   'nibrs_start_date': None},
#  'GA0570000': {'ori': 'GA0570000',
#   'agency_name': "Floyd County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FLOYD',
#   'nibrs': True,
#   'latitude': 34.280457,
#   'longitude': -85.1429,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0310400': {'ori': 'GA0310400',
#   'agency_name': 'Jonesboro Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': False,
#   'latitude': 33.516556,
#   'longitude': -84.353935,
#   'nibrs_start_date': None},
#  'GA0010100': {'ori': 'GA0010100',
#   'agency_name': 'Baxley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'APPLING',
#   'nibrs': True,
#   'latitude': 31.739712,
#   'longitude': -82.290103,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0440900': {'ori': 'GA0440900',
#   'agency_name': 'Stone Mountain Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': True,
#   'latitude': 33.80639,
#   'longitude': -84.170364,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1370200': {'ori': 'GA1370200',
#   'agency_name': 'Omega Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COLQUITT; TIFT',
#   'nibrs': True,
#   'latitude': 31.457003,
#   'longitude': -83.525931,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0480100': {'ori': 'GA0480100',
#   'agency_name': 'Douglasville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGLAS',
#   'nibrs': True,
#   'latitude': 33.699317,
#   'longitude': -84.765944,
#   'nibrs_start_date': '07/01/2019'},
#  'GA1290200': {'ori': 'GA1290200',
#   'agency_name': 'Leslie Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': True,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0950100': {'ori': 'GA0950100',
#   'agency_name': 'Darien Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MCINTOSH',
#   'nibrs': True,
#   'latitude': 31.482978,
#   'longitude': -81.370199,
#   'nibrs_start_date': '02/01/2020'},
#  'GA0780500': {'ori': 'GA0780500',
#   'agency_name': 'Hoschton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JACKSON',
#   'nibrs': False,
#   'latitude': 34.134157,
#   'longitude': -83.565133,
#   'nibrs_start_date': None},
#  'GA1230000': {'ori': 'GA1230000',
#   'agency_name': "Schley County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SCHLEY',
#   'nibrs': True,
#   'latitude': 32.263441,
#   'longitude': -84.322724,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0331200': {'ori': 'GA0331200',
#   'agency_name': 'Kennesaw State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.93994,
#   'longitude': -84.574166,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP4400': {'ori': 'GAGSP4400',
#   'agency_name': 'State Patrol: Forsyth',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONROE',
#   'nibrs': False,
#   'latitude': 33.017435,
#   'longitude': -83.922938,
#   'nibrs_start_date': None},
#  'GAGSP2100': {'ori': 'GAGSP2100',
#   'agency_name': 'State Patrol: Sylvania',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SCREVEN',
#   'nibrs': False,
#   'latitude': 32.748623,
#   'longitude': -81.65879,
#   'nibrs_start_date': None},
#  'GA0560200': {'ori': 'GA0560200',
#   'agency_name': 'Peachtree City Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.412717,
#   'longitude': -84.493941,
#   'nibrs_start_date': '11/01/2019'},
#  'GA1060000': {'ori': 'GA1060000',
#   'agency_name': "Muscogee  County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MUSCOGEE',
#   'nibrs': True,
#   'latitude': 32.510197,
#   'longitude': -84.874946,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0690600': {'ori': 'GA0690600',
#   'agency_name': 'Hall County Marshal',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HALL',
#   'nibrs': True,
#   'latitude': 34.317588,
#   'longitude': -83.818497,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0650100': {'ori': 'GA0650100',
#   'agency_name': 'Cairo Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GRADY',
#   'nibrs': True,
#   'latitude': 30.875891,
#   'longitude': -84.245066,
#   'nibrs_start_date': '04/01/2019'},
#  'GA1360400': {'ori': 'GA1360400',
#   'agency_name': 'Meigs Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MITCHELL; THOMAS',
#   'nibrs': False,
#   'latitude': 30.864606,
#   'longitude': -83.91982,
#   'nibrs_start_date': None},
#  'GA0420000': {'ori': 'GA0420000',
#   'agency_name': "Dawson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DAWSON',
#   'nibrs': False,
#   'latitude': 34.422028,
#   'longitude': -84.12007,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1140100': {'ori': 'GA1140100',
#   'agency_name': 'Zebulon Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIKE',
#   'nibrs': True,
#   'latitude': 33.090768,
#   'longitude': -84.386627,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0720000': {'ori': 'GA0720000',
#   'agency_name': "Harris County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HARRIS',
#   'nibrs': True,
#   'latitude': 32.731549,
#   'longitude': -84.912432,
#   'nibrs_start_date': '12/01/2019'},
#  'GA0470300': {'ori': 'GA0470300',
#   'agency_name': 'Albany State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGHERTY',
#   'nibrs': False,
#   'latitude': 31.572027,
#   'longitude': -84.144394,
#   'nibrs_start_date': None},
#  'GA0290900': {'ori': 'GA0290900',
#   'agency_name': 'Athens Technical College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLARKE',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '01/01/2019'},
#  'GA1530000': {'ori': 'GA1530000',
#   'agency_name': "Wheeler County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHEELER',
#   'nibrs': False,
#   'latitude': 32.14889,
#   'longitude': -82.78266,
#   'nibrs_start_date': None},
#  'GA1050200': {'ori': 'GA1050200',
#   'agency_name': 'Eton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MURRAY',
#   'nibrs': True,
#   'latitude': 34.797097,
#   'longitude': -84.73799,
#   'nibrs_start_date': '08/01/2019'},
#  'GA0250000': {'ori': 'GA0250000',
#   'agency_name': "Chatham County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': False,
#   'latitude': 31.980523,
#   'longitude': -81.08519,
#   'nibrs_start_date': None},
#  'GA0160500': {'ori': 'GA0160500',
#   'agency_name': 'Register Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': False,
#   'latitude': 32.367367,
#   'longitude': -81.88627,
#   'nibrs_start_date': None},
#  'GA0970000': {'ori': 'GA0970000',
#   'agency_name': "Madison County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MADISON',
#   'nibrs': True,
#   'latitude': 34.128484,
#   'longitude': -83.203644,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0320100': {'ori': 'GA0320100',
#   'agency_name': 'Homerville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLINCH',
#   'nibrs': False,
#   'latitude': 30.917653,
#   'longitude': -82.702614,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0630200': {'ori': 'GA0630200',
#   'agency_name': 'Glynn County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GLYNN',
#   'nibrs': True,
#   'latitude': 31.212746,
#   'longitude': -81.496517,
#   'nibrs_start_date': '05/01/2019'},
#  'GA057069E': {'ori': 'GA057069E',
#   'agency_name': 'Berry College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FLOYD',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '06/01/2019'},
#  'GAGSP3100': {'ori': 'GAGSP3100',
#   'agency_name': 'State Patrol: Valdosta',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LOWNDES',
#   'nibrs': False,
#   'latitude': 30.833127,
#   'longitude': -83.268992,
#   'nibrs_start_date': None},
#  'GA1000000': {'ori': 'GA1000000',
#   'agency_name': "Miller County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MILLER',
#   'nibrs': False,
#   'latitude': 31.17431,
#   'longitude': -84.73826,
#   'nibrs_start_date': None},
#  'GA1190400': {'ori': 'GA1190400',
#   'agency_name': 'Dillard Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RABUN',
#   'nibrs': True,
#   'latitude': 34.883026,
#   'longitude': -83.404735,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1340600': {'ori': 'GA1340600',
#   'agency_name': 'Jacksonville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TELFAIR',
#   'nibrs': False,
#   'latitude': 31.913639,
#   'longitude': -82.931062,
#   'nibrs_start_date': None},
#  'GA0110000': {'ori': 'GA0110000',
#   'agency_name': "Bibb County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BIBB',
#   'nibrs': True,
#   'latitude': 32.831833,
#   'longitude': -83.64161,
#   'nibrs_start_date': '02/01/2019'},
#  'GA0960200': {'ori': 'GA0960200',
#   'agency_name': 'Ideal Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MACON',
#   'nibrs': False,
#   'latitude': 32.366216,
#   'longitude': -84.052162,
#   'nibrs_start_date': None},
#  'GA0010000': {'ori': 'GA0010000',
#   'agency_name': "Appling County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'APPLING',
#   'nibrs': True,
#   'latitude': 31.782509,
#   'longitude': -82.35828,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0310300': {'ori': 'GA0310300',
#   'agency_name': 'Morrow Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': True,
#   'latitude': 33.582436,
#   'longitude': -84.33722,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0570100': {'ori': 'GA0570100',
#   'agency_name': 'Floyd County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FLOYD',
#   'nibrs': True,
#   'latitude': 34.169235,
#   'longitude': -85.21126,
#   'nibrs_start_date': '01/01/2020'},
#  'GA1500600': {'ori': 'GA1500600',
#   'agency_name': 'Washington County Board of Education',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WASHINGTON',
#   'nibrs': True,
#   'latitude': 32.971848,
#   'longitude': -82.798112,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0100200': {'ori': 'GA0100200',
#   'agency_name': 'Alapaha Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BERRIEN',
#   'nibrs': True,
#   'latitude': 31.274308,
#   'longitude': -83.231906,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0790000': {'ori': 'GA0790000',
#   'agency_name': "Jasper County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JASPER',
#   'nibrs': True,
#   'latitude': 33.318128,
#   'longitude': -83.689505,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0440800': {'ori': 'GA0440800',
#   'agency_name': 'Pine Lake Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': False,
#   'latitude': 33.770661,
#   'longitude': -84.226343,
#   'nibrs_start_date': None},
#  'GA0780200': {'ori': 'GA0780200',
#   'agency_name': 'Jefferson Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JACKSON',
#   'nibrs': True,
#   'latitude': 34.11839,
#   'longitude': -83.57744,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0480000': {'ori': 'GA0480000',
#   'agency_name': "Douglas County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGLAS',
#   'nibrs': True,
#   'latitude': 33.748375,
#   'longitude': -84.7535,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1290300': {'ori': 'GA1290300',
#   'agency_name': 'Plains Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': False,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': None},
#  'GA0220600': {'ori': 'GA0220600',
#   'agency_name': 'University of West Georgia',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CARROLL',
#   'nibrs': True,
#   'latitude': 33.571545,
#   'longitude': -85.094604,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0820000': {'ori': 'GA0820000',
#   'agency_name': "Jenkins County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JENKINS',
#   'nibrs': True,
#   'latitude': 32.794563,
#   'longitude': -81.971524,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0560300': {'ori': 'GA0560300',
#   'agency_name': 'Tyrone Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.478733,
#   'longitude': -84.594215,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP4300': {'ori': 'GAGSP4300',
#   'agency_name': 'State Patrol: Calhoun',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GORDON',
#   'nibrs': False,
#   'latitude': 34.460278,
#   'longitude': -84.91662,
#   'nibrs_start_date': None},
#  'GAGSP2000': {'ori': 'GAGSP2000',
#   'agency_name': 'State Patrol: Dublin',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LAURENS',
#   'nibrs': False,
#   'latitude': 32.39322,
#   'longitude': -82.926317,
#   'nibrs_start_date': None},
#  'GA0600900': {'ori': 'GA0600900',
#   'agency_name': 'Georgia State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.754486,
#   'longitude': -84.38908,
#   'nibrs_start_date': '05/01/2019'},
#  'GA1540100': {'ori': 'GA1540100',
#   'agency_name': 'Cleveland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHITE',
#   'nibrs': True,
#   'latitude': 34.643776,
#   'longitude': -83.743417,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1150000': {'ori': 'GA1150000',
#   'agency_name': "Polk County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'POLK',
#   'nibrs': True,
#   'latitude': 33.996015,
#   'longitude': -85.188338,
#   'nibrs_start_date': '12/01/2018'},
#  'GAAPD0000': {'ori': 'GAAPD0000',
#   'agency_name': 'Atlanta Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB; FULTON',
#   'nibrs': True,
#   'latitude': 33.74819,
#   'longitude': -84.39517,
#   'nibrs_start_date': '10/01/2020'},
#  'GA0470200': {'ori': 'GA0470200',
#   'agency_name': 'Dougherty County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGHERTY',
#   'nibrs': True,
#   'latitude': 31.532588,
#   'longitude': -84.20904,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1360100': {'ori': 'GA1360100',
#   'agency_name': 'Thomasville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'THOMAS',
#   'nibrs': True,
#   'latitude': 30.864606,
#   'longitude': -83.91982,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0447200': {'ori': 'GA0447200',
#   'agency_name': 'Brookhaven Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0070300': {'ori': 'GA0070300',
#   'agency_name': 'Statham Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARROW',
#   'nibrs': False,
#   'latitude': 33.992009,
#   'longitude': -83.712303,
#   'nibrs_start_date': None},
#  'GA0606200': {'ori': 'GA0606200',
#   'agency_name': 'Morehouse School of Medicine',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': False,
#   'latitude': 33.743107,
#   'longitude': -84.41023,
#   'nibrs_start_date': None},
#  'GA0080100': {'ori': 'GA0080100',
#   'agency_name': 'Cartersville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARTOW',
#   'nibrs': True,
#   'latitude': 34.240917,
#   'longitude': -84.838188,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0250300': {'ori': 'GA0250300',
#   'agency_name': 'Savannah-Chatham Metropolitan Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': False,
#   'latitude': 32.075733,
#   'longitude': -81.088394,
#   'nibrs_start_date': None},
#  'GA0810200': {'ori': 'GA0810200',
#   'agency_name': 'Wadley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.051874,
#   'longitude': -82.41905,
#   'nibrs_start_date': None},
#  'GA1050100': {'ori': 'GA1050100',
#   'agency_name': 'Chatsworth Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MURRAY',
#   'nibrs': True,
#   'latitude': 34.797097,
#   'longitude': -84.73799,
#   'nibrs_start_date': '02/01/2019'},
#  'GA0640000': {'ori': 'GA0640000',
#   'agency_name': "Gordon County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GORDON',
#   'nibrs': True,
#   'latitude': 34.509667,
#   'longitude': -84.873862,
#   'nibrs_start_date': '12/01/2018'},
#  'GAGSP3000': {'ori': 'GAGSP3000',
#   'agency_name': 'State Patrol: Cordele',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CRISP',
#   'nibrs': False,
#   'latitude': 31.914753,
#   'longitude': -83.753338,
#   'nibrs_start_date': None},
#  'GA1000100': {'ori': 'GA1000100',
#   'agency_name': 'Colquitt Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MILLER',
#   'nibrs': False,
#   'latitude': 31.162908,
#   'longitude': -84.730386,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0320000': {'ori': 'GA0320000',
#   'agency_name': "Clinch County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLINCH',
#   'nibrs': True,
#   'latitude': 31.039433,
#   'longitude': -82.749954,
#   'nibrs_start_date': '07/01/2020'},
#  'GA0080200': {'ori': 'GA0080200',
#   'agency_name': 'Adairsville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARTOW',
#   'nibrs': True,
#   'latitude': 34.368633,
#   'longitude': -84.93449,
#   'nibrs_start_date': '11/01/2018'},
#  'GA0630300': {'ori': 'GA0630300',
#   'agency_name': 'College of Coastal Georgia',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GLYNN',
#   'nibrs': True,
#   'latitude': 31.212746,
#   'longitude': -81.496517,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1190300': {'ori': 'GA1190300',
# ...
#   'agency_type_name': 'Other State Agency',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.759632,
#   'longitude': -84.382416,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1130000': {'ori': 'GA1130000',
#   'agency_name': "Pierce County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIERCE',
#   'nibrs': True,
#   'latitude': 31.302244,
#   'longitude': -82.23383,
#   'nibrs_start_date': '06/01/2018'},
#  'GA120059E': {'ori': 'GA120059E',
#   'agency_name': 'Andrew College ',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RANDOLPH',
#   'nibrs': False,
#   'latitude': 31.771894,
#   'longitude': -84.79704,
#   'nibrs_start_date': None},
#  'GA0970300': {'ori': 'GA0970300',
#   'agency_name': 'Danielsville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MADISON',
#   'nibrs': True,
#   'latitude': 34.128484,
#   'longitude': -83.203644,
#   'nibrs_start_date': '07/01/2019'},
#  'GA0410000': {'ori': 'GA0410000',
#   'agency_name': "Dade County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DADE',
#   'nibrs': False,
#   'latitude': 34.852424,
#   'longitude': -85.506201,
#   'nibrs_start_date': None},
#  'GA0070000': {'ori': 'GA0070000',
#   'agency_name': "Barrow County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARROW',
#   'nibrs': True,
#   'latitude': 33.992009,
#   'longitude': -83.712303,
#   'nibrs_start_date': '01/01/2018'},
#  'GA0840000': {'ori': 'GA0840000',
#   'agency_name': "Jones County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JONES',
#   'nibrs': True,
#   'latitude': 33.020226,
#   'longitude': -83.562339,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0330200': {'ori': 'GA0330200',
#   'agency_name': 'Cobb County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.958862,
#   'longitude': -84.54633,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1340100': {'ori': 'GA1340100',
#   'agency_name': 'McRae Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHEELER; TELFAIR',
#   'nibrs': True,
#   'latitude': 31.913639,
#   'longitude': -82.931062,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0670800': {'ori': 'GA0670800',
#   'agency_name': 'Snellville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GWINNETT',
#   'nibrs': True,
#   'latitude': 33.83367,
#   'longitude': -84.00958,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0760200': {'ori': 'GA0760200',
#   'agency_name': 'Warner Robins Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PEACH; HOUSTON',
#   'nibrs': True,
#   'latitude': 32.458381,
#   'longitude': -83.662856,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0280100': {'ori': 'GA0280100',
#   'agency_name': 'Canton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHEROKEE',
#   'nibrs': True,
#   'latitude': 34.23541,
#   'longitude': -84.490005,
#   'nibrs_start_date': '11/01/2020'},
#  'GAGSP1900': {'ori': 'GAGSP1900',
#   'agency_name': 'State Patrol: Swainsboro',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL',
#   'nibrs': False,
#   'latitude': 32.5911,
#   'longitude': -82.299763,
#   'nibrs_start_date': None},
#  'GA1200000': {'ori': 'GA1200000',
#   'agency_name': "Randolph County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RANDOLPH',
#   'nibrs': False,
#   'latitude': 31.762651,
#   'longitude': -84.752311,
#   'nibrs_start_date': None},
#  'GA0530500': {'ori': 'GA0530500',
#   'agency_name': 'Stillmore Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL',
#   'nibrs': False,
#   'latitude': 32.5911,
#   'longitude': -82.299763,
#   'nibrs_start_date': None},
#  'GA1550200': {'ori': 'GA1550200',
#   'agency_name': 'Tunnel Hill Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHITFIELD',
#   'nibrs': True,
#   'latitude': 34.801726,
#   'longitude': -84.968541,
#   'nibrs_start_date': '02/01/2020'},
#  'GA0830200': {'ori': 'GA0830200',
#   'agency_name': 'Adrian Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL; JOHNSON',
#   'nibrs': False,
#   'latitude': 32.689831,
#   'longitude': -82.661354,
#   'nibrs_start_date': None},
#  'GA0610300': {'ori': 'GA0610300',
#   'agency_name': 'East Ellijay Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GILMER',
#   'nibrs': True,
#   'latitude': 34.690541,
#   'longitude': -84.453984,
#   'nibrs_start_date': '12/01/2019'},
#  'GA0750400': {'ori': 'GA0750400',
#   'agency_name': 'Locust Grove Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HENRY',
#   'nibrs': False,
#   'latitude': 33.452881,
#   'longitude': -84.15444,
#   'nibrs_start_date': None},
#  'GA0310600': {'ori': 'GA0310600',
#   'agency_name': 'Lake City Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': True,
#   'latitude': 33.60693,
#   'longitude': -84.34333,
#   'nibrs_start_date': '09/01/2018'},
#  'GA1290000': {'ori': 'GA1290000',
#   'agency_name': "Sumter County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': True,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': '01/01/2018'},
#  'GA1070000': {'ori': 'GA1070000',
#   'agency_name': "Newton County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'NEWTON',
#   'nibrs': True,
#   'latitude': 33.544065,
#   'longitude': -83.855192,
#   'nibrs_start_date': '10/01/2018'},
#  'GA0050300': {'ori': 'GA0050300',
#   'agency_name': 'Georgia College and State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': True,
#   'latitude': 33.059504,
#   'longitude': -83.255452,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0560000': {'ori': 'GA0560000',
#   'agency_name': "Fayette County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.446476,
#   'longitude': -84.45227,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0990000': {'ori': 'GA0990000',
#   'agency_name': "Meriwether County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MERIWETHER',
#   'nibrs': True,
#   'latitude': 33.03022,
#   'longitude': -84.663279,
#   'nibrs_start_date': '01/01/2019'},
#  'GA0602700': {'ori': 'GA0602700',
#   'agency_name': 'Fulton County Marshal',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.752655,
#   'longitude': -84.38997,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0600400': {'ori': 'GA0600400',
#   'agency_name': 'Alpharetta Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.790034,
#   'longitude': -84.468182,
#   'nibrs_start_date': '03/01/2019'},
#  'GA1280100': {'ori': 'GA1280100',
#   'agency_name': 'Lumpkin Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'STEWART',
#   'nibrs': False,
#   'latitude': 32.073225,
#   'longitude': -84.834912,
#   'nibrs_start_date': None},
#  'GA1410000': {'ori': 'GA1410000',
#   'agency_name': "Troup County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TROUP',
#   'nibrs': False,
#   'latitude': 32.989746,
#   'longitude': -85.00395,
#   'nibrs_start_date': None},
#  'GA0690400': {'ori': 'GA0690400',
#   'agency_name': 'Oakwood Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HALL',
#   'nibrs': True,
#   'latitude': 34.317588,
#   'longitude': -83.818497,
#   'nibrs_start_date': '11/01/2019'},
#  'GA0130000': {'ori': 'GA0130000',
#   'agency_name': "Brantley County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BRANTLEY',
#   'nibrs': True,
#   'latitude': 31.197334,
#   'longitude': -81.982978,
#   'nibrs_start_date': '10/01/2019'},
#  'GAGSP0800': {'ori': 'GAGSP0800',
#   'agency_name': 'State Patrol: Madison',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MORGAN',
#   'nibrs': False,
#   'latitude': 33.593732,
#   'longitude': -83.492324,
#   'nibrs_start_date': None},
#  'GA0340100': {'ori': 'GA0340100',
#   'agency_name': 'Douglas Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COFFEE',
#   'nibrs': True,
#   'latitude': 31.511168,
#   'longitude': -82.852135,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0470500': {'ori': 'GA0470500',
#   'agency_name': 'Dougherty County Board of Education',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGHERTY',
#   'nibrs': True,
#   'latitude': 31.532588,
#   'longitude': -84.20904,
#   'nibrs_start_date': '07/01/2019'},
#  'GA1350000': {'ori': 'GA1350000',
#   'agency_name': "Terrell County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TERRELL',
#   'nibrs': False,
#   'latitude': 31.777191,
#   'longitude': -84.439446,
#   'nibrs_start_date': None},
#  'GA0250600': {'ori': 'GA0250600',
#   'agency_name': 'Tybee Island Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': True,
#   'latitude': 31.980523,
#   'longitude': -81.08519,
#   'nibrs_start_date': '05/01/2019'},
#  'GA0900000': {'ori': 'GA0900000',
#   'agency_name': "Lincoln County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LINCOLN',
#   'nibrs': False,
#   'latitude': 33.792151,
#   'longitude': -82.448299,
#   'nibrs_start_date': None},
#  'GA0550200': {'ori': 'GA0550200',
#   'agency_name': 'Blue Ridge Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FANNIN',
#   'nibrs': False,
#   'latitude': 34.866226,
#   'longitude': -84.32594,
#   'nibrs_start_date': None},
#  'GA0770100': {'ori': 'GA0770100',
#   'agency_name': 'Ocilla Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'IRWIN',
#   'nibrs': True,
#   'latitude': 31.591131,
#   'longitude': -83.25055,
#   'nibrs_start_date': '07/01/2019'},
#  'GA0810500': {'ori': 'GA0810500',
#   'agency_name': 'Stapleton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': True,
#   'latitude': 33.051874,
#   'longitude': -82.41905,
#   'nibrs_start_date': '07/01/2020'},
#  'GA0120200': {'ori': 'GA0120200',
#   'agency_name': 'Middle Georgia State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BLECKLEY',
#   'nibrs': True,
#   'latitude': 32.435403,
#   'longitude': -83.331717,
#   'nibrs_start_date': '01/01/2019'}}

# %%
# Connect to database
client = pymongo.MongoClient('mongodb://localhost:27017')
db = client.CrimeAgencyData

# Deletes any existing database to prevent data from duplicating each time script is executed
client.drop_database('CrimeAgencyData')

# Loop through the GA_data
for x in GA_data:
    agency_data = [
        {
            "ORI" : GA_data[x]["ori"],
            "Agency Name" : GA_data[x]["agency_name"],
            "County" : GA_data[x]["county_name"],
            "Latitude" : GA_data[x]["latitude"],
            "Longitude" : GA_data[x]["longitude"]
        }
    ]
    
    # Add entry to the database
    db.destination.insert_many(agency_data)
    pprint.pprint(agency_data)
# Out:
# [{'Agency Name': 'Portal Police Department',
#   'County': 'BULLOCH',
#   'Latitude': 32.393408,
#   'Longitude': -81.74381,
#   'ORI': 'GA0160300',
#   '_id': ObjectId('63336f1c783bd5742f53e3dc')}]
# [{'Agency Name': 'Alto Police Department',
#   'County': 'BANKS; HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   'ORI': 'GA0680900',
#   '_id': ObjectId('63336f1c783bd5742f53e3dd')}]
# [{'Agency Name': 'Trenton Police Department',
#   'County': 'DADE',
#   'Latitude': 34.852424,
#   'Longitude': -85.506201,
#   'ORI': 'GA0410100',
#   '_id': ObjectId('63336f1c783bd5742f53e3de')}]
# [{'Agency Name': 'Kingston Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080300',
#   '_id': ObjectId('63336f1c783bd5742f53e3df')}]
# [{'Agency Name': 'State Patrol: Milledgeville',
#   'County': 'BALDWIN',
#   'Latitude': 33.059504,
#   'Longitude': -83.255452,
#   'ORI': 'GAGSP3300',
#   '_id': ObjectId('63336f1c783bd5742f53e3e0')}]
# [{'Agency Name': 'Morris Brown College',
#   'County': 'FULTON',
#   'Latitude': 33.75472,
#   'Longitude': -84.40874,
#   'ORI': 'GA060459E',
#   '_id': ObjectId('63336f1c783bd5742f53e3e1')}]
# [{'Agency Name': 'Austell Police Department',
#   'County': 'DOUGLAS; COBB',
#   'Latitude': 33.93994,
#   'Longitude': -84.574166,
#   'ORI': 'GA0330100',
#   '_id': ObjectId('63336f1c783bd5742f53e3e2')}]
# [{'Agency Name': 'Hephzibah Police Department',
#   'County': 'RICHMOND',
#   'Latitude': 33.361487,
#   'Longitude': -82.074998,
#   'ORI': 'GA1210300',
#   '_id': ObjectId('63336f1c783bd5742f53e3e3')}]
# [{'Agency Name': "Atkinson County Sheriff's Office",
#   'County': 'ATKINSON',
#   'Latitude': 31.296677,
#   'Longitude': -82.878067,
#   'ORI': 'GA0020000',
#   '_id': ObjectId('63336f1c783bd5742f53e3e4')}]
# [{'Agency Name': 'State Patrol: Americus',
#   'County': 'SUMTER',
#   'Latitude': 32.037216,
#   'Longitude': -84.14207,
#   'ORI': 'GAGSP1000',
#   '_id': ObjectId('63336f1c783bd5742f53e3e5')}]
# [{'Agency Name': 'Talbotton Police Department',
#   'County': 'TALBOT',
#   'Latitude': 32.704603,
#   'Longitude': -84.530029,
#   'ORI': 'GA1300100',
#   '_id': ObjectId('63336f1c783bd5742f53e3e6')}]
# [{'Agency Name': 'Fitzgerald Police Department',
#   'County': 'BEN HILL',
#   'Latitude': 31.740775,
#   'Longitude': -83.14719,
#   'ORI': 'GA0090100',
#   '_id': ObjectId('63336f1c783bd5742f53e3e7')}]
# [{'Agency Name': "Macon County Sheriff's Office",
#   'County': 'MACON',
#   'Latitude': 32.366216,
#   'Longitude': -84.052162,
#   'ORI': 'GA0960000',
#   '_id': ObjectId('63336f1c783bd5742f53e3e8')}]
# [{'Agency Name': 'Americus Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290100',
#   '_id': ObjectId('63336f1c783bd5742f53e3e9')}]
# [{'Agency Name': "Lee County Sheriff's Office",
#   'County': 'LEE',
#   'Latitude': 31.818419,
#   'Longitude': -84.146681,
#   'ORI': 'GA0880000',
#   '_id': ObjectId('63336f1c783bd5742f53e3ea')}]
# [{'Agency Name': 'Riverdale Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.572205,
#   'Longitude': -84.415726,
#   'ORI': 'GA0310500',
#   '_id': ObjectId('63336f1c783bd5742f53e3eb')}]
# [{'Agency Name': "Berrien County Sheriff's Office",
#   'County': 'BERRIEN',
#   'Latitude': 31.191711,
#   'Longitude': -83.27352,
#   'ORI': 'GA0100000',
#   '_id': ObjectId('63336f1c783bd5742f53e3ec')}]
# [{'Agency Name': 'Tifton Police Department',
#   'County': 'TIFT',
#   'Latitude': 31.449644,
#   'Longitude': -83.509926,
#   'ORI': 'GA1370100',
#   '_id': ObjectId('63336f1c783bd5742f53e3ed')}]
# [{'Agency Name': 'McIntosh County Schools',
#   'County': 'MCINTOSH',
#   'Latitude': 31.482978,
#   'Longitude': -81.370199,
#   'ORI': 'GA0950200',
#   '_id': ObjectId('63336f1c783bd5742f53e3ee')}]
# [{'Agency Name': 'Arcade Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   'ORI': 'GA0780400',
#   '_id': ObjectId('63336f1c783bd5742f53e3ef')}]
# [{'Agency Name': "Jefferson County Sheriff's Office",
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810000',
#   '_id': ObjectId('63336f1c783bd5742f53e3f0')}]
# [{'Agency Name': 'Cobb County Board of Education',
#   'County': 'COBB',
#   'Latitude': 33.916363,
#   'Longitude': -84.546295,
#   'ORI': 'GA0331300',
#   '_id': ObjectId('63336f1c783bd5742f53e3f1')}]
# [{'Agency Name': 'State Patrol: Statesboro',
#   'County': 'BULLOCH',
#   'Latitude': 32.411438,
#   'Longitude': -81.80494,
#   'ORI': 'GAGSP4500',
#   '_id': ObjectId('63336f1c783bd5742f53e3f2')}]
# [{'Agency Name': 'State Patrol: Waycross',
#   'County': 'WARE',
#   'Latitude': 31.050881,
#   'Longitude': -82.421507,
#   'ORI': 'GAGSP2200',
#   '_id': ObjectId('63336f1c783bd5742f53e3f3')}]
# [{'Agency Name': 'Fayetteville Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.412717,
#   'Longitude': -84.493941,
#   'ORI': 'GA0560100',
#   '_id': ObjectId('63336f1c783bd5742f53e3f4')}]
# [{'Agency Name': "Grady County Sheriff's Office",
#   'County': 'GRADY',
#   'Latitude': 30.875891,
#   'Longitude': -84.245066,
#   'ORI': 'GA0650000',
#   '_id': ObjectId('63336f1d783bd5742f53e3f5')}]
# [{'Agency Name': 'Columbus Police Department',
#   'County': 'MUSCOGEE',
#   'Latitude': 32.464756,
#   'Longitude': -84.98599,
#   'ORI': 'GA1060100',
#   '_id': ObjectId('63336f1d783bd5742f53e3f6')}]
# [{'Agency Name': 'Pine Mountain Police Department',
#   'County': 'MERIWETHER; HARRIS',
#   'Latitude': 32.731549,
#   'Longitude': -84.912432,
#   'ORI': 'GA0720100',
#   '_id': ObjectId('63336f1d783bd5742f53e3f7')}]
# [{'Agency Name': 'DeKalb County School System',
#   'County': 'DEKALB',
#   'Latitude': 33.800564,
#   'Longitude': -84.20196,
#   'ORI': 'GA0445100',
#   '_id': ObjectId('63336f1d783bd5742f53e3f8')}]
# [{'Agency Name': "Burke  County Sheriff's Office",
#   'County': 'BURKE',
#   'Latitude': 33.050819,
#   'Longitude': -82.011571,
#   'ORI': 'GA0170000',
#   '_id': ObjectId('63336f1d783bd5742f53e3f9')}]
# [{'Agency Name': 'Coolidge Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360300',
#   '_id': ObjectId('63336f1d783bd5742f53e3fa')}]
# [{'Agency Name': "Pike County Sheriff's Office",
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   'ORI': 'GA1140000',
#   '_id': ObjectId('63336f1d783bd5742f53e3fb')}]
# [{'Agency Name': 'Alamo Police Department',
#   'County': 'WHEELER',
#   'Latitude': 32.109276,
#   'Longitude': -82.738701,
#   'ORI': 'GA1530100',
#   '_id': ObjectId('63336f1d783bd5742f53e3fc')}]
# [{'Agency Name': 'Conyers Police Department',
#   'County': 'ROCKDALE',
#   'Latitude': 33.65794,
#   'Longitude': -84.01751,
#   'ORI': 'GA1220100',
#   '_id': ObjectId('63336f1d783bd5742f53e3fd')}]
# [{'Agency Name': 'Chatham County Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 32.060173,
#   'Longitude': -81.166336,
#   'ORI': 'GA0250100',
#   '_id': ObjectId('63336f1d783bd5742f53e3fe')}]
# [{'Agency Name': 'Fairmount Police Department',
#   'County': 'GORDON',
#   'Latitude': 34.509667,
#   'Longitude': -84.873862,
#   'ORI': 'GA0640200',
#   '_id': ObjectId('63336f1d783bd5742f53e3ff')}]
# [{'Agency Name': 'Savannah Technical College',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0252400',
#   '_id': ObjectId('63336f1d783bd5742f53e400')}]
# [{'Agency Name': 'Patterson Police Department',
#   'County': 'PIERCE',
#   'Latitude': 31.353988,
#   'Longitude': -82.210427,
#   'ORI': 'GA1130200',
#   '_id': ObjectId('63336f1d783bd5742f53e401')}]
# [{'Agency Name': 'West Georgia Technical College',
#   'County': 'HARALSON',
#   'Latitude': 33.795165,
#   'Longitude': -85.220062,
#   'ORI': 'GA0710500',
#   '_id': ObjectId('63336f1d783bd5742f53e402')}]
# [{'Agency Name': 'Georgia Southern University',
#   'County': 'BULLOCH',
#   'Latitude': 32.393408,
#   'Longitude': -81.74381,
#   'ORI': 'GA0160400',
#   '_id': ObjectId('63336f1d783bd5742f53e403')}]
# [{'Agency Name': "Cobb County Sheriff's Office",
#   'County': 'COBB',
#   'Latitude': 33.952282,
#   'Longitude': -84.5482,
#   'ORI': 'GA0330000',
#   '_id': ObjectId('63336f1d783bd5742f53e404')}]
# [{'Agency Name': 'Georgia Regents University',
#   'County': 'RICHMOND',
#   'Latitude': 33.47503,
#   'Longitude': -81.98768,
#   'ORI': 'GA1210400',
#   '_id': ObjectId('63336f1d783bd5742f53e405')}]
# [{'Agency Name': 'State Patrol: Athens',
#   'County': 'CLARKE',
#   'Latitude': 33.952185,
#   'Longitude': -83.367152,
#   'ORI': 'GAGSP3200',
#   '_id': ObjectId('63336f1d783bd5742f53e406')}]
# [{'Agency Name': 'Sky Valley Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190500',
#   '_id': ObjectId('63336f1d783bd5742f53e407')}]
# [{'Agency Name': 'Woodland Police Department',
#   'County': 'TALBOT',
#   'Latitude': 32.704603,
#   'Longitude': -84.530029,
#   'ORI': 'GA1300200',
#   '_id': ObjectId('63336f1d783bd5742f53e408')}]
# [{'Agency Name': 'Homeland Police Department',
#   'County': 'CHARLTON',
#   'Latitude': 30.856588,
#   'Longitude': -82.02113,
#   'ORI': 'GA0240200',
#   '_id': ObjectId('63336f1d783bd5742f53e409')}]
# [{'Agency Name': "Echols County Sheriff's Office",
#   'County': 'ECHOLS',
#   'Latitude': 30.7085,
#   'Longitude': -82.836132,
#   'ORI': 'GA0500000',
#   '_id': ObjectId('63336f1d783bd5742f53e40a')}]
# [{'Agency Name': 'Hazlehurst Police Department',
#   'County': 'JEFF DAVIS',
#   'Latitude': 31.867207,
#   'Longitude': -82.599304,
#   'ORI': 'GA0800100',
#   '_id': ObjectId('63336f1d783bd5742f53e40b')}]
# [{'Agency Name': 'East Georgia State College',
#   'County': 'EMANUEL',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0530700',
#   '_id': ObjectId('63336f1d783bd5742f53e40c')}]
# [{'Agency Name': "Early County Sheriff's Office",
#   'County': 'EARLY',
#   'Latitude': 31.324191,
#   'Longitude': -84.906723,
#   'ORI': 'GA0490000',
#   '_id': ObjectId('63336f1d783bd5742f53e40d')}]
# [{'Agency Name': 'Young Harris College',
#   'County': 'TOWNS',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA139039E',
#   '_id': ObjectId('63336f1d783bd5742f53e40e')}]
# [{'Agency Name': "Toombs County Sheriff's Office",
#   'County': 'TOOMBS',
#   'Latitude': 32.20298,
#   'Longitude': -82.34015,
#   'ORI': 'GA1380000',
#   '_id': ObjectId('63336f1d783bd5742f53e40f')}]
# [{'Agency Name': "Floyd County Sheriff's Office",
#   'County': 'FLOYD',
#   'Latitude': 34.280457,
#   'Longitude': -85.1429,
#   'ORI': 'GA0570000',
#   '_id': ObjectId('63336f1d783bd5742f53e410')}]
# [{'Agency Name': 'Jonesboro Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.516556,
#   'Longitude': -84.353935,
#   'ORI': 'GA0310400',
#   '_id': ObjectId('63336f1d783bd5742f53e411')}]
# [{'Agency Name': 'Baxley Police Department',
#   'County': 'APPLING',
#   'Latitude': 31.739712,
#   'Longitude': -82.290103,
#   'ORI': 'GA0010100',
#   '_id': ObjectId('63336f1d783bd5742f53e412')}]
# [{'Agency Name': 'Stone Mountain Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.80639,
#   'Longitude': -84.170364,
#   'ORI': 'GA0440900',
#   '_id': ObjectId('63336f1d783bd5742f53e413')}]
# [{'Agency Name': 'Omega Police Department',
#   'County': 'COLQUITT; TIFT',
#   'Latitude': 31.457003,
#   'Longitude': -83.525931,
#   'ORI': 'GA1370200',
#   '_id': ObjectId('63336f1d783bd5742f53e414')}]
# [{'Agency Name': 'Douglasville Police Department',
#   'County': 'DOUGLAS',
#   'Latitude': 33.699317,
#   'Longitude': -84.765944,
#   'ORI': 'GA0480100',
#   '_id': ObjectId('63336f1d783bd5742f53e415')}]
# [{'Agency Name': 'Leslie Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290200',
#   '_id': ObjectId('63336f1d783bd5742f53e416')}]
# [{'Agency Name': 'Darien Police Department',
#   'County': 'MCINTOSH',
#   'Latitude': 31.482978,
#   'Longitude': -81.370199,
#   'ORI': 'GA0950100',
#   '_id': ObjectId('63336f1d783bd5742f53e417')}]
# [{'Agency Name': 'Hoschton Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   'ORI': 'GA0780500',
#   '_id': ObjectId('63336f1d783bd5742f53e418')}]
# [{'Agency Name': "Schley County Sheriff's Office",
#   'County': 'SCHLEY',
#   'Latitude': 32.263441,
#   'Longitude': -84.322724,
#   'ORI': 'GA1230000',
#   '_id': ObjectId('63336f1d783bd5742f53e419')}]
# [{'Agency Name': 'Kennesaw State University',
#   'County': 'COBB',
#   'Latitude': 33.93994,
#   'Longitude': -84.574166,
#   'ORI': 'GA0331200',
#   '_id': ObjectId('63336f1d783bd5742f53e41a')}]
# [{'Agency Name': 'State Patrol: Forsyth',
#   'County': 'MONROE',
#   'Latitude': 33.017435,
#   'Longitude': -83.922938,
#   'ORI': 'GAGSP4400',
#   '_id': ObjectId('63336f1d783bd5742f53e41b')}]
# [{'Agency Name': 'State Patrol: Sylvania',
#   'County': 'SCREVEN',
#   'Latitude': 32.748623,
#   'Longitude': -81.65879,
#   'ORI': 'GAGSP2100',
#   '_id': ObjectId('63336f1d783bd5742f53e41c')}]
# [{'Agency Name': 'Peachtree City Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.412717,
#   'Longitude': -84.493941,
#   'ORI': 'GA0560200',
#   '_id': ObjectId('63336f1d783bd5742f53e41d')}]
# [{'Agency Name': "Muscogee  County Sheriff's Office",
#   'County': 'MUSCOGEE',
#   'Latitude': 32.510197,
#   'Longitude': -84.874946,
#   'ORI': 'GA1060000',
#   '_id': ObjectId('63336f1d783bd5742f53e41e')}]
# [{'Agency Name': 'Hall County Marshal',
#   'County': 'HALL',
#   'Latitude': 34.317588,
#   'Longitude': -83.818497,
#   'ORI': 'GA0690600',
#   '_id': ObjectId('63336f1d783bd5742f53e41f')}]
# [{'Agency Name': 'Cairo Police Department',
#   'County': 'GRADY',
#   'Latitude': 30.875891,
#   'Longitude': -84.245066,
#   'ORI': 'GA0650100',
#   '_id': ObjectId('63336f1d783bd5742f53e420')}]
# [{'Agency Name': 'Meigs Police Department',
#   'County': 'MITCHELL; THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360400',
#   '_id': ObjectId('63336f1d783bd5742f53e421')}]
# [{'Agency Name': "Dawson County Sheriff's Office",
#   'County': 'DAWSON',
#   'Latitude': 34.422028,
#   'Longitude': -84.12007,
#   'ORI': 'GA0420000',
#   '_id': ObjectId('63336f1d783bd5742f53e422')}]
# [{'Agency Name': 'Zebulon Police Department',
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   'ORI': 'GA1140100',
#   '_id': ObjectId('63336f1d783bd5742f53e423')}]
# [{'Agency Name': "Harris County Sheriff's Office",
#   'County': 'HARRIS',
#   'Latitude': 32.731549,
#   'Longitude': -84.912432,
#   'ORI': 'GA0720000',
#   '_id': ObjectId('63336f1d783bd5742f53e424')}]
# [{'Agency Name': 'Albany State University',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.572027,
#   'Longitude': -84.144394,
#   'ORI': 'GA0470300',
#   '_id': ObjectId('63336f1d783bd5742f53e425')}]
# [{'Agency Name': 'Athens Technical College',
#   'County': 'CLARKE',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0290900',
#   '_id': ObjectId('63336f1d783bd5742f53e426')}]
# [{'Agency Name': "Wheeler County Sheriff's Office",
#   'County': 'WHEELER',
#   'Latitude': 32.14889,
#   'Longitude': -82.78266,
#   'ORI': 'GA1530000',
#   '_id': ObjectId('63336f1d783bd5742f53e427')}]
# [{'Agency Name': 'Eton Police Department',
#   'County': 'MURRAY',
#   'Latitude': 34.797097,
#   'Longitude': -84.73799,
#   'ORI': 'GA1050200',
#   '_id': ObjectId('63336f1d783bd5742f53e428')}]
# [{'Agency Name': "Chatham County Sheriff's Office",
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0250000',
#   '_id': ObjectId('63336f1d783bd5742f53e429')}]
# [{'Agency Name': 'Register Police Department',
#   'County': 'BULLOCH',
#   'Latitude': 32.367367,
#   'Longitude': -81.88627,
#   'ORI': 'GA0160500',
#   '_id': ObjectId('63336f1d783bd5742f53e42a')}]
# [{'Agency Name': "Madison County Sheriff's Office",
#   'County': 'MADISON',
#   'Latitude': 34.128484,
#   'Longitude': -83.203644,
#   'ORI': 'GA0970000',
#   '_id': ObjectId('63336f1d783bd5742f53e42b')}]
# [{'Agency Name': 'Homerville Police Department',
#   'County': 'CLINCH',
#   'Latitude': 30.917653,
#   'Longitude': -82.702614,
#   'ORI': 'GA0320100',
#   '_id': ObjectId('63336f1d783bd5742f53e42c')}]
# [{'Agency Name': 'Glynn County Police Department',
#   'County': 'GLYNN',
#   'Latitude': 31.212746,
#   'Longitude': -81.496517,
#   'ORI': 'GA0630200',
#   '_id': ObjectId('63336f1d783bd5742f53e42d')}]
# [{'Agency Name': 'Berry College',
#   'County': 'FLOYD',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA057069E',
#   '_id': ObjectId('63336f1d783bd5742f53e42e')}]
# [{'Agency Name': 'State Patrol: Valdosta',
#   'County': 'LOWNDES',
#   'Latitude': 30.833127,
#   'Longitude': -83.268992,
#   'ORI': 'GAGSP3100',
#   '_id': ObjectId('63336f1d783bd5742f53e42f')}]
# [{'Agency Name': "Miller County Sheriff's Office",
#   'County': 'MILLER',
#   'Latitude': 31.17431,
#   'Longitude': -84.73826,
#   'ORI': 'GA1000000',
#   '_id': ObjectId('63336f1d783bd5742f53e430')}]
# [{'Agency Name': 'Dillard Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190400',
#   '_id': ObjectId('63336f1d783bd5742f53e431')}]
# [{'Agency Name': 'Jacksonville Police Department',
#   'County': 'TELFAIR',
#   'Latitude': 31.913639,
#   'Longitude': -82.931062,
#   'ORI': 'GA1340600',
#   '_id': ObjectId('63336f1d783bd5742f53e432')}]
# [{'Agency Name': "Bibb County Sheriff's Office",
#   'County': 'BIBB',
#   'Latitude': 32.831833,
#   'Longitude': -83.64161,
#   'ORI': 'GA0110000',
#   '_id': ObjectId('63336f1d783bd5742f53e433')}]
# [{'Agency Name': 'Ideal Police Department',
#   'County': 'MACON',
#   'Latitude': 32.366216,
#   'Longitude': -84.052162,
#   'ORI': 'GA0960200',
#   '_id': ObjectId('63336f1d783bd5742f53e434')}]
# [{'Agency Name': "Appling County Sheriff's Office",
#   'County': 'APPLING',
#   'Latitude': 31.782509,
#   'Longitude': -82.35828,
#   'ORI': 'GA0010000',
#   '_id': ObjectId('63336f1d783bd5742f53e435')}]
# [{'Agency Name': 'Morrow Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.582436,
#   'Longitude': -84.33722,
#   'ORI': 'GA0310300',
#   '_id': ObjectId('63336f1d783bd5742f53e436')}]
# [{'Agency Name': 'Floyd County Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.169235,
#   'Longitude': -85.21126,
#   'ORI': 'GA0570100',
#   '_id': ObjectId('63336f1d783bd5742f53e437')}]
# [{'Agency Name': 'Washington County Board of Education',
#   'County': 'WASHINGTON',
#   'Latitude': 32.971848,
#   'Longitude': -82.798112,
#   'ORI': 'GA1500600',
#   '_id': ObjectId('63336f1d783bd5742f53e438')}]
# [{'Agency Name': 'Alapaha Police Department',
#   'County': 'BERRIEN',
#   'Latitude': 31.274308,
#   'Longitude': -83.231906,
#   'ORI': 'GA0100200',
#   '_id': ObjectId('63336f1d783bd5742f53e439')}]
# [{'Agency Name': "Jasper County Sheriff's Office",
#   'County': 'JASPER',
#   'Latitude': 33.318128,
#   'Longitude': -83.689505,
#   'ORI': 'GA0790000',
#   '_id': ObjectId('63336f1d783bd5742f53e43a')}]
# [{'Agency Name': 'Pine Lake Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.770661,
#   'Longitude': -84.226343,
#   'ORI': 'GA0440800',
#   '_id': ObjectId('63336f1d783bd5742f53e43b')}]
# [{'Agency Name': 'Jefferson Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.11839,
#   'Longitude': -83.57744,
#   'ORI': 'GA0780200',
#   '_id': ObjectId('63336f1d783bd5742f53e43c')}]
# [{'Agency Name': "Douglas County Sheriff's Office",
#   'County': 'DOUGLAS',
#   'Latitude': 33.748375,
#   'Longitude': -84.7535,
#   'ORI': 'GA0480000',
#   '_id': ObjectId('63336f1d783bd5742f53e43d')}]
# [{'Agency Name': 'Plains Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290300',
#   '_id': ObjectId('63336f1d783bd5742f53e43e')}]
# [{'Agency Name': 'University of West Georgia',
#   'County': 'CARROLL',
#   'Latitude': 33.571545,
#   'Longitude': -85.094604,
#   'ORI': 'GA0220600',
#   '_id': ObjectId('63336f1d783bd5742f53e43f')}]
# [{'Agency Name': "Jenkins County Sheriff's Office",
#   'County': 'JENKINS',
#   'Latitude': 32.794563,
#   'Longitude': -81.971524,
#   'ORI': 'GA0820000',
#   '_id': ObjectId('63336f1d783bd5742f53e440')}]
# [{'Agency Name': 'Tyrone Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.478733,
#   'Longitude': -84.594215,
#   'ORI': 'GA0560300',
#   '_id': ObjectId('63336f1d783bd5742f53e441')}]
# [{'Agency Name': 'State Patrol: Calhoun',
#   'County': 'GORDON',
#   'Latitude': 34.460278,
#   'Longitude': -84.91662,
#   'ORI': 'GAGSP4300',
#   '_id': ObjectId('63336f1d783bd5742f53e442')}]
# [{'Agency Name': 'State Patrol: Dublin',
#   'County': 'LAURENS',
#   'Latitude': 32.39322,
#   'Longitude': -82.926317,
#   'ORI': 'GAGSP2000',
#   '_id': ObjectId('63336f1d783bd5742f53e443')}]
# [{'Agency Name': 'Georgia State University',
#   'County': 'FULTON',
#   'Latitude': 33.754486,
#   'Longitude': -84.38908,
#   'ORI': 'GA0600900',
#   '_id': ObjectId('63336f1d783bd5742f53e444')}]
# [{'Agency Name': 'Cleveland Police Department',
#   'County': 'WHITE',
#   'Latitude': 34.643776,
#   'Longitude': -83.743417,
#   'ORI': 'GA1540100',
#   '_id': ObjectId('63336f1d783bd5742f53e445')}]
# [{'Agency Name': "Polk County Sheriff's Office",
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150000',
#   '_id': ObjectId('63336f1d783bd5742f53e446')}]
# [{'Agency Name': 'Atlanta Police Department',
#   'County': 'DEKALB; FULTON',
#   'Latitude': 33.74819,
#   'Longitude': -84.39517,
#   'ORI': 'GAAPD0000',
#   '_id': ObjectId('63336f1d783bd5742f53e447')}]
# [{'Agency Name': 'Dougherty County Police Department',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470200',
#   '_id': ObjectId('63336f1d783bd5742f53e448')}]
# [{'Agency Name': 'Thomasville Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360100',
#   '_id': ObjectId('63336f1d783bd5742f53e449')}]
# [{'Agency Name': 'Brookhaven Police Department',
#   'County': 'DEKALB',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0447200',
#   '_id': ObjectId('63336f1d783bd5742f53e44a')}]
# [{'Agency Name': 'Statham Police Department',
#   'County': 'BARROW',
#   'Latitude': 33.992009,
#   'Longitude': -83.712303,
#   'ORI': 'GA0070300',
#   '_id': ObjectId('63336f1d783bd5742f53e44b')}]
# [{'Agency Name': 'Morehouse School of Medicine',
#   'County': 'FULTON',
#   'Latitude': 33.743107,
#   'Longitude': -84.41023,
#   'ORI': 'GA0606200',
#   '_id': ObjectId('63336f1d783bd5742f53e44c')}]
# [{'Agency Name': 'Cartersville Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080100',
#   '_id': ObjectId('63336f1d783bd5742f53e44d')}]
# [{'Agency Name': 'Savannah-Chatham Metropolitan Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 32.075733,
#   'Longitude': -81.088394,
#   'ORI': 'GA0250300',
#   '_id': ObjectId('63336f1d783bd5742f53e44e')}]
# [{'Agency Name': 'Wadley Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810200',
#   '_id': ObjectId('63336f1d783bd5742f53e44f')}]
# [{'Agency Name': 'Chatsworth Police Department',
#   'County': 'MURRAY',
#   'Latitude': 34.797097,
#   'Longitude': -84.73799,
#   'ORI': 'GA1050100',
#   '_id': ObjectId('63336f1d783bd5742f53e450')}]
# [{'Agency Name': "Gordon County Sheriff's Office",
#   'County': 'GORDON',
#   'Latitude': 34.509667,
#   'Longitude': -84.873862,
#   'ORI': 'GA0640000',
#   '_id': ObjectId('63336f1d783bd5742f53e451')}]
# [{'Agency Name': 'State Patrol: Cordele',
#   'County': 'CRISP',
#   'Latitude': 31.914753,
#   'Longitude': -83.753338,
#   'ORI': 'GAGSP3000',
#   '_id': ObjectId('63336f1d783bd5742f53e452')}]
# [{'Agency Name': 'Colquitt Police Department',
#   'County': 'MILLER',
#   'Latitude': 31.162908,
#   'Longitude': -84.730386,
#   'ORI': 'GA1000100',
#   '_id': ObjectId('63336f1d783bd5742f53e453')}]
# [{'Agency Name': "Clinch County Sheriff's Office",
#   'County': 'CLINCH',
#   'Latitude': 31.039433,
#   'Longitude': -82.749954,
#   'ORI': 'GA0320000',
#   '_id': ObjectId('63336f1d783bd5742f53e454')}]
# [{'Agency Name': 'Adairsville Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.368633,
#   'Longitude': -84.93449,
#   'ORI': 'GA0080200',
#   '_id': ObjectId('63336f1d783bd5742f53e455')}]
# [{'Agency Name': 'College of Coastal Georgia',
#   'County': 'GLYNN',
#   'Latitude': 31.212746,
#   'Longitude': -81.496517,
#   'ORI': 'GA0630300',
#   '_id': ObjectId('63336f1d783bd5742f53e456')}]
# [{'Agency Name': 'Tallulah Falls Police Department',
#   'County': 'RABUN; HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   'ORI': 'GA1190300',
#   '_id': ObjectId('63336f1d783bd5742f53e457')}]
# [{'Agency Name': 'Montezuma Police Department',
#   'County': 'MACON',
#   'Latitude': 32.366216,
#   'Longitude': -84.052162,
#   'ORI': 'GA0960100',
#   '_id': ObjectId('63336f1d783bd5742f53e458')}]
# [{'Agency Name': 'Forest Park Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.60854,
#   'Longitude': -84.37918,
#   'ORI': 'GA0310200',
#   '_id': ObjectId('63336f1d783bd5742f53e459')}]
# [{'Agency Name': "Forsyth County Sheriff's Office",
#   'County': 'FORSYTH',
#   'Latitude': 34.225143,
#   'Longitude': -84.127435,
#   'ORI': 'GA0580000',
#   '_id': ObjectId('63336f1d783bd5742f53e45a')}]
# [{'Agency Name': 'Rome Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.169235,
#   'Longitude': -85.21126,
#   'ORI': 'GA0570200',
#   '_id': ObjectId('63336f1d783bd5742f53e45b')}]
# [{'Agency Name': 'Lithonia Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.710865,
#   'Longitude': -84.10791,
#   'ORI': 'GA0440700',
#   '_id': ObjectId('63336f1d783bd5742f53e45c')}]
# [{'Agency Name': 'Nashville Police Department',
#   'County': 'BERRIEN',
#   'Latitude': 31.274308,
#   'Longitude': -83.231906,
#   'ORI': 'GA0100100',
#   '_id': ObjectId('63336f1d783bd5742f53e45d')}]
# [{'Agency Name': 'South Fulton',
#   'County': 'FULTON',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0607200',
#   '_id': ObjectId('63336f1d783bd5742f53e45e')}]
# [{'Agency Name': 'Monticello Police Department',
#   'County': 'JASPER',
#   'Latitude': 33.318128,
#   'Longitude': -83.689505,
#   'ORI': 'GA0790100',
#   '_id': ObjectId('63336f1d783bd5742f53e45f')}]
# [{'Agency Name': 'Maysville Police Department',
#   'County': 'BANKS; JACKSON',
#   'Latitude': 34.351922,
#   'Longitude': -83.498441,
#   'ORI': 'GA0780300',
#   '_id': ObjectId('63336f1d783bd5742f53e460')}]
# [{'Agency Name': "Tift County Sheriff's Office",
#   'County': 'TIFT',
#   'Latitude': 31.457003,
#   'Longitude': -83.525931,
#   'ORI': 'GA1370000',
#   '_id': ObjectId('63336f1d783bd5742f53e461')}]
# [{'Agency Name': 'Georgia Southwestern State University',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290400',
#   '_id': ObjectId('63336f1d783bd5742f53e462')}]
# [{'Agency Name': "Decatur County Sheriff's Office",
#   'County': 'DECATUR',
#   'Latitude': 30.908264,
#   'Longitude': -84.59721,
#   'ORI': 'GA0430000',
#   '_id': ObjectId('63336f1d783bd5742f53e463')}]
# [{'Agency Name': 'Mount Zion Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.582237,
#   'Longitude': -85.080527,
#   'ORI': 'GA0220700',
#   '_id': ObjectId('63336f1d783bd5742f53e464')}]
# [{'Agency Name': 'Fayette County Marshal',
#   'County': 'FAYETTE',
#   'Latitude': 33.447628,
#   'Longitude': -84.462875,
#   'ORI': 'GA0560400',
#   '_id': ObjectId('63336f1d783bd5742f53e465')}]
# [{'Agency Name': "White County Sheriff's Office",
#   'County': 'WHITE',
#   'Latitude': 34.618458,
#   'Longitude': -83.75649,
#   'ORI': 'GA1540000',
#   '_id': ObjectId('63336f1d783bd5742f53e466')}]
# [{'Agency Name': 'State Patrol: Savannah',
#   'County': 'CHATHAM',
#   'Latitude': 32.361711,
#   'Longitude': -81.343337,
#   'ORI': 'GAGSP4200',
#   '_id': ObjectId('63336f1d783bd5742f53e467')}]
# [{'Agency Name': 'Cedartown Police Department',
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150100',
#   '_id': ObjectId('63336f1d783bd5742f53e468')}]
# [{'Agency Name': 'Palmetto Police Department',
#   'County': 'COWETA; FULTON',
#   'Latitude': 33.790034,
#   'Longitude': -84.468182,
#   'ORI': 'GA0600800',
#   '_id': ObjectId('63336f1d783bd5742f53e469')}]
# [{'Agency Name': "Ben Hill County Sheriff's Office",
#   'County': 'BEN HILL',
#   'Latitude': 31.740775,
#   'Longitude': -83.14719,
#   'ORI': 'GA0090000',
#   '_id': ObjectId('63336f1d783bd5742f53e46a')}]
# [{'Agency Name': "Chattahoochee County Sheriff's Office",
#   'County': 'CHATTAHOOCHEE',
#   'Latitude': 32.347445,
#   'Longitude': -84.788021,
#   'ORI': 'GA0260000',
#   '_id': ObjectId('63336f1d783bd5742f53e46b')}]
# [{'Agency Name': 'Albany Police Department',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470100',
#   '_id': ObjectId('63336f1d783bd5742f53e46c')}]
# [{'Agency Name': 'Boston Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360200',
#   '_id': ObjectId('63336f1d783bd5742f53e46d')}]
# [{'Agency Name': 'Molena Police Department',
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   'ORI': 'GA1140300',
#   '_id': ObjectId('63336f1d783bd5742f53e46e')}]
# [{'Agency Name': 'Dunwoody  Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.770661,
#   'Longitude': -84.226343,
#   'ORI': 'GA0447100',
#   '_id': ObjectId('63336f1d783bd5742f53e46f')}]
# [{'Agency Name': "Rockdale County Sheriff's Office",
#   'County': 'ROCKDALE',
#   'Latitude': 33.685886,
#   'Longitude': -84.05896,
#   'ORI': 'GA1220000',
#   '_id': ObjectId('63336f1d783bd5742f53e470')}]
# [{'Agency Name': 'Louisville Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810100',
#   '_id': ObjectId('63336f1d783bd5742f53e471')}]
# [{'Agency Name': 'Savannah Fire and Emergency Services Arson Unit',
#   'County': 'CHATHAM',
#   'Latitude': 32.08216,
#   'Longitude': -81.09664,
#   'ORI': 'GA0252500',
#   '_id': ObjectId('63336f1d783bd5742f53e472')}]
# [{'Agency Name': 'Garden City Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0250200',
#   '_id': ObjectId('63336f1d783bd5742f53e473')}]
# [{'Agency Name': "Murray County Sheriff's Office",
#   'County': 'MURRAY',
#   'Latitude': 34.78274,
#   'Longitude': -84.785446,
#   'ORI': 'GA1050000',
#   '_id': ObjectId('63336f1d783bd5742f53e474')}]
# [{'Agency Name': 'Calhoun Police Department',
#   'County': 'GORDON',
#   'Latitude': 34.50379,
#   'Longitude': -84.95111,
#   'ORI': 'GA0640100',
#   '_id': ObjectId('63336f1d783bd5742f53e475')}]
# [{'Agency Name': 'Midway Police Department',
#   'County': 'LIBERTY',
#   'Latitude': 31.807296,
#   'Longitude': -81.457864,
#   'ORI': 'GA0890200',
#   '_id': ObjectId('63336f1d783bd5742f53e476')}]
# [{'Agency Name': 'Euharlee Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080700',
#   '_id': ObjectId('63336f1d783bd5742f53e477')}]
# [{'Agency Name': 'Sandy Springs Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.925224,
#   'Longitude': -84.359856,
#   'ORI': 'GA0605600',
#   '_id': ObjectId('63336f1d783bd5742f53e478')}]
# [{'Agency Name': "Haralson County Sheriff's Office",
#   'County': 'HARALSON',
#   'Latitude': 33.795165,
#   'Longitude': -85.220062,
#   'ORI': 'GA0710000',
#   '_id': ObjectId('63336f1d783bd5742f53e479')}]
# [{'Agency Name': 'Screven Police Department',
#   'County': 'WAYNE',
#   'Latitude': 31.547845,
#   'Longitude': -81.912376,
#   'ORI': 'GA1510200',
#   '_id': ObjectId('63336f1d783bd5742f53e47a')}]
# [{'Agency Name': 'Hiawassee Police Department',
#   'County': 'TOWNS',
#   'Latitude': 34.902662,
#   'Longitude': -83.732215,
#   'ORI': 'GA1390100',
#   '_id': ObjectId('63336f1d783bd5742f53e47b')}]
# [{'Agency Name': 'Madison Police Department',
#   'County': 'MORGAN',
#   'Latitude': 33.593732,
#   'Longitude': -83.492324,
#   'ORI': 'GA1040100',
#   '_id': ObjectId('63336f1d783bd5742f53e47c')}]
# [{'Agency Name': 'Monroe Police Department',
#   'County': 'WALTON',
#   'Latitude': 33.782648,
#   'Longitude': -83.734215,
#   'ORI': 'GA1470100',
#   '_id': ObjectId('63336f1d783bd5742f53e47d')}]
# [{'Agency Name': 'Cecil',
#   'County': 'COOK',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0370400',
#   '_id': ObjectId('63336f1d783bd5742f53e47e')}]
# [{'Agency Name': 'Pembroke Police Department',
#   'County': 'BRYAN',
#   'Latitude': 32.017969,
#   'Longitude': -81.438543,
#   'ORI': 'GA0150100',
#   '_id': ObjectId('63336f1d783bd5742f53e47f')}]
# [{'Agency Name': 'State Patrol: Lawrenceville',
#   'County': 'GWINNETT',
#   'Latitude': 33.959099,
#   'Longitude': -84.022949,
#   'ORI': 'GAGSP3700',
#   '_id': ObjectId('63336f1d783bd5742f53e480')}]
# [{'Agency Name': 'Richmond County Marshal',
#   'County': 'RICHMOND',
#   'Latitude': 33.361487,
#   'Longitude': -82.074998,
#   'ORI': 'GA1210700',
#   '_id': ObjectId('63336f1d783bd5742f53e481')}]
# [{'Agency Name': 'Mountain City Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190200',
#   '_id': ObjectId('63336f1d783bd5742f53e482')}]
# [{'Agency Name': 'State Patrol: Donalsonville',
#   'County': 'SEMINOLE',
#   'Latitude': 30.933894,
#   'Longitude': -84.867592,
#   'ORI': 'GAGSP1400',
#   '_id': ObjectId('63336f1d783bd5742f53e483')}]
# [{'Agency Name': 'Greensboro Police Department',
#   'County': 'GREENE',
#   'Latitude': 33.573967,
#   'Longitude': -83.17531,
#   'ORI': 'GA0660100',
#   '_id': ObjectId('63336f1d783bd5742f53e484')}]
# [{'Agency Name': 'Fort Oglethorpe Police Department',
#   'County': 'WALKER; CATOOSA',
#   'Latitude': 34.899393,
#   'Longitude': -85.137353,
#   'ORI': 'GA0230100',
#   '_id': ObjectId('63336f1d783bd5742f53e485')}]
# [{'Agency Name': 'Franklin Police Department',
#   'County': 'HEARD',
#   'Latitude': 33.290968,
#   'Longitude': -85.139594,
#   'ORI': 'GA0740100',
#   '_id': ObjectId('63336f1d783bd5742f53e486')}]
# [{'Agency Name': 'Cumming Police Department',
#   'County': 'FORSYTH',
#   'Latitude': 34.204327,
#   'Longitude': -84.13951,
#   'ORI': 'GA0580100',
#   '_id': ObjectId('63336f1d783bd5742f53e487')}]
# [{'Agency Name': 'Albany Technical College',
#   'County': 'DOUGHERTY',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0471100',
#   '_id': ObjectId('63336f1d783bd5742f53e488')}]
# [{'Agency Name': 'Clayton County Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.541374,
#   'Longitude': -84.34508,
#   'ORI': 'GA0310100',
#   '_id': ObjectId('63336f1d783bd5742f53e489')}]
# [{'Agency Name': "Calhoun County Sheriff's Office",
#   'County': 'CALHOUN',
#   'Latitude': 31.521279,
#   'Longitude': -84.62629,
#   'ORI': 'GA0190000',
#   '_id': ObjectId('63336f1d783bd5742f53e48a')}]
# [{'Agency Name': "Worth County Sheriff's Office",
#   'County': 'WORTH',
#   'Latitude': 31.527578,
#   'Longitude': -83.83554,
#   'ORI': 'GA1590000',
#   '_id': ObjectId('63336f1d783bd5742f53e48b')}]
# [{'Agency Name': 'Lookout Mountain Police Department',
#   'County': 'WALKER',
#   'Latitude': 34.978447,
#   'Longitude': -85.35674,
#   'ORI': 'GA1460300',
#   '_id': ObjectId('63336f1d783bd5742f53e48c')}]
# [{'Agency Name': 'Pendergrass  Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   'ORI': 'GA0780900',
#   '_id': ObjectId('63336f1d783bd5742f53e48d')}]
# [{'Agency Name': "Pulaski County Sheriff's Office",
#   'County': 'PULASKI',
#   'Latitude': 32.238794,
#   'Longitude': -83.481855,
#   'ORI': 'GA1160000',
#   '_id': ObjectId('63336f1d783bd5742f53e48e')}]
# [{'Agency Name': 'Valdosta State University',
#   'County': 'LOWNDES',
#   'Latitude': 30.813684,
#   'Longitude': -83.264366,
#   'ORI': 'GA0920500',
#   '_id': ObjectId('63336f1d783bd5742f53e48f')}]
# [{'Agency Name': 'Cave Spring Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.263677,
#   'Longitude': -85.21373,
#   'ORI': 'GA0570300',
#   '_id': ObjectId('63336f1d783bd5742f53e490')}]
# [{'Agency Name': 'Georgia Institute of Technology',
#   'County': 'FULTON',
#   'Latitude': 33.779533,
#   'Longitude': -84.40235,
#   'ORI': 'GA0601000',
#   '_id': ObjectId('63336f1d783bd5742f53e491')}]
# [{'Agency Name': 'Doraville Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.90096,
#   'Longitude': -84.27897,
#   'ORI': 'GA0440600',
#   '_id': ObjectId('63336f1d783bd5742f53e492')}]
# [{'Agency Name': "Tattnall County Sheriff's Office",
#   'County': 'TATTNALL',
#   'Latitude': 32.043768,
#   'Longitude': -82.059208,
#   'ORI': 'GA1320000',
#   '_id': ObjectId('63336f1d783bd5742f53e493')}]
# [{'Agency Name': 'Gwinnett County Public Schools',
#   'County': 'GWINNETT',
#   'Latitude': 33.959099,
#   'Longitude': -84.022949,
#   'ORI': 'GA0671000',
#   '_id': ObjectId('63336f1d783bd5742f53e494')}]
# [{'Agency Name': 'Temple Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.582237,
#   'Longitude': -85.080527,
#   'ORI': 'GA0220400',
#   '_id': ObjectId('63336f1d783bd5742f53e495')}]
# [{'Agency Name': 'Sylvania Police Department',
#   'County': 'SCREVEN',
#   'Latitude': 32.744751,
#   'Longitude': -81.617585,
#   'ORI': 'GA1240100',
#   '_id': ObjectId('63336f1d783bd5742f53e496')}]
# [{'Agency Name': 'Lakeland Police Department',
#   'County': 'LANIER',
#   'Latitude': 31.038197,
#   'Longitude': -83.063164,
#   'ORI': 'GA0860100',
#   '_id': ObjectId('63336f1d783bd5742f53e497')}]
# [{'Agency Name': 'Bainbridge Police Department',
#   'County': 'DECATUR',
#   'Latitude': 30.878091,
#   'Longitude': -84.577894,
#   'ORI': 'GA0430100',
#   '_id': ObjectId('63336f1d783bd5742f53e498')}]
# [{'Agency Name': 'Irwinton Police Department',
#   'County': 'WILKINSON',
#   'Latitude': 32.804312,
#   'Longitude': -83.175497,
#   'ORI': 'GA1580200',
#   '_id': ObjectId('63336f1d783bd5742f53e499')}]
# [{'Agency Name': 'Rockmart Police Department',
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150200',
#   '_id': ObjectId('63336f1d783bd5742f53e49a')}]
# [{'Agency Name': 'Warm Springs Police Department',
#   'County': 'MERIWETHER',
#   'Latitude': 33.03022,
#   'Longitude': -84.663279,
#   'ORI': 'GA0990500',
#   '_id': ObjectId('63336f1d783bd5742f53e49b')}]
# [{'Agency Name': 'State Patrol: Thomaston',
#   'County': 'UPSON',
#   'Latitude': 32.881837,
#   'Longitude': -84.292281,
#   'ORI': 'GAGSP2600',
#   '_id': ObjectId('63336f1d783bd5742f53e49c')}]
# [{'Agency Name': 'State Patrol: Cartersville',
#   'County': 'BARTOW',
#   'Latitude': 34.204853,
#   'Longitude': -84.81206,
#   'ORI': 'GAGSP0300',
#   '_id': ObjectId('63336f1d783bd5742f53e49d')}]
# [{'Agency Name': "Union County Sheriff's Office",
#   'County': 'UNION',
#   'Latitude': 34.83377,
#   'Longitude': -83.989573,
#   'ORI': 'GA1440000',
#   '_id': ObjectId('63336f1d783bd5742f53e49e')}]
# [{'Agency Name': "Mitchell County Sheriff's Office",
#   'County': 'MITCHELL',
#   'Latitude': 31.228997,
#   'Longitude': -84.192038,
#   'ORI': 'GA1010000',
#   '_id': ObjectId('63336f1d783bd5742f53e49f')}]
# [{'Agency Name': "Dougherty County Sheriff's Office",
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470000',
#   '_id': ObjectId('63336f1d783bd5742f53e4a0')}]
# [{'Agency Name': 'Nelson Police Department',
#   'County': 'CHEROKEE; PICKENS',
#   'Latitude': 34.456625,
#   'Longitude': -84.490263,
#   'ORI': 'GA0280600',
#   '_id': ObjectId('63336f1d783bd5742f53e4a1')}]
# [{'Agency Name': "Baker County Sheriff's Office",
#   'County': 'BAKER',
#   'Latitude': 31.31958,
#   'Longitude': -84.454881,
#   'ORI': 'GA0040000',
#   '_id': ObjectId('63336f1d783bd5742f53e4a2')}]
# [{'Agency Name': 'Gordon State College',
#   'County': 'LAMAR',
#   'Latitude': 33.044018,
#   'Longitude': -84.15348,
#   'ORI': 'GA0850300',
#   '_id': ObjectId('63336f1d783bd5742f53e4a3')}]
# [{'Agency Name': "McDuffie County Sheriff's Office",
#   'County': 'MCDUFFIE',
#   'Latitude': 33.482464,
#   'Longitude': -82.473188,
#   'ORI': 'GA0940000',
#   '_id': ObjectId('63336f1d783bd5742f53e4a4')}]
# [{'Agency Name': 'Newnan Police Department',
#   'County': 'COWETA',
#   'Latitude': 33.352897,
#   'Longitude': -84.762138,
#   'ORI': 'GA0380100',
#   '_id': ObjectId('63336f1d783bd5742f53e4a5')}]
# [{'Agency Name': 'Wesleyan College',
#   'County': 'BIBB',
#   'Latitude': 32.876038,
#   'Longitude': -83.71381,
#   'ORI': 'GA011119E',
#   '_id': ObjectId('63336f1d783bd5742f53e4a6')}]
# [{'Agency Name': "Effingham County Sheriff's Office",
#   'County': 'EFFINGHAM',
#   'Latitude': 32.361711,
#   'Longitude': -81.343337,
#   'ORI': 'GA0510000',
#   '_id': ObjectId('63336f1d783bd5742f53e4a7')}]
# [{'Agency Name': 'Winterville Police Department',
#   'County': 'CLARKE',
#   'Latitude': 33.952185,
#   'Longitude': -83.367152,
#   'ORI': 'GA0290400',
#   '_id': ObjectId('63336f1d783bd5742f53e4a8')}]
# [{'Agency Name': 'Hinesville Police Department',
#   'County': 'LIBERTY',
#   'Latitude': 31.846628,
#   'Longitude': -81.59546,
#   'ORI': 'GA0890100',
#   '_id': ObjectId('63336f1d783bd5742f53e4a9')}]
# [{'Agency Name': 'Bremen Police Department',
#   'County': 'CARROLL; HARALSON',
#   'Latitude': 33.795165,
#   'Longitude': -85.220062,
#   'ORI': 'GA0710100',
#   '_id': ObjectId('63336f1d783bd5742f53e4aa')}]
# [{'Agency Name': 'Vienna Police Department',
#   'County': 'DOOLY',
#   'Latitude': 32.151995,
#   'Longitude': -83.807167,
#   'ORI': 'GA0460100',
#   '_id': ObjectId('63336f1d783bd5742f53e4ab')}]
# [{'Agency Name': "Bulloch County Sheriff's Office",
#   'County': 'BULLOCH',
#   'Latitude': 32.467293,
#   'Longitude': -81.76302,
#   'ORI': 'GA0160000',
#   '_id': ObjectId('63336f1d783bd5742f53e4ac')}]
# [{'Agency Name': "Franklin County Sheriff's Office",
#   'County': 'FRANKLIN',
#   'Latitude': 34.375155,
#   'Longitude': -83.22729,
#   'ORI': 'GA0590000',
#   '_id': ObjectId('63336f1d783bd5742f53e4ad')}]
# [{'Agency Name': "Walton County Sheriff's Office",
#   'County': 'WALTON',
#   'Latitude': 33.77116,
#   'Longitude': -83.700356,
#   'ORI': 'GA1470000',
#   '_id': ObjectId('63336f1d783bd5742f53e4ae')}]
# [{'Agency Name': 'Blythe Police Department',
#   'County': 'BURKE; RICHMOND',
#   'Latitude': 33.300552,
#   'Longitude': -82.20991,
#   'ORI': 'GA1210800',
#   '_id': ObjectId('63336f1d783bd5742f53e4af')}]
# [{'Agency Name': 'Richmond Hill Police Department',
#   'County': 'BRYAN',
#   'Latitude': 32.017969,
#   'Longitude': -81.438543,
#   'ORI': 'GA0150200',
#   '_id': ObjectId('63336f1d783bd5742f53e4b0')}]
# [{'Agency Name': 'State Patrol: Douglas',
#   'County': 'COFFEE',
#   'Latitude': 31.477943,
#   'Longitude': -82.85098,
#   'ORI': 'GAGSP3600',
#   '_id': ObjectId('63336f1d783bd5742f53e4b1')}]
# [{'Agency Name': 'State Patrol: Tifton',
#   'County': 'TIFT',
#   'Latitude': 31.457003,
#   'Longitude': -83.525931,
#   'ORI': 'GAGSP1300',
#   '_id': ObjectId('63336f1d783bd5742f53e4b2')}]
# [{'Agency Name': 'Clayton Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190100',
#   '_id': ObjectId('63336f1d783bd5742f53e4b3')}]
# [{'Agency Name': "Morgan County Sheriff's Office",
#   'County': 'MORGAN',
#   'Latitude': 33.630917,
#   'Longitude': -83.45087,
#   'ORI': 'GA1040000',
#   '_id': ObjectId('63336f1d783bd5742f53e4b4')}]
# [{'Agency Name': "Greene County Sheriff's Office",
#   'County': 'GREENE',
#   'Latitude': 33.57232,
#   'Longitude': -83.19265,
#   'ORI': 'GA0660000',
#   '_id': ObjectId('63336f1d783bd5742f53e4b5')}]
# [{'Agency Name': 'Oconee  Police Department',
#   'County': 'WASHINGTON',
#   'Latitude': 32.857193,
#   'Longitude': -82.95505,
#   'ORI': 'GA1500500',
#   '_id': ObjectId('63336f1d783bd5742f53e4b6')}]
# [{'Agency Name': "Heard County Sheriff's Office",
#   'County': 'HEARD',
#   'Latitude': 33.290968,
#   'Longitude': -85.139594,
#   'ORI': 'GA0740000',
#   '_id': ObjectId('63336f1d783bd5742f53e4b7')}]
# [{'Agency Name': "Clayton County Sheriff's Office",
#   'County': 'CLAYTON',
#   'Latitude': 33.51437,
#   'Longitude': -84.36194,
#   'ORI': 'GA0310000',
#   '_id': ObjectId('63336f1d783bd5742f53e4b8')}]
# [{'Agency Name': 'Uvalda Police Department',
#   'County': 'MONTGOMERY',
#   'Latitude': 32.172108,
#   'Longitude': -82.533349,
#   'ORI': 'GA1030200',
#   '_id': ObjectId('63336f1d783bd5742f53e4b9')}]
# [{'Agency Name': 'Clarkston Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.809055,
#   'Longitude': -84.23962,
#   'ORI': 'GA0440500',
#   '_id': ObjectId('63336f1d783bd5742f53e4ba')}]
# [{'Agency Name': "Catoosa County Sheriff's Office",
#   'County': 'CATOOSA',
#   'Latitude': 34.899393,
#   'Longitude': -85.137353,
#   'ORI': 'GA0230000',
#   '_id': ObjectId('63336f1d783bd5742f53e4bb')}]
# [{'Agency Name': 'Sylvester Police Department',
#   'County': 'WORTH',
#   'Latitude': 31.551773,
#   'Longitude': -83.84996,
#   'ORI': 'GA1590100',
#   '_id': ObjectId('63336f1d783bd5742f53e4bc')}]
# [{'Agency Name': 'Rossville Police Department',
#   'County': 'WALKER',
#   'Latitude': 34.735827,
#   'Longitude': -85.305385,
#   'ORI': 'GA1460200',
#   '_id': ObjectId('63336f1d783bd5742f53e4bd')}]
# [{'Agency Name': 'Whitesburg Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.49634,
#   'Longitude': -84.91557,
#   'ORI': 'GA0220500',
#   '_id': ObjectId('63336f1d783bd5742f53e4be')}]
# [{'Agency Name': 'Morehouse College',
#   'County': 'FULTON',
#   'Latitude': 33.790034,
#   'Longitude': -84.468182,
#   'ORI': 'GA0604400',
#   '_id': ObjectId('63336f1d783bd5742f53e4bf')}]
# [{'Agency Name': 'Attapulgus Police Department',
#   'County': 'DECATUR',
#   'Latitude': 30.878091,
#   'Longitude': -84.577894,
#   'ORI': 'GA0430200',
#   '_id': ObjectId('63336f1d783bd5742f53e4c0')}]
# [{'Agency Name': 'Jackson Police Department',
#   'County': 'BUTTS',
#   'Latitude': 33.290355,
#   'Longitude': -83.958221,
#   'ORI': 'GA0180100',
#   '_id': ObjectId('63336f1d783bd5742f53e4c1')}]
# [{'Agency Name': 'Lanier County Board of Education',
#   'County': 'LANIER',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0860200',
#   '_id': ObjectId('63336f1d783bd5742f53e4c2')}]
# [{'Agency Name': 'McIntyre Police Department',
#   'County': 'WILKINSON',
#   'Latitude': 32.804312,
#   'Longitude': -83.175497,
#   'ORI': 'GA1580300',
#   '_id': ObjectId('63336f1d783bd5742f53e4c3')}]
# [{'Agency Name': 'Polk County Police Department',
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150300',
#   '_id': ObjectId('63336f1d783bd5742f53e4c4')}]
# [{'Agency Name': "Laurens County Sheriff's Office",
#   'County': 'LAURENS',
#   'Latitude': 32.49778,
#   'Longitude': -82.921265,
#   'ORI': 'GA0870000',
#   '_id': ObjectId('63336f1d783bd5742f53e4c5')}]
# [{'Agency Name': 'State Patrol: Metropolitan Traffic Unit, Atlanta',
#   'County': 'DEKALB',
#   'Latitude': 33.77505,
#   'Longitude': -84.520905,
#   'ORI': 'GAGSP4800',
#   '_id': ObjectId('63336f1d783bd5742f53e4c6')}]
# [{'Agency Name': 'State Patrol: La Grange',
#   'County': 'TROUP',
#   'Latitude': 32.98718,
#   'Longitude': -85.0013,
#   'ORI': 'GAGSP0200',
#   '_id': ObjectId('63336f1d783bd5742f53e4c7')}]
# [{'Agency Name': 'State Patrol: Thomson',
#   'County': 'MCDUFFIE',
#   'Latitude': 33.488678,
#   'Longitude': -82.21785,
#   'ORI': 'GAGSP2500',
#   '_id': ObjectId('63336f1d783bd5742f53e4c8')}]
# [{'Agency Name': "Rabun County Sheriff's Office",
#   'County': 'RABUN',
#   'Latitude': 34.87886,
#   'Longitude': -83.40285,
#   'ORI': 'GA1190000',
#   '_id': ObjectId('63336f1d783bd5742f53e4c9')}]
# [{'Agency Name': 'Sardis Police Department',
#   'County': 'BURKE',
#   'Latitude': 33.050819,
#   'Longitude': -82.011571,
#   'ORI': 'GA0170300',
#   '_id': ObjectId('63336f1d783bd5742f53e4ca')}]
# [{'Agency Name': 'Camilla Police Department',
#   'County': 'MITCHELL',
#   'Latitude': 31.231115,
#   'Longitude': -84.21176,
#   'ORI': 'GA1010100',
#   '_id': ObjectId('63336f1d783bd5742f53e4cb')}]
# [{'Agency Name': 'Cherokee County Board of Education',
#   'County': 'CHEROKEE',
#   'Latitude': 34.236027,
#   'Longitude': -84.49235,
#   'ORI': 'GA0280700',
#   '_id': ObjectId('63336f1d783bd5742f53e4cc')}]
# [{'Agency Name': 'Alma Police Department',
#   'County': 'BACON',
#   'Latitude': 31.563327,
#   'Longitude': -82.387859,
#   'ORI': 'GA0030100',
#   '_id': ObjectId('63336f1d783bd5742f53e4cd')}]
# [{'Agency Name': 'Metropolitan Atlanta Rapid Transit Authority',
#   'County': 'FULTON',
#   'Latitude': 33.821636,
#   'Longitude': -84.367455,
#   'ORI': 'GA0602100',
#   '_id': ObjectId('63336f1d783bd5742f53e4ce')}]
# [{'Agency Name': "Coweta County Sheriff's Office",
#   'County': 'COWETA',
#   'Latitude': 33.382137,
#   'Longitude': -84.78246,
#   'ORI': 'GA0380000',
#   '_id': ObjectId('63336f1d783bd5742f53e4cf')}]
# [{'Agency Name': 'Blairsville Police Department',
#   'County': 'UNION',
#   'Latitude': 34.83377,
#   'Longitude': -83.989573,
#   'ORI': 'GA1440100',
#   '_id': ObjectId('63336f1d783bd5742f53e4d0')}]
# [{'Agency Name': "Wayne County Sheriff's Office",
#   'County': 'WAYNE',
#   'Latitude': 31.604576,
#   'Longitude': -81.87975,
#   'ORI': 'GA1510000',
#   '_id': ObjectId('63336f1d783bd5742f53e4d1')}]
# [{'Agency Name': 'Twiggs County Board of Education',
#   'County': 'TWIGGS',
#   'Latitude': 32.68013,
#   'Longitude': -83.333824,
#   'ORI': 'GA1430400',
#   '_id': ObjectId('63336f1d783bd5742f53e4d2')}]
# [{'Agency Name': 'Statesboro Police Department',
#   'County': 'BULLOCH',
#   'Latitude': 32.445255,
#   'Longitude': -81.7862,
#   'ORI': 'GA0160100',
#   '_id': ObjectId('63336f1d783bd5742f53e4d3')}]
# [{'Agency Name': 'Glynn County School System',
#   'County': 'GLYNN',
#   'Latitude': 31.212746,
#   'Longitude': -81.496517,
#   'ORI': 'GA0630600',
#   '_id': ObjectId('63336f1d783bd5742f53e4d4')}]
# [{'Agency Name': "Dooly County Sheriff's Office",
#   'County': 'DOOLY',
#   'Latitude': 32.151995,
#   'Longitude': -83.807167,
# ...
#   'County': 'FANNIN',
#   'Latitude': 34.864494,
#   'Longitude': -84.32744,
#   'ORI': 'GA0550000',
#   '_id': ObjectId('63336f1e783bd5742f53e61a')}]
# [{'Agency Name': "Thomas County Sheriff's Office",
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360000',
#   '_id': ObjectId('63336f1e783bd5742f53e61b')}]
# [{'Agency Name': 'Toccoa Police Department',
#   'County': 'STEPHENS',
#   'Latitude': 34.552914,
#   'Longitude': -83.290216,
#   'ORI': 'GA1270100',
#   '_id': ObjectId('63336f1e783bd5742f53e61c')}]
# [{'Agency Name': 'Broxton Police Department',
#   'County': 'COFFEE',
#   'Latitude': 31.549245,
#   'Longitude': -82.844938,
#   'ORI': 'GA0340300',
#   '_id': ObjectId('63336f1e783bd5742f53e61d')}]
# [{'Agency Name': "Marion County Sheriff's Office",
#   'County': 'MARION',
#   'Latitude': 32.359538,
#   'Longitude': -84.529561,
#   'ORI': 'GA0980000',
#   '_id': ObjectId('63336f1e783bd5742f53e61e')}]
# [{'Agency Name': 'Wrens Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810300',
#   '_id': ObjectId('63336f1e783bd5742f53e61f')}]
# [{'Agency Name': "Bartow County Sheriff's Office",
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080000',
#   '_id': ObjectId('63336f1e783bd5742f53e620')}]
# [{'Agency Name': 'Pooler Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 32.115654,
#   'Longitude': -81.24752,
#   'ORI': 'GA0250400',
#   '_id': ObjectId('63336f1e783bd5742f53e621')}]
# [{'Agency Name': "Treutlen County Sheriff's Office",
#   'County': 'TREUTLEN',
#   'Latitude': 32.409586,
#   'Longitude': -82.570882,
#   'ORI': 'GA1400000',
#   '_id': ObjectId('63336f1e783bd5742f53e622')}]
# [{'Agency Name': 'Mount Airy Police Department',
#   'County': 'HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   'ORI': 'GA0680400',
#   '_id': ObjectId('63336f1e783bd5742f53e623')}]
# [{'Agency Name': 'Abbeville Police Department',
#   'County': 'WILCOX',
#   'Latitude': 31.990778,
#   'Longitude': -83.30794,
#   'ORI': 'GA1560100',
#   '_id': ObjectId('63336f1e783bd5742f53e624')}]
# [{'Agency Name': 'Blackshear Police Department',
#   'County': 'PIERCE',
#   'Latitude': 31.353988,
#   'Longitude': -82.210427,
#   'ORI': 'GA1130100',
#   '_id': ObjectId('63336f1e783bd5742f53e625')}]
# [{'Agency Name': 'Bibb County Board of Education',
#   'County': 'BIBB',
#   'Latitude': 32.841473,
#   'Longitude': -83.660034,
#   'ORI': 'GA0110400',
#   '_id': ObjectId('63336f1e783bd5742f53e626')}]
# [{'Agency Name': 'Centerville Police Department',
#   'County': 'HOUSTON',
#   'Latitude': 32.630127,
#   'Longitude': -83.68969,
#   'ORI': 'GA0760300',
#   '_id': ObjectId('63336f1e783bd5742f53e627')}]
# [{'Agency Name': 'Thunderbolt Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 32.031807,
#   'Longitude': -81.050545,
#   'ORI': 'GA0250700',
#   '_id': ObjectId('63336f1e783bd5742f53e628')}]
# [{'Agency Name': 'Marietta Police Department',
#   'County': 'COBB',
#   'Latitude': 33.95526,
#   'Longitude': -84.54541,
#   'ORI': 'GA0330300',
#   '_id': ObjectId('63336f1e783bd5742f53e629')}]
# [{'Agency Name': "Cherokee County Sheriff's Office",
#   'County': 'CHEROKEE',
#   'Latitude': 34.196648,
#   'Longitude': -84.49234,
#   'ORI': 'GA0280000',
#   '_id': ObjectId('63336f1e783bd5742f53e62a')}]
# [{'Agency Name': 'Cohutta Police Department',
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   'ORI': 'GA1550300',
#   '_id': ObjectId('63336f1e783bd5742f53e62b')}]
# [{'Agency Name': 'Oak Park Police Department',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   'ORI': 'GA0530600',
#   '_id': ObjectId('63336f1e783bd5742f53e62c')}]
# [{'Agency Name': 'Mercer University',
#   'County': 'BIBB',
#   'Latitude': 32.82903,
#   'Longitude': -83.648766,
#   'ORI': 'GA011099E',
#   '_id': ObjectId('63336f1e783bd5742f53e62d')}]
# [{'Agency Name': 'Wrightsville Police Department',
#   'County': 'JOHNSON',
#   'Latitude': 32.72852,
#   'Longitude': -82.731895,
#   'ORI': 'GA0830100',
#   '_id': ObjectId('63336f1e783bd5742f53e62e')}]
# [{'Agency Name': 'Blakely Police Department',
#   'County': 'EARLY',
#   'Latitude': 31.324191,
#   'Longitude': -84.906723,
#   'ORI': 'GA0490100',
#   '_id': ObjectId('63336f1e783bd5742f53e62f')}]
# [{'Agency Name': 'Pickens County Board of Education',
#   'County': 'PICKENS',
#   'Latitude': 34.456625,
#   'Longitude': -84.490263,
#   'ORI': 'GA1120300',
#   '_id': ObjectId('63336f1e783bd5742f53e630')}]
# [{'Agency Name': 'Henry County Police Department',
#   'County': 'HENRY',
#   'Latitude': 33.452881,
#   'Longitude': -84.15444,
#   'ORI': 'GA0750500',
#   '_id': ObjectId('63336f1e783bd5742f53e631')}]
# [{'Agency Name': 'Cordele Police Department',
#   'County': 'CRISP',
#   'Latitude': 31.973846,
#   'Longitude': -83.782745,
#   'ORI': 'GA0400100',
#   '_id': ObjectId('63336f1e783bd5742f53e632')}]
# [{'Agency Name': "Glascock County Sheriff's Office",
#   'County': 'GLASCOCK',
#   'Latitude': 33.227491,
#   'Longitude': -82.606913,
#   'ORI': 'GA0620000',
#   '_id': ObjectId('63336f1e783bd5742f53e633')}]
# [{'Agency Name': 'Trion Police Department',
#   'County': 'CHATTOOGA',
#   'Latitude': 34.54347,
#   'Longitude': -85.312996,
#   'ORI': 'GA0270200',
#   '_id': ObjectId('63336f1e783bd5742f53e634')}]
# [{'Agency Name': 'Covington Police Department',
#   'County': 'NEWTON',
#   'Latitude': 33.595737,
#   'Longitude': -83.857635,
#   'ORI': 'GA1070100',
#   '_id': ObjectId('63336f1e783bd5742f53e635')}]
# [{'Agency Name': 'Georgia Military College',
#   'County': 'BALDWIN',
#   'Latitude': 33.08015,
#   'Longitude': -83.22491,
#   'ORI': 'GA0050400',
#   '_id': ObjectId('63336f1e783bd5742f53e636')}]
# [{'Agency Name': 'Roswell Police Department',
#   'County': 'FULTON',
#   'Latitude': 34.021626,
#   'Longitude': -84.35973,
#   'ORI': 'GA0600500',
#   '_id': ObjectId('63336f1e783bd5742f53e637')}]
# [{'Agency Name': 'Hogansville Police Department',
#   'County': 'TROUP',
#   'Latitude': 33.17311,
#   'Longitude': -84.920135,
#   'ORI': 'GA1410100',
#   '_id': ObjectId('63336f1e783bd5742f53e638')}]
# [{'Agency Name': 'Richland Police Department',
#   'County': 'STEWART',
#   'Latitude': 32.073225,
#   'Longitude': -84.834912,
#   'ORI': 'GA1280200',
#   '_id': ObjectId('63336f1e783bd5742f53e639')}]
# [{'Agency Name': 'State Patrol: Marietta',
#   'County': 'COBB',
#   'Latitude': 33.93994,
#   'Longitude': -84.574166,
#   'ORI': 'GAGSP0900',
#   '_id': ObjectId('63336f1e783bd5742f53e63a')}]
# [{'Agency Name': 'McCaysville Police Department',
#   'County': 'FANNIN',
#   'Latitude': 34.866497,
#   'Longitude': -84.31744,
#   'ORI': 'GA0550100',
#   '_id': ObjectId('63336f1e783bd5742f53e63b')}]
# [{'Agency Name': 'Buena Vista Police Department',
#   'County': 'MARION',
#   'Latitude': 32.359538,
#   'Longitude': -84.529561,
#   'ORI': 'GA0980100',
#   '_id': ObjectId('63336f1e783bd5742f53e63c')}]
# [{'Agency Name': 'Albany-Dougherty Metropolitan Drug Squad',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470600',
#   '_id': ObjectId('63336f1e783bd5742f53e63d')}]
# [{'Agency Name': 'Suwanee Police Department',
#   'County': 'GWINNETT',
#   'Latitude': 33.959099,
#   'Longitude': -84.022949,
#   'ORI': 'GA0670900',
#   '_id': ObjectId('63336f1e783bd5742f53e63e')}]
# [{'Agency Name': "Coffee County Sheriff's Office",
#   'County': 'COFFEE',
#   'Latitude': 31.549245,
#   'Longitude': -82.844938,
#   'ORI': 'GA0340000',
#   '_id': ObjectId('63336f1e783bd5742f53e63f')}]
# [{'Agency Name': "Irwin County Sheriff's Office",
#   'County': 'IRWIN',
#   'Latitude': 31.591131,
#   'Longitude': -83.25055,
#   'ORI': 'GA0770000',
#   '_id': ObjectId('63336f1e783bd5742f53e640')}]
# [{'Agency Name': 'Cochran Police Department',
#   'County': 'BLECKLEY',
#   'Latitude': 32.386444,
#   'Longitude': -83.35458,
#   'ORI': 'GA0120100',
#   '_id': ObjectId('63336f1e783bd5742f53e641')}]
# [{'Agency Name': "Wilcox County Sheriff's Office",
#   'County': 'WILCOX',
#   'Latitude': 31.962717,
#   'Longitude': -83.438262,
#   'ORI': 'GA1560000',
#   '_id': ObjectId('63336f1e783bd5742f53e642')}]
# [{'Agency Name': 'Augusta Technical College',
#   'County': 'RICHMOND',
#   'Latitude': 33.419178,
#   'Longitude': -82.051254,
#   'ORI': 'GA1212100',
#   '_id': ObjectId('63336f1e783bd5742f53e643')}]
# [{'Agency Name': 'Georgia World Congress',
#   'County': 'FULTON',
#   'Latitude': 33.759632,
#   'Longitude': -84.382416,
#   'ORI': 'GA0603800',
#   '_id': ObjectId('63336f1e783bd5742f53e644')}]
# [{'Agency Name': "Pierce County Sheriff's Office",
#   'County': 'PIERCE',
#   'Latitude': 31.302244,
#   'Longitude': -82.23383,
#   'ORI': 'GA1130000',
#   '_id': ObjectId('63336f1e783bd5742f53e645')}]
# [{'Agency Name': 'Andrew College ',
#   'County': 'RANDOLPH',
#   'Latitude': 31.771894,
#   'Longitude': -84.79704,
#   'ORI': 'GA120059E',
#   '_id': ObjectId('63336f1e783bd5742f53e646')}]
# [{'Agency Name': 'Danielsville Police Department',
#   'County': 'MADISON',
#   'Latitude': 34.128484,
#   'Longitude': -83.203644,
#   'ORI': 'GA0970300',
#   '_id': ObjectId('63336f1e783bd5742f53e647')}]
# [{'Agency Name': "Dade County Sheriff's Office",
#   'County': 'DADE',
#   'Latitude': 34.852424,
#   'Longitude': -85.506201,
#   'ORI': 'GA0410000',
#   '_id': ObjectId('63336f1e783bd5742f53e648')}]
# [{'Agency Name': "Barrow County Sheriff's Office",
#   'County': 'BARROW',
#   'Latitude': 33.992009,
#   'Longitude': -83.712303,
#   'ORI': 'GA0070000',
#   '_id': ObjectId('63336f1e783bd5742f53e649')}]
# [{'Agency Name': "Jones County Sheriff's Office",
#   'County': 'JONES',
#   'Latitude': 33.020226,
#   'Longitude': -83.562339,
#   'ORI': 'GA0840000',
#   '_id': ObjectId('63336f1e783bd5742f53e64a')}]
# [{'Agency Name': 'Cobb County Police Department',
#   'County': 'COBB',
#   'Latitude': 33.958862,
#   'Longitude': -84.54633,
#   'ORI': 'GA0330200',
#   '_id': ObjectId('63336f1e783bd5742f53e64b')}]
# [{'Agency Name': 'McRae Police Department',
#   'County': 'WHEELER; TELFAIR',
#   'Latitude': 31.913639,
#   'Longitude': -82.931062,
#   'ORI': 'GA1340100',
#   '_id': ObjectId('63336f1e783bd5742f53e64c')}]
# [{'Agency Name': 'Snellville Police Department',
#   'County': 'GWINNETT',
#   'Latitude': 33.83367,
#   'Longitude': -84.00958,
#   'ORI': 'GA0670800',
#   '_id': ObjectId('63336f1e783bd5742f53e64d')}]
# [{'Agency Name': 'Warner Robins Police Department',
#   'County': 'PEACH; HOUSTON',
#   'Latitude': 32.458381,
#   'Longitude': -83.662856,
#   'ORI': 'GA0760200',
#   '_id': ObjectId('63336f1e783bd5742f53e64e')}]
# [{'Agency Name': 'Canton Police Department',
#   'County': 'CHEROKEE',
#   'Latitude': 34.23541,
#   'Longitude': -84.490005,
#   'ORI': 'GA0280100',
#   '_id': ObjectId('63336f1e783bd5742f53e64f')}]
# [{'Agency Name': 'State Patrol: Swainsboro',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   'ORI': 'GAGSP1900',
#   '_id': ObjectId('63336f1e783bd5742f53e650')}]
# [{'Agency Name': "Randolph County Sheriff's Office",
#   'County': 'RANDOLPH',
#   'Latitude': 31.762651,
#   'Longitude': -84.752311,
#   'ORI': 'GA1200000',
#   '_id': ObjectId('63336f1e783bd5742f53e651')}]
# [{'Agency Name': 'Stillmore Police Department',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   'ORI': 'GA0530500',
#   '_id': ObjectId('63336f1e783bd5742f53e652')}]
# [{'Agency Name': 'Tunnel Hill Police Department',
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   'ORI': 'GA1550200',
#   '_id': ObjectId('63336f1e783bd5742f53e653')}]
# [{'Agency Name': 'Adrian Police Department',
#   'County': 'EMANUEL; JOHNSON',
#   'Latitude': 32.689831,
#   'Longitude': -82.661354,
#   'ORI': 'GA0830200',
#   '_id': ObjectId('63336f1e783bd5742f53e654')}]
# [{'Agency Name': 'East Ellijay Police Department',
#   'County': 'GILMER',
#   'Latitude': 34.690541,
#   'Longitude': -84.453984,
#   'ORI': 'GA0610300',
#   '_id': ObjectId('63336f1e783bd5742f53e655')}]
# [{'Agency Name': 'Locust Grove Police Department',
#   'County': 'HENRY',
#   'Latitude': 33.452881,
#   'Longitude': -84.15444,
#   'ORI': 'GA0750400',
#   '_id': ObjectId('63336f1e783bd5742f53e656')}]
# [{'Agency Name': 'Lake City Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.60693,
#   'Longitude': -84.34333,
#   'ORI': 'GA0310600',
#   '_id': ObjectId('63336f1e783bd5742f53e657')}]
# [{'Agency Name': "Sumter County Sheriff's Office",
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290000',
#   '_id': ObjectId('63336f1e783bd5742f53e658')}]
# [{'Agency Name': "Newton County Sheriff's Office",
#   'County': 'NEWTON',
#   'Latitude': 33.544065,
#   'Longitude': -83.855192,
#   'ORI': 'GA1070000',
#   '_id': ObjectId('63336f1e783bd5742f53e659')}]
# [{'Agency Name': 'Georgia College and State University',
#   'County': 'BALDWIN',
#   'Latitude': 33.059504,
#   'Longitude': -83.255452,
#   'ORI': 'GA0050300',
#   '_id': ObjectId('63336f1e783bd5742f53e65a')}]
# [{'Agency Name': "Fayette County Sheriff's Office",
#   'County': 'FAYETTE',
#   'Latitude': 33.446476,
#   'Longitude': -84.45227,
#   'ORI': 'GA0560000',
#   '_id': ObjectId('63336f1e783bd5742f53e65b')}]
# [{'Agency Name': "Meriwether County Sheriff's Office",
#   'County': 'MERIWETHER',
#   'Latitude': 33.03022,
#   'Longitude': -84.663279,
#   'ORI': 'GA0990000',
#   '_id': ObjectId('63336f1e783bd5742f53e65c')}]
# [{'Agency Name': 'Fulton County Marshal',
#   'County': 'FULTON',
#   'Latitude': 33.752655,
#   'Longitude': -84.38997,
#   'ORI': 'GA0602700',
#   '_id': ObjectId('63336f1e783bd5742f53e65d')}]
# [{'Agency Name': 'Alpharetta Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.790034,
#   'Longitude': -84.468182,
#   'ORI': 'GA0600400',
#   '_id': ObjectId('63336f1e783bd5742f53e65e')}]
# [{'Agency Name': 'Lumpkin Police Department',
#   'County': 'STEWART',
#   'Latitude': 32.073225,
#   'Longitude': -84.834912,
#   'ORI': 'GA1280100',
#   '_id': ObjectId('63336f1e783bd5742f53e65f')}]
# [{'Agency Name': "Troup County Sheriff's Office",
#   'County': 'TROUP',
#   'Latitude': 32.989746,
#   'Longitude': -85.00395,
#   'ORI': 'GA1410000',
#   '_id': ObjectId('63336f1e783bd5742f53e660')}]
# [{'Agency Name': 'Oakwood Police Department',
#   'County': 'HALL',
#   'Latitude': 34.317588,
#   'Longitude': -83.818497,
#   'ORI': 'GA0690400',
#   '_id': ObjectId('63336f1e783bd5742f53e661')}]
# [{'Agency Name': "Brantley County Sheriff's Office",
#   'County': 'BRANTLEY',
#   'Latitude': 31.197334,
#   'Longitude': -81.982978,
#   'ORI': 'GA0130000',
#   '_id': ObjectId('63336f1e783bd5742f53e662')}]
# [{'Agency Name': 'State Patrol: Madison',
#   'County': 'MORGAN',
#   'Latitude': 33.593732,
#   'Longitude': -83.492324,
#   'ORI': 'GAGSP0800',
#   '_id': ObjectId('63336f1e783bd5742f53e663')}]
# [{'Agency Name': 'Douglas Police Department',
#   'County': 'COFFEE',
#   'Latitude': 31.511168,
#   'Longitude': -82.852135,
#   'ORI': 'GA0340100',
#   '_id': ObjectId('63336f1e783bd5742f53e664')}]
# [{'Agency Name': 'Dougherty County Board of Education',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470500',
#   '_id': ObjectId('63336f1e783bd5742f53e665')}]
# [{'Agency Name': "Terrell County Sheriff's Office",
#   'County': 'TERRELL',
#   'Latitude': 31.777191,
#   'Longitude': -84.439446,
#   'ORI': 'GA1350000',
#   '_id': ObjectId('63336f1e783bd5742f53e666')}]
# [{'Agency Name': 'Tybee Island Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0250600',
#   '_id': ObjectId('63336f1e783bd5742f53e667')}]
# [{'Agency Name': "Lincoln County Sheriff's Office",
#   'County': 'LINCOLN',
#   'Latitude': 33.792151,
#   'Longitude': -82.448299,
#   'ORI': 'GA0900000',
#   '_id': ObjectId('63336f1e783bd5742f53e668')}]
# [{'Agency Name': 'Blue Ridge Police Department',
#   'County': 'FANNIN',
#   'Latitude': 34.866226,
#   'Longitude': -84.32594,
#   'ORI': 'GA0550200',
#   '_id': ObjectId('63336f1e783bd5742f53e669')}]
# [{'Agency Name': 'Ocilla Police Department',
#   'County': 'IRWIN',
#   'Latitude': 31.591131,
#   'Longitude': -83.25055,
#   'ORI': 'GA0770100',
#   '_id': ObjectId('63336f1e783bd5742f53e66a')}]
# [{'Agency Name': 'Stapleton Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810500',
#   '_id': ObjectId('63336f1e783bd5742f53e66b')}]
# [{'Agency Name': 'Middle Georgia State University',
#   'County': 'BLECKLEY',
#   'Latitude': 32.435403,
#   'Longitude': -83.331717,
#   'ORI': 'GA0120200',
#   '_id': ObjectId('63336f1e783bd5742f53e66c')}]
