# %% [markdown]
# # Prep SQL for Flask Routes

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
#db initializations
engine = create_engine(f'postgresql://postgres:password@localhost/GACRIME')
connection = engine.connect()

# %% [markdown]
# ### SQL for offenses.json

# %%
sql = """
    SELECT
        agc.agencyid, agency_name, offense, cnty.countyid, cnty.county_name, actual, percapita_income, offn.data_year "year"
    FROM
        "Agency" agc
        inner join "CountyAgency" cntyagc on agc.agencyid = cntyagc.agencyid
        inner join "County" cnty on cntyagc.countyid = cnty.countyid
        inner join "Income" inc on cnty.countyid = inc.countyid
        inner join "Offense" offn on agc.ori = offn.ori
     WHERE
        offn.data_year = inc.data_year
    ORDER BY
        agc.agencyid, countyid, offense, offn.data_year
"""

# %%
offenses_df = pd.read_sql(sql, connection)

# %%
offenses_resultlist = []

for index, row in offenses_df.iterrows():
    
    resultdict = {}
    resultdict["agencyid"] = row.agencyid
    resultdict["agency_name"] = row.agency_name
    resultdict["offense"] = row.offense
    resultdict["countyid"] = row.countyid
    resultdict["county_name"] = row.county_name
    resultdict["actual"] = row.actual
    resultdict["percapita_income"] = row.percapita_income
    resultdict["year"] = row.year
    
    offenses_resultlist.append(resultdict)
    
offenses_resultlist
# Out:
# [{'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 4,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 2,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 1,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'arson',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'arson',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'arson',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'arson',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'burglary',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 6,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'burglary',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 1,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'burglary',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 3,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'burglary',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'homicide',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'homicide',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'homicide',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'homicide',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'larceny',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 3,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'larceny',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 7,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'larceny',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'larceny',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 1,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 2,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'property-crime',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 9,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'property-crime',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 8,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'property-crime',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 3,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'property-crime',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 3,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'rape',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'rape',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'rape',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'rape',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'robbery',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'robbery',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'robbery',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'robbery',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'violent-crime',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 4,
#   'percapita_income': 27059,
#   'year': 2017},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'violent-crime',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 0,
#   'percapita_income': 26687,
#   'year': 2018},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'violent-crime',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 2,
#   'percapita_income': 28621,
#   'year': 2019},
#  {'agencyid': 1,
#   'agency_name': 'Abbeville Police Department',
#   'offense': 'violent-crime',
#   'countyid': 190,
#   'county_name': 'WILCOX',
#   'actual': 1,
#   'percapita_income': 29895,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'aggravated-assault',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'aggravated-assault',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'aggravated-assault',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'aggravated-assault',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'arson',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'arson',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'arson',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'arson',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'burglary',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'burglary',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'burglary',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 2,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'burglary',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'homicide',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'homicide',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'homicide',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'homicide',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'human-trafficing',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'human-trafficing',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'human-trafficing',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'human-trafficing',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'larceny',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 32,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'larceny',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 12,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'larceny',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 10,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'larceny',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 17,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 1,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'property-crime',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 32,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'property-crime',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 13,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'property-crime',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 12,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'property-crime',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 17,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'rape',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'rape',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 1,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'rape',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 2,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'rape',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 1,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'rape-legacy',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'rape-legacy',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'rape-legacy',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 1,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'rape-legacy',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 1,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'robbery',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'robbery',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'robbery',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'robbery',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'violent-crime',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 0,
#   'percapita_income': 35800,
#   'year': 2017},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'violent-crime',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 1,
#   'percapita_income': 37273,
#   'year': 2018},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'violent-crime',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 2,
#   'percapita_income': 38346,
#   'year': 2019},
#  {'agencyid': 2,
#   'agency_name': 'Abraham Baldwin Agricultural College',
#   'offense': 'violent-crime',
#   'countyid': 171,
#   'county_name': 'TIFT',
#   'actual': 1,
#   'percapita_income': 42279,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 27,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 14,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 14,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 37,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'arson',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'arson',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'arson',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'arson',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'burglary',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 43,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'burglary',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 33,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'burglary',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 26,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'burglary',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 19,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'homicide',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'homicide',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 1,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'homicide',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'homicide',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 1,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'larceny',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 513,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'larceny',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 449,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'larceny',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 447,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'larceny',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 282,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 23,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 21,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 14,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 15,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'property-crime',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 579,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'property-crime',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 503,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'property-crime',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 487,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'property-crime',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 316,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'rape',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 7,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'rape',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 5,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'rape',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 3,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'rape',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 2,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 0,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 1,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 1,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'robbery',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 6,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'robbery',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 4,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'robbery',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 1,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'robbery',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 3,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'violent-crime',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 40,
#   'percapita_income': 55448,
#   'year': 2017},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'violent-crime',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 24,
#   'percapita_income': 57762,
#   'year': 2018},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'violent-crime',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 18,
#   'percapita_income': 60383,
#   'year': 2019},
#  {'agencyid': 3,
#   'agency_name': 'Acworth Police Department',
#   'offense': 'violent-crime',
#   'countyid': 46,
#   'county_name': 'COBB',
#   'actual': 43,
#   'percapita_income': 63214,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 4,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 5,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 6,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 8,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'arson',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'arson',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'arson',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'arson',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 1,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'burglary',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 14,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'burglary',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 17,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'burglary',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 15,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'burglary',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 3,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'homicide',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'homicide',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'homicide',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'homicide',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'larceny',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 100,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'larceny',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 76,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'larceny',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 59,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'larceny',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 60,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 17,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 16,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 9,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 3,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'property-crime',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 131,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'property-crime',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 109,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'property-crime',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 83,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'property-crime',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 66,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'rape',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 1,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'rape',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 1,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'rape',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 2,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'rape',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 2,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 1,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'robbery',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 1,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'robbery',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 2,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'robbery',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'robbery',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 0,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'violent-crime',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 6,
#   'percapita_income': 37028,
#   'year': 2017},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'violent-crime',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 8,
#   'percapita_income': 38310,
#   'year': 2018},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'violent-crime',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 8,
#   'percapita_income': 39755,
#   'year': 2019},
#  {'agencyid': 4,
#   'agency_name': 'Adairsville Police Department',
#   'offense': 'violent-crime',
#   'countyid': 12,
#   'county_name': 'BARTOW',
#   'actual': 10,
#   'percapita_income': 42734,
#   'year': 2020},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 16,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'aggravated-assault',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 4,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'arson',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'arson',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'arson',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'burglary',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 70,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'burglary',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'burglary',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 16,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'homicide',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 1,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'homicide',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'homicide',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'human-trafficing',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'larceny',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 281,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'larceny',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'larceny',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 57,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 12,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 2,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'property-crime',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 363,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'property-crime',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'property-crime',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 75,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'rape',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 2,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'rape',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'rape',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'robbery',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 14,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'robbery',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'robbery',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 1,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'violent-crime',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 33,
#   'percapita_income': 30891,
#   'year': 2017},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'violent-crime',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 0,
#   'percapita_income': 32303,
#   'year': 2018},
#  {'agencyid': 5,
#   'agency_name': 'Adel Police Department',
#   'offense': 'violent-crime',
#   'countyid': 52,
#   'county_name': 'COOK',
#   'actual': 5,
#   'percapita_income': 33589,
#   'year': 2019},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'aggravated-assault',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 0,
#   'percapita_income': 48914,
#   'year': 2017},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'aggravated-assault',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 0,
#   'percapita_income': 51310,
#   'year': 2018},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'aggravated-assault',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 0,
#   'percapita_income': 52950,
#   'year': 2019},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'aggravated-assault',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 0,
#   'percapita_income': 56428,
#   'year': 2020},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'arson',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 0,
#   'percapita_income': 48914,
#   'year': 2017},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'arson',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 0,
#   'percapita_income': 51310,
#   'year': 2018},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'arson',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 0,
#   'percapita_income': 52950,
#   'year': 2019},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'arson',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 0,
#   'percapita_income': 56428,
#   'year': 2020},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'burglary',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 4,
#   'percapita_income': 48914,
#   'year': 2017},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'burglary',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 1,
#   'percapita_income': 51310,
#   'year': 2018},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'burglary',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 1,
#   'percapita_income': 52950,
#   'year': 2019},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'burglary',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 4,
#   'percapita_income': 56428,
#   'year': 2020},
#  {'agencyid': 7,
#   'agency_name': 'Agnes Scott College',
#   'offense': 'homicide',
#   'countyid': 60,
#   'county_name': 'DEKALB',
#   'actual': 0,
#   'percapita_income': 48914,
#   'year': 2017},
#  {'agencyid': 7,
# ...
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'rape',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 105,
#   'percapita_income': 37588,
#   'year': 2020},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 0,
#   'percapita_income': 32362,
#   'year': 2017},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 41,
#   'percapita_income': 33481,
#   'year': 2018},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 57,
#   'percapita_income': 34935,
#   'year': 2019},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'rape-legacy',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 42,
#   'percapita_income': 37588,
#   'year': 2020},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'robbery',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 123,
#   'percapita_income': 32362,
#   'year': 2017},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'robbery',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 109,
#   'percapita_income': 33481,
#   'year': 2018},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'robbery',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 130,
#   'percapita_income': 34935,
#   'year': 2019},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'robbery',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 102,
#   'percapita_income': 37588,
#   'year': 2020},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'violent-crime',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 519,
#   'percapita_income': 32362,
#   'year': 2017},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'violent-crime',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 497,
#   'percapita_income': 33481,
#   'year': 2018},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'violent-crime',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 624,
#   'percapita_income': 34935,
#   'year': 2019},
#  {'agencyid': 26,
#   'agency_name': 'Athens-Clarke County Police Department',
#   'offense': 'violent-crime',
#   'countyid': 41,
#   'county_name': 'CLARKE',
#   'actual': 654,
#   'percapita_income': 37588,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'aggravated-assault',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 5,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'aggravated-assault',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 21,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'arson',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'arson',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'burglary',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 4,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'burglary',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 17,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'homicide',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'homicide',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'human-trafficing',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'human-trafficing',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'larceny',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 10,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'larceny',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 48,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'motor-vehicle-theft',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 3,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'motor-vehicle-theft',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 11,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'property-crime',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 17,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'property-crime',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 76,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'rape',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'rape',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 1,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'rape-legacy',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'rape-legacy',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'robbery',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 0,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'robbery',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 1,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'violent-crime',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 5,
#   'percapita_income': 30251,
#   'year': 2019},
#  {'agencyid': 27,
#   'agency_name': "Atkinson County Sheriff's Office",
#   'offense': 'violent-crime',
#   'countyid': 2,
#   'county_name': 'ATKINSON',
#   'actual': 23,
#   'percapita_income': 31938,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'aggravated-assault',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 2,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'aggravated-assault',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 2,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'aggravated-assault',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'aggravated-assault',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'arson',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'arson',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'arson',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'arson',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'burglary',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'burglary',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'burglary',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'burglary',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'homicide',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'homicide',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'homicide',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'homicide',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'human-trafficing',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'human-trafficing',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'human-trafficing',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'human-trafficing',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'larceny',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 9,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'larceny',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 19,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'larceny',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 2,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'larceny',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'motor-vehicle-theft',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'property-crime',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 9,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'property-crime',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 19,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'property-crime',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 2,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'property-crime',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'rape',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'rape',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'rape',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'rape',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'rape-legacy',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 82345,
#   'year': 2017},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'rape-legacy',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 87395,
#   'year': 2018},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'rape-legacy',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 92961,
#   'year': 2019},
#  {'agencyid': 28,
#   'agency_name': 'Atlanta Metropolitan State College',
#   'offense': 'rape-legacy',
#   'countyid': 81,
#   'county_name': 'FULTON',
#   'actual': 0,
#   'percapita_income': 95683,
#   'year': 2020},
#  ...]

# %% [markdown]
# ### SQL for Ga_Department_Locations.json

# %%
sql = """
SELECT DISTINCT
    agc.agency_name, cnty.county_name, latitude, longitude,
    (select percapita_income from public."Income" where countyid = cnty.countyid and data_year = 2017) "ipc_17",
    (select percapita_income from public."Income" where countyid = cnty.countyid and data_year = 2018) "ipc_18",
    (select percapita_income from public."Income" where countyid = cnty.countyid and data_year = 2019) "ipc_19",
    (select percapita_income from public."Income" where countyid = cnty.countyid and data_year = 2020) "ipc_20"
FROM
    public."Agency" agc
    inner join public."CountyAgency" cntyagc on agc.agencyid = cntyagc.agencyid
    inner join public."County" cnty on cntyagc.countyid = cnty.countyid
    inner join public."Income" inc on cnty.countyid = inc.countyid
    inner join public."Offense" offn on agc.ori = offn.ori
 WHERE
    offn.data_year = inc.data_year;
"""

# %%
dept_locations_df = pd.read_sql(sql, connection)

# %%
offenses_resultlist = []

for index, row in dept_locations_df.iterrows():
    
    resultdict = {}
    resultdict["Agency Name"] = row.agency_name
    resultdict["County"] = row.county_name
    resultdict["Latitude"] = row.latitude
    resultdict["Longitude"] = row.longitude
    resultdict["2017 Income per Capita"] = row.ipc_17
    resultdict["2018 Income per Capita"] = row.ipc_18
    resultdict["2019 Income per Capita"] = row.ipc_19
    resultdict["2020 Income per Capita"] = row.ipc_20
    
    offenses_resultlist.append(resultdict)
    
offenses_resultlist
# Out:
# [{'Agency Name': 'Abbeville Police Department',
#   'County': 'WILCOX',
#   'Latitude': 31.990778,
#   'Longitude': -83.30794,
#   '2017 Income per Capita': 27059,
#   '2018 Income per Capita': 26687,
#   '2019 Income per Capita': 28621,
#   '2020 Income per Capita': 29895},
#  {'Agency Name': 'Abraham Baldwin Agricultural College',
#   'County': 'TIFT',
#   'Latitude': 31.457003,
#   'Longitude': -83.525931,
#   '2017 Income per Capita': 35800,
#   '2018 Income per Capita': 37273,
#   '2019 Income per Capita': 38346,
#   '2020 Income per Capita': 42279},
#  {'Agency Name': 'Acworth Police Department',
#   'County': 'COBB',
#   'Latitude': 34.06116,
#   'Longitude': -84.66078,
#   '2017 Income per Capita': 55448,
#   '2018 Income per Capita': 57762,
#   '2019 Income per Capita': 60383,
#   '2020 Income per Capita': 63214},
#  {'Agency Name': 'Adairsville Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.368633,
#   'Longitude': -84.93449,
#   '2017 Income per Capita': 37028,
#   '2018 Income per Capita': 38310,
#   '2019 Income per Capita': 39755,
#   '2020 Income per Capita': 42734},
#  {'Agency Name': 'Adel Police Department',
#   'County': 'COOK',
#   'Latitude': 31.152962,
#   'Longitude': -83.429567,
#   '2017 Income per Capita': 30891,
#   '2018 Income per Capita': 32303,
#   '2019 Income per Capita': 33589,
#   '2020 Income per Capita': 36301},
#  {'Agency Name': 'Agnes Scott College',
#   'County': 'DEKALB',
#   'Latitude': 33.769936,
#   'Longitude': -84.29559,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': 'Alamo Police Department',
#   'County': 'WHEELER',
#   'Latitude': 32.109276,
#   'Longitude': -82.738701,
#   '2017 Income per Capita': 18513,
#   '2018 Income per Capita': 18465,
#   '2019 Income per Capita': 18944,
#   '2020 Income per Capita': 21087},
#  {'Agency Name': 'Alapaha Police Department',
#   'County': 'BERRIEN',
#   'Latitude': 31.274308,
#   'Longitude': -83.231906,
#   '2017 Income per Capita': 30822,
#   '2018 Income per Capita': 31117,
#   '2019 Income per Capita': 32573,
#   '2020 Income per Capita': 35260},
#  {'Agency Name': 'Albany Police Department',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   '2017 Income per Capita': 33580,
#   '2018 Income per Capita': 34246,
#   '2019 Income per Capita': 35951,
#   '2020 Income per Capita': 40161},
#  {'Agency Name': 'Albany State University',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.572027,
#   'Longitude': -84.144394,
#   '2017 Income per Capita': 33580,
#   '2018 Income per Capita': 34246,
#   '2019 Income per Capita': 35951,
#   '2020 Income per Capita': 40161},
#  {'Agency Name': 'Albany Technical College',
#   'County': 'DOUGHERTY',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 33580,
#   '2018 Income per Capita': 34246,
#   '2019 Income per Capita': 35951,
#   '2020 Income per Capita': 40161},
#  {'Agency Name': 'Alma Police Department',
#   'County': 'BACON',
#   'Latitude': 31.563327,
#   'Longitude': -82.387859,
#   '2017 Income per Capita': 31441,
#   '2018 Income per Capita': 31516,
#   '2019 Income per Capita': 32784,
#   '2020 Income per Capita': 38281},
#  {'Agency Name': 'Alpharetta Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.790034,
#   'Longitude': -84.468182,
#   '2017 Income per Capita': 82345,
#   '2018 Income per Capita': 87395,
#   '2019 Income per Capita': 92961,
#   '2020 Income per Capita': 95683},
#  {'Agency Name': 'Americus Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   '2017 Income per Capita': 34944,
#   '2018 Income per Capita': 35051,
#   '2019 Income per Capita': 37011,
#   '2020 Income per Capita': 40387},
#  {'Agency Name': 'Andrew College ',
#   'County': 'RANDOLPH',
#   'Latitude': 31.771894,
#   'Longitude': -84.79704,
#   '2017 Income per Capita': 30912,
#   '2018 Income per Capita': 31828,
#   '2019 Income per Capita': 33565,
#   '2020 Income per Capita': 37204},
#  {'Agency Name': 'Appling County Board of Education',
#   'County': 'APPLING',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 33240,
#   '2018 Income per Capita': 33620,
#   '2019 Income per Capita': 35558,
#   '2020 Income per Capita': 39199},
#  {'Agency Name': "Appling County Sheriff's Office",
#   'County': 'APPLING',
#   'Latitude': 31.782509,
#   'Longitude': -82.35828,
#   '2017 Income per Capita': 33240,
#   '2018 Income per Capita': 33620,
#   '2019 Income per Capita': 35558,
#   '2020 Income per Capita': 39199},
#  {'Agency Name': 'Aragon Police Department',
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   '2017 Income per Capita': 31012,
#   '2018 Income per Capita': 32097,
#   '2019 Income per Capita': 33470,
#   '2020 Income per Capita': 36190},
#  {'Agency Name': 'Arcade Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   '2017 Income per Capita': 41409,
#   '2018 Income per Capita': 43180,
#   '2019 Income per Capita': 42927,
#   '2020 Income per Capita': 45099},
#  {'Agency Name': 'Ashburn Police Department',
#   'County': 'TURNER',
#   'Latitude': 31.718232,
#   'Longitude': -83.628566,
#   '2017 Income per Capita': 33292,
#   '2018 Income per Capita': 33394,
#   '2019 Income per Capita': 36111,
#   '2020 Income per Capita': 39281},
#  {'Agency Name': 'Athens-Clarke County Police Department',
#   'County': 'CLARKE',
#   'Latitude': 33.94101,
#   'Longitude': -83.32669,
#   '2017 Income per Capita': 32362,
#   '2018 Income per Capita': 33481,
#   '2019 Income per Capita': 34935,
#   '2020 Income per Capita': 37588},
#  {'Agency Name': 'Athens Technical College',
#   'County': 'CLARKE',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 32362,
#   '2018 Income per Capita': 33481,
#   '2019 Income per Capita': 34935,
#   '2020 Income per Capita': 37588},
#  {'Agency Name': "Atkinson County Sheriff's Office",
#   'County': 'ATKINSON',
#   'Latitude': 31.296677,
#   'Longitude': -82.878067,
#   '2017 Income per Capita': 28937,
#   '2018 Income per Capita': 28962,
#   '2019 Income per Capita': 30251,
#   '2020 Income per Capita': 31938},
#  {'Agency Name': 'Atlanta Metropolitan State College',
#   'County': 'FULTON',
#   'Latitude': 33.70959,
#   'Longitude': -84.40797,
#   '2017 Income per Capita': 82345,
#   '2018 Income per Capita': 87395,
#   '2019 Income per Capita': 92961,
#   '2020 Income per Capita': 95683},
#  {'Agency Name': 'Atlanta Public Schools',
#   'County': 'FULTON',
#   'Latitude': 33.748756,
#   'Longitude': -84.391945,
#   '2017 Income per Capita': 82345,
#   '2018 Income per Capita': 87395,
#   '2019 Income per Capita': 92961,
#   '2020 Income per Capita': 95683},
#  {'Agency Name': 'Atlanta Technical College',
#   'County': 'FULTON',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 82345,
#   '2018 Income per Capita': 87395,
#   '2019 Income per Capita': 92961,
#   '2020 Income per Capita': 95683},
#  {'Agency Name': 'Attapulgus Police Department',
#   'County': 'DECATUR',
#   'Latitude': 30.878091,
#   'Longitude': -84.577894,
#   '2017 Income per Capita': 33717,
#   '2018 Income per Capita': 35527,
#   '2019 Income per Capita': 37197,
#   '2020 Income per Capita': 40879},
#  {'Agency Name': "Augusta-Richmond County Sheriff's Office",
#   'County': 'RICHMOND',
#   'Latitude': 33.46506,
#   'Longitude': -81.959816,
#   '2017 Income per Capita': 36198,
#   '2018 Income per Capita': 37321,
#   '2019 Income per Capita': 38663,
#   '2020 Income per Capita': 41999},
#  {'Agency Name': 'Augusta Board of Education',
#   'County': 'RICHMOND',
#   'Latitude': 33.475838,
#   'Longitude': -81.96675,
#   '2017 Income per Capita': 36198,
#   '2018 Income per Capita': 37321,
#   '2019 Income per Capita': 38663,
#   '2020 Income per Capita': 41999},
#  {'Agency Name': 'Augusta Technical College',
#   'County': 'RICHMOND',
#   'Latitude': 33.419178,
#   'Longitude': -82.051254,
#   '2017 Income per Capita': 36198,
#   '2018 Income per Capita': 37321,
#   '2019 Income per Capita': 38663,
#   '2020 Income per Capita': 41999},
#  {'Agency Name': 'Avondale Estates Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.775436,
#   'Longitude': -84.26623,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': "Bacon County Sheriff's Office",
#   'County': 'BACON',
#   'Latitude': 31.563327,
#   'Longitude': -82.387859,
#   '2017 Income per Capita': 31441,
#   '2018 Income per Capita': 31516,
#   '2019 Income per Capita': 32784,
#   '2020 Income per Capita': 38281},
#  {'Agency Name': 'Bainbridge Police Department',
#   'County': 'DECATUR',
#   'Latitude': 30.878091,
#   'Longitude': -84.577894,
#   '2017 Income per Capita': 33717,
#   '2018 Income per Capita': 35527,
#   '2019 Income per Capita': 37197,
#   '2020 Income per Capita': 40879},
#  {'Agency Name': 'Bainbridge State College',
#   'County': 'DECATUR',
#   'Latitude': 30.901915,
#   'Longitude': -84.52778,
#   '2017 Income per Capita': 33717,
#   '2018 Income per Capita': 35527,
#   '2019 Income per Capita': 37197,
#   '2020 Income per Capita': 40879},
#  {'Agency Name': "Baker County Sheriff's Office",
#   'County': 'BAKER',
#   'Latitude': 31.31958,
#   'Longitude': -84.454881,
#   '2017 Income per Capita': 33548,
#   '2018 Income per Capita': 35175,
#   '2019 Income per Capita': 39932,
#   '2020 Income per Capita': 43156},
#  {'Agency Name': "Baldwin County Sheriff's Office",
#   'County': 'BALDWIN',
#   'Latitude': 33.059504,
#   'Longitude': -83.255452,
#   '2017 Income per Capita': 31915,
#   '2018 Income per Capita': 32534,
#   '2019 Income per Capita': 33865,
#   '2020 Income per Capita': 36399},
#  {'Agency Name': 'Ball Ground Police Department',
#   'County': 'CHEROKEE',
#   'Latitude': 34.244317,
#   'Longitude': -84.475057,
#   '2017 Income per Capita': 50281,
#   '2018 Income per Capita': 52052,
#   '2019 Income per Capita': 53774,
#   '2020 Income per Capita': 56278},
#  {'Agency Name': "Banks County Sheriff's Office",
#   'County': 'BANKS',
#   'Latitude': 34.351922,
#   'Longitude': -83.498441,
#   '2017 Income per Capita': 35193,
#   '2018 Income per Capita': 35862,
#   '2019 Income per Capita': 35990,
#   '2020 Income per Capita': 37333},
#  {'Agency Name': 'Barnesville Police Department',
#   'County': 'LAMAR',
#   'Latitude': 33.07446,
#   'Longitude': -84.146721,
#   '2017 Income per Capita': 32049,
#   '2018 Income per Capita': 33093,
#   '2019 Income per Capita': 34457,
#   '2020 Income per Capita': 37303},
#  {'Agency Name': "Barrow County Sheriff's Office",
#   'County': 'BARROW',
#   'Latitude': 33.992009,
#   'Longitude': -83.712303,
#   '2017 Income per Capita': 35807,
#   '2018 Income per Capita': 36720,
#   '2019 Income per Capita': 37318,
#   '2020 Income per Capita': 40435},
#  {'Agency Name': "Bartow County Sheriff's Office",
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   '2017 Income per Capita': 37028,
#   '2018 Income per Capita': 38310,
#   '2019 Income per Capita': 39755,
#   '2020 Income per Capita': 42734},
#  {'Agency Name': 'Bartow Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   '2017 Income per Capita': 32753,
#   '2018 Income per Capita': 32684,
#   '2019 Income per Capita': 34766,
#   '2020 Income per Capita': 39544},
#  {'Agency Name': 'Baxley Police Department',
#   'County': 'APPLING',
#   'Latitude': 31.739712,
#   'Longitude': -82.290103,
#   '2017 Income per Capita': 33240,
#   '2018 Income per Capita': 33620,
#   '2019 Income per Capita': 35558,
#   '2020 Income per Capita': 39199},
#  {'Agency Name': "Ben Hill County Sheriff's Office",
#   'County': 'BEN HILL',
#   'Latitude': 31.740775,
#   'Longitude': -83.14719,
#   '2017 Income per Capita': 29600,
#   '2018 Income per Capita': 31250,
#   '2019 Income per Capita': 32539,
#   '2020 Income per Capita': 36234},
#  {'Agency Name': 'Berlin Police Department',
#   'County': 'COLQUITT',
#   'Latitude': 31.189758,
#   'Longitude': -83.769741,
#   '2017 Income per Capita': 32304,
#   '2018 Income per Capita': 32728,
#   '2019 Income per Capita': 33793,
#   '2020 Income per Capita': 37418},
#  {'Agency Name': "Berrien County Sheriff's Office",
#   'County': 'BERRIEN',
#   'Latitude': 31.191711,
#   'Longitude': -83.27352,
#   '2017 Income per Capita': 30822,
#   '2018 Income per Capita': 31117,
#   '2019 Income per Capita': 32573,
#   '2020 Income per Capita': 35260},
#  {'Agency Name': 'Berry College',
#   'County': 'FLOYD',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 36491,
#   '2018 Income per Capita': 37593,
#   '2019 Income per Capita': 38630,
#   '2020 Income per Capita': 41238},
#  {'Agency Name': 'Bibb County Board of Education',
#   'County': 'BIBB',
#   'Latitude': 32.841473,
#   'Longitude': -83.660034,
#   '2017 Income per Capita': 39509,
#   '2018 Income per Capita': 40433,
#   '2019 Income per Capita': 41517,
#   '2020 Income per Capita': 44830},
#  {'Agency Name': "Bibb County Sheriff's Office",
#   'County': 'BIBB',
#   'Latitude': 32.831833,
#   'Longitude': -83.64161,
#   '2017 Income per Capita': 39509,
#   '2018 Income per Capita': 40433,
#   '2019 Income per Capita': 41517,
#   '2020 Income per Capita': 44830},
#  {'Agency Name': 'Blackshear Police Department',
#   'County': 'PIERCE',
#   'Latitude': 31.353988,
#   'Longitude': -82.210427,
#   '2017 Income per Capita': 35232,
#   '2018 Income per Capita': 35671,
#   '2019 Income per Capita': 36889,
#   '2020 Income per Capita': 39979},
#  {'Agency Name': 'Blairsville Police Department',
#   'County': 'UNION',
#   'Latitude': 34.83377,
#   'Longitude': -83.989573,
#   '2017 Income per Capita': 36333,
#   '2018 Income per Capita': 36919,
#   '2019 Income per Capita': 38294,
#   '2020 Income per Capita': 39839},
#  {'Agency Name': 'Blakely Police Department',
#   'County': 'EARLY',
#   'Latitude': 31.324191,
#   'Longitude': -84.906723,
#   '2017 Income per Capita': 35181,
#   '2018 Income per Capita': 35805,
#   '2019 Income per Capita': 39225,
#   '2020 Income per Capita': 42889},
#  {'Agency Name': "Bleckley County Sheriff's Office",
#   'County': 'BLECKLEY',
#   'Latitude': 32.435403,
#   'Longitude': -83.331717,
#   '2017 Income per Capita': 33013,
#   '2018 Income per Capita': 33520,
#   '2019 Income per Capita': 34464,
#   '2020 Income per Capita': 36712},
#  {'Agency Name': 'Bloomingdale Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   '2017 Income per Capita': 45559,
#   '2018 Income per Capita': 47256,
#   '2019 Income per Capita': 48545,
#   '2020 Income per Capita': 51805},
#  {'Agency Name': 'Blue Ridge Police Department',
#   'County': 'FANNIN',
#   'Latitude': 34.866226,
#   'Longitude': -84.32594,
#   '2017 Income per Capita': 35178,
#   '2018 Income per Capita': 36459,
#   '2019 Income per Capita': 38128,
#   '2020 Income per Capita': 39796},
#  {'Agency Name': 'Boston Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   '2017 Income per Capita': 42415,
#   '2018 Income per Capita': 44536,
#   '2019 Income per Capita': 45470,
#   '2020 Income per Capita': 49443},
#  {'Agency Name': 'Bowdon Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.538067,
#   'Longitude': -85.252075,
#   '2017 Income per Capita': 37126,
#   '2018 Income per Capita': 38273,
#   '2019 Income per Capita': 39725,
#   '2020 Income per Capita': 42058},
#  {'Agency Name': "Brantley County Sheriff's Office",
#   'County': 'BRANTLEY',
#   'Latitude': 31.197334,
#   'Longitude': -81.982978,
#   '2017 Income per Capita': 26070,
#   '2018 Income per Capita': 27046,
#   '2019 Income per Capita': 27472,
#   '2020 Income per Capita': 30007},
#  {'Agency Name': 'Brookhaven Police Department',
#   'County': 'DEKALB',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': 'Brooklet Police Department',
#   'County': 'BULLOCH',
#   'Latitude': 32.393408,
#   'Longitude': -81.74381,
#   '2017 Income per Capita': 31342,
#   '2018 Income per Capita': 32360,
#   '2019 Income per Capita': 32718,
#   '2020 Income per Capita': 35376},
#  {'Agency Name': "Brooks County Sheriff's Office",
#   'County': 'BROOKS',
#   'Latitude': 30.822934,
#   'Longitude': -83.581905,
#   '2017 Income per Capita': 33756,
#   '2018 Income per Capita': 34708,
#   '2019 Income per Capita': 36742,
#   '2020 Income per Capita': 40221},
#  {'Agency Name': 'Broxton Police Department',
#   'County': 'COFFEE',
#   'Latitude': 31.549245,
#   'Longitude': -82.844938,
#   '2017 Income per Capita': 31301,
#   '2018 Income per Capita': 31761,
#   '2019 Income per Capita': 32880,
#   '2020 Income per Capita': 35507},
#  {'Agency Name': 'Brunswick Police Department',
#   'County': 'GLYNN',
#   'Latitude': 31.146036,
#   'Longitude': -81.49548,
#   '2017 Income per Capita': 44266,
#   '2018 Income per Capita': 46614,
#   '2019 Income per Capita': 47795,
#   '2020 Income per Capita': 50480},
#  {'Agency Name': "Bryan County Sheriff's Office",
#   'County': 'BRYAN',
#   'Latitude': 32.017969,
#   'Longitude': -81.438543,
#   '2017 Income per Capita': 50475,
#   '2018 Income per Capita': 53382,
#   '2019 Income per Capita': 53404,
#   '2020 Income per Capita': 56648},
#  {'Agency Name': 'Buchanan Police Department',
#   'County': 'HARALSON',
#   'Latitude': 33.795165,
#   'Longitude': -85.220062,
#   '2017 Income per Capita': 35038,
#   '2018 Income per Capita': 36186,
#   '2019 Income per Capita': 37319,
#   '2020 Income per Capita': 39401},
#  {'Agency Name': 'Buena Vista Police Department',
#   'County': 'MARION',
#   'Latitude': 32.359538,
#   'Longitude': -84.529561,
#   '2017 Income per Capita': 27858,
#   '2018 Income per Capita': 29193,
#   '2019 Income per Capita': 29832,
#   '2020 Income per Capita': 31621},
#  {'Agency Name': "Bulloch County Sheriff's Office",
#   'County': 'BULLOCH',
#   'Latitude': 32.467293,
#   'Longitude': -81.76302,
#   '2017 Income per Capita': 31342,
#   '2018 Income per Capita': 32360,
#   '2019 Income per Capita': 32718,
#   '2020 Income per Capita': 35376},
#  {'Agency Name': "Burke  County Sheriff's Office",
#   'County': 'BURKE',
#   'Latitude': 33.050819,
#   'Longitude': -82.011571,
#   '2017 Income per Capita': 34447,
#   '2018 Income per Capita': 34940,
#   '2019 Income per Capita': 38419,
#   '2020 Income per Capita': 41973},
#  {'Agency Name': 'Butler Police Department',
#   'County': 'TAYLOR',
#   'Latitude': 32.554667,
#   'Longitude': -84.251426,
#   '2017 Income per Capita': 29246,
#   '2018 Income per Capita': 30456,
#   '2019 Income per Capita': 32157,
#   '2020 Income per Capita': 33630},
#  {'Agency Name': "Butts County Sheriff's Office",
#   'County': 'BUTTS',
#   'Latitude': 33.296364,
#   'Longitude': -83.94759,
#   '2017 Income per Capita': 32752,
#   '2018 Income per Capita': 34243,
#   '2019 Income per Capita': 34761,
#   '2020 Income per Capita': 37403},
#  {'Agency Name': 'Byron Police Department',
#   'County': 'PEACH',
#   'Latitude': 32.571324,
#   'Longitude': -83.831978,
#   '2017 Income per Capita': 37217,
#   '2018 Income per Capita': 36947,
#   '2019 Income per Capita': 38915,
#   '2020 Income per Capita': 41931},
#  {'Agency Name': 'Cairo Police Department',
#   'County': 'GRADY',
#   'Latitude': 30.875891,
#   'Longitude': -84.245066,
#   '2017 Income per Capita': 33287,
#   '2018 Income per Capita': 34108,
#   '2019 Income per Capita': 35195,
#   '2020 Income per Capita': 37725},
#  {'Agency Name': "Calhoun County Sheriff's Office",
#   'County': 'CALHOUN',
#   'Latitude': 31.521279,
#   'Longitude': -84.62629,
#   '2017 Income per Capita': 24114,
#   '2018 Income per Capita': 23262,
#   '2019 Income per Capita': 25701,
#   '2020 Income per Capita': 28426},
#  {'Agency Name': 'Calhoun Police Department',
#   'County': 'GORDON',
#   'Latitude': 34.50379,
#   'Longitude': -84.95111,
#   '2017 Income per Capita': 35831,
#   '2018 Income per Capita': 34849,
#   '2019 Income per Capita': 35882,
#   '2020 Income per Capita': 37759},
#  {'Agency Name': "Camden County Sheriff's Office",
#   'County': 'CAMDEN',
#   'Latitude': 30.913347,
#   'Longitude': -81.642001,
#   '2017 Income per Capita': 35493,
#   '2018 Income per Capita': 35872,
#   '2019 Income per Capita': 36807,
#   '2020 Income per Capita': 39262},
#  {'Agency Name': 'Camilla Police Department',
#   'County': 'MITCHELL',
#   'Latitude': 31.231115,
#   'Longitude': -84.21176,
#   '2017 Income per Capita': 34257,
#   '2018 Income per Capita': 33947,
#   '2019 Income per Capita': 36448,
#   '2020 Income per Capita': 39711},
#  {'Agency Name': "Candler County Sheriff's Office",
#   'County': 'CANDLER',
#   'Latitude': 32.403997,
#   'Longitude': -82.07131,
#   '2017 Income per Capita': 31070,
#   '2018 Income per Capita': 32024,
#   '2019 Income per Capita': 33649,
#   '2020 Income per Capita': 36613},
#  {'Agency Name': 'Canton Police Department',
#   'County': 'CHEROKEE',
#   'Latitude': 34.23541,
#   'Longitude': -84.490005,
#   '2017 Income per Capita': 50281,
#   '2018 Income per Capita': 52052,
#   '2019 Income per Capita': 53774,
#   '2020 Income per Capita': 56278},
#  {'Agency Name': "Carroll County Sheriff's Office",
#   'County': 'CARROLL',
#   'Latitude': 33.56817,
#   'Longitude': -85.03639,
#   '2017 Income per Capita': 37126,
#   '2018 Income per Capita': 38273,
#   '2019 Income per Capita': 39725,
#   '2020 Income per Capita': 42058},
#  {'Agency Name': 'Carrollton Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.582237,
#   'Longitude': -85.080527,
#   '2017 Income per Capita': 37126,
#   '2018 Income per Capita': 38273,
#   '2019 Income per Capita': 39725,
#   '2020 Income per Capita': 42058},
#  {'Agency Name': 'Cartersville Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   '2017 Income per Capita': 37028,
#   '2018 Income per Capita': 38310,
#   '2019 Income per Capita': 39755,
#   '2020 Income per Capita': 42734},
#  {'Agency Name': "Catoosa County Sheriff's Office",
#   'County': 'CATOOSA',
#   'Latitude': 34.899393,
#   'Longitude': -85.137353,
#   '2017 Income per Capita': 33929,
#   '2018 Income per Capita': 34882,
#   '2019 Income per Capita': 36030,
#   '2020 Income per Capita': 38815},
#  {'Agency Name': 'Cave Spring Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.263677,
#   'Longitude': -85.21373,
#   '2017 Income per Capita': 36491,
#   '2018 Income per Capita': 37593,
#   '2019 Income per Capita': 38630,
#   '2020 Income per Capita': 41238},
#  {'Agency Name': 'Cecil',
#   'County': 'COOK',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 30891,
#   '2018 Income per Capita': 32303,
#   '2019 Income per Capita': 33589,
#   '2020 Income per Capita': 36301},
#  {'Agency Name': 'Cedartown Police Department',
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   '2017 Income per Capita': 31012,
#   '2018 Income per Capita': 32097,
#   '2019 Income per Capita': 33470,
#   '2020 Income per Capita': 36190},
#  {'Agency Name': 'Centerville Police Department',
#   'County': 'HOUSTON',
#   'Latitude': 32.630127,
#   'Longitude': -83.68969,
#   '2017 Income per Capita': 41524,
#   '2018 Income per Capita': 42784,
#   '2019 Income per Capita': 43847,
#   '2020 Income per Capita': 46579},
#  {'Agency Name': 'Chamblee Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.895386,
#   'Longitude': -84.29837,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': "Charlton County Sheriff's Office",
#   'County': 'CHARLTON',
#   'Latitude': 30.830587,
#   'Longitude': -82.00494,
#   '2017 Income per Capita': 24177,
#   '2018 Income per Capita': 24465,
#   '2019 Income per Capita': 24884,
#   '2020 Income per Capita': 27192},
#  {'Agency Name': 'Chatham County Board of Education',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   '2017 Income per Capita': 45559,
#   '2018 Income per Capita': 47256,
#   '2019 Income per Capita': 48545,
#   '2020 Income per Capita': 51805},
#  {'Agency Name': 'Chatham County Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 32.060173,
#   'Longitude': -81.166336,
#   '2017 Income per Capita': 45559,
#   '2018 Income per Capita': 47256,
#   '2019 Income per Capita': 48545,
#   '2020 Income per Capita': 51805},
#  {'Agency Name': "Chatham County Sheriff's Office",
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   '2017 Income per Capita': 45559,
#   '2018 Income per Capita': 47256,
#   '2019 Income per Capita': 48545,
#   '2020 Income per Capita': 51805},
#  {'Agency Name': 'Chatsworth Police Department',
#   'County': 'MURRAY',
#   'Latitude': 34.797097,
#   'Longitude': -84.73799,
#   '2017 Income per Capita': 29446,
#   '2018 Income per Capita': 30402,
#   '2019 Income per Capita': 31148,
#   '2020 Income per Capita': 33841},
#  {'Agency Name': "Chattahoochee County Sheriff's Office",
#   'County': 'CHATTAHOOCHEE',
#   'Latitude': 32.347445,
#   'Longitude': -84.788021,
#   '2017 Income per Capita': 31503,
#   '2018 Income per Capita': 29964,
#   '2019 Income per Capita': 30433,
#   '2020 Income per Capita': 33166},
#  {'Agency Name': 'Chattahoochee Hills Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.579945,
#   'Longitude': -84.76857,
#   '2017 Income per Capita': 82345,
#   '2018 Income per Capita': 87395,
#   '2019 Income per Capita': 92961,
#   '2020 Income per Capita': 95683},
#  {'Agency Name': 'Chattahoochee Technical College',
#   'County': 'BARTOW',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 37028,
#   '2018 Income per Capita': 38310,
#   '2019 Income per Capita': 39755,
#   '2020 Income per Capita': 42734},
#  {'Agency Name': "Chattooga County Sheriff's Office",
#   'County': 'CHATTOOGA',
#   'Latitude': 34.480766,
#   'Longitude': -85.34815,
#   '2017 Income per Capita': 29702,
#   '2018 Income per Capita': 30296,
#   '2019 Income per Capita': 31069,
#   '2020 Income per Capita': 33855},
#  {'Agency Name': 'Cherokee County Board of Education',
#   'County': 'CHEROKEE',
#   'Latitude': 34.236027,
#   'Longitude': -84.49235,
#   '2017 Income per Capita': 50281,
#   '2018 Income per Capita': 52052,
#   '2019 Income per Capita': 53774,
#   '2020 Income per Capita': 56278},
#  {'Agency Name': 'Cherokee County Marshal',
#   'County': 'CHEROKEE',
#   'Latitude': 34.244317,
#   'Longitude': -84.475057,
#   '2017 Income per Capita': 50281,
#   '2018 Income per Capita': 52052,
#   '2019 Income per Capita': 53774,
#   '2020 Income per Capita': 56278},
#  {'Agency Name': "Cherokee County Sheriff's Office",
#   'County': 'CHEROKEE',
#   'Latitude': 34.196648,
#   'Longitude': -84.49234,
#   '2017 Income per Capita': 50281,
#   '2018 Income per Capita': 52052,
#   '2019 Income per Capita': 53774,
#   '2020 Income per Capita': 56278},
#  {'Agency Name': 'Chickamauga Police Department',
#   'County': 'WALKER',
#   'Latitude': 34.735827,
#   'Longitude': -85.305385,
#   '2017 Income per Capita': 31848,
#   '2018 Income per Capita': 32834,
#   '2019 Income per Capita': 33883,
#   '2020 Income per Capita': 36157},
#  {'Agency Name': 'Clark Atlanta University',
#   'County': 'FULTON',
#   'Latitude': 33.747498,
#   'Longitude': -84.41283,
#   '2017 Income per Capita': 82345,
#   '2018 Income per Capita': 87395,
#   '2019 Income per Capita': 92961,
#   '2020 Income per Capita': 95683},
#  {'Agency Name': "Clarke County Sheriff's Office",
#   'County': 'CLARKE',
#   'Latitude': 33.9596,
#   'Longitude': -83.37472,
#   '2017 Income per Capita': 32362,
#   '2018 Income per Capita': 33481,
#   '2019 Income per Capita': 34935,
#   '2020 Income per Capita': 37588},
#  {'Agency Name': 'Clarkesville Police Department',
#   'County': 'HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   '2017 Income per Capita': 33042,
#   '2018 Income per Capita': 34002,
#   '2019 Income per Capita': 35006,
#   '2020 Income per Capita': 36691},
#  {'Agency Name': 'Clarkston Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.809055,
#   'Longitude': -84.23962,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': 'Claxton Police Department',
#   'County': 'EVANS',
#   'Latitude': 32.151902,
#   'Longitude': -81.887618,
#   '2017 Income per Capita': 33343,
#   '2018 Income per Capita': 33769,
#   '2019 Income per Capita': 34065,
#   '2020 Income per Capita': 37408},
#  {'Agency Name': "Clay County Sheriff's Office",
#   'County': 'CLAY',
#   'Latitude': 31.619831,
#   'Longitude': -84.992583,
#   '2017 Income per Capita': 30808,
#   '2018 Income per Capita': 32081,
#   '2019 Income per Capita': 34175,
#   '2020 Income per Capita': 38731},
#  {'Agency Name': 'Clayton County Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.541374,
#   'Longitude': -84.34508,
#   '2017 Income per Capita': 26721,
#   '2018 Income per Capita': 27430,
#   '2019 Income per Capita': 28329,
#   '2020 Income per Capita': 32702},
#  {'Agency Name': "Clayton County Sheriff's Office",
#   'County': 'CLAYTON',
#   'Latitude': 33.51437,
#   'Longitude': -84.36194,
#   '2017 Income per Capita': 26721,
#   '2018 Income per Capita': 27430,
#   '2019 Income per Capita': 28329,
#   '2020 Income per Capita': 32702},
#  {'Agency Name': 'Clayton Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   '2017 Income per Capita': 40810,
#   '2018 Income per Capita': 40470,
#   '2019 Income per Capita': 41317,
#   '2020 Income per Capita': 44160},
#  {'Agency Name': 'Clayton State University',
#   'County': 'CLAYTON',
#   'Latitude': 33.542686,
#   'Longitude': -84.355573,
#   '2017 Income per Capita': 26721,
#   '2018 Income per Capita': 27430,
#   '2019 Income per Capita': 28329,
#   '2020 Income per Capita': 32702},
#  {'Agency Name': 'Cleveland Police Department',
#   'County': 'WHITE',
#   'Latitude': 34.643776,
#   'Longitude': -83.743417,
#   '2017 Income per Capita': 34904,
#   '2018 Income per Capita': 35641,
#   '2019 Income per Capita': 36814,
#   '2020 Income per Capita': 38858},
#  {'Agency Name': "Clinch County Sheriff's Office",
#   'County': 'CLINCH',
#   'Latitude': 31.039433,
#   'Longitude': -82.749954,
#   '2017 Income per Capita': 35573,
#   '2018 Income per Capita': 36689,
#   '2019 Income per Capita': 38551,
#   '2020 Income per Capita': 44238},
#  {'Agency Name': 'Cobb County Board of Education',
#   'County': 'COBB',
#   'Latitude': 33.916363,
#   'Longitude': -84.546295,
#   '2017 Income per Capita': 55448,
#   '2018 Income per Capita': 57762,
#   '2019 Income per Capita': 60383,
#   '2020 Income per Capita': 63214},
#  {'Agency Name': 'Cobb County Police Department',
#   'County': 'COBB',
#   'Latitude': 33.958862,
#   'Longitude': -84.54633,
#   '2017 Income per Capita': 55448,
#   '2018 Income per Capita': 57762,
#   '2019 Income per Capita': 60383,
#   '2020 Income per Capita': 63214},
#  {'Agency Name': "Cobb County Sheriff's Office",
#   'County': 'COBB',
#   'Latitude': 33.952282,
#   'Longitude': -84.5482,
#   '2017 Income per Capita': 55448,
#   '2018 Income per Capita': 57762,
#   '2019 Income per Capita': 60383,
#   '2020 Income per Capita': 63214},
#  {'Agency Name': 'Cochran Police Department',
#   'County': 'BLECKLEY',
#   'Latitude': 32.386444,
#   'Longitude': -83.35458,
#   '2017 Income per Capita': 33013,
#   '2018 Income per Capita': 33520,
#   '2019 Income per Capita': 34464,
#   '2020 Income per Capita': 36712},
#  {'Agency Name': "Coffee County Sheriff's Office",
#   'County': 'COFFEE',
#   'Latitude': 31.549245,
#   'Longitude': -82.844938,
#   '2017 Income per Capita': 31301,
#   '2018 Income per Capita': 31761,
#   '2019 Income per Capita': 32880,
#   '2020 Income per Capita': 35507},
#  {'Agency Name': 'Cohutta Police Department',
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   '2017 Income per Capita': 36997,
#   '2018 Income per Capita': 39105,
#   '2019 Income per Capita': 40622,
#   '2020 Income per Capita': 43456},
#  {'Agency Name': 'College of Coastal Georgia',
#   'County': 'GLYNN',
#   'Latitude': 31.212746,
#   'Longitude': -81.496517,
#   '2017 Income per Capita': 44266,
#   '2018 Income per Capita': 46614,
#   '2019 Income per Capita': 47795,
#   '2020 Income per Capita': 50480},
#  {'Agency Name': "Colquitt  County Sheriff's Office",
#   'County': 'COLQUITT',
#   'Latitude': 31.189758,
#   'Longitude': -83.769741,
#   '2017 Income per Capita': 32304,
#   '2018 Income per Capita': 32728,
#   '2019 Income per Capita': 33793,
#   '2020 Income per Capita': 37418},
#  {'Agency Name': 'Colquitt Police Department',
#   'County': 'MILLER',
#   'Latitude': 31.162908,
#   'Longitude': -84.730386,
#   '2017 Income per Capita': 39678,
#   '2018 Income per Capita': 43499,
#   '2019 Income per Capita': 46158,
#   '2020 Income per Capita': 49844},
#  {'Agency Name': "Columbia County Sheriff's Office",
#   'County': 'COLUMBIA',
#   'Latitude': 33.550551,
#   'Longitude': -82.251361,
#   '2017 Income per Capita': 48358,
#   '2018 Income per Capita': 49844,
#   '2019 Income per Capita': 51534,
#   '2020 Income per Capita': 54420},
#  {'Agency Name': 'Columbus Police Department',
#   'County': 'MUSCOGEE',
#   'Latitude': 32.464756,
#   'Longitude': -84.98599,
#   '2017 Income per Capita': 41950,
#   '2018 Income per Capita': 43215,
#   '2019 Income per Capita': 44896,
#   '2020 Income per Capita': 48080},
#  {'Agency Name': 'Columbus State University',
#   'County': 'MUSCOGEE',
#   'Latitude': 32.510197,
#   'Longitude': -84.874946,
#   '2017 Income per Capita': 41950,
#   '2018 Income per Capita': 43215,
#   '2019 Income per Capita': 44896,
#   '2020 Income per Capita': 48080},
#  {'Agency Name': 'Commerce Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   '2017 Income per Capita': 41409,
#   '2018 Income per Capita': 43180,
#   '2019 Income per Capita': 42927,
#   '2020 Income per Capita': 45099},
#  {'Agency Name': 'Conyers Police Department',
#   'County': 'ROCKDALE',
#   'Latitude': 33.65794,
#   'Longitude': -84.01751,
#   '2017 Income per Capita': 34002,
#   '2018 Income per Capita': 35074,
#   '2019 Income per Capita': 36434,
#   '2020 Income per Capita': 40051},
#  {'Agency Name': "Cook County Sheriff's Office",
#   'County': 'COOK',
#   'Latitude': 31.152962,
#   'Longitude': -83.429567,
#   '2017 Income per Capita': 30891,
#   '2018 Income per Capita': 32303,
#   '2019 Income per Capita': 33589,
#   '2020 Income per Capita': 36301},
#  {'Agency Name': 'Coolidge Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   '2017 Income per Capita': 42415,
#   '2018 Income per Capita': 44536,
#   '2019 Income per Capita': 45470,
#   '2020 Income per Capita': 49443},
#  {'Agency Name': 'Cordele Police Department',
#   'County': 'CRISP',
#   'Latitude': 31.973846,
#   'Longitude': -83.782745,
#   '2017 Income per Capita': 31585,
#   '2018 Income per Capita': 32341,
#   '2019 Income per Capita': 34299,
#   '2020 Income per Capita': 37250},
#  {'Agency Name': 'Cornelia Police Department',
#   'County': 'HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   '2017 Income per Capita': 33042,
#   '2018 Income per Capita': 34002,
#   '2019 Income per Capita': 35006,
#   '2020 Income per Capita': 36691},
#  {'Agency Name': 'Covington Police Department',
#   'County': 'NEWTON',
#   'Latitude': 33.595737,
#   'Longitude': -83.857635,
#   '2017 Income per Capita': 32812,
#   '2018 Income per Capita': 34033,
#   '2019 Income per Capita': 34829,
#   '2020 Income per Capita': 38256},
#  {'Agency Name': "Coweta County Sheriff's Office",
#   'County': 'COWETA',
#   'Latitude': 33.382137,
#   'Longitude': -84.78246,
#   '2017 Income per Capita': 45358,
#   '2018 Income per Capita': 47395,
#   '2019 Income per Capita': 49042,
#   '2020 Income per Capita': 52106},
#  {'Agency Name': "Crawford County Sheriff's Office",
#   'County': 'CRAWFORD',
#   'Latitude': 32.709428,
#   'Longitude': -83.979187,
#   '2017 Income per Capita': 33368,
#   '2018 Income per Capita': 33841,
#   '2019 Income per Capita': 34633,
#   '2020 Income per Capita': 37563},
#  {'Agency Name': "Crisp County Sheriff's Office",
#   'County': 'CRISP',
#   'Latitude': 31.914753,
#   'Longitude': -83.753338,
#   '2017 Income per Capita': 31585,
#   '2018 Income per Capita': 32341,
#   '2019 Income per Capita': 34299,
#   '2020 Income per Capita': 37250},
#  {'Agency Name': 'Cumming Police Department',
#   'County': 'FORSYTH',
#   'Latitude': 34.204327,
#   'Longitude': -84.13951,
#   '2017 Income per Capita': 61970,
#   '2018 Income per Capita': 63462,
#   '2019 Income per Capita': 64919,
#   '2020 Income per Capita': 67859},
#  {'Agency Name': 'Cuthbert Police Department',
#   'County': 'RANDOLPH',
#   'Latitude': 31.762651,
#   'Longitude': -84.752311,
#   '2017 Income per Capita': 30912,
#   '2018 Income per Capita': 31828,
#   '2019 Income per Capita': 33565,
#   '2020 Income per Capita': 37204},
#  {'Agency Name': "Dade County Sheriff's Office",
#   'County': 'DADE',
#   'Latitude': 34.852424,
#   'Longitude': -85.506201,
#   '2017 Income per Capita': 33728,
#   '2018 Income per Capita': 35561,
#   '2019 Income per Capita': 34992,
#   '2020 Income per Capita': 37327},
#  {'Agency Name': 'Dallas Police Department',
#   'County': 'PAULDING',
#   'Latitude': 33.920903,
#   'Longitude': -84.866979,
#   '2017 Income per Capita': 36915,
#   '2018 Income per Capita': 38249,
#   '2019 Income per Capita': 39309,
#   '2020 Income per Capita': 42595},
#  {'Agency Name': 'Dalton Police Department',
#   'County': 'WHITFIELD',
#   'Latitude': 34.773823,
#   'Longitude': -84.97399,
#   '2017 Income per Capita': 36997,
#   '2018 Income per Capita': 39105,
#   '2019 Income per Capita': 40622,
#   '2020 Income per Capita': 43456},
#  {'Agency Name': 'Dalton State College',
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   '2017 Income per Capita': 36997,
#   '2018 Income per Capita': 39105,
#   '2019 Income per Capita': 40622,
#   '2020 Income per Capita': 43456},
#  {'Agency Name': 'Danielsville Police Department',
#   'County': 'MADISON',
#   'Latitude': 34.128484,
#   'Longitude': -83.203644,
#   '2017 Income per Capita': 36366,
#   '2018 Income per Capita': 37075,
#   '2019 Income per Capita': 37625,
#   '2020 Income per Capita': 38890},
#  {'Agency Name': 'Darien Police Department',
#   'County': 'MCINTOSH',
#   'Latitude': 31.482978,
#   'Longitude': -81.370199,
#   '2017 Income per Capita': 29523,
#   '2018 Income per Capita': 31032,
#   '2019 Income per Capita': 31770,
#   '2020 Income per Capita': 34500},
#  {'Agency Name': 'Davisboro Police Department',
#   'County': 'WASHINGTON',
#   'Latitude': 32.971848,
#   'Longitude': -82.798112,
#   '2017 Income per Capita': 34168,
#   '2018 Income per Capita': 34685,
#   '2019 Income per Capita': 35889,
#   '2020 Income per Capita': 39151},
#  {'Agency Name': "Dawson County Sheriff's Office",
#   'County': 'DAWSON',
#   'Latitude': 34.422028,
#   'Longitude': -84.12007,
#   '2017 Income per Capita': 44208,
#   '2018 Income per Capita': 45988,
#   '2019 Income per Capita': 46101,
#   '2020 Income per Capita': 48170},
#  {'Agency Name': 'Dawson Police Department',
#   'County': 'TERRELL',
#   'Latitude': 31.777191,
#   'Longitude': -84.439446,
#   '2017 Income per Capita': 37481,
#   '2018 Income per Capita': 38739,
#   '2019 Income per Capita': 41393,
#   '2020 Income per Capita': 44976},
#  {'Agency Name': 'Decatur County Schools',
#   'County': 'DECATUR',
#   'Latitude': 30.897661,
#   'Longitude': -84.55789,
#   '2017 Income per Capita': 33717,
#   '2018 Income per Capita': 35527,
#   '2019 Income per Capita': 37197,
#   '2020 Income per Capita': 40879},
#  {'Agency Name': "Decatur County Sheriff's Office",
#   'County': 'DECATUR',
#   'Latitude': 30.908264,
#   'Longitude': -84.59721,
#   '2017 Income per Capita': 33717,
#   '2018 Income per Capita': 35527,
#   '2019 Income per Capita': 37197,
#   '2020 Income per Capita': 40879},
#  {'Agency Name': 'Decatur Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.773537,
#   'Longitude': -84.30166,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': 'DeKalb County Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.77625,
#   'Longitude': -84.24072,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': 'DeKalb County School System',
#   'County': 'DEKALB',
#   'Latitude': 33.800564,
#   'Longitude': -84.20196,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': "DeKalb County Sheriff's Office",
#   'County': 'DEKALB',
#   'Latitude': 33.774567,
#   'Longitude': -84.29654,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': 'Demorest Police Department',
#   'County': 'HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   '2017 Income per Capita': 33042,
#   '2018 Income per Capita': 34002,
#   '2019 Income per Capita': 35006,
#   '2020 Income per Capita': 36691},
#  {'Agency Name': 'Department of Transportation Office of Investigations',
#   'County': 'FULTON',
#   'Latitude': 33.746944,
#   'Longitude': -84.39647,
#   '2017 Income per Capita': 82345,
#   '2018 Income per Capita': 87395,
#   '2019 Income per Capita': 92961,
#   '2020 Income per Capita': 95683},
#  {'Agency Name': 'Dillard Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   '2017 Income per Capita': 40810,
#   '2018 Income per Capita': 40470,
#   '2019 Income per Capita': 41317,
#   '2020 Income per Capita': 44160},
#  {'Agency Name': "Dodge County Sheriff's Office",
#   'County': 'DODGE',
#   'Latitude': 32.200294,
#   'Longitude': -83.17538,
#   '2017 Income per Capita': 29484,
#   '2018 Income per Capita': 30026,
#   '2019 Income per Capita': 31116,
#   '2020 Income per Capita': 33419},
#  {'Agency Name': 'Doerun Police Department',
#   'County': 'COLQUITT',
#   'Latitude': 31.189758,
#   'Longitude': -83.769741,
#   '2017 Income per Capita': 32304,
#   '2018 Income per Capita': 32728,
#   '2019 Income per Capita': 33793,
#   '2020 Income per Capita': 37418},
#  {'Agency Name': 'Donalsonville Police Department',
#   'County': 'SEMINOLE',
#   'Latitude': 30.933894,
#   'Longitude': -84.867592,
#   '2017 Income per Capita': 40671,
#   '2018 Income per Capita': 41511,
#   '2019 Income per Capita': 45837,
#   '2020 Income per Capita': 48082},
#  {'Agency Name': "Dooly County Sheriff's Office",
#   'County': 'DOOLY',
#   'Latitude': 32.151995,
#   'Longitude': -83.807167,
#   '2017 Income per Capita': 29914,
#   '2018 Income per Capita': 29886,
#   '2019 Income per Capita': 32995,
#   '2020 Income per Capita': 34582},
#  {'Agency Name': 'Doraville Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.90096,
#   'Longitude': -84.27897,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': 'Dougherty County Board of Education',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   '2017 Income per Capita': 33580,
#   '2018 Income per Capita': 34246,
#   '2019 Income per Capita': 35951,
#   '2020 Income per Capita': 40161},
#  {'Agency Name': 'Dougherty County Police Department',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   '2017 Income per Capita': 33580,
#   '2018 Income per Capita': 34246,
#   '2019 Income per Capita': 35951,
#   '2020 Income per Capita': 40161},
#  {'Agency Name': "Dougherty County Sheriff's Office",
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   '2017 Income per Capita': 33580,
#   '2018 Income per Capita': 34246,
#   '2019 Income per Capita': 35951,
#   '2020 Income per Capita': 40161},
#  {'Agency Name': "Douglas County Sheriff's Office",
#   'County': 'DOUGLAS',
#   'Latitude': 33.748375,
#   'Longitude': -84.7535,
#   '2017 Income per Capita': 34199,
#   '2018 Income per Capita': 35406,
#   '2019 Income per Capita': 36772,
#   '2020 Income per Capita': 40264},
#  {'Agency Name': 'Douglas Police Department',
#   'County': 'COFFEE',
#   'Latitude': 31.511168,
#   'Longitude': -82.852135,
#   '2017 Income per Capita': 31301,
#   '2018 Income per Capita': 31761,
#   '2019 Income per Capita': 32880,
#   '2020 Income per Capita': 35507},
#  {'Agency Name': 'Douglasville Police Department',
#   'County': 'DOUGLAS',
#   'Latitude': 33.699317,
#   'Longitude': -84.765944,
#   '2017 Income per Capita': 34199,
#   '2018 Income per Capita': 35406,
#   '2019 Income per Capita': 36772,
#   '2020 Income per Capita': 40264},
#  {'Agency Name': 'Dublin Police Department',
#   'County': 'LAURENS',
#   'Latitude': 32.39322,
#   'Longitude': -82.926317,
#   '2017 Income per Capita': 35844,
#   '2018 Income per Capita': 37385,
#   '2019 Income per Capita': 38249,
#   '2020 Income per Capita': 41650},
#  {'Agency Name': 'Duluth Police Department',
#   'County': 'GWINNETT',
#   'Latitude': 33.994205,
#   'Longitude': -84.15061,
#   '2017 Income per Capita': 40337,
#   '2018 Income per Capita': 41877,
#   '2019 Income per Capita': 43573,
#   '2020 Income per Capita': 46886},
#  {'Agency Name': 'Dunwoody  Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.770661,
#   'Longitude': -84.226343,
#   '2017 Income per Capita': 48914,
#   '2018 Income per Capita': 51310,
#   '2019 Income per Capita': 52950,
#   '2020 Income per Capita': 56428},
#  {'Agency Name': "Early County Sheriff's Office",
#   'County': 'EARLY',
#   'Latitude': 31.324191,
#   'Longitude': -84.906723,
#   '2017 Income per Capita': 35181,
#   '2018 Income per Capita': 35805,
#   '2019 Income per Capita': 39225,
#   '2020 Income per Capita': 42889},
#  {'Agency Name': 'East Dublin Police Department',
#   'County': 'LAURENS',
#   'Latitude': 32.547714,
#   'Longitude': -82.870766,
#   '2017 Income per Capita': 35844,
#   '2018 Income per Capita': 37385,
#   '2019 Income per Capita': 38249,
#   '2020 Income per Capita': 41650},
#  {'Agency Name': 'East Ellijay Police Department',
#   'County': 'GILMER',
#   'Latitude': 34.690541,
#   'Longitude': -84.453984,
#   '2017 Income per Capita': 34342,
#   '2018 Income per Capita': 35252,
#   '2019 Income per Capita': 35979,
#   '2020 Income per Capita': 37542},
#  {'Agency Name': 'East Georgia State College',
#   'County': 'EMANUEL',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 31948,
#   '2018 Income per Capita': 31778,
#   '2019 Income per Capita': 33463,
#   '2020 Income per Capita': 37678},
#  {'Agency Name': 'East Point Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.681007,
#   'Longitude': -84.44159,
#   '2017 Income per Capita': 82345,
#   '2018 Income per Capita': 87395,
#   '2019 Income per Capita': 92961,
#   '2020 Income per Capita': 95683},
#  {'Agency Name': 'Eastman Police Department',
#   'County': 'DODGE',
#   'Latitude': 32.160235,
#   'Longitude': -83.156241,
#   '2017 Income per Capita': 29484,
#   '2018 Income per Capita': 30026,
#   '2019 Income per Capita': 31116,
#   '2020 Income per Capita': 33419},
#  {'Agency Name': 'Eatonton Police Department',
#   'County': 'PUTNAM',
#   'Latitude': 33.32106,
#   'Longitude': -83.37179,
#   '2017 Income per Capita': 41074,
#   '2018 Income per Capita': 43753,
#   '2019 Income per Capita': 45402,
#   '2020 Income per Capita': 48498},
#  {'Agency Name': "Echols County Sheriff's Office",
#   'County': 'ECHOLS',
#   'Latitude': 30.7085,
#   'Longitude': -82.836132,
#   '2017 Income per Capita': 27087,
#   '2018 Income per Capita': 28002,
#   '2019 Income per Capita': 28417,
#   '2020 Income per Capita': 31945},
#  {'Agency Name': 'Edison Police Department',
#   'County': 'CALHOUN',
#   'Latitude': 31.521279,
#   'Longitude': -84.62629,
#   '2017 Income per Capita': 24114,
#   '2018 Income per Capita': 23262,
#   '2019 Income per Capita': 25701,
#   '2020 Income per Capita': 28426},
#  {'Agency Name': "Effingham County Sheriff's Office",
#   'County': 'EFFINGHAM',
#   'Latitude': 32.361711,
#   'Longitude': -81.343337,
#   '2017 Income per Capita': 40521,
#   '2018 Income per Capita': 41839,
#   '2019 Income per Capita': 41988,
#   '2020 Income per Capita': 45069},
#  {'Agency Name': "Elbert County Sheriff's Office",
#   'County': 'ELBERT',
#   'Latitude': 34.116486,
#   'Longitude': -82.841815,
#   '2017 Income per Capita': 35129,
#   '2018 Income per Capita': 35669,
#   '2019 Income per Capita': 35899,
#   '2020 Income per Capita': 38414},
#  {'Agency Name': 'Elberton Police Department',
#   'County': 'ELBERT',
#   'Latitude': 34.116486,
#   'Longitude': -82.841815,
#   '2017 Income per Capita': 35129,
#   '2018 Income per Capita': 35669,
#   '2019 Income per Capita': 35899,
#   '2020 Income per Capita': 38414},
#  {'Agency Name': 'Ellaville Police Department',
#   'County': 'SCHLEY',
#   'Latitude': 32.263441,
#   'Longitude': -84.322724,
#   '2017 Income per Capita': 30213,
#   '2018 Income per Capita': 31890,
#   '2019 Income per Capita': 33278,
#   '2020 Income per Capita': 35588},
#  {'Agency Name': 'Ellijay Police Department',
#   'County': 'GILMER',
#   'Latitude': 34.690541,
#   'Longitude': -84.453984,
#   '2017 Income per Capita': 34342,
#   '2018 Income per Capita': 35252,
#   '2019 Income per Capita': 35979,
#   '2020 Income per Capita': 37542},
#  {'Agency Name': "Emanuel County Sheriff's Office",
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
# ...
#   'Latitude': 34.902662,
#   'Longitude': -83.732215,
#   '2017 Income per Capita': 37025,
#   '2018 Income per Capita': 38273,
#   '2019 Income per Capita': 40105,
#   '2020 Income per Capita': 42908},
#  {'Agency Name': 'Trenton Police Department',
#   'County': 'DADE',
#   'Latitude': 34.852424,
#   'Longitude': -85.506201,
#   '2017 Income per Capita': 33728,
#   '2018 Income per Capita': 35561,
#   '2019 Income per Capita': 34992,
#   '2020 Income per Capita': 37327},
#  {'Agency Name': "Treutlen County Sheriff's Office",
#   'County': 'TREUTLEN',
#   'Latitude': 32.409586,
#   'Longitude': -82.570882,
#   '2017 Income per Capita': 28694,
#   '2018 Income per Capita': 28662,
#   '2019 Income per Capita': 28946,
#   '2020 Income per Capita': 31899},
#  {'Agency Name': 'Trion Police Department',
#   'County': 'CHATTOOGA',
#   'Latitude': 34.54347,
#   'Longitude': -85.312996,
#   '2017 Income per Capita': 29702,
#   '2018 Income per Capita': 30296,
#   '2019 Income per Capita': 31069,
#   '2020 Income per Capita': 33855},
#  {'Agency Name': 'Troup County Marshal',
#   'County': 'TROUP',
#   'Latitude': 33.039577,
#   'Longitude': -85.03109,
#   '2017 Income per Capita': 34810,
#   '2018 Income per Capita': 35676,
#   '2019 Income per Capita': 37461,
#   '2020 Income per Capita': 40920},
#  {'Agency Name': "Troup County Sheriff's Office",
#   'County': 'TROUP',
#   'Latitude': 32.989746,
#   'Longitude': -85.00395,
#   '2017 Income per Capita': 34810,
#   '2018 Income per Capita': 35676,
#   '2019 Income per Capita': 37461,
#   '2020 Income per Capita': 40920},
#  {'Agency Name': 'Tunnel Hill Police Department',
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   '2017 Income per Capita': 36997,
#   '2018 Income per Capita': 39105,
#   '2019 Income per Capita': 40622,
#   '2020 Income per Capita': 43456},
#  {'Agency Name': 'Turner County Schools',
#   'County': 'TURNER',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 33292,
#   '2018 Income per Capita': 33394,
#   '2019 Income per Capita': 36111,
#   '2020 Income per Capita': 39281},
#  {'Agency Name': "Turner County Sheriff's Office",
#   'County': 'TURNER',
#   'Latitude': 31.6853,
#   'Longitude': -83.6399,
#   '2017 Income per Capita': 33292,
#   '2018 Income per Capita': 33394,
#   '2019 Income per Capita': 36111,
#   '2020 Income per Capita': 39281},
#  {'Agency Name': 'Twiggs County Board of Education',
#   'County': 'TWIGGS',
#   'Latitude': 32.68013,
#   'Longitude': -83.333824,
#   '2017 Income per Capita': 37252,
#   '2018 Income per Capita': 40393,
#   '2019 Income per Capita': 40913,
#   '2020 Income per Capita': 44686},
#  {'Agency Name': "Twiggs County Sheriff's Office",
#   'County': 'TWIGGS',
#   'Latitude': 32.665847,
#   'Longitude': -83.425879,
#   '2017 Income per Capita': 37252,
#   '2018 Income per Capita': 40393,
#   '2019 Income per Capita': 40913,
#   '2020 Income per Capita': 44686},
#  {'Agency Name': 'Twin City Police Department',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   '2017 Income per Capita': 31948,
#   '2018 Income per Capita': 31778,
#   '2019 Income per Capita': 33463,
#   '2020 Income per Capita': 37678},
#  {'Agency Name': 'Tybee Island Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   '2017 Income per Capita': 45559,
#   '2018 Income per Capita': 47256,
#   '2019 Income per Capita': 48545,
#   '2020 Income per Capita': 51805},
#  {'Agency Name': 'Tyrone Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.478733,
#   'Longitude': -84.594215,
#   '2017 Income per Capita': 61841,
#   '2018 Income per Capita': 66106,
#   '2019 Income per Capita': 68696,
#   '2020 Income per Capita': 71384},
#  {'Agency Name': 'Union City Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.57888,
#   'Longitude': -84.551994,
#   '2017 Income per Capita': 82345,
#   '2018 Income per Capita': 87395,
#   '2019 Income per Capita': 92961,
#   '2020 Income per Capita': 95683},
#  {'Agency Name': "Union County Sheriff's Office",
#   'County': 'UNION',
#   'Latitude': 34.83377,
#   'Longitude': -83.989573,
#   '2017 Income per Capita': 36333,
#   '2018 Income per Capita': 36919,
#   '2019 Income per Capita': 38294,
#   '2020 Income per Capita': 39839},
#  {'Agency Name': 'University of Georgia',
#   'County': 'CLARKE',
#   'Latitude': 33.952185,
#   'Longitude': -83.367152,
#   '2017 Income per Capita': 32362,
#   '2018 Income per Capita': 33481,
#   '2019 Income per Capita': 34935,
#   '2020 Income per Capita': 37588},
#  {'Agency Name': 'University of North Georgia',
#   'County': 'LUMPKIN',
#   'Latitude': 34.568135,
#   'Longitude': -83.998906,
#   '2017 Income per Capita': 36259,
#   '2018 Income per Capita': 38117,
#   '2019 Income per Capita': 39041,
#   '2020 Income per Capita': 41181},
#  {'Agency Name': 'University of West Georgia',
#   'County': 'CARROLL',
#   'Latitude': 33.571545,
#   'Longitude': -85.094604,
#   '2017 Income per Capita': 37126,
#   '2018 Income per Capita': 38273,
#   '2019 Income per Capita': 39725,
#   '2020 Income per Capita': 42058},
#  {'Agency Name': "Upson County Sheriff's Office",
#   'County': 'UPSON',
#   'Latitude': 32.937847,
#   'Longitude': -84.33762,
#   '2017 Income per Capita': 33633,
#   '2018 Income per Capita': 34893,
#   '2019 Income per Capita': 36600,
#   '2020 Income per Capita': 39391},
#  {'Agency Name': 'Uvalda Police Department',
#   'County': 'MONTGOMERY',
#   'Latitude': 32.172108,
#   'Longitude': -82.533349,
#   '2017 Income per Capita': 29008,
#   '2018 Income per Capita': 29016,
#   '2019 Income per Capita': 30196,
#   '2020 Income per Capita': 34061},
#  {'Agency Name': 'Valdosta Police Department',
#   'County': 'LOWNDES',
#   'Latitude': 30.826075,
#   'Longitude': -83.278145,
#   '2017 Income per Capita': 35750,
#   '2018 Income per Capita': 37150,
#   '2019 Income per Capita': 38136,
#   '2020 Income per Capita': 41117},
#  {'Agency Name': 'Valdosta State University',
#   'County': 'LOWNDES',
#   'Latitude': 30.813684,
#   'Longitude': -83.264366,
#   '2017 Income per Capita': 35750,
#   '2018 Income per Capita': 37150,
#   '2019 Income per Capita': 38136,
#   '2020 Income per Capita': 41117},
#  {'Agency Name': 'Vienna Police Department',
#   'County': 'DOOLY',
#   'Latitude': 32.151995,
#   'Longitude': -83.807167,
#   '2017 Income per Capita': 29914,
#   '2018 Income per Capita': 29886,
#   '2019 Income per Capita': 32995,
#   '2020 Income per Capita': 34582},
#  {'Agency Name': 'Wadley Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   '2017 Income per Capita': 32753,
#   '2018 Income per Capita': 32684,
#   '2019 Income per Capita': 34766,
#   '2020 Income per Capita': 39544},
#  {'Agency Name': "Walker County Sheriff's Office",
#   'County': 'WALKER',
#   'Latitude': 34.735827,
#   'Longitude': -85.305385,
#   '2017 Income per Capita': 31848,
#   '2018 Income per Capita': 32834,
#   '2019 Income per Capita': 33883,
#   '2020 Income per Capita': 36157},
#  {'Agency Name': 'Walthourville Police Department',
#   'County': 'LIBERTY',
#   'Latitude': 31.807296,
#   'Longitude': -81.457864,
#   '2017 Income per Capita': 34459,
#   '2018 Income per Capita': 36766,
#   '2019 Income per Capita': 36969,
#   '2020 Income per Capita': 40087},
#  {'Agency Name': "Walton County Sheriff's Office",
#   'County': 'WALTON',
#   'Latitude': 33.77116,
#   'Longitude': -83.700356,
#   '2017 Income per Capita': 39434,
#   '2018 Income per Capita': 41047,
#   '2019 Income per Capita': 42588,
#   '2020 Income per Capita': 44977},
#  {'Agency Name': "Ware County Sheriff's Office",
#   'County': 'WARE',
#   'Latitude': 31.25967,
#   'Longitude': -82.40221,
#   '2017 Income per Capita': 32626,
#   '2018 Income per Capita': 33082,
#   '2019 Income per Capita': 33737,
#   '2020 Income per Capita': 37306},
#  {'Agency Name': 'Warm Springs Police Department',
#   'County': 'MERIWETHER',
#   'Latitude': 33.03022,
#   'Longitude': -84.663279,
#   '2017 Income per Capita': 33059,
#   '2018 Income per Capita': 34437,
#   '2019 Income per Capita': 35604,
#   '2020 Income per Capita': 39121},
#  {'Agency Name': "Warren County Sheriff's Office",
#   'County': 'WARREN',
#   'Latitude': 33.419169,
#   'Longitude': -82.688012,
#   '2017 Income per Capita': 32724,
#   '2018 Income per Capita': 33999,
#   '2019 Income per Capita': 36015,
#   '2020 Income per Capita': 39545},
#  {'Agency Name': 'Warrenton Police Department',
#   'County': 'WARREN',
#   'Latitude': 33.419169,
#   'Longitude': -82.688012,
#   '2017 Income per Capita': 32724,
#   '2018 Income per Capita': 33999,
#   '2019 Income per Capita': 36015,
#   '2020 Income per Capita': 39545},
#  {'Agency Name': 'Warwick Police Department',
#   'County': 'WORTH',
#   'Latitude': 31.551773,
#   'Longitude': -83.84996,
#   '2017 Income per Capita': 32818,
#   '2018 Income per Capita': 34010,
#   '2019 Income per Capita': 36250,
#   '2020 Income per Capita': 39102},
#  {'Agency Name': 'Washington County Board of Education',
#   'County': 'WASHINGTON',
#   'Latitude': 32.971848,
#   'Longitude': -82.798112,
#   '2017 Income per Capita': 34168,
#   '2018 Income per Capita': 34685,
#   '2019 Income per Capita': 35889,
#   '2020 Income per Capita': 39151},
#  {'Agency Name': "Washington County Sheriff's Office",
#   'County': 'WASHINGTON',
#   'Latitude': 32.971848,
#   'Longitude': -82.798112,
#   '2017 Income per Capita': 34168,
#   '2018 Income per Capita': 34685,
#   '2019 Income per Capita': 35889,
#   '2020 Income per Capita': 39151},
#  {'Agency Name': 'Watkinsville Police Department',
#   'County': 'OCONEE',
#   'Latitude': 33.834125,
#   'Longitude': -83.437728,
#   '2017 Income per Capita': 64454,
#   '2018 Income per Capita': 66432,
#   '2019 Income per Capita': 71604,
#   '2020 Income per Capita': 71768},
#  {'Agency Name': 'Waverly Hall Police Department',
#   'County': 'HARRIS',
#   'Latitude': 32.731549,
#   'Longitude': -84.912432,
#   '2017 Income per Capita': 45709,
#   '2018 Income per Capita': 47669,
#   '2019 Income per Capita': 49048,
#   '2020 Income per Capita': 51168},
#  {'Agency Name': "Wayne County Sheriff's Office",
#   'County': 'WAYNE',
#   'Latitude': 31.604576,
#   'Longitude': -81.87975,
#   '2017 Income per Capita': 29868,
#   '2018 Income per Capita': 31330,
#   '2019 Income per Capita': 31927,
#   '2020 Income per Capita': 34877},
#  {'Agency Name': 'Waynesboro Police Department',
#   'County': 'BURKE',
#   'Latitude': 33.091118,
#   'Longitude': -82.015236,
#   '2017 Income per Capita': 34447,
#   '2018 Income per Capita': 34940,
#   '2019 Income per Capita': 38419,
#   '2020 Income per Capita': 41973},
#  {'Agency Name': "Webster County Sheriff's Office",
#   'County': 'WEBSTER',
#   'Latitude': 32.046554,
#   'Longitude': -84.553218,
#   '2017 Income per Capita': 31809,
#   '2018 Income per Capita': 32221,
#   '2019 Income per Capita': 33487,
#   '2020 Income per Capita': 36032},
#  {'Agency Name': 'Wesleyan College',
#   'County': 'BIBB',
#   'Latitude': 32.876038,
#   'Longitude': -83.71381,
#   '2017 Income per Capita': 39509,
#   '2018 Income per Capita': 40433,
#   '2019 Income per Capita': 41517,
#   '2020 Income per Capita': 44830},
#  {'Agency Name': 'West Georgia Technical College',
#   'County': 'HARALSON',
#   'Latitude': 33.795165,
#   'Longitude': -85.220062,
#   '2017 Income per Capita': 35038,
#   '2018 Income per Capita': 36186,
#   '2019 Income per Capita': 37319,
#   '2020 Income per Capita': 39401},
#  {'Agency Name': "Wheeler County Sheriff's Office",
#   'County': 'WHEELER',
#   'Latitude': 32.14889,
#   'Longitude': -82.78266,
#   '2017 Income per Capita': 18513,
#   '2018 Income per Capita': 18465,
#   '2019 Income per Capita': 18944,
#   '2020 Income per Capita': 21087},
#  {'Agency Name': 'Whigham Police Department',
#   'County': 'GRADY',
#   'Latitude': 30.875891,
#   'Longitude': -84.245066,
#   '2017 Income per Capita': 33287,
#   '2018 Income per Capita': 34108,
#   '2019 Income per Capita': 35195,
#   '2020 Income per Capita': 37725},
#  {'Agency Name': "White County Sheriff's Office",
#   'County': 'WHITE',
#   'Latitude': 34.618458,
#   'Longitude': -83.75649,
#   '2017 Income per Capita': 34904,
#   '2018 Income per Capita': 35641,
#   '2019 Income per Capita': 36814,
#   '2020 Income per Capita': 38858},
#  {'Agency Name': 'White Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   '2017 Income per Capita': 37028,
#   '2018 Income per Capita': 38310,
#   '2019 Income per Capita': 39755,
#   '2020 Income per Capita': 42734},
#  {'Agency Name': 'Whitesburg Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.49634,
#   'Longitude': -84.91557,
#   '2017 Income per Capita': 37126,
#   '2018 Income per Capita': 38273,
#   '2019 Income per Capita': 39725,
#   '2020 Income per Capita': 42058},
#  {'Agency Name': "Whitfield County Sheriff's Office",
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   '2017 Income per Capita': 36997,
#   '2018 Income per Capita': 39105,
#   '2019 Income per Capita': 40622,
#   '2020 Income per Capita': 43456},
#  {'Agency Name': "Wilcox County Sheriff's Office",
#   'County': 'WILCOX',
#   'Latitude': 31.962717,
#   'Longitude': -83.438262,
#   '2017 Income per Capita': 27059,
#   '2018 Income per Capita': 26687,
#   '2019 Income per Capita': 28621,
#   '2020 Income per Capita': 29895},
#  {'Agency Name': "Wilkes County Sheriff's Office",
#   'County': 'WILKES',
#   'Latitude': 33.724213,
#   'Longitude': -82.72123,
#   '2017 Income per Capita': 39932,
#   '2018 Income per Capita': 40172,
#   '2019 Income per Capita': 41337,
#   '2020 Income per Capita': 42093},
#  {'Agency Name': "Wilkinson County Sheriff's Office",
#   'County': 'WILKINSON',
#   'Latitude': 32.804312,
#   'Longitude': -83.175497,
#   '2017 Income per Capita': 34206,
#   '2018 Income per Capita': 35334,
#   '2019 Income per Capita': 37209,
#   '2020 Income per Capita': 40158},
#  {'Agency Name': 'Willacoochee Police Department',
#   'County': 'ATKINSON',
#   'Latitude': 31.340805,
#   'Longitude': -83.04818,
#   '2017 Income per Capita': 28937,
#   '2018 Income per Capita': 28962,
#   '2019 Income per Capita': 30251,
#   '2020 Income per Capita': 31938},
#  {'Agency Name': 'Winder Police Department',
#   'County': 'BARROW',
#   'Latitude': 33.993984,
#   'Longitude': -83.71819,
#   '2017 Income per Capita': 35807,
#   '2018 Income per Capita': 36720,
#   '2019 Income per Capita': 37318,
#   '2020 Income per Capita': 40435},
#  {'Agency Name': 'Winterville Police Department',
#   'County': 'CLARKE',
#   'Latitude': 33.952185,
#   'Longitude': -83.367152,
#   '2017 Income per Capita': 32362,
#   '2018 Income per Capita': 33481,
#   '2019 Income per Capita': 34935,
#   '2020 Income per Capita': 37588},
#  {'Agency Name': 'Woodbury Police Department',
#   'County': 'MERIWETHER',
#   'Latitude': 33.03022,
#   'Longitude': -84.663279,
#   '2017 Income per Capita': 33059,
#   '2018 Income per Capita': 34437,
#   '2019 Income per Capita': 35604,
#   '2020 Income per Capita': 39121},
#  {'Agency Name': 'Woodstock Police Department',
#   'County': 'CHEROKEE',
#   'Latitude': 34.08742,
#   'Longitude': -84.47999,
#   '2017 Income per Capita': 50281,
#   '2018 Income per Capita': 52052,
#   '2019 Income per Capita': 53774,
#   '2020 Income per Capita': 56278},
#  {'Agency Name': "Worth County Sheriff's Office",
#   'County': 'WORTH',
#   'Latitude': 31.527578,
#   'Longitude': -83.83554,
#   '2017 Income per Capita': 32818,
#   '2018 Income per Capita': 34010,
#   '2019 Income per Capita': 36250,
#   '2020 Income per Capita': 39102},
#  {'Agency Name': 'Wrens Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   '2017 Income per Capita': 32753,
#   '2018 Income per Capita': 32684,
#   '2019 Income per Capita': 34766,
#   '2020 Income per Capita': 39544},
#  {'Agency Name': 'Wrightsville Police Department',
#   'County': 'JOHNSON',
#   'Latitude': 32.72852,
#   'Longitude': -82.731895,
#   '2017 Income per Capita': 24158,
#   '2018 Income per Capita': 24822,
#   '2019 Income per Capita': 25343,
#   '2020 Income per Capita': 27965},
#  {'Agency Name': 'Young Harris College',
#   'County': 'TOWNS',
#   'Latitude': nan,
#   'Longitude': nan,
#   '2017 Income per Capita': 37025,
#   '2018 Income per Capita': 38273,
#   '2019 Income per Capita': 40105,
#   '2020 Income per Capita': 42908},
#  {'Agency Name': 'Zebulon Police Department',
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   '2017 Income per Capita': 38458,
#   '2018 Income per Capita': 40168,
#   '2019 Income per Capita': 41710,
#   '2020 Income per Capita': 44311}]
