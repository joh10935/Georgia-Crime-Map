# %% [markdown]
# # Load Data to SQL ETL

# %% [markdown]
# Use this page to ETL data into your postgresql database

# %% [markdown]
# ### Imports

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %% [markdown]
# ### Initializations

# %%
# set key
api_key = "<your data.gov api key>"

#your postgresql db
engine = create_engine(f'postgresql://postgres:password@localhost/GACRIME')

# %% [markdown]
# ### Load Agency Table / Build Dictionary

# %%
# Call Agencies by State (GA) Endpoint
base_url = f"http://api.usa.gov/crime/fbi/sapi//api/agencies/byStateAbbr/GA?API_KEY={api_key}"
response = requests.get(base_url).json()

# Extract into DF
agencyDF = pd.json_normalize(response['results'])
agencyDF = agencyDF[['ori','agency_name','agency_type_name','county_name','latitude','longitude']]

agencyDF = agencyDF.sort_values(by=['agency_name'])
agencyDF.insert(0, 'agencyid', range(1, 1 + len(agencyDF.index)))
agencyDF.to_sql(name='Agency', con=engine, if_exists='replace', index=False)

#put agencies in dictionary for lookup
agency_dict = dict(zip(agencyDF.agency_name, agencyDF.agencyid))
agency_dict
# Out:
# {'Abbeville Police Department': 1,
#  'Abraham Baldwin Agricultural College': 2,
#  'Acworth Police Department': 3,
#  'Adairsville Police Department': 4,
#  'Adel Police Department': 5,
#  'Adrian Police Department': 6,
#  'Agnes Scott College': 7,
#  'Alamo Police Department': 8,
#  'Alapaha Police Department': 9,
#  'Albany Police Department': 10,
#  'Albany State University': 11,
#  'Albany Technical College': 12,
#  'Albany-Dougherty Metropolitan Drug Squad': 13,
#  'Alma Police Department': 14,
#  'Alpharetta Police Department': 15,
#  'Alto Police Department': 16,
#  'Americus Police Department': 17,
#  'Andrew College ': 18,
#  'Appling County Board of Education': 19,
#  "Appling County Sheriff's Office": 20,
#  'Aragon Police Department': 21,
#  'Arcade Police Department': 22,
#  'Arlington Police Department': 23,
#  'Ashburn Police Department': 24,
#  'Athens Technical College': 25,
#  'Athens-Clarke County Police Department': 26,
#  "Atkinson County Sheriff's Office": 27,
#  'Atlanta Metropolitan State College': 28,
#  'Atlanta Police Department': 29,
#  'Atlanta Public Schools': 30,
#  'Atlanta Technical College': 31,
#  'Attapulgus Police Department': 32,
#  'Auburn Police Department': 33,
#  'Augusta Board of Education': 34,
#  'Augusta Technical College': 35,
#  "Augusta-Richmond County Sheriff's Office": 36,
#  'Austell Police Department': 37,
#  'Avondale Estates Police Department': 38,
#  "Bacon County Sheriff's Office": 39,
#  'Bainbridge Police Department': 40,
#  'Bainbridge State College': 41,
#  "Baker County Sheriff's Office": 42,
#  "Baldwin County Sheriff's Office": 43,
#  'Baldwin Police Department': 44,
#  'Ball Ground Police Department': 45,
#  "Banks County Sheriff's Office": 46,
#  'Barnesville Police Department': 47,
#  "Barrow County Sheriff's Office": 48,
#  "Bartow County Sheriff's Office": 49,
#  'Bartow Police Department': 50,
#  'Baxley Police Department': 51,
#  "Ben Hill County Sheriff's Office": 52,
#  'Berlin Police Department': 53,
#  "Berrien County Sheriff's Office": 54,
#  'Berry College': 55,
#  'Bibb County Board of Education': 56,
#  "Bibb County Sheriff's Office": 57,
#  'Blackshear Police Department': 58,
#  'Blairsville Police Department': 59,
#  'Blakely Police Department': 60,
#  "Bleckley County Sheriff's Office": 61,
#  'Bloomingdale Police Department': 62,
#  'Blue Ridge Police Department': 63,
#  'Blythe Police Department': 64,
#  'Boston Police Department': 65,
#  'Bowdon Police Department': 66,
#  "Brantley County Sheriff's Office": 67,
#  'Braselton Police Department': 68,
#  'Braswell  Police Department': 69,
#  'Bremen Police Department': 70,
#  'Brookhaven Police Department': 71,
#  'Brooklet Police Department': 72,
#  "Brooks County Sheriff's Office": 73,
#  'Broxton Police Department': 74,
#  'Brunswick Police Department': 75,
#  "Bryan County Sheriff's Office": 76,
#  'Buchanan Police Department': 77,
#  'Buena Vista Police Department': 78,
#  "Bulloch County Sheriff's Office": 79,
#  "Burke  County Sheriff's Office": 80,
#  'Butler Police Department': 81,
#  "Butts County Sheriff's Office": 82,
#  'Byron Police Department': 83,
#  'Cairo Police Department': 84,
#  "Calhoun County Sheriff's Office": 85,
#  'Calhoun Police Department': 86,
#  "Camden County Sheriff's Office": 87,
#  'Camilla Police Department': 88,
#  "Candler County Sheriff's Office": 89,
#  'Canon Police Department': 90,
#  'Canton Police Department': 91,
#  "Carroll County Sheriff's Office": 92,
#  'Carrollton Police Department': 93,
#  'Cartersville Police Department': 94,
#  "Catoosa County Sheriff's Office": 95,
#  'Cave Spring Police Department': 96,
#  'Cecil': 97,
#  'Cedartown Police Department': 98,
#  'Centerville Police Department': 99,
#  'Chamblee Police Department': 100,
#  "Charlton County Sheriff's Office": 101,
#  'Chatham County Board of Education': 102,
#  'Chatham County Police Department': 103,
#  "Chatham County Sheriff's Office": 104,
#  'Chatsworth Police Department': 105,
#  "Chattahoochee County Sheriff's Office": 106,
#  'Chattahoochee Hills Police Department': 107,
#  'Chattahoochee Technical College': 108,
#  "Chattooga County Sheriff's Office": 109,
#  'Cherokee County Board of Education': 110,
#  'Cherokee County Marshal': 111,
#  "Cherokee County Sheriff's Office": 112,
#  'Chickamauga Police Department': 113,
#  'Clark Atlanta University': 114,
#  "Clarke County Sheriff's Office": 115,
#  'Clarkesville Police Department': 116,
#  'Clarkston Police Department': 117,
#  'Claxton Police Department': 118,
#  "Clay County Sheriff's Office": 119,
#  'Clayton County Police Department': 120,
#  "Clayton County Sheriff's Office": 121,
#  'Clayton Police Department': 122,
#  'Clayton State University': 123,
#  'Cleveland Police Department': 124,
#  "Clinch County Sheriff's Office": 125,
#  'Cobb County Board of Education': 126,
#  'Cobb County Police Department': 127,
#  "Cobb County Sheriff's Office": 128,
#  'Cochran Police Department': 129,
#  "Coffee County Sheriff's Office": 130,
#  'Cohutta Police Department': 131,
#  'College Park Police Department': 132,
#  'College of Coastal Georgia': 133,
#  "Colquitt  County Sheriff's Office": 134,
#  'Colquitt Police Department': 135,
#  "Columbia County Sheriff's Office": 136,
#  'Columbus Police Department': 137,
#  'Columbus State University': 138,
#  'Commerce Police Department': 139,
#  'Conyers Police Department': 140,
#  "Cook County Sheriff's Office": 141,
#  'Coolidge Police Department': 142,
#  'Cordele Police Department': 143,
#  'Cornelia Police Department': 144,
#  'Covington Police Department': 145,
#  "Coweta County Sheriff's Office": 146,
#  "Crawford County Sheriff's Office": 147,
#  "Crisp County Sheriff's Office": 148,
#  'Cumming Police Department': 149,
#  'Cuthbert Police Department': 150,
#  "Dade County Sheriff's Office": 151,
#  'Dallas Police Department': 152,
#  'Dalton Police Department': 153,
#  'Dalton State College': 154,
#  'Danielsville Police Department': 155,
#  'Darien Police Department': 156,
#  'Davisboro Police Department': 157,
#  "Dawson County Sheriff's Office": 158,
#  'Dawson Police Department': 159,
#  'DeKalb County Police Department': 160,
#  'DeKalb County School System': 161,
#  "DeKalb County Sheriff's Office": 162,
#  'Decatur County Schools': 163,
#  "Decatur County Sheriff's Office": 164,
#  'Decatur Police Department': 165,
#  'Demorest Police Department': 166,
#  'Department of Transportation Office of Investigations': 167,
#  'Dillard Police Department': 168,
#  "Dodge County Sheriff's Office": 169,
#  'Doerun Police Department': 170,
#  'Donalsonville Police Department': 171,
#  "Dooly County Sheriff's Office": 172,
#  'Doraville Police Department': 173,
#  'Dougherty County Board of Education': 174,
#  'Dougherty County Police Department': 175,
#  "Dougherty County Sheriff's Office": 176,
#  "Douglas County Sheriff's Office": 177,
#  'Douglas Police Department': 178,
#  'Douglasville Police Department': 179,
#  'Dublin Police Department': 180,
#  'Duluth Police Department': 181,
#  'Dunwoody  Police Department': 182,
#  "Early County Sheriff's Office": 183,
#  'East Dublin Police Department': 184,
#  'East Ellijay Police Department': 185,
#  'East Georgia State College': 186,
#  'East Point Police Department': 187,
#  'Eastman Police Department': 188,
#  'Eatonton Police Department': 189,
#  "Echols County Sheriff's Office": 190,
#  'Edison Police Department': 191,
#  "Effingham County Sheriff's Office": 192,
#  "Elbert County Sheriff's Office": 193,
#  'Elberton Police Department': 194,
#  'Ellaville Police Department': 195,
#  'Ellijay Police Department': 196,
#  "Emanuel County Sheriff's Office": 197,
#  'Emerson Police Department': 198,
#  'Emory University': 199,
#  'Enigma Police Department': 200,
#  'Eton Police Department': 201,
#  'Euharlee Police Department': 202,
#  "Evans County Sheriff's Office": 203,
#  'Fairburn Police Department': 204,
#  'Fairmount Police Department': 205,
#  "Fannin County Sheriff's Office": 206,
#  'Fayette County Marshal': 207,
#  "Fayette County Sheriff's Office": 208,
#  'Fayetteville Police Department': 209,
#  'Fitzgerald Police Department': 210,
#  'Flowery Branch Police Department': 211,
#  'Floyd County Police Department': 212,
#  "Floyd County Sheriff's Office": 213,
#  'Folkston Police Department': 214,
#  'Forest Park Police Department': 215,
#  'Forsyth County Fire Investigation Unit': 216,
#  "Forsyth County Sheriff's Office": 217,
#  'Forsyth Police Department': 218,
#  'Fort Oglethorpe Police Department': 219,
#  'Fort Valley Police Department': 220,
#  'Fort Valley State University': 221,
#  "Franklin County Sheriff's Office": 222,
#  'Franklin Police Department': 223,
#  'Franklin Springs Police Department': 224,
#  'Fulton County Marshal': 225,
#  'Fulton County Police Department': 226,
#  'Fulton County School System': 227,
#  "Fulton County Sheriff's Office": 228,
#  'Gainesville Police Department': 229,
#  'Garden City Police Department': 230,
#  'Georgia Bureau of Investigation: Headquarters': 231,
#  'Georgia College and State University': 232,
#  'Georgia Department of Public Safety': 233,
#  'Georgia Forestry Commission': 234,
#  'Georgia Gwinnett College': 235,
#  'Georgia Highlands College': 236,
#  'Georgia Institute of Technology': 237,
#  'Georgia Military College': 238,
#  'Georgia Northwestern Technical College': 239,
#  'Georgia Piedmont Technical College': 240,
#  'Georgia Public Safety Training Center': 241,
#  'Georgia Regents University': 242,
#  'Georgia Southern University': 243,
#  'Georgia Southwestern State University': 244,
#  'Georgia State University': 245,
#  'Georgia World Congress': 246,
#  "Gilmer County Sheriff's Office": 247,
#  "Glascock County Sheriff's Office": 248,
#  'Glennville Police Department': 249,
#  'Glynn County Police Department': 250,
#  'Glynn County School System': 251,
#  "Glynn County Sheriff's Office": 252,
#  "Gordon County Sheriff's Office": 253,
#  'Gordon Police Department': 254,
#  'Gordon State College': 255,
#  'Grady County Schools': 256,
#  "Grady County Sheriff's Office": 257,
#  'Graham': 258,
#  'Grantville Police Department': 259,
#  'Gray Police Department': 260,
#  "Greene County Sheriff's Office": 261,
#  'Greensboro Police Department': 262,
#  'Greenville Police Department': 263,
#  'Griffin Police Department': 264,
#  'Grovetown Police Department': 265,
#  'Guyton Police Department': 266,
#  'Gwinnett County Police Department': 267,
#  'Gwinnett County Public Schools': 268,
#  'Gwinnett Technical College': 269,
#  "Habersham County Sheriff's Office": 270,
#  'Hagan Police Department': 271,
#  'Hahira Police Department': 272,
#  'Hall County Marshal': 273,
#  "Hall County Sheriff's Office": 274,
#  'Hamilton Police Department': 275,
#  'Hampton Police Department': 276,
#  "Hancock County Sheriff's Office": 277,
#  'Hapeville Police Department': 278,
#  "Haralson County Sheriff's Office": 279,
#  'Harlem Police Department': 280,
#  "Harris County Sheriff's Office": 281,
#  "Hart County Sheriff's Office": 282,
#  'Hartsfield-Jackson Atlanta International Airport': 283,
#  'Hartwell Police Department': 284,
#  'Hazlehurst Police Department': 285,
#  "Heard County Sheriff's Office": 286,
#  'Helen Police Department': 287,
#  'Henry County Police Department': 288,
#  "Henry County Sheriff's Office": 289,
#  'Hephzibah Police Department': 290,
#  'Hiawassee Police Department': 291,
#  'Hinesville Police Department': 292,
#  'Hiram Police Department': 293,
#  'Hoboken Police Department': 294,
#  'Hogansville Police Department': 295,
#  'Holly Springs Police Department': 296,
#  'Homeland Police Department': 297,
#  'Homerville Police Department': 298,
#  'Hoschton Police Department': 299,
#  "Houston County Sheriff's Office": 300,
#  'Ideal Police Department': 301,
#  "Irwin County Sheriff's Office": 302,
#  'Irwinton Police Department': 303,
#  'Ivey Police Department': 304,
#  "Jackson County Sheriff's Office": 305,
#  'Jackson Police Department': 306,
#  'Jacksonville Police Department': 307,
#  "Jasper County Sheriff's Office": 308,
#  'Jasper Police Department': 309,
#  "Jeff Davis County Sheriff's Office": 310,
#  "Jefferson County Sheriff's Office": 311,
#  'Jefferson Police Department': 312,
#  "Jenkins County Sheriff's Office": 313,
#  'Jesup Police Department': 314,
#  'Johns Creek Police Department': 315,
#  "Johnson County Sheriff's Office": 316,
#  "Jones County Sheriff's Office": 317,
#  'Jonesboro Police Department': 318,
#  'Kennesaw Police Department': 319,
#  'Kennesaw State University': 320,
#  'Kingsland Police Department': 321,
#  'Kingston Police Department': 322,
#  'LaGrange Police Department': 323,
#  'Lafayette Police Department': 324,
#  'Lake City Police Department': 325,
#  'Lake Park Police Department': 326,
#  'Lakeland Police Department': 327,
#  "Lamar County Sheriff's Office": 328,
#  'Lanier County Board of Education': 329,
#  "Lanier County Sheriff's Office": 330,
#  "Laurens County Sheriff's Office": 331,
#  'Lavonia Police Department': 332,
#  'Lawrenceville Police Department': 333,
#  'Leary Police Department': 334,
#  "Lee County Sheriff's Office": 335,
#  'Leesburg Police Department': 336,
#  'Lenox Police Department': 337,
#  'Leslie Police Department': 338,
#  "Liberty County Sheriff's Office": 339,
#  'Lilburn Police Department': 340,
#  "Lincoln County Sheriff's Office": 341,
#  'Lincolnton Police Department': 342,
#  'Lithonia Police Department': 343,
#  'Locust Grove Police Department': 344,
#  'Loganville Police Department': 345,
#  "Long County Sheriff's Office": 346,
#  'Lookout Mountain Police Department': 347,
#  'Louisville Police Department': 348,
#  'Lovejoy': 349,
#  "Lowndes County Sheriff's Office": 350,
#  'Ludowici Police Department': 351,
#  'Lumber City Police Department': 352,
#  "Lumpkin County Sheriff's Office": 353,
#  'Lumpkin Police Department': 354,
#  'Luthersville Police Department': 355,
#  'Lyons Police Department': 356,
#  "Macon County Sheriff's Office": 357,
#  "Madison County Sheriff's Office": 358,
#  'Madison Police Department': 359,
#  'Manchester Police Department': 360,
#  'Marietta Police Department': 361,
#  "Marion County Sheriff's Office": 362,
#  'Marshallville Police Department': 363,
#  'Maysville Police Department': 364,
#  'McCaysville Police Department': 365,
#  'McDonough Police Department': 366,
#  "McDuffie County Sheriff's Office": 367,
#  'McIntosh County Schools': 368,
#  "McIntosh County Sheriff's Office": 369,
#  'McIntyre Police Department': 370,
#  'McRae Police Department': 371,
#  'Meigs Police Department': 372,
#  'Mercer University': 373,
#  "Meriwether County Sheriff's Office": 374,
#  'Metropolitan Atlanta Rapid Transit Authority': 375,
#  'Metter Police Department': 376,
#  'Middle Georgia State University': 377,
#  'Midville Police Department': 378,
#  'Midway Police Department': 379,
#  'Milan Police Department': 380,
#  'Milledgeville Police Department': 381,
#  'Millen Police Department': 382,
#  "Miller County Sheriff's Office": 383,
#  'Milton Police Department': 384,
#  "Mitchell County Sheriff's Office": 385,
#  'Molena Police Department': 386,
#  "Monroe County Sheriff's Office": 387,
#  'Monroe Police Department': 388,
#  'Montezuma Police Department': 389,
#  "Montgomery County Sheriff's Office": 390,
#  'Monticello Police Department': 391,
#  'Morehouse College': 392,
#  'Morehouse School of Medicine': 393,
#  "Morgan County Sheriff's Office": 394,
#  'Morris Brown College': 395,
#  'Morrow Police Department': 396,
#  'Morven Police Department': 397,
#  'Moultrie Police Department': 398,
#  'Mount Airy Police Department': 399,
#  'Mount Vernon Police Department': 400,
#  'Mount Zion Police Department': 401,
#  'Mountain City Police Department': 402,
#  "Murray County Sheriff's Office": 403,
#  "Muscogee  County Sheriff's Office": 404,
#  'Muscogee City Marshal': 405,
#  'Muscogee County Schools': 406,
#  'Nahunta Police Department': 407,
#  'Nashville Police Department': 408,
#  'Nelson Police Department': 409,
#  'Newington Police Department': 410,
#  'Newnan Police Department': 411,
#  "Newton County Sheriff's Office": 412,
#  'Newton Police Department': 413,
#  'Nicholls Police Department': 414,
#  'Norcross Police Department': 415,
#  'Norman Park Police Department': 416,
#  'North Georgia Technical College': 417,
#  'Oak Park Police Department': 418,
#  'Oakwood Police Department': 419,
#  'Ocilla Police Department': 420,
#  'Oconee  Police Department': 421,
#  "Oconee County Sheriff's Office": 422,
#  "Oglethorpe County Sheriff's Office": 423,
#  'Oglethorpe Police Department': 424,
#  'Oliver Police Department': 425,
#  'Omega Police Department': 426,
#  'Oxford Police Department': 427,
#  'Paine College': 428,
#  'Palmetto Police Department': 429,
#  'Patterson Police Department': 430,
#  'Paulding County Marshal': 431,
#  "Paulding County Sheriff's Office": 432,
#  'Pavo Police Department': 433,
#  "Peach County Sheriff's Office": 434,
#  'Peachtree City Police Department': 435,
#  'Pearson Police Department': 436,
#  'Pelham Police Department': 437,
#  'Pembroke Police Department': 438,
#  'Pendergrass  Police Department': 439,
#  'Perry Police Department': 440,
#  'Pickens County Board of Education': 441,
#  "Pickens County Sheriff's Office": 442,
#  'Piedmont College ': 443,
#  "Pierce County Sheriff's Office": 444,
#  "Pike County Sheriff's Office": 445,
#  'Pine Lake Police Department': 446,
#  'Pine Mountain Police Department': 447,
#  'Pineview Police Department': 448,
#  'Plains Police Department': 449,
#  'Polk County Police Department': 450,
#  "Polk County Sheriff's Office": 451,
#  'Pooler Police Department': 452,
#  'Port Wentworth Police Department': 453,
#  'Portal Police Department': 454,
#  'Porterdale Police Department': 455,
#  'Ports Authority Savannah': 456,
#  'Poulan Police Department': 457,
#  'Powder Springs Police Department': 458,
#  "Pulaski County Sheriff's Office": 459,
#  "Putnam County Sheriff's Office": 460,
#  "Quitman County Sheriff's Office": 461,
#  'Quitman Police Department': 462,
#  "Rabun County Sheriff's Office": 463,
#  "Randolph County Sheriff's Office": 464,
#  'Ray City Police Department': 465,
#  'Register Police Department': 466,
#  'Reidsville Police Department': 467,
#  'Remerton Police Department': 468,
#  'Reynolds Police Department': 469,
#  'Richland Police Department': 470,
#  'Richmond County Marshal': 471,
#  'Richmond Hill Police Department': 472,
#  'Rincon Police Department': 473,
#  'Ringgold Police Department': 474,
#  'Riverdale Police Department': 475,
#  'Roberta Police Department': 476,
#  'Rochelle Police Department': 477,
#  "Rockdale County Sheriff's Office": 478,
#  'Rockmart Police Department': 479,
#  'Rome Police Department': 480,
#  'Roosevelt Institute Facility Police': 481,
#  'Rossville Police Department': 482,
#  'Roswell Police Department': 483,
#  'Royston Police Department': 484,
#  'Sale City Police Department': 485,
#  'Sandersville Police Department': 486,
#  'Sandy Springs Police Department': 487,
#  'Sardis Police Department': 488,
#  'Savannah Fire and Emergency Services Arson Unit': 489,
#  'Savannah State University': 490,
#  'Savannah Technical College': 491,
#  'Savannah-Chatham Metropolitan Police Department': 492,
#  "Schley County Sheriff's Office": 493,
#  "Screven  County Sheriff's Office": 494,
#  'Screven Police Department': 495,
#  "Seminole County Sheriff's Office": 496,
#  'Senoia Police Department': 497,
#  'Shiloh Police Department': 498,
#  'Sky Valley Police Department': 499,
#  'Smyrna Police Department': 500,
#  'Snellville Police Department': 501,
#  'Social Circle Police Department': 502,
#  'Soperton Police Department': 503,
#  'South Fulton': 504,
#  'South Georgia State College': 505,
#  'Southern Crescent Technical College': 506,
#  "Spalding County Sheriff's Office": 507,
#  'Sparks Police Department': 508,
#  'Sparta Police Department': 509,
#  'Spelman College': 510,
#  'Springfield Police Department': 511,
#  'St. Marys Police Department': 512,
#  'Stapleton Police Department': 513,
#  'State Board of Workers Compensation Fraud Investigation Division': 514,
#  'State Patrol: Albany': 515,
#  'State Patrol: Americus': 516,
#  'State Patrol: Athens': 517,
#  'State Patrol: Blue Ridge': 518,
#  'State Patrol: Brunswick': 519,
#  'State Patrol: Calhoun': 520,
#  'State Patrol: Canton': 521,
#  'State Patrol: Cartersville': 522,
#  'State Patrol: Cedartown': 523,
#  'State Patrol: Conyers': 524,
#  'State Patrol: Cordele': 525,
#  'State Patrol: Cuthbert': 526,
#  'State Patrol: Dalton': 527,
#  'State Patrol: Donalsonville': 528,
#  'State Patrol: Douglas': 529,
#  'State Patrol: Dublin': 530,
#  'State Patrol: Forsyth': 531,
#  'State Patrol: Gainesville': 532,
#  'State Patrol: Griffin': 533,
#  'State Patrol: Hapeville': 534,
#  'State Patrol: Helena': 535,
#  'State Patrol: Highway Support Division, Thomaston': 536,
#  'State Patrol: Hinesville': 537,
#  'State Patrol: La Grange': 538,
#  'State Patrol: Lafayette': 539,
#  'State Patrol: Lawrenceville': 540,
#  'State Patrol: Madison': 541,
#  'State Patrol: Manchester': 542,
#  'State Patrol: Marietta': 543,
#  'State Patrol: Metropolitan Traffic Unit, Atlanta': 544,
#  'State Patrol: Milledgeville': 545,
#  'State Patrol: Newnan': 546,
#  'State Patrol: Perry': 547,
#  'State Patrol: Reidsville': 548,
#  'State Patrol: Rome': 549,
#  'State Patrol: Savannah': 550,
#  'State Patrol: Statesboro': 551,
#  'State Patrol: Swainsboro': 552,
#  'State Patrol: Sylvania': 553,
#  'State Patrol: Thomaston': 554,
#  'State Patrol: Thomasville': 555,
#  'State Patrol: Thomson': 556,
#  'State Patrol: Tifton': 557,
#  'State Patrol: Toccoa': 558,
#  'State Patrol: Valdosta': 559,
#  'State Patrol: Villa Rica': 560,
#  'State Patrol: Washington': 561,
#  'State Patrol: Waycross': 562,
#  'Statesboro Police Department': 563,
#  'Statham Police Department': 564,
#  "Stephens County Sheriff's Office": 565,
#  "Stewart County Sheriff's Office": 566,
#  'Stillmore Police Department': 567,
#  'Stone Mountain Park Police': 568,
#  'Stone Mountain Police Department': 569,
#  'Summerville Police Department': 570,
#  "Sumter County Sheriff's Office": 571,
#  'Suwanee Police Department': 572,
#  'Swainsboro Police Department': 573,
#  'Sycamore Police Department': 574,
#  'Sylvania Police Department': 575,
#  'Sylvester Police Department': 576,
#  "Talbot County Sheriff's Office": 577,
#  'Talbotton Police Department': 578,
#  "Taliaferro County Sheriff's Office": 579,
#  'Tallapoosa Police Department': 580,
#  'Tallulah Falls Police Department': 581,
#  "Tattnall County Sheriff's Office": 582,
#  "Taylor County Sheriff's Office": 583,
#  "Telfair County Sheriff's Office": 584,
#  'Temple Police Department': 585,
#  "Terrell County Sheriff's Office": 586,
#  "Thomas County Sheriff's Office": 587,
#  'Thomaston Police Department': 588,
#  'Thomasville Police Department': 589,
#  'Thunderbolt Police Department': 590,
#  "Tift County Sheriff's Office": 591,
#  'Tifton Police Department': 592,
#  'Toccoa Police Department': 593,
#  "Toombs County Sheriff's Office": 594,
#  'Toomsboro Police Department': 595,
#  "Towns County Sheriff's Office": 596,
#  'Trenton Police Department': 597,
#  "Treutlen County Sheriff's Office": 598,
#  'Trion Police Department': 599,
#  'Troup County Marshal': 600,
#  "Troup County Sheriff's Office": 601,
#  'Tunnel Hill Police Department': 602,
#  'Turner County Schools': 603,
#  "Turner County Sheriff's Office": 604,
#  'Twiggs County Board of Education': 605,
#  "Twiggs County Sheriff's Office": 606,
#  'Twin City Police Department': 607,
#  'Tybee Island Police Department': 608,
#  'Tyrone Police Department': 609,
#  'Union City Police Department': 610,
#  "Union County Sheriff's Office": 611,
#  'University of Georgia': 612,
#  'University of North Georgia': 613,
#  'University of West Georgia': 614,
#  "Upson County Sheriff's Office": 615,
#  'Uvalda Police Department': 616,
#  'Valdosta Police Department': 617,
#  'Valdosta State University': 618,
#  'Vidalia Police Department': 619,
#  'Vienna Police Department': 620,
#  'Villa Rica Police Department': 621,
#  'Wadley Police Department': 622,
#  "Walker County Sheriff's Office": 623,
#  'Walthourville Police Department': 624,
#  "Walton County Sheriff's Office": 625,
#  "Ware County Sheriff's Office": 626,
#  'Warm Springs Police Department': 627,
#  'Warner Robins Police Department': 628,
#  "Warren County Sheriff's Office": 629,
#  'Warrenton Police Department': 630,
#  'Warwick Police Department': 631,
#  'Washington County Board of Education': 632,
#  "Washington County Sheriff's Office": 633,
#  'Watkinsville Police Department': 634,
#  'Waverly Hall Police Department': 635,
#  'Waycross Police Department': 636,
#  "Wayne County Sheriff's Office": 637,
#  'Waynesboro Police Department': 638,
#  "Webster County Sheriff's Office": 639,
#  'Wesleyan College': 640,
#  'West Georgia Technical College': 641,
#  'West Point Police Department': 642,
#  "Wheeler County Sheriff's Office": 643,
#  'Whigham Police Department': 644,
#  "White County Sheriff's Office": 645,
#  'White Police Department': 646,
#  'Whitesburg Police Department': 647,
#  "Whitfield County Sheriff's Office": 648,
#  "Wilcox County Sheriff's Office": 649,
#  "Wilkes County Sheriff's Office": 650,
#  "Wilkinson County Sheriff's Office": 651,
#  'Willacoochee Police Department': 652,
#  'Winder Police Department': 653,
#  'Winterville Police Department': 654,
#  'Woodbury Police Department': 655,
#  'Woodstock Police Department': 656,
#  "Worth County Sheriff's Office": 657,
#  'Wrens Police Department': 658,
#  'Wrightsville Police Department': 659,
#  'Young Harris College': 660,
#  'Zebulon Police Department': 661}

# %% [markdown]
# ### Load County Table / Build Dictionary

# %%
# Reuse result from agencies call, extract into DF
countyList = []
countyDF = pd.json_normalize(response['results'])
countyDF = countyDF['county_name']

# split multi-counties into individual
for row in countyDF:

    #split the multi-counties
    counties = row.split('; ')

    for cnty in counties:
        if cnty not in countyList and cnty != '':
            countyList.append(cnty)

# cleanup and store in SQL
countyList.sort()
countyDF = pd.DataFrame(countyList, columns =['county_name'])
countyDF.insert(0, 'countyid', range(1, 1 + len(countyDF)))
countyDF.to_sql(name='County', con=engine, if_exists='replace', index=False)

#put counties in dictionary for lookup
county_dict = dict(zip(countyDF.county_name, countyDF.countyid))
county_dict
# Out:
# {'APPLING': 1,
#  'ATKINSON': 2,
#  'BACON': 3,
#  'BAKER': 4,
#  'BALDWIN': 5,
#  'BANKS': 6,
#  'BANKS, HABERSHAM': 7,
#  'BANKS, JACKSON': 8,
#  'BARROW': 9,
#  'BARROW, GWINNETT': 10,
#  'BARROW, GWINNETT, HALL, JACKSON': 11,
#  'BARTOW': 12,
#  'BEN HILL': 13,
#  'BERRIEN': 14,
#  'BERRIEN, LANIER': 15,
#  'BIBB': 16,
#  'BLECKLEY': 17,
#  'BRANTLEY': 18,
#  'BROOKS': 19,
#  'BROOKS, THOMAS': 20,
#  'BRYAN': 21,
#  'BULLOCH': 22,
#  'BURKE': 23,
#  'BURKE, RICHMOND': 24,
#  'BUTTS': 25,
#  'CALHOUN': 26,
#  'CALHOUN, EARLY': 27,
#  'CAMDEN': 28,
#  'CANDLER': 29,
#  'CARROLL': 30,
#  'CARROLL, DOUGLAS': 31,
#  'CARROLL, HARALSON': 32,
#  'CATOOSA': 33,
#  'CATOOSA, WALKER': 34,
#  'CHARLTON': 35,
#  'CHATHAM': 36,
#  'CHATTAHOOCHEE': 37,
#  'CHATTOOGA': 38,
#  'CHEROKEE': 39,
#  'CHEROKEE, PICKENS': 40,
#  'CLARKE': 41,
#  'CLAY': 42,
#  'CLAYTON': 43,
#  'CLAYTON, FULTON': 44,
#  'CLINCH': 45,
#  'COBB': 46,
#  'COBB, DOUGLAS': 47,
#  'COFFEE': 48,
#  'COLQUITT': 49,
#  'COLQUITT, TIFT': 50,
#  'COLUMBIA': 51,
#  'COOK': 52,
#  'COWETA': 53,
#  'COWETA, FULTON': 54,
#  'CRAWFORD': 55,
#  'CRISP': 56,
#  'DADE': 57,
#  'DAWSON': 58,
#  'DECATUR': 59,
#  'DEKALB': 60,
#  'DEKALB, FULTON': 61,
#  'DODGE': 62,
#  'DODGE, TELFAIR': 63,
#  'DOOLY': 64,
#  'DOUGHERTY': 65,
#  'DOUGLAS': 66,
#  'EARLY': 67,
#  'ECHOLS': 68,
#  'EFFINGHAM': 69,
#  'ELBERT': 70,
#  'EMANUEL': 71,
#  'EMANUEL, JOHNSON': 72,
#  'EVANS': 73,
#  'FANNIN': 74,
#  'FAYETTE': 75,
#  'FLOYD': 76,
#  'FORSYTH': 77,
#  'FRANKLIN': 78,
#  'FRANKLIN, HART': 79,
#  'FRANKLIN, HART, MADISON': 80,
#  'FULTON': 81,
#  'GILMER': 82,
#  'GLASCOCK': 83,
#  'GLYNN': 84,
#  'GORDON': 85,
#  'GRADY': 86,
#  'GREENE': 87,
#  'GWINNETT': 88,
#  'GWINNETT, WALTON': 89,
#  'HABERSHAM': 90,
#  'HABERSHAM, RABUN': 91,
#  'HALL': 92,
#  'HANCOCK': 93,
#  'HARALSON': 94,
#  'HARRIS': 95,
#  'HARRIS, MERIWETHER': 96,
#  'HARRIS, TROUP': 97,
#  'HART': 98,
#  'HEARD': 99,
#  'HENRY': 100,
#  'HOUSTON': 101,
#  'HOUSTON, PEACH': 102,
#  'IRWIN': 103,
#  'JACKSON': 104,
#  'JASPER': 105,
#  'JEFF DAVIS': 106,
#  'JEFFERSON': 107,
#  'JENKINS': 108,
#  'JOHNSON': 109,
#  'JONES': 110,
#  'LAMAR': 111,
#  'LANIER': 112,
#  'LAURENS': 113,
#  'LEE': 114,
#  'LIBERTY': 115,
#  'LINCOLN': 116,
#  'LONG': 117,
#  'LOWNDES': 118,
#  'LUMPKIN': 119,
#  'MACON': 120,
#  'MADISON': 121,
#  'MARION': 122,
#  'MCDUFFIE': 123,
#  'MCINTOSH': 124,
#  'MERIWETHER': 125,
#  'MERIWETHER, TALBOT': 126,
#  'MILLER': 127,
#  'MITCHELL': 128,
#  'MITCHELL, THOMAS': 129,
#  'MONROE': 130,
#  'MONTGOMERY': 131,
#  'MONTGOMERY, TOOMBS': 132,
#  'MORGAN': 133,
#  'MURRAY': 134,
#  'MUSCOGEE': 135,
#  'NEWTON': 136,
#  'NEWTON, WALTON': 137,
#  'NOT SPECIFIED': 138,
#  'OCONEE': 139,
#  'OGLETHORPE': 140,
#  'PAULDING': 141,
#  'PAULDING, POLK': 142,
#  'PEACH': 143,
#  'PICKENS': 144,
#  'PIERCE': 145,
#  'PIERCE, WARE': 146,
#  'PIKE': 147,
#  'POLK': 148,
#  'PULASKI': 149,
#  'PUTNAM': 150,
#  'QUITMAN': 151,
#  'RABUN': 152,
#  'RANDOLPH': 153,
#  'RICHMOND': 154,
#  'ROCKDALE': 155,
#  'SCHLEY': 156,
#  'SCREVEN': 157,
#  'SEMINOLE': 158,
#  'SPALDING': 159,
#  'STEPHENS': 160,
#  'STEWART': 161,
#  'SUMTER': 162,
#  'TALBOT': 163,
#  'TALIAFERRO': 164,
#  'TATTNALL': 165,
#  'TAYLOR': 166,
#  'TELFAIR': 167,
#  'TELFAIR, WHEELER': 168,
#  'TERRELL': 169,
#  'THOMAS': 170,
#  'TIFT': 171,
#  'TOOMBS': 172,
#  'TOWNS': 173,
#  'TREUTLEN': 174,
#  'TROUP': 175,
#  'TURNER': 176,
#  'TWIGGS': 177,
#  'UNION': 178,
#  'UPSON': 179,
#  'WALKER': 180,
#  'WALTON': 181,
#  'WARE': 182,
#  'WARREN': 183,
#  'WASHINGTON': 184,
#  'WAYNE': 185,
#  'WEBSTER': 186,
#  'WHEELER': 187,
#  'WHITE': 188,
#  'WHITFIELD': 189,
#  'WILCOX': 190,
#  'WILKES': 191,
#  'WILKINSON': 192,
#  'WORTH': 193}

# %% [markdown]
# ### Load CountyAgency Relationship Table

# %%
# Reuse result from agencies call, extract into DF
resultDF = pd.json_normalize(response['results'])[['agency_name','county_name']]
countyagencyDF = pd.DataFrame(columns=['agencyid','countyid'])

for index, row in resultDF.iterrows():
    
    # split the multi-counties
    if ';' in row.county_name:
        counties = row.county_name.split('; ')

        for cnty in counties:
            if cnty != '':
                countyagencyDF.loc[len(countyagencyDF.index)] = [agency_dict.get(row[0]), county_dict.get(cnty)]
    else:
        countyagencyDF.loc[len(countyagencyDF.index)] = [agency_dict.get(row[0]), county_dict.get(row[1])]
        
countyagencyDF = countyagencyDF.sort_values(by=['agencyid','countyid'])
countyagencyDF.insert(0, 'countyagencyid', range(1, 1 + len(countyagencyDF.index)))
countyagencyDF.to_sql(name='CountyAgency', con=engine, if_exists='replace', index=False)
countyagencyDF.head(5)
# Out:
#      countyagencyid  agencyid  countyid
# 596               1         1       190
# 539               2         2       171
# 136               3         3        46
# 22                4         4        12
# 155               5         5        52

# %% [markdown]
# ### Load Income Table

# %%
DF_raw = pd.read_csv('data/incomepercapita.csv')
incomeDF = pd.DataFrame(columns=['countyid','percapita_income','data_year'])

for index, row in DF_raw.iterrows():
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[1], 2017]
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[2], 2018]
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[3], 2019]
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[4], 2020]
        
incomeDF = incomeDF.sort_values(by=['countyid','data_year'])
incomeDF.insert(0, 'incomeid', range(1, 1 + len(incomeDF.index)))
incomeDF.to_sql(name='Income', con=engine, if_exists='replace', index=False)
incomeDF.head(5)
# Out:
#    incomeid  countyid  percapita_income  data_year
# 0         1         1             33240       2017
# 1         2         1             33620       2018
# 2         3         1             35558       2019
# 3         4         1             39199       2020
# 4         5         2             28937       2017

# %% [markdown]
# ### Load Offenses Table

# %%
offenseDF = pd.DataFrame(columns=['ori','data_year','offense','cleared','actual'])

# Loop through agencyDF calling offense endpoint for each ori
for index, row in agencyDF.iterrows():

    # Call Summarized Offenses by ORI Endpoint
    ori_url = f"http://api.usa.gov/crime/fbi/sapi//api/summarized/agencies/{row.ori}/offenses/2017/2020?API_KEY={api_key}"
    ori_response = requests.get(ori_url).json()

    # Extract into DF
    if (len(ori_response['results']) > 0):
        resultDF = pd.json_normalize(ori_response['results'])[['ori','data_year','offense','cleared','actual']]
        offenseDF = pd.concat([offenseDF, resultDF])

offenseDF = offenseDF.sort_values(by=['ori','offense','data_year'])
offenseDF.insert(0, 'offenseid', range(1, 1 + len(offenseDF.index)))
offenseDF.to_sql(name='Offense', con=engine, if_exists='replace', index=False)
offenseDF.head(5)
