# %% [markdown]
# ### Imports

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import pprint
import pymongo

# %%
from sqlalchemy import create_engine, func
import psycopg2
import os
import requests

# %% [markdown]
# ### Initializations

# %%
api_key = "eVDzrjlfZg8aVJnAy1jNIovawgD9jxyEoBnhCda3"

# %%
# Create base url and get json data
base_url = f"https://api.usa.gov/crime/fbi/sapi//api/agencies?API_KEY={api_key}"
response = requests.get(base_url).json()

# %%
#db initializations
engine = create_engine(f'postgresql://postgres:password@localhost/GACRIME')

# %%
# Show only Georgia results
GA_data = response["GA"]
GA_data
# Out:
# {'GA0160300': {'ori': 'GA0160300',
#   'agency_name': 'Portal Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': False,
#   'latitude': 32.393408,
#   'longitude': -81.74381,
#   'nibrs_start_date': None},
#  'GA0680900': {'ori': 'GA0680900',
#   'agency_name': 'Alto Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BANKS; HABERSHAM',
#   'nibrs': True,
#   'latitude': 34.635108,
#   'longitude': -83.526406,
#   'nibrs_start_date': '01/01/2019'},
#  'GA0410100': {'ori': 'GA0410100',
#   'agency_name': 'Trenton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DADE',
#   'nibrs': False,
#   'latitude': 34.852424,
#   'longitude': -85.506201,
#   'nibrs_start_date': None},
#  'GA0080300': {'ori': 'GA0080300',
#   'agency_name': 'Kingston Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARTOW',
#   'nibrs': True,
#   'latitude': 34.240917,
#   'longitude': -84.838188,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP3300': {'ori': 'GAGSP3300',
#   'agency_name': 'State Patrol: Milledgeville',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 33.059504,
#   'longitude': -83.255452,
#   'nibrs_start_date': None},
#  'GA060459E': {'ori': 'GA060459E',
#   'agency_name': 'Morris Brown College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': False,
#   'latitude': 33.75472,
#   'longitude': -84.40874,
#   'nibrs_start_date': None},
#  'GA0330100': {'ori': 'GA0330100',
#   'agency_name': 'Austell Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGLAS; COBB',
#   'nibrs': True,
#   'latitude': 33.93994,
#   'longitude': -84.574166,
#   'nibrs_start_date': '01/01/2020'},
#  'GA1210300': {'ori': 'GA1210300',
#   'agency_name': 'Hephzibah Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RICHMOND',
#   'nibrs': False,
#   'latitude': 33.361487,
#   'longitude': -82.074998,
#   'nibrs_start_date': None},
#  'GA0020000': {'ori': 'GA0020000',
#   'agency_name': "Atkinson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ATKINSON',
#   'nibrs': True,
#   'latitude': 31.296677,
#   'longitude': -82.878067,
#   'nibrs_start_date': '10/01/2019'},
#  'GAGSP1000': {'ori': 'GAGSP1000',
#   'agency_name': 'State Patrol: Americus',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': False,
#   'latitude': 32.037216,
#   'longitude': -84.14207,
#   'nibrs_start_date': None},
#  'GA1300100': {'ori': 'GA1300100',
#   'agency_name': 'Talbotton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TALBOT',
#   'nibrs': False,
#   'latitude': 32.704603,
#   'longitude': -84.530029,
#   'nibrs_start_date': None},
#  'GA0090100': {'ori': 'GA0090100',
#   'agency_name': 'Fitzgerald Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BEN HILL',
#   'nibrs': True,
#   'latitude': 31.740775,
#   'longitude': -83.14719,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0960000': {'ori': 'GA0960000',
#   'agency_name': "Macon County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MACON',
#   'nibrs': False,
#   'latitude': 32.366216,
#   'longitude': -84.052162,
#   'nibrs_start_date': None},
#  'GA1290100': {'ori': 'GA1290100',
#   'agency_name': 'Americus Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': True,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': '08/01/2019'},
#  'GA0880000': {'ori': 'GA0880000',
#   'agency_name': "Lee County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LEE',
#   'nibrs': True,
#   'latitude': 31.818419,
#   'longitude': -84.146681,
#   'nibrs_start_date': '04/01/2019'},
#  'GA0310500': {'ori': 'GA0310500',
#   'agency_name': 'Riverdale Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': True,
#   'latitude': 33.572205,
#   'longitude': -84.415726,
#   'nibrs_start_date': '06/01/2019'},
#  'GA0100000': {'ori': 'GA0100000',
#   'agency_name': "Berrien County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BERRIEN',
#   'nibrs': True,
#   'latitude': 31.191711,
#   'longitude': -83.27352,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1370100': {'ori': 'GA1370100',
#   'agency_name': 'Tifton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TIFT',
#   'nibrs': False,
#   'latitude': 31.449644,
#   'longitude': -83.509926,
#   'nibrs_start_date': None},
#  'GA0950200': {'ori': 'GA0950200',
#   'agency_name': 'McIntosh County Schools',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MCINTOSH',
#   'nibrs': False,
#   'latitude': 31.482978,
#   'longitude': -81.370199,
#   'nibrs_start_date': None},
#  'GA0780400': {'ori': 'GA0780400',
#   'agency_name': 'Arcade Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JACKSON',
#   'nibrs': True,
#   'latitude': 34.134157,
#   'longitude': -83.565133,
#   'nibrs_start_date': '12/01/2019'},
#  'GA0810000': {'ori': 'GA0810000',
#   'agency_name': "Jefferson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': True,
#   'latitude': 33.051874,
#   'longitude': -82.41905,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0331300': {'ori': 'GA0331300',
#   'agency_name': 'Cobb County Board of Education',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.916363,
#   'longitude': -84.546295,
#   'nibrs_start_date': '10/01/2019'},
#  'GAGSP4500': {'ori': 'GAGSP4500',
#   'agency_name': 'State Patrol: Statesboro',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': False,
#   'latitude': 32.411438,
#   'longitude': -81.80494,
#   'nibrs_start_date': None},
#  'GAGSP2200': {'ori': 'GAGSP2200',
#   'agency_name': 'State Patrol: Waycross',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WARE',
#   'nibrs': False,
#   'latitude': 31.050881,
#   'longitude': -82.421507,
#   'nibrs_start_date': None},
#  'GA0560100': {'ori': 'GA0560100',
#   'agency_name': 'Fayetteville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.412717,
#   'longitude': -84.493941,
#   'nibrs_start_date': '08/01/2019'},
#  'GA0650000': {'ori': 'GA0650000',
#   'agency_name': "Grady County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GRADY',
#   'nibrs': True,
#   'latitude': 30.875891,
#   'longitude': -84.245066,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1060100': {'ori': 'GA1060100',
#   'agency_name': 'Columbus Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MUSCOGEE',
#   'nibrs': False,
#   'latitude': 32.464756,
#   'longitude': -84.98599,
#   'nibrs_start_date': None},
#  'GA0720100': {'ori': 'GA0720100',
#   'agency_name': 'Pine Mountain Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MERIWETHER; HARRIS',
#   'nibrs': True,
#   'latitude': 32.731549,
#   'longitude': -84.912432,
#   'nibrs_start_date': '01/01/2019'},
#  'GA0445100': {'ori': 'GA0445100',
#   'agency_name': 'DeKalb County School System',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': True,
#   'latitude': 33.800564,
#   'longitude': -84.20196,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0170000': {'ori': 'GA0170000',
#   'agency_name': "Burke  County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BURKE',
#   'nibrs': True,
#   'latitude': 33.050819,
#   'longitude': -82.011571,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1360300': {'ori': 'GA1360300',
#   'agency_name': 'Coolidge Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'THOMAS',
#   'nibrs': True,
#   'latitude': 30.864606,
#   'longitude': -83.91982,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1140000': {'ori': 'GA1140000',
#   'agency_name': "Pike County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIKE',
#   'nibrs': True,
#   'latitude': 33.090768,
#   'longitude': -84.386627,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1530100': {'ori': 'GA1530100',
#   'agency_name': 'Alamo Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHEELER',
#   'nibrs': True,
#   'latitude': 32.109276,
#   'longitude': -82.738701,
#   'nibrs_start_date': '07/01/2019'},
#  'GA1220100': {'ori': 'GA1220100',
#   'agency_name': 'Conyers Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ROCKDALE',
#   'nibrs': False,
#   'latitude': 33.65794,
#   'longitude': -84.01751,
#   'nibrs_start_date': None},
#  'GA0250100': {'ori': 'GA0250100',
#   'agency_name': 'Chatham County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': False,
#   'latitude': 32.060173,
#   'longitude': -81.166336,
#   'nibrs_start_date': None},
#  'GA0640200': {'ori': 'GA0640200',
#   'agency_name': 'Fairmount Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GORDON',
#   'nibrs': False,
#   'latitude': 34.509667,
#   'longitude': -84.873862,
#   'nibrs_start_date': None},
#  'GA0252400': {'ori': 'GA0252400',
#   'agency_name': 'Savannah Technical College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': True,
#   'latitude': 31.980523,
#   'longitude': -81.08519,
#   'nibrs_start_date': '01/01/2019'},
#  'GA1130200': {'ori': 'GA1130200',
#   'agency_name': 'Patterson Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIERCE',
#   'nibrs': False,
#   'latitude': 31.353988,
#   'longitude': -82.210427,
#   'nibrs_start_date': None},
#  'GA0710500': {'ori': 'GA0710500',
#   'agency_name': 'West Georgia Technical College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HARALSON',
#   'nibrs': True,
#   'latitude': 33.795165,
#   'longitude': -85.220062,
#   'nibrs_start_date': '03/01/2019'},
#  'GA0160400': {'ori': 'GA0160400',
#   'agency_name': 'Georgia Southern University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': True,
#   'latitude': 32.393408,
#   'longitude': -81.74381,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0330000': {'ori': 'GA0330000',
#   'agency_name': "Cobb County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.952282,
#   'longitude': -84.5482,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1210400': {'ori': 'GA1210400',
#   'agency_name': 'Georgia Regents University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RICHMOND',
#   'nibrs': True,
#   'latitude': 33.47503,
#   'longitude': -81.98768,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP3200': {'ori': 'GAGSP3200',
#   'agency_name': 'State Patrol: Athens',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLARKE',
#   'nibrs': False,
#   'latitude': 33.952185,
#   'longitude': -83.367152,
#   'nibrs_start_date': None},
#  'GA1190500': {'ori': 'GA1190500',
#   'agency_name': 'Sky Valley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RABUN',
#   'nibrs': False,
#   'latitude': 34.883026,
#   'longitude': -83.404735,
#   'nibrs_start_date': None},
#  'GA1300200': {'ori': 'GA1300200',
#   'agency_name': 'Woodland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TALBOT',
#   'nibrs': True,
#   'latitude': 32.704603,
#   'longitude': -84.530029,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0240200': {'ori': 'GA0240200',
#   'agency_name': 'Homeland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHARLTON',
#   'nibrs': False,
#   'latitude': 30.856588,
#   'longitude': -82.02113,
#   'nibrs_start_date': None},
#  'GA0500000': {'ori': 'GA0500000',
#   'agency_name': "Echols County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ECHOLS',
#   'nibrs': True,
#   'latitude': 30.7085,
#   'longitude': -82.836132,
#   'nibrs_start_date': '11/01/2018'},
#  'GA0800100': {'ori': 'GA0800100',
#   'agency_name': 'Hazlehurst Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFF DAVIS',
#   'nibrs': True,
#   'latitude': 31.867207,
#   'longitude': -82.599304,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0530700': {'ori': 'GA0530700',
#   'agency_name': 'East Georgia State College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL',
#   'nibrs': False,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': None},
#  'GA0490000': {'ori': 'GA0490000',
#   'agency_name': "Early County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EARLY',
#   'nibrs': True,
#   'latitude': 31.324191,
#   'longitude': -84.906723,
#   'nibrs_start_date': '10/01/2019'},
#  'GA139039E': {'ori': 'GA139039E',
#   'agency_name': 'Young Harris College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TOWNS',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1380000': {'ori': 'GA1380000',
#   'agency_name': "Toombs County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TOOMBS',
#   'nibrs': False,
#   'latitude': 32.20298,
#   'longitude': -82.34015,
#   'nibrs_start_date': None},
#  'GA0570000': {'ori': 'GA0570000',
#   'agency_name': "Floyd County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FLOYD',
#   'nibrs': True,
#   'latitude': 34.280457,
#   'longitude': -85.1429,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0310400': {'ori': 'GA0310400',
#   'agency_name': 'Jonesboro Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': False,
#   'latitude': 33.516556,
#   'longitude': -84.353935,
#   'nibrs_start_date': None},
#  'GA0010100': {'ori': 'GA0010100',
#   'agency_name': 'Baxley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'APPLING',
#   'nibrs': True,
#   'latitude': 31.739712,
#   'longitude': -82.290103,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0440900': {'ori': 'GA0440900',
#   'agency_name': 'Stone Mountain Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': True,
#   'latitude': 33.80639,
#   'longitude': -84.170364,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1370200': {'ori': 'GA1370200',
#   'agency_name': 'Omega Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COLQUITT; TIFT',
#   'nibrs': True,
#   'latitude': 31.457003,
#   'longitude': -83.525931,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0480100': {'ori': 'GA0480100',
#   'agency_name': 'Douglasville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGLAS',
#   'nibrs': True,
#   'latitude': 33.699317,
#   'longitude': -84.765944,
#   'nibrs_start_date': '07/01/2019'},
#  'GA1290200': {'ori': 'GA1290200',
#   'agency_name': 'Leslie Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': True,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0950100': {'ori': 'GA0950100',
#   'agency_name': 'Darien Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MCINTOSH',
#   'nibrs': True,
#   'latitude': 31.482978,
#   'longitude': -81.370199,
#   'nibrs_start_date': '02/01/2020'},
#  'GA0780500': {'ori': 'GA0780500',
#   'agency_name': 'Hoschton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JACKSON',
#   'nibrs': False,
#   'latitude': 34.134157,
#   'longitude': -83.565133,
#   'nibrs_start_date': None},
#  'GA1230000': {'ori': 'GA1230000',
#   'agency_name': "Schley County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SCHLEY',
#   'nibrs': True,
#   'latitude': 32.263441,
#   'longitude': -84.322724,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0331200': {'ori': 'GA0331200',
#   'agency_name': 'Kennesaw State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.93994,
#   'longitude': -84.574166,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP4400': {'ori': 'GAGSP4400',
#   'agency_name': 'State Patrol: Forsyth',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONROE',
#   'nibrs': False,
#   'latitude': 33.017435,
#   'longitude': -83.922938,
#   'nibrs_start_date': None},
#  'GAGSP2100': {'ori': 'GAGSP2100',
#   'agency_name': 'State Patrol: Sylvania',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SCREVEN',
#   'nibrs': False,
#   'latitude': 32.748623,
#   'longitude': -81.65879,
#   'nibrs_start_date': None},
#  'GA0560200': {'ori': 'GA0560200',
#   'agency_name': 'Peachtree City Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.412717,
#   'longitude': -84.493941,
#   'nibrs_start_date': '11/01/2019'},
#  'GA1060000': {'ori': 'GA1060000',
#   'agency_name': "Muscogee  County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MUSCOGEE',
#   'nibrs': True,
#   'latitude': 32.510197,
#   'longitude': -84.874946,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0690600': {'ori': 'GA0690600',
#   'agency_name': 'Hall County Marshal',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HALL',
#   'nibrs': True,
#   'latitude': 34.317588,
#   'longitude': -83.818497,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0650100': {'ori': 'GA0650100',
#   'agency_name': 'Cairo Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GRADY',
#   'nibrs': True,
#   'latitude': 30.875891,
#   'longitude': -84.245066,
#   'nibrs_start_date': '04/01/2019'},
#  'GA1360400': {'ori': 'GA1360400',
#   'agency_name': 'Meigs Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MITCHELL; THOMAS',
#   'nibrs': False,
#   'latitude': 30.864606,
#   'longitude': -83.91982,
#   'nibrs_start_date': None},
#  'GA0420000': {'ori': 'GA0420000',
#   'agency_name': "Dawson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DAWSON',
#   'nibrs': False,
#   'latitude': 34.422028,
#   'longitude': -84.12007,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1140100': {'ori': 'GA1140100',
#   'agency_name': 'Zebulon Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIKE',
#   'nibrs': True,
#   'latitude': 33.090768,
#   'longitude': -84.386627,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0720000': {'ori': 'GA0720000',
#   'agency_name': "Harris County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HARRIS',
#   'nibrs': True,
#   'latitude': 32.731549,
#   'longitude': -84.912432,
#   'nibrs_start_date': '12/01/2019'},
#  'GA0470300': {'ori': 'GA0470300',
#   'agency_name': 'Albany State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGHERTY',
#   'nibrs': False,
#   'latitude': 31.572027,
#   'longitude': -84.144394,
#   'nibrs_start_date': None},
#  'GA0290900': {'ori': 'GA0290900',
#   'agency_name': 'Athens Technical College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLARKE',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '01/01/2019'},
#  'GA1530000': {'ori': 'GA1530000',
#   'agency_name': "Wheeler County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHEELER',
#   'nibrs': False,
#   'latitude': 32.14889,
#   'longitude': -82.78266,
#   'nibrs_start_date': None},
#  'GA1050200': {'ori': 'GA1050200',
#   'agency_name': 'Eton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MURRAY',
#   'nibrs': True,
#   'latitude': 34.797097,
#   'longitude': -84.73799,
#   'nibrs_start_date': '08/01/2019'},
#  'GA0250000': {'ori': 'GA0250000',
#   'agency_name': "Chatham County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': False,
#   'latitude': 31.980523,
#   'longitude': -81.08519,
#   'nibrs_start_date': None},
#  'GA0160500': {'ori': 'GA0160500',
#   'agency_name': 'Register Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BULLOCH',
#   'nibrs': False,
#   'latitude': 32.367367,
#   'longitude': -81.88627,
#   'nibrs_start_date': None},
#  'GA0970000': {'ori': 'GA0970000',
#   'agency_name': "Madison County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MADISON',
#   'nibrs': True,
#   'latitude': 34.128484,
#   'longitude': -83.203644,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0320100': {'ori': 'GA0320100',
#   'agency_name': 'Homerville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLINCH',
#   'nibrs': False,
#   'latitude': 30.917653,
#   'longitude': -82.702614,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0630200': {'ori': 'GA0630200',
#   'agency_name': 'Glynn County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GLYNN',
#   'nibrs': True,
#   'latitude': 31.212746,
#   'longitude': -81.496517,
#   'nibrs_start_date': '05/01/2019'},
#  'GA057069E': {'ori': 'GA057069E',
#   'agency_name': 'Berry College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FLOYD',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '06/01/2019'},
#  'GAGSP3100': {'ori': 'GAGSP3100',
#   'agency_name': 'State Patrol: Valdosta',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LOWNDES',
#   'nibrs': False,
#   'latitude': 30.833127,
#   'longitude': -83.268992,
#   'nibrs_start_date': None},
#  'GA1000000': {'ori': 'GA1000000',
#   'agency_name': "Miller County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MILLER',
#   'nibrs': False,
#   'latitude': 31.17431,
#   'longitude': -84.73826,
#   'nibrs_start_date': None},
#  'GA1190400': {'ori': 'GA1190400',
#   'agency_name': 'Dillard Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RABUN',
#   'nibrs': True,
#   'latitude': 34.883026,
#   'longitude': -83.404735,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1340600': {'ori': 'GA1340600',
#   'agency_name': 'Jacksonville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TELFAIR',
#   'nibrs': False,
#   'latitude': 31.913639,
#   'longitude': -82.931062,
#   'nibrs_start_date': None},
#  'GA0110000': {'ori': 'GA0110000',
#   'agency_name': "Bibb County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BIBB',
#   'nibrs': True,
#   'latitude': 32.831833,
#   'longitude': -83.64161,
#   'nibrs_start_date': '02/01/2019'},
#  'GA0960200': {'ori': 'GA0960200',
#   'agency_name': 'Ideal Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MACON',
#   'nibrs': False,
#   'latitude': 32.366216,
#   'longitude': -84.052162,
#   'nibrs_start_date': None},
#  'GA0010000': {'ori': 'GA0010000',
#   'agency_name': "Appling County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'APPLING',
#   'nibrs': True,
#   'latitude': 31.782509,
#   'longitude': -82.35828,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0310300': {'ori': 'GA0310300',
#   'agency_name': 'Morrow Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': True,
#   'latitude': 33.582436,
#   'longitude': -84.33722,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0570100': {'ori': 'GA0570100',
#   'agency_name': 'Floyd County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FLOYD',
#   'nibrs': True,
#   'latitude': 34.169235,
#   'longitude': -85.21126,
#   'nibrs_start_date': '01/01/2020'},
#  'GA1500600': {'ori': 'GA1500600',
#   'agency_name': 'Washington County Board of Education',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WASHINGTON',
#   'nibrs': True,
#   'latitude': 32.971848,
#   'longitude': -82.798112,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0100200': {'ori': 'GA0100200',
#   'agency_name': 'Alapaha Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BERRIEN',
#   'nibrs': True,
#   'latitude': 31.274308,
#   'longitude': -83.231906,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0790000': {'ori': 'GA0790000',
#   'agency_name': "Jasper County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JASPER',
#   'nibrs': True,
#   'latitude': 33.318128,
#   'longitude': -83.689505,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0440800': {'ori': 'GA0440800',
#   'agency_name': 'Pine Lake Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': False,
#   'latitude': 33.770661,
#   'longitude': -84.226343,
#   'nibrs_start_date': None},
#  'GA0780200': {'ori': 'GA0780200',
#   'agency_name': 'Jefferson Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JACKSON',
#   'nibrs': True,
#   'latitude': 34.11839,
#   'longitude': -83.57744,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0480000': {'ori': 'GA0480000',
#   'agency_name': "Douglas County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGLAS',
#   'nibrs': True,
#   'latitude': 33.748375,
#   'longitude': -84.7535,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1290300': {'ori': 'GA1290300',
#   'agency_name': 'Plains Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': False,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': None},
#  'GA0220600': {'ori': 'GA0220600',
#   'agency_name': 'University of West Georgia',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CARROLL',
#   'nibrs': True,
#   'latitude': 33.571545,
#   'longitude': -85.094604,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0820000': {'ori': 'GA0820000',
#   'agency_name': "Jenkins County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JENKINS',
#   'nibrs': True,
#   'latitude': 32.794563,
#   'longitude': -81.971524,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0560300': {'ori': 'GA0560300',
#   'agency_name': 'Tyrone Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.478733,
#   'longitude': -84.594215,
#   'nibrs_start_date': '08/01/2019'},
#  'GAGSP4300': {'ori': 'GAGSP4300',
#   'agency_name': 'State Patrol: Calhoun',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GORDON',
#   'nibrs': False,
#   'latitude': 34.460278,
#   'longitude': -84.91662,
#   'nibrs_start_date': None},
#  'GAGSP2000': {'ori': 'GAGSP2000',
#   'agency_name': 'State Patrol: Dublin',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LAURENS',
#   'nibrs': False,
#   'latitude': 32.39322,
#   'longitude': -82.926317,
#   'nibrs_start_date': None},
#  'GA0600900': {'ori': 'GA0600900',
#   'agency_name': 'Georgia State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.754486,
#   'longitude': -84.38908,
#   'nibrs_start_date': '05/01/2019'},
#  'GA1540100': {'ori': 'GA1540100',
#   'agency_name': 'Cleveland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHITE',
#   'nibrs': True,
#   'latitude': 34.643776,
#   'longitude': -83.743417,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1150000': {'ori': 'GA1150000',
#   'agency_name': "Polk County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'POLK',
#   'nibrs': True,
#   'latitude': 33.996015,
#   'longitude': -85.188338,
#   'nibrs_start_date': '12/01/2018'},
#  'GAAPD0000': {'ori': 'GAAPD0000',
#   'agency_name': 'Atlanta Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB; FULTON',
#   'nibrs': True,
#   'latitude': 33.74819,
#   'longitude': -84.39517,
#   'nibrs_start_date': '10/01/2020'},
#  'GA0470200': {'ori': 'GA0470200',
#   'agency_name': 'Dougherty County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGHERTY',
#   'nibrs': True,
#   'latitude': 31.532588,
#   'longitude': -84.20904,
#   'nibrs_start_date': '09/01/2019'},
#  'GA1360100': {'ori': 'GA1360100',
#   'agency_name': 'Thomasville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'THOMAS',
#   'nibrs': True,
#   'latitude': 30.864606,
#   'longitude': -83.91982,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0447200': {'ori': 'GA0447200',
#   'agency_name': 'Brookhaven Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DEKALB',
#   'nibrs': True,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0070300': {'ori': 'GA0070300',
#   'agency_name': 'Statham Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARROW',
#   'nibrs': False,
#   'latitude': 33.992009,
#   'longitude': -83.712303,
#   'nibrs_start_date': None},
#  'GA0606200': {'ori': 'GA0606200',
#   'agency_name': 'Morehouse School of Medicine',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': False,
#   'latitude': 33.743107,
#   'longitude': -84.41023,
#   'nibrs_start_date': None},
#  'GA0080100': {'ori': 'GA0080100',
#   'agency_name': 'Cartersville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARTOW',
#   'nibrs': True,
#   'latitude': 34.240917,
#   'longitude': -84.838188,
#   'nibrs_start_date': '12/01/2018'},
#  'GA0250300': {'ori': 'GA0250300',
#   'agency_name': 'Savannah-Chatham Metropolitan Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': False,
#   'latitude': 32.075733,
#   'longitude': -81.088394,
#   'nibrs_start_date': None},
#  'GA0810200': {'ori': 'GA0810200',
#   'agency_name': 'Wadley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.051874,
#   'longitude': -82.41905,
#   'nibrs_start_date': None},
#  'GA1050100': {'ori': 'GA1050100',
#   'agency_name': 'Chatsworth Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MURRAY',
#   'nibrs': True,
#   'latitude': 34.797097,
#   'longitude': -84.73799,
#   'nibrs_start_date': '02/01/2019'},
#  'GA0640000': {'ori': 'GA0640000',
#   'agency_name': "Gordon County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GORDON',
#   'nibrs': True,
#   'latitude': 34.509667,
#   'longitude': -84.873862,
#   'nibrs_start_date': '12/01/2018'},
#  'GAGSP3000': {'ori': 'GAGSP3000',
#   'agency_name': 'State Patrol: Cordele',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CRISP',
#   'nibrs': False,
#   'latitude': 31.914753,
#   'longitude': -83.753338,
#   'nibrs_start_date': None},
#  'GA1000100': {'ori': 'GA1000100',
#   'agency_name': 'Colquitt Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MILLER',
#   'nibrs': False,
#   'latitude': 31.162908,
#   'longitude': -84.730386,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0320000': {'ori': 'GA0320000',
#   'agency_name': "Clinch County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLINCH',
#   'nibrs': True,
#   'latitude': 31.039433,
#   'longitude': -82.749954,
#   'nibrs_start_date': '07/01/2020'},
#  'GA0080200': {'ori': 'GA0080200',
#   'agency_name': 'Adairsville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARTOW',
#   'nibrs': True,
#   'latitude': 34.368633,
#   'longitude': -84.93449,
#   'nibrs_start_date': '11/01/2018'},
#  'GA0630300': {'ori': 'GA0630300',
#   'agency_name': 'College of Coastal Georgia',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GLYNN',
#   'nibrs': True,
#   'latitude': 31.212746,
#   'longitude': -81.496517,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1190300': {'ori': 'GA1190300',
# ...
#   'agency_type_name': 'Other State Agency',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.759632,
#   'longitude': -84.382416,
#   'nibrs_start_date': '10/01/2019'},
#  'GA1130000': {'ori': 'GA1130000',
#   'agency_name': "Pierce County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PIERCE',
#   'nibrs': True,
#   'latitude': 31.302244,
#   'longitude': -82.23383,
#   'nibrs_start_date': '06/01/2018'},
#  'GA120059E': {'ori': 'GA120059E',
#   'agency_name': 'Andrew College ',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RANDOLPH',
#   'nibrs': False,
#   'latitude': 31.771894,
#   'longitude': -84.79704,
#   'nibrs_start_date': None},
#  'GA0970300': {'ori': 'GA0970300',
#   'agency_name': 'Danielsville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MADISON',
#   'nibrs': True,
#   'latitude': 34.128484,
#   'longitude': -83.203644,
#   'nibrs_start_date': '07/01/2019'},
#  'GA0410000': {'ori': 'GA0410000',
#   'agency_name': "Dade County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DADE',
#   'nibrs': False,
#   'latitude': 34.852424,
#   'longitude': -85.506201,
#   'nibrs_start_date': None},
#  'GA0070000': {'ori': 'GA0070000',
#   'agency_name': "Barrow County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARROW',
#   'nibrs': True,
#   'latitude': 33.992009,
#   'longitude': -83.712303,
#   'nibrs_start_date': '01/01/2018'},
#  'GA0840000': {'ori': 'GA0840000',
#   'agency_name': "Jones County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JONES',
#   'nibrs': True,
#   'latitude': 33.020226,
#   'longitude': -83.562339,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0330200': {'ori': 'GA0330200',
#   'agency_name': 'Cobb County Police Department',
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COBB',
#   'nibrs': True,
#   'latitude': 33.958862,
#   'longitude': -84.54633,
#   'nibrs_start_date': '08/01/2019'},
#  'GA1340100': {'ori': 'GA1340100',
#   'agency_name': 'McRae Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHEELER; TELFAIR',
#   'nibrs': True,
#   'latitude': 31.913639,
#   'longitude': -82.931062,
#   'nibrs_start_date': '01/01/2020'},
#  'GA0670800': {'ori': 'GA0670800',
#   'agency_name': 'Snellville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GWINNETT',
#   'nibrs': True,
#   'latitude': 33.83367,
#   'longitude': -84.00958,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0760200': {'ori': 'GA0760200',
#   'agency_name': 'Warner Robins Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'PEACH; HOUSTON',
#   'nibrs': True,
#   'latitude': 32.458381,
#   'longitude': -83.662856,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0280100': {'ori': 'GA0280100',
#   'agency_name': 'Canton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHEROKEE',
#   'nibrs': True,
#   'latitude': 34.23541,
#   'longitude': -84.490005,
#   'nibrs_start_date': '11/01/2020'},
#  'GAGSP1900': {'ori': 'GAGSP1900',
#   'agency_name': 'State Patrol: Swainsboro',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL',
#   'nibrs': False,
#   'latitude': 32.5911,
#   'longitude': -82.299763,
#   'nibrs_start_date': None},
#  'GA1200000': {'ori': 'GA1200000',
#   'agency_name': "Randolph County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'RANDOLPH',
#   'nibrs': False,
#   'latitude': 31.762651,
#   'longitude': -84.752311,
#   'nibrs_start_date': None},
#  'GA0530500': {'ori': 'GA0530500',
#   'agency_name': 'Stillmore Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL',
#   'nibrs': False,
#   'latitude': 32.5911,
#   'longitude': -82.299763,
#   'nibrs_start_date': None},
#  'GA1550200': {'ori': 'GA1550200',
#   'agency_name': 'Tunnel Hill Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'WHITFIELD',
#   'nibrs': True,
#   'latitude': 34.801726,
#   'longitude': -84.968541,
#   'nibrs_start_date': '02/01/2020'},
#  'GA0830200': {'ori': 'GA0830200',
#   'agency_name': 'Adrian Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'EMANUEL; JOHNSON',
#   'nibrs': False,
#   'latitude': 32.689831,
#   'longitude': -82.661354,
#   'nibrs_start_date': None},
#  'GA0610300': {'ori': 'GA0610300',
#   'agency_name': 'East Ellijay Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'GILMER',
#   'nibrs': True,
#   'latitude': 34.690541,
#   'longitude': -84.453984,
#   'nibrs_start_date': '12/01/2019'},
#  'GA0750400': {'ori': 'GA0750400',
#   'agency_name': 'Locust Grove Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HENRY',
#   'nibrs': False,
#   'latitude': 33.452881,
#   'longitude': -84.15444,
#   'nibrs_start_date': None},
#  'GA0310600': {'ori': 'GA0310600',
#   'agency_name': 'Lake City Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CLAYTON',
#   'nibrs': True,
#   'latitude': 33.60693,
#   'longitude': -84.34333,
#   'nibrs_start_date': '09/01/2018'},
#  'GA1290000': {'ori': 'GA1290000',
#   'agency_name': "Sumter County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SUMTER',
#   'nibrs': True,
#   'latitude': 32.042197,
#   'longitude': -84.204259,
#   'nibrs_start_date': '01/01/2018'},
#  'GA1070000': {'ori': 'GA1070000',
#   'agency_name': "Newton County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'NEWTON',
#   'nibrs': True,
#   'latitude': 33.544065,
#   'longitude': -83.855192,
#   'nibrs_start_date': '10/01/2018'},
#  'GA0050300': {'ori': 'GA0050300',
#   'agency_name': 'Georgia College and State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': True,
#   'latitude': 33.059504,
#   'longitude': -83.255452,
#   'nibrs_start_date': '09/01/2019'},
#  'GA0560000': {'ori': 'GA0560000',
#   'agency_name': "Fayette County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FAYETTE',
#   'nibrs': True,
#   'latitude': 33.446476,
#   'longitude': -84.45227,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0990000': {'ori': 'GA0990000',
#   'agency_name': "Meriwether County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MERIWETHER',
#   'nibrs': True,
#   'latitude': 33.03022,
#   'longitude': -84.663279,
#   'nibrs_start_date': '01/01/2019'},
#  'GA0602700': {'ori': 'GA0602700',
#   'agency_name': 'Fulton County Marshal',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.752655,
#   'longitude': -84.38997,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0600400': {'ori': 'GA0600400',
#   'agency_name': 'Alpharetta Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FULTON',
#   'nibrs': True,
#   'latitude': 33.790034,
#   'longitude': -84.468182,
#   'nibrs_start_date': '03/01/2019'},
#  'GA1280100': {'ori': 'GA1280100',
#   'agency_name': 'Lumpkin Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'STEWART',
#   'nibrs': False,
#   'latitude': 32.073225,
#   'longitude': -84.834912,
#   'nibrs_start_date': None},
#  'GA1410000': {'ori': 'GA1410000',
#   'agency_name': "Troup County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TROUP',
#   'nibrs': False,
#   'latitude': 32.989746,
#   'longitude': -85.00395,
#   'nibrs_start_date': None},
#  'GA0690400': {'ori': 'GA0690400',
#   'agency_name': 'Oakwood Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'HALL',
#   'nibrs': True,
#   'latitude': 34.317588,
#   'longitude': -83.818497,
#   'nibrs_start_date': '11/01/2019'},
#  'GA0130000': {'ori': 'GA0130000',
#   'agency_name': "Brantley County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BRANTLEY',
#   'nibrs': True,
#   'latitude': 31.197334,
#   'longitude': -81.982978,
#   'nibrs_start_date': '10/01/2019'},
#  'GAGSP0800': {'ori': 'GAGSP0800',
#   'agency_name': 'State Patrol: Madison',
#   'agency_type_name': 'State Police',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MORGAN',
#   'nibrs': False,
#   'latitude': 33.593732,
#   'longitude': -83.492324,
#   'nibrs_start_date': None},
#  'GA0340100': {'ori': 'GA0340100',
#   'agency_name': 'Douglas Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'COFFEE',
#   'nibrs': True,
#   'latitude': 31.511168,
#   'longitude': -82.852135,
#   'nibrs_start_date': '10/01/2019'},
#  'GA0470500': {'ori': 'GA0470500',
#   'agency_name': 'Dougherty County Board of Education',
#   'agency_type_name': 'Other',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'DOUGHERTY',
#   'nibrs': True,
#   'latitude': 31.532588,
#   'longitude': -84.20904,
#   'nibrs_start_date': '07/01/2019'},
#  'GA1350000': {'ori': 'GA1350000',
#   'agency_name': "Terrell County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TERRELL',
#   'nibrs': False,
#   'latitude': 31.777191,
#   'longitude': -84.439446,
#   'nibrs_start_date': None},
#  'GA0250600': {'ori': 'GA0250600',
#   'agency_name': 'Tybee Island Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'CHATHAM',
#   'nibrs': True,
#   'latitude': 31.980523,
#   'longitude': -81.08519,
#   'nibrs_start_date': '05/01/2019'},
#  'GA0900000': {'ori': 'GA0900000',
#   'agency_name': "Lincoln County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'LINCOLN',
#   'nibrs': False,
#   'latitude': 33.792151,
#   'longitude': -82.448299,
#   'nibrs_start_date': None},
#  'GA0550200': {'ori': 'GA0550200',
#   'agency_name': 'Blue Ridge Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'FANNIN',
#   'nibrs': False,
#   'latitude': 34.866226,
#   'longitude': -84.32594,
#   'nibrs_start_date': None},
#  'GA0770100': {'ori': 'GA0770100',
#   'agency_name': 'Ocilla Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'IRWIN',
#   'nibrs': True,
#   'latitude': 31.591131,
#   'longitude': -83.25055,
#   'nibrs_start_date': '07/01/2019'},
#  'GA0810500': {'ori': 'GA0810500',
#   'agency_name': 'Stapleton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': True,
#   'latitude': 33.051874,
#   'longitude': -82.41905,
#   'nibrs_start_date': '07/01/2020'},
#  'GA0120200': {'ori': 'GA0120200',
#   'agency_name': 'Middle Georgia State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Georgia',
#   'state_abbr': 'GA',
#   'division_name': 'South Atlantic',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BLECKLEY',
#   'nibrs': True,
#   'latitude': 32.435403,
#   'longitude': -83.331717,
#   'nibrs_start_date': '01/01/2019'}}

# %%
# Connect to database
client = pymongo.MongoClient('mongodb://localhost:27017')
db = client.CrimeAgencyData

# Deletes any existing database to prevent data from duplicating each time script is executed
client.drop_database('CrimeAgencyData')

agency_data = []

# Loop through the GA_data
for x in GA_data:
    agency_data = [
        {
            "ORI" : GA_data[x]["ori"],
            "Agency Name" : GA_data[x]["agency_name"],
            "County" : GA_data[x]["county_name"],
            "Latitude" : GA_data[x]["latitude"],
            "Longitude" : GA_data[x]["longitude"]
        }
    ]
    
    
    # Add entry to the database
    db.destination.insert_many(agency_data)
    
    agency_data.append(agency_data)
    pprint.pprint(agency_data)
# Out:
# [{'Agency Name': 'Portal Police Department',
#   'County': 'BULLOCH',
#   'Latitude': 32.393408,
#   'Longitude': -81.74381,
#   'ORI': 'GA0160300',
#   '_id': ObjectId('6335e0588391502eb9b0ad3b')},
#  <Recursion on list with id=3107352224840>]
# [{'Agency Name': 'Alto Police Department',
#   'County': 'BANKS; HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   'ORI': 'GA0680900',
#   '_id': ObjectId('6335e0588391502eb9b0ad3c')},
#  <Recursion on list with id=3107352164616>]
# [{'Agency Name': 'Trenton Police Department',
#   'County': 'DADE',
#   'Latitude': 34.852424,
#   'Longitude': -85.506201,
#   'ORI': 'GA0410100',
#   '_id': ObjectId('6335e0588391502eb9b0ad3d')},
#  <Recursion on list with id=3107352181704>]
# [{'Agency Name': 'Kingston Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080300',
#   '_id': ObjectId('6335e0588391502eb9b0ad3e')},
#  <Recursion on list with id=3107351659208>]
# [{'Agency Name': 'State Patrol: Milledgeville',
#   'County': 'BALDWIN',
#   'Latitude': 33.059504,
#   'Longitude': -83.255452,
#   'ORI': 'GAGSP3300',
#   '_id': ObjectId('6335e0588391502eb9b0ad3f')},
#  <Recursion on list with id=3107351660232>]
# [{'Agency Name': 'Morris Brown College',
#   'County': 'FULTON',
#   'Latitude': 33.75472,
#   'Longitude': -84.40874,
#   'ORI': 'GA060459E',
#   '_id': ObjectId('6335e0588391502eb9b0ad40')},
#  <Recursion on list with id=3107327104264>]
# [{'Agency Name': 'Austell Police Department',
#   'County': 'DOUGLAS; COBB',
#   'Latitude': 33.93994,
#   'Longitude': -84.574166,
#   'ORI': 'GA0330100',
#   '_id': ObjectId('6335e0588391502eb9b0ad41')},
#  <Recursion on list with id=3107352165768>]
# [{'Agency Name': 'Hephzibah Police Department',
#   'County': 'RICHMOND',
#   'Latitude': 33.361487,
#   'Longitude': -82.074998,
#   'ORI': 'GA1210300',
#   '_id': ObjectId('6335e0588391502eb9b0ad42')},
#  <Recursion on list with id=3107104692296>]
# [{'Agency Name': "Atkinson County Sheriff's Office",
#   'County': 'ATKINSON',
#   'Latitude': 31.296677,
#   'Longitude': -82.878067,
#   'ORI': 'GA0020000',
#   '_id': ObjectId('6335e0588391502eb9b0ad43')},
#  <Recursion on list with id=3107351630728>]
# [{'Agency Name': 'State Patrol: Americus',
#   'County': 'SUMTER',
#   'Latitude': 32.037216,
#   'Longitude': -84.14207,
#   'ORI': 'GAGSP1000',
#   '_id': ObjectId('6335e0588391502eb9b0ad44')},
#  <Recursion on list with id=3107352166600>]
# [{'Agency Name': 'Talbotton Police Department',
#   'County': 'TALBOT',
#   'Latitude': 32.704603,
#   'Longitude': -84.530029,
#   'ORI': 'GA1300100',
#   '_id': ObjectId('6335e0588391502eb9b0ad45')},
#  <Recursion on list with id=3107352168200>]
# [{'Agency Name': 'Fitzgerald Police Department',
#   'County': 'BEN HILL',
#   'Latitude': 31.740775,
#   'Longitude': -83.14719,
#   'ORI': 'GA0090100',
#   '_id': ObjectId('6335e0588391502eb9b0ad46')},
#  <Recursion on list with id=3107352166856>]
# [{'Agency Name': "Macon County Sheriff's Office",
#   'County': 'MACON',
#   'Latitude': 32.366216,
#   'Longitude': -84.052162,
#   'ORI': 'GA0960000',
#   '_id': ObjectId('6335e0588391502eb9b0ad47')},
#  <Recursion on list with id=3107352165256>]
# [{'Agency Name': 'Americus Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290100',
#   '_id': ObjectId('6335e0588391502eb9b0ad48')},
#  <Recursion on list with id=3107352168264>]
# [{'Agency Name': "Lee County Sheriff's Office",
#   'County': 'LEE',
#   'Latitude': 31.818419,
#   'Longitude': -84.146681,
#   'ORI': 'GA0880000',
#   '_id': ObjectId('6335e0588391502eb9b0ad49')},
#  <Recursion on list with id=3107352165320>]
# [{'Agency Name': 'Riverdale Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.572205,
#   'Longitude': -84.415726,
#   'ORI': 'GA0310500',
#   '_id': ObjectId('6335e0588391502eb9b0ad4a')},
#  <Recursion on list with id=3107352845512>]
# [{'Agency Name': "Berrien County Sheriff's Office",
#   'County': 'BERRIEN',
#   'Latitude': 31.191711,
#   'Longitude': -83.27352,
#   'ORI': 'GA0100000',
#   '_id': ObjectId('6335e0588391502eb9b0ad4b')},
#  <Recursion on list with id=3107352165128>]
# [{'Agency Name': 'Tifton Police Department',
#   'County': 'TIFT',
#   'Latitude': 31.449644,
#   'Longitude': -83.509926,
#   'ORI': 'GA1370100',
#   '_id': ObjectId('6335e0588391502eb9b0ad4c')},
#  <Recursion on list with id=3107352166664>]
# [{'Agency Name': 'McIntosh County Schools',
#   'County': 'MCINTOSH',
#   'Latitude': 31.482978,
#   'Longitude': -81.370199,
#   'ORI': 'GA0950200',
#   '_id': ObjectId('6335e0588391502eb9b0ad4d')},
#  <Recursion on list with id=3107354183688>]
# [{'Agency Name': 'Arcade Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   'ORI': 'GA0780400',
#   '_id': ObjectId('6335e0588391502eb9b0ad4e')},
#  <Recursion on list with id=3107354336264>]
# [{'Agency Name': "Jefferson County Sheriff's Office",
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810000',
#   '_id': ObjectId('6335e0588391502eb9b0ad4f')},
#  <Recursion on list with id=3107354371272>]
# [{'Agency Name': 'Cobb County Board of Education',
#   'County': 'COBB',
#   'Latitude': 33.916363,
#   'Longitude': -84.546295,
#   'ORI': 'GA0331300',
#   '_id': ObjectId('6335e0588391502eb9b0ad50')},
#  <Recursion on list with id=3107354352200>]
# [{'Agency Name': 'State Patrol: Statesboro',
#   'County': 'BULLOCH',
#   'Latitude': 32.411438,
#   'Longitude': -81.80494,
#   'ORI': 'GAGSP4500',
#   '_id': ObjectId('6335e0588391502eb9b0ad51')},
#  <Recursion on list with id=3107352168328>]
# [{'Agency Name': 'State Patrol: Waycross',
#   'County': 'WARE',
#   'Latitude': 31.050881,
#   'Longitude': -82.421507,
#   'ORI': 'GAGSP2200',
#   '_id': ObjectId('6335e0588391502eb9b0ad52')},
#  <Recursion on list with id=3107351660744>]
# [{'Agency Name': 'Fayetteville Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.412717,
#   'Longitude': -84.493941,
#   'ORI': 'GA0560100',
#   '_id': ObjectId('6335e0588391502eb9b0ad53')},
#  <Recursion on list with id=3107352167880>]
# [{'Agency Name': "Grady County Sheriff's Office",
#   'County': 'GRADY',
#   'Latitude': 30.875891,
#   'Longitude': -84.245066,
#   'ORI': 'GA0650000',
#   '_id': ObjectId('6335e0588391502eb9b0ad54')},
#  <Recursion on list with id=3107354350856>]
# [{'Agency Name': 'Columbus Police Department',
#   'County': 'MUSCOGEE',
#   'Latitude': 32.464756,
#   'Longitude': -84.98599,
#   'ORI': 'GA1060100',
#   '_id': ObjectId('6335e0588391502eb9b0ad55')},
#  <Recursion on list with id=3107352167112>]
# [{'Agency Name': 'Pine Mountain Police Department',
#   'County': 'MERIWETHER; HARRIS',
#   'Latitude': 32.731549,
#   'Longitude': -84.912432,
#   'ORI': 'GA0720100',
#   '_id': ObjectId('6335e0588391502eb9b0ad56')},
#  <Recursion on list with id=3107354374024>]
# [{'Agency Name': 'DeKalb County School System',
#   'County': 'DEKALB',
#   'Latitude': 33.800564,
#   'Longitude': -84.20196,
#   'ORI': 'GA0445100',
#   '_id': ObjectId('6335e0588391502eb9b0ad57')},
#  <Recursion on list with id=3107354365640>]
# [{'Agency Name': "Burke  County Sheriff's Office",
#   'County': 'BURKE',
#   'Latitude': 33.050819,
#   'Longitude': -82.011571,
#   'ORI': 'GA0170000',
#   '_id': ObjectId('6335e0588391502eb9b0ad58')},
#  <Recursion on list with id=3107354364232>]
# [{'Agency Name': 'Coolidge Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360300',
#   '_id': ObjectId('6335e0588391502eb9b0ad59')},
#  <Recursion on list with id=3107354365000>]
# [{'Agency Name': "Pike County Sheriff's Office",
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   'ORI': 'GA1140000',
#   '_id': ObjectId('6335e0588391502eb9b0ad5a')},
#  <Recursion on list with id=3107354372552>]
# [{'Agency Name': 'Alamo Police Department',
#   'County': 'WHEELER',
#   'Latitude': 32.109276,
#   'Longitude': -82.738701,
#   'ORI': 'GA1530100',
#   '_id': ObjectId('6335e0588391502eb9b0ad5b')},
#  <Recursion on list with id=3107354352584>]
# [{'Agency Name': 'Conyers Police Department',
#   'County': 'ROCKDALE',
#   'Latitude': 33.65794,
#   'Longitude': -84.01751,
#   'ORI': 'GA1220100',
#   '_id': ObjectId('6335e0588391502eb9b0ad5c')},
#  <Recursion on list with id=3107354382024>]
# [{'Agency Name': 'Chatham County Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 32.060173,
#   'Longitude': -81.166336,
#   'ORI': 'GA0250100',
#   '_id': ObjectId('6335e0588391502eb9b0ad5d')},
#  <Recursion on list with id=3107354381512>]
# [{'Agency Name': 'Fairmount Police Department',
#   'County': 'GORDON',
#   'Latitude': 34.509667,
#   'Longitude': -84.873862,
#   'ORI': 'GA0640200',
#   '_id': ObjectId('6335e0588391502eb9b0ad5e')},
#  <Recursion on list with id=3107354381064>]
# [{'Agency Name': 'Savannah Technical College',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0252400',
#   '_id': ObjectId('6335e0588391502eb9b0ad5f')},
#  <Recursion on list with id=3107354393480>]
# [{'Agency Name': 'Patterson Police Department',
#   'County': 'PIERCE',
#   'Latitude': 31.353988,
#   'Longitude': -82.210427,
#   'ORI': 'GA1130200',
#   '_id': ObjectId('6335e0588391502eb9b0ad60')},
#  <Recursion on list with id=3107327038664>]
# [{'Agency Name': 'West Georgia Technical College',
#   'County': 'HARALSON',
#   'Latitude': 33.795165,
#   'Longitude': -85.220062,
#   'ORI': 'GA0710500',
#   '_id': ObjectId('6335e0588391502eb9b0ad61')},
#  <Recursion on list with id=3107310088520>]
# [{'Agency Name': 'Georgia Southern University',
#   'County': 'BULLOCH',
#   'Latitude': 32.393408,
#   'Longitude': -81.74381,
#   'ORI': 'GA0160400',
#   '_id': ObjectId('6335e0588391502eb9b0ad62')},
#  <Recursion on list with id=3107354380552>]
# [{'Agency Name': "Cobb County Sheriff's Office",
#   'County': 'COBB',
#   'Latitude': 33.952282,
#   'Longitude': -84.5482,
#   'ORI': 'GA0330000',
#   '_id': ObjectId('6335e0588391502eb9b0ad63')},
#  <Recursion on list with id=3107354392584>]
# [{'Agency Name': 'Georgia Regents University',
#   'County': 'RICHMOND',
#   'Latitude': 33.47503,
#   'Longitude': -81.98768,
#   'ORI': 'GA1210400',
#   '_id': ObjectId('6335e0588391502eb9b0ad64')},
#  <Recursion on list with id=3107354363720>]
# [{'Agency Name': 'State Patrol: Athens',
#   'County': 'CLARKE',
#   'Latitude': 33.952185,
#   'Longitude': -83.367152,
#   'ORI': 'GAGSP3200',
#   '_id': ObjectId('6335e0588391502eb9b0ad65')},
#  <Recursion on list with id=3107354394376>]
# [{'Agency Name': 'Sky Valley Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190500',
#   '_id': ObjectId('6335e0588391502eb9b0ad66')},
#  <Recursion on list with id=3107354410696>]
# [{'Agency Name': 'Woodland Police Department',
#   'County': 'TALBOT',
#   'Latitude': 32.704603,
#   'Longitude': -84.530029,
#   'ORI': 'GA1300200',
#   '_id': ObjectId('6335e0588391502eb9b0ad67')},
#  <Recursion on list with id=3107354400328>]
# [{'Agency Name': 'Homeland Police Department',
#   'County': 'CHARLTON',
#   'Latitude': 30.856588,
#   'Longitude': -82.02113,
#   'ORI': 'GA0240200',
#   '_id': ObjectId('6335e0588391502eb9b0ad68')},
#  <Recursion on list with id=3107354412936>]
# [{'Agency Name': "Echols County Sheriff's Office",
#   'County': 'ECHOLS',
#   'Latitude': 30.7085,
#   'Longitude': -82.836132,
#   'ORI': 'GA0500000',
#   '_id': ObjectId('6335e0588391502eb9b0ad69')},
#  <Recursion on list with id=3107354400776>]
# [{'Agency Name': 'Hazlehurst Police Department',
#   'County': 'JEFF DAVIS',
#   'Latitude': 31.867207,
#   'Longitude': -82.599304,
#   'ORI': 'GA0800100',
#   '_id': ObjectId('6335e0588391502eb9b0ad6a')},
#  <Recursion on list with id=3107354410056>]
# [{'Agency Name': 'East Georgia State College',
#   'County': 'EMANUEL',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0530700',
#   '_id': ObjectId('6335e0588391502eb9b0ad6b')},
#  <Recursion on list with id=3107354401736>]
# [{'Agency Name': "Early County Sheriff's Office",
#   'County': 'EARLY',
#   'Latitude': 31.324191,
#   'Longitude': -84.906723,
#   'ORI': 'GA0490000',
#   '_id': ObjectId('6335e0588391502eb9b0ad6c')},
#  <Recursion on list with id=3107354410568>]
# [{'Agency Name': 'Young Harris College',
#   'County': 'TOWNS',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA139039E',
#   '_id': ObjectId('6335e0588391502eb9b0ad6d')},
#  <Recursion on list with id=3107306127304>]
# [{'Agency Name': "Toombs County Sheriff's Office",
#   'County': 'TOOMBS',
#   'Latitude': 32.20298,
#   'Longitude': -82.34015,
#   'ORI': 'GA1380000',
#   '_id': ObjectId('6335e0588391502eb9b0ad6e')},
#  <Recursion on list with id=3107354373064>]
# [{'Agency Name': "Floyd County Sheriff's Office",
#   'County': 'FLOYD',
#   'Latitude': 34.280457,
#   'Longitude': -85.1429,
#   'ORI': 'GA0570000',
#   '_id': ObjectId('6335e0588391502eb9b0ad6f')},
#  <Recursion on list with id=3107309533896>]
# [{'Agency Name': 'Jonesboro Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.516556,
#   'Longitude': -84.353935,
#   'ORI': 'GA0310400',
#   '_id': ObjectId('6335e0588391502eb9b0ad70')},
#  <Recursion on list with id=3107354414728>]
# [{'Agency Name': 'Baxley Police Department',
#   'County': 'APPLING',
#   'Latitude': 31.739712,
#   'Longitude': -82.290103,
#   'ORI': 'GA0010100',
#   '_id': ObjectId('6335e0588391502eb9b0ad71')},
#  <Recursion on list with id=3107354399944>]
# [{'Agency Name': 'Stone Mountain Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.80639,
#   'Longitude': -84.170364,
#   'ORI': 'GA0440900',
#   '_id': ObjectId('6335e0588391502eb9b0ad72')},
#  <Recursion on list with id=3107354438664>]
# [{'Agency Name': 'Omega Police Department',
#   'County': 'COLQUITT; TIFT',
#   'Latitude': 31.457003,
#   'Longitude': -83.525931,
#   'ORI': 'GA1370200',
#   '_id': ObjectId('6335e0588391502eb9b0ad73')},
#  <Recursion on list with id=3107354439624>]
# [{'Agency Name': 'Douglasville Police Department',
#   'County': 'DOUGLAS',
#   'Latitude': 33.699317,
#   'Longitude': -84.765944,
#   'ORI': 'GA0480100',
#   '_id': ObjectId('6335e0588391502eb9b0ad74')},
#  <Recursion on list with id=3107354446536>]
# [{'Agency Name': 'Leslie Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290200',
#   '_id': ObjectId('6335e0588391502eb9b0ad75')},
#  <Recursion on list with id=3107354445640>]
# [{'Agency Name': 'Darien Police Department',
#   'County': 'MCINTOSH',
#   'Latitude': 31.482978,
#   'Longitude': -81.370199,
#   'ORI': 'GA0950100',
#   '_id': ObjectId('6335e0588391502eb9b0ad76')},
#  <Recursion on list with id=3107354373512>]
# [{'Agency Name': 'Hoschton Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   'ORI': 'GA0780500',
#   '_id': ObjectId('6335e0588391502eb9b0ad77')},
#  <Recursion on list with id=3107354424904>]
# [{'Agency Name': "Schley County Sheriff's Office",
#   'County': 'SCHLEY',
#   'Latitude': 32.263441,
#   'Longitude': -84.322724,
#   'ORI': 'GA1230000',
#   '_id': ObjectId('6335e0588391502eb9b0ad78')},
#  <Recursion on list with id=3107354452552>]
# [{'Agency Name': 'Kennesaw State University',
#   'County': 'COBB',
#   'Latitude': 33.93994,
#   'Longitude': -84.574166,
#   'ORI': 'GA0331200',
#   '_id': ObjectId('6335e0588391502eb9b0ad79')},
#  <Recursion on list with id=3107354453512>]
# [{'Agency Name': 'State Patrol: Forsyth',
#   'County': 'MONROE',
#   'Latitude': 33.017435,
#   'Longitude': -83.922938,
#   'ORI': 'GAGSP4400',
#   '_id': ObjectId('6335e0588391502eb9b0ad7a')},
#  <Recursion on list with id=3107354427272>]
# [{'Agency Name': 'State Patrol: Sylvania',
#   'County': 'SCREVEN',
#   'Latitude': 32.748623,
#   'Longitude': -81.65879,
#   'ORI': 'GAGSP2100',
#   '_id': ObjectId('6335e0588391502eb9b0ad7b')},
#  <Recursion on list with id=3107354439176>]
# [{'Agency Name': 'Peachtree City Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.412717,
#   'Longitude': -84.493941,
#   'ORI': 'GA0560200',
#   '_id': ObjectId('6335e0588391502eb9b0ad7c')},
#  <Recursion on list with id=3107354423944>]
# [{'Agency Name': "Muscogee  County Sheriff's Office",
#   'County': 'MUSCOGEE',
#   'Latitude': 32.510197,
#   'Longitude': -84.874946,
#   'ORI': 'GA1060000',
#   '_id': ObjectId('6335e0588391502eb9b0ad7d')},
#  <Recursion on list with id=3107354402696>]
# [{'Agency Name': 'Hall County Marshal',
#   'County': 'HALL',
#   'Latitude': 34.317588,
#   'Longitude': -83.818497,
#   'ORI': 'GA0690600',
#   '_id': ObjectId('6335e0588391502eb9b0ad7e')},
#  <Recursion on list with id=3107354454856>]
# [{'Agency Name': 'Cairo Police Department',
#   'County': 'GRADY',
#   'Latitude': 30.875891,
#   'Longitude': -84.245066,
#   'ORI': 'GA0650100',
#   '_id': ObjectId('6335e0588391502eb9b0ad7f')},
#  <Recursion on list with id=3107354455752>]
# [{'Agency Name': 'Meigs Police Department',
#   'County': 'MITCHELL; THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360400',
#   '_id': ObjectId('6335e0588391502eb9b0ad80')},
#  <Recursion on list with id=3107354425864>]
# [{'Agency Name': "Dawson County Sheriff's Office",
#   'County': 'DAWSON',
#   'Latitude': 34.422028,
#   'Longitude': -84.12007,
#   'ORI': 'GA0420000',
#   '_id': ObjectId('6335e0588391502eb9b0ad81')},
#  <Recursion on list with id=3107354459528>]
# [{'Agency Name': 'Zebulon Police Department',
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   'ORI': 'GA1140100',
#   '_id': ObjectId('6335e0588391502eb9b0ad82')},
#  <Recursion on list with id=3107354455240>]
# [{'Agency Name': "Harris County Sheriff's Office",
#   'County': 'HARRIS',
#   'Latitude': 32.731549,
#   'Longitude': -84.912432,
#   'ORI': 'GA0720000',
#   '_id': ObjectId('6335e0588391502eb9b0ad83')},
#  <Recursion on list with id=3107354458632>]
# [{'Agency Name': 'Albany State University',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.572027,
#   'Longitude': -84.144394,
#   'ORI': 'GA0470300',
#   '_id': ObjectId('6335e0588391502eb9b0ad84')},
#  <Recursion on list with id=3107354458120>]
# [{'Agency Name': 'Athens Technical College',
#   'County': 'CLARKE',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0290900',
#   '_id': ObjectId('6335e0588391502eb9b0ad85')},
#  <Recursion on list with id=3107354425416>]
# [{'Agency Name': "Wheeler County Sheriff's Office",
#   'County': 'WHEELER',
#   'Latitude': 32.14889,
#   'Longitude': -82.78266,
#   'ORI': 'GA1530000',
#   '_id': ObjectId('6335e0588391502eb9b0ad86')},
#  <Recursion on list with id=3107354437704>]
# [{'Agency Name': 'Eton Police Department',
#   'County': 'MURRAY',
#   'Latitude': 34.797097,
#   'Longitude': -84.73799,
#   'ORI': 'GA1050200',
#   '_id': ObjectId('6335e0588391502eb9b0ad87')},
#  <Recursion on list with id=3107306145480>]
# [{'Agency Name': "Chatham County Sheriff's Office",
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0250000',
#   '_id': ObjectId('6335e0588391502eb9b0ad88')},
#  <Recursion on list with id=3107354409096>]
# [{'Agency Name': 'Register Police Department',
#   'County': 'BULLOCH',
#   'Latitude': 32.367367,
#   'Longitude': -81.88627,
#   'ORI': 'GA0160500',
#   '_id': ObjectId('6335e0588391502eb9b0ad89')},
#  <Recursion on list with id=3107354473544>]
# [{'Agency Name': "Madison County Sheriff's Office",
#   'County': 'MADISON',
#   'Latitude': 34.128484,
#   'Longitude': -83.203644,
#   'ORI': 'GA0970000',
#   '_id': ObjectId('6335e0588391502eb9b0ad8a')},
#  <Recursion on list with id=3107354488456>]
# [{'Agency Name': 'Homerville Police Department',
#   'County': 'CLINCH',
#   'Latitude': 30.917653,
#   'Longitude': -82.702614,
#   'ORI': 'GA0320100',
#   '_id': ObjectId('6335e0588391502eb9b0ad8b')},
#  <Recursion on list with id=3107310256712>]
# [{'Agency Name': 'Glynn County Police Department',
#   'County': 'GLYNN',
#   'Latitude': 31.212746,
#   'Longitude': -81.496517,
#   'ORI': 'GA0630200',
#   '_id': ObjectId('6335e0588391502eb9b0ad8c')},
#  <Recursion on list with id=3107354474504>]
# [{'Agency Name': 'Berry College',
#   'County': 'FLOYD',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA057069E',
#   '_id': ObjectId('6335e0588391502eb9b0ad8d')},
#  <Recursion on list with id=3107310201544>]
# [{'Agency Name': 'State Patrol: Valdosta',
#   'County': 'LOWNDES',
#   'Latitude': 30.833127,
#   'Longitude': -83.268992,
#   'ORI': 'GAGSP3100',
#   '_id': ObjectId('6335e0588391502eb9b0ad8e')},
#  <Recursion on list with id=3107354476424>]
# [{'Agency Name': "Miller County Sheriff's Office",
#   'County': 'MILLER',
#   'Latitude': 31.17431,
#   'Longitude': -84.73826,
#   'ORI': 'GA1000000',
#   '_id': ObjectId('6335e0588391502eb9b0ad8f')},
#  <Recursion on list with id=3107354485704>]
# [{'Agency Name': 'Dillard Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190400',
#   '_id': ObjectId('6335e0588391502eb9b0ad90')},
#  <Recursion on list with id=3107354480776>]
# [{'Agency Name': 'Jacksonville Police Department',
#   'County': 'TELFAIR',
#   'Latitude': 31.913639,
#   'Longitude': -82.931062,
#   'ORI': 'GA1340600',
#   '_id': ObjectId('6335e0588391502eb9b0ad91')},
#  <Recursion on list with id=3107354473608>]
# [{'Agency Name': "Bibb County Sheriff's Office",
#   'County': 'BIBB',
#   'Latitude': 32.831833,
#   'Longitude': -83.64161,
#   'ORI': 'GA0110000',
#   '_id': ObjectId('6335e0588391502eb9b0ad92')},
#  <Recursion on list with id=3107354484680>]
# [{'Agency Name': 'Ideal Police Department',
#   'County': 'MACON',
#   'Latitude': 32.366216,
#   'Longitude': -84.052162,
#   'ORI': 'GA0960200',
#   '_id': ObjectId('6335e0588391502eb9b0ad93')},
#  <Recursion on list with id=3107306823496>]
# [{'Agency Name': "Appling County Sheriff's Office",
#   'County': 'APPLING',
#   'Latitude': 31.782509,
#   'Longitude': -82.35828,
#   'ORI': 'GA0010000',
#   '_id': ObjectId('6335e0588391502eb9b0ad94')},
#  <Recursion on list with id=3107354503048>]
# [{'Agency Name': 'Morrow Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.582436,
#   'Longitude': -84.33722,
#   'ORI': 'GA0310300',
#   '_id': ObjectId('6335e0588391502eb9b0ad95')},
#  <Recursion on list with id=3107354490888>]
# [{'Agency Name': 'Floyd County Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.169235,
#   'Longitude': -85.21126,
#   'ORI': 'GA0570100',
#   '_id': ObjectId('6335e0588391502eb9b0ad96')},
#  <Recursion on list with id=3107354488008>]
# [{'Agency Name': 'Washington County Board of Education',
#   'County': 'WASHINGTON',
#   'Latitude': 32.971848,
#   'Longitude': -82.798112,
#   'ORI': 'GA1500600',
#   '_id': ObjectId('6335e0588391502eb9b0ad97')},
#  <Recursion on list with id=3107354334600>]
# [{'Agency Name': 'Alapaha Police Department',
#   'County': 'BERRIEN',
#   'Latitude': 31.274308,
#   'Longitude': -83.231906,
#   'ORI': 'GA0100200',
#   '_id': ObjectId('6335e0588391502eb9b0ad98')},
#  <Recursion on list with id=3107354516168>]
# [{'Agency Name': "Jasper County Sheriff's Office",
#   'County': 'JASPER',
#   'Latitude': 33.318128,
#   'Longitude': -83.689505,
#   'ORI': 'GA0790000',
#   '_id': ObjectId('6335e0588391502eb9b0ad99')},
#  <Recursion on list with id=3107354503496>]
# [{'Agency Name': 'Pine Lake Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.770661,
#   'Longitude': -84.226343,
#   'ORI': 'GA0440800',
#   '_id': ObjectId('6335e0588391502eb9b0ad9a')},
#  <Recursion on list with id=3107354504968>]
# [{'Agency Name': 'Jefferson Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.11839,
#   'Longitude': -83.57744,
#   'ORI': 'GA0780200',
#   '_id': ObjectId('6335e0588391502eb9b0ad9b')},
#  <Recursion on list with id=3107354487560>]
# [{'Agency Name': "Douglas County Sheriff's Office",
#   'County': 'DOUGLAS',
#   'Latitude': 33.748375,
#   'Longitude': -84.7535,
#   'ORI': 'GA0480000',
#   '_id': ObjectId('6335e0588391502eb9b0ad9c')},
#  <Recursion on list with id=3107354515144>]
# [{'Agency Name': 'Plains Police Department',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290300',
#   '_id': ObjectId('6335e0588391502eb9b0ad9d')},
#  <Recursion on list with id=3107354335432>]
# [{'Agency Name': 'University of West Georgia',
#   'County': 'CARROLL',
#   'Latitude': 33.571545,
#   'Longitude': -85.094604,
#   'ORI': 'GA0220600',
#   '_id': ObjectId('6335e0588391502eb9b0ad9e')},
#  <Recursion on list with id=3107354455752>]
# [{'Agency Name': "Jenkins County Sheriff's Office",
#   'County': 'JENKINS',
#   'Latitude': 32.794563,
#   'Longitude': -81.971524,
#   'ORI': 'GA0820000',
#   '_id': ObjectId('6335e0588391502eb9b0ad9f')},
#  <Recursion on list with id=3107354402696>]
# [{'Agency Name': 'Tyrone Police Department',
#   'County': 'FAYETTE',
#   'Latitude': 33.478733,
#   'Longitude': -84.594215,
#   'ORI': 'GA0560300',
#   '_id': ObjectId('6335e0588391502eb9b0ada0')},
#  <Recursion on list with id=3107354425864>]
# [{'Agency Name': 'State Patrol: Calhoun',
#   'County': 'GORDON',
#   'Latitude': 34.460278,
#   'Longitude': -84.91662,
#   'ORI': 'GAGSP4300',
#   '_id': ObjectId('6335e0588391502eb9b0ada1')},
#  <Recursion on list with id=3107354455240>]
# [{'Agency Name': 'State Patrol: Dublin',
#   'County': 'LAURENS',
#   'Latitude': 32.39322,
#   'Longitude': -82.926317,
#   'ORI': 'GAGSP2000',
#   '_id': ObjectId('6335e0588391502eb9b0ada2')},
#  <Recursion on list with id=3107354427272>]
# [{'Agency Name': 'Georgia State University',
#   'County': 'FULTON',
#   'Latitude': 33.754486,
#   'Longitude': -84.38908,
#   'ORI': 'GA0600900',
#   '_id': ObjectId('6335e0588391502eb9b0ada3')},
#  <Recursion on list with id=3107354424904>]
# [{'Agency Name': 'Cleveland Police Department',
#   'County': 'WHITE',
#   'Latitude': 34.643776,
#   'Longitude': -83.743417,
#   'ORI': 'GA1540100',
#   '_id': ObjectId('6335e0588391502eb9b0ada4')},
#  <Recursion on list with id=3107354514312>]
# [{'Agency Name': "Polk County Sheriff's Office",
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150000',
#   '_id': ObjectId('6335e0588391502eb9b0ada5')},
#  <Recursion on list with id=3107354373512>]
# [{'Agency Name': 'Atlanta Police Department',
#   'County': 'DEKALB; FULTON',
#   'Latitude': 33.74819,
#   'Longitude': -84.39517,
#   'ORI': 'GAAPD0000',
#   '_id': ObjectId('6335e0588391502eb9b0ada6')},
#  <Recursion on list with id=3107354446536>]
# [{'Agency Name': 'Dougherty County Police Department',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470200',
#   '_id': ObjectId('6335e0588391502eb9b0ada7')},
#  <Recursion on list with id=3107354439176>]
# [{'Agency Name': 'Thomasville Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360100',
#   '_id': ObjectId('6335e0588391502eb9b0ada8')},
#  <Recursion on list with id=3107354373064>]
# [{'Agency Name': 'Brookhaven Police Department',
#   'County': 'DEKALB',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0447200',
#   '_id': ObjectId('6335e0588391502eb9b0ada9')},
#  <Recursion on list with id=3107354445640>]
# [{'Agency Name': 'Statham Police Department',
#   'County': 'BARROW',
#   'Latitude': 33.992009,
#   'Longitude': -83.712303,
#   'ORI': 'GA0070300',
#   '_id': ObjectId('6335e0588391502eb9b0adaa')},
#  <Recursion on list with id=3107354454856>]
# [{'Agency Name': 'Morehouse School of Medicine',
#   'County': 'FULTON',
#   'Latitude': 33.743107,
#   'Longitude': -84.41023,
#   'ORI': 'GA0606200',
#   '_id': ObjectId('6335e0588391502eb9b0adab')},
#  <Recursion on list with id=3107354414728>]
# [{'Agency Name': 'Cartersville Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080100',
#   '_id': ObjectId('6335e0588391502eb9b0adac')},
#  <Recursion on list with id=3107354439624>]
# [{'Agency Name': 'Savannah-Chatham Metropolitan Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 32.075733,
#   'Longitude': -81.088394,
#   'ORI': 'GA0250300',
#   '_id': ObjectId('6335e0588391502eb9b0adad')},
#  <Recursion on list with id=3107354438664>]
# [{'Agency Name': 'Wadley Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810200',
#   '_id': ObjectId('6335e0588391502eb9b0adae')},
#  <Recursion on list with id=3107354453512>]
# [{'Agency Name': 'Chatsworth Police Department',
#   'County': 'MURRAY',
#   'Latitude': 34.797097,
#   'Longitude': -84.73799,
#   'ORI': 'GA1050100',
#   '_id': ObjectId('6335e0588391502eb9b0adaf')},
#  <Recursion on list with id=3107309533896>]
# [{'Agency Name': "Gordon County Sheriff's Office",
#   'County': 'GORDON',
#   'Latitude': 34.509667,
#   'Longitude': -84.873862,
#   'ORI': 'GA0640000',
#   '_id': ObjectId('6335e0588391502eb9b0adb0')},
#  <Recursion on list with id=3107354410056>]
# [{'Agency Name': 'State Patrol: Cordele',
#   'County': 'CRISP',
#   'Latitude': 31.914753,
#   'Longitude': -83.753338,
#   'ORI': 'GAGSP3000',
#   '_id': ObjectId('6335e0588391502eb9b0adb1')},
#  <Recursion on list with id=3107354410696>]
# [{'Agency Name': 'Colquitt Police Department',
#   'County': 'MILLER',
#   'Latitude': 31.162908,
#   'Longitude': -84.730386,
#   'ORI': 'GA1000100',
#   '_id': ObjectId('6335e0588391502eb9b0adb2')},
#  <Recursion on list with id=3107354400776>]
# [{'Agency Name': "Clinch County Sheriff's Office",
#   'County': 'CLINCH',
#   'Latitude': 31.039433,
#   'Longitude': -82.749954,
#   'ORI': 'GA0320000',
#   '_id': ObjectId('6335e0588391502eb9b0adb3')},
#  <Recursion on list with id=3107354394376>]
# [{'Agency Name': 'Adairsville Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.368633,
#   'Longitude': -84.93449,
#   'ORI': 'GA0080200',
#   '_id': ObjectId('6335e0588391502eb9b0adb4')},
#  <Recursion on list with id=3107354363720>]
# [{'Agency Name': 'College of Coastal Georgia',
#   'County': 'GLYNN',
#   'Latitude': 31.212746,
#   'Longitude': -81.496517,
#   'ORI': 'GA0630300',
#   '_id': ObjectId('6335e0588391502eb9b0adb5')},
#  <Recursion on list with id=3107354392584>]
# [{'Agency Name': 'Tallulah Falls Police Department',
#   'County': 'RABUN; HABERSHAM',
#   'Latitude': 34.635108,
#   'Longitude': -83.526406,
#   'ORI': 'GA1190300',
#   '_id': ObjectId('6335e0588391502eb9b0adb6')},
#  <Recursion on list with id=3107354459528>]
# [{'Agency Name': 'Montezuma Police Department',
#   'County': 'MACON',
#   'Latitude': 32.366216,
#   'Longitude': -84.052162,
#   'ORI': 'GA0960100',
#   '_id': ObjectId('6335e0588391502eb9b0adb7')},
#  <Recursion on list with id=3107354412936>]
# [{'Agency Name': 'Forest Park Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.60854,
#   'Longitude': -84.37918,
#   'ORI': 'GA0310200',
#   '_id': ObjectId('6335e0588391502eb9b0adb8')},
#  <Recursion on list with id=3107354380552>]
# [{'Agency Name': "Forsyth County Sheriff's Office",
#   'County': 'FORSYTH',
#   'Latitude': 34.225143,
#   'Longitude': -84.127435,
#   'ORI': 'GA0580000',
#   '_id': ObjectId('6335e0588391502eb9b0adb9')},
#  <Recursion on list with id=3107327038664>]
# [{'Agency Name': 'Rome Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.169235,
#   'Longitude': -85.21126,
#   'ORI': 'GA0570200',
#   '_id': ObjectId('6335e0588391502eb9b0adba')},
#  <Recursion on list with id=3107354352584>]
# [{'Agency Name': 'Lithonia Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.710865,
#   'Longitude': -84.10791,
#   'ORI': 'GA0440700',
#   '_id': ObjectId('6335e0588391502eb9b0adbb')},
#  <Recursion on list with id=3107354365000>]
# [{'Agency Name': 'Nashville Police Department',
#   'County': 'BERRIEN',
#   'Latitude': 31.274308,
#   'Longitude': -83.231906,
#   'ORI': 'GA0100100',
#   '_id': ObjectId('6335e0588391502eb9b0adbc')},
#  <Recursion on list with id=3107354401736>]
# [{'Agency Name': 'South Fulton',
#   'County': 'FULTON',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0607200',
#   '_id': ObjectId('6335e0588391502eb9b0adbd')},
#  <Recursion on list with id=3107354400328>]
# [{'Agency Name': 'Monticello Police Department',
#   'County': 'JASPER',
#   'Latitude': 33.318128,
#   'Longitude': -83.689505,
#   'ORI': 'GA0790100',
#   '_id': ObjectId('6335e0588391502eb9b0adbe')},
#  <Recursion on list with id=3107354372552>]
# [{'Agency Name': 'Maysville Police Department',
#   'County': 'BANKS; JACKSON',
#   'Latitude': 34.351922,
#   'Longitude': -83.498441,
#   'ORI': 'GA0780300',
#   '_id': ObjectId('6335e0588391502eb9b0adbf')},
#  <Recursion on list with id=3107354399944>]
# [{'Agency Name': "Tift County Sheriff's Office",
#   'County': 'TIFT',
#   'Latitude': 31.457003,
#   'Longitude': -83.525931,
#   'ORI': 'GA1370000',
#   '_id': ObjectId('6335e0588391502eb9b0adc0')},
#  <Recursion on list with id=3107352167112>]
# [{'Agency Name': 'Georgia Southwestern State University',
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290400',
#   '_id': ObjectId('6335e0588391502eb9b0adc1')},
#  <Recursion on list with id=3107354382024>]
# [{'Agency Name': "Decatur County Sheriff's Office",
#   'County': 'DECATUR',
#   'Latitude': 30.908264,
#   'Longitude': -84.59721,
#   'ORI': 'GA0430000',
#   '_id': ObjectId('6335e0588391502eb9b0adc2')},
#  <Recursion on list with id=3107354381512>]
# [{'Agency Name': 'Mount Zion Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.582237,
#   'Longitude': -85.080527,
#   'ORI': 'GA0220700',
#   '_id': ObjectId('6335e0588391502eb9b0adc3')},
#  <Recursion on list with id=3107306127304>]
# [{'Agency Name': 'Fayette County Marshal',
#   'County': 'FAYETTE',
#   'Latitude': 33.447628,
#   'Longitude': -84.462875,
#   'ORI': 'GA0560400',
#   '_id': ObjectId('6335e0588391502eb9b0adc4')},
#  <Recursion on list with id=3107354393480>]
# [{'Agency Name': "White County Sheriff's Office",
#   'County': 'WHITE',
#   'Latitude': 34.618458,
#   'Longitude': -83.75649,
#   'ORI': 'GA1540000',
#   '_id': ObjectId('6335e0588391502eb9b0adc5')},
#  <Recursion on list with id=3107354410568>]
# [{'Agency Name': 'State Patrol: Savannah',
#   'County': 'CHATHAM',
#   'Latitude': 32.361711,
#   'Longitude': -81.343337,
#   'ORI': 'GAGSP4200',
#   '_id': ObjectId('6335e0588391502eb9b0adc6')},
#  <Recursion on list with id=3107354336264>]
# [{'Agency Name': 'Cedartown Police Department',
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150100',
#   '_id': ObjectId('6335e0588391502eb9b0adc7')},
#  <Recursion on list with id=3107354371272>]
# [{'Agency Name': 'Palmetto Police Department',
#   'County': 'COWETA; FULTON',
#   'Latitude': 33.790034,
#   'Longitude': -84.468182,
#   'ORI': 'GA0600800',
#   '_id': ObjectId('6335e0588391502eb9b0adc8')},
#  <Recursion on list with id=3107352167880>]
# [{'Agency Name': "Ben Hill County Sheriff's Office",
#   'County': 'BEN HILL',
#   'Latitude': 31.740775,
#   'Longitude': -83.14719,
#   'ORI': 'GA0090000',
#   '_id': ObjectId('6335e0588391502eb9b0adc9')},
#  <Recursion on list with id=3107354374024>]
# [{'Agency Name': "Chattahoochee County Sheriff's Office",
#   'County': 'CHATTAHOOCHEE',
#   'Latitude': 32.347445,
#   'Longitude': -84.788021,
#   'ORI': 'GA0260000',
#   '_id': ObjectId('6335e0588391502eb9b0adca')},
#  <Recursion on list with id=3107354364232>]
# [{'Agency Name': 'Albany Police Department',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470100',
#   '_id': ObjectId('6335e0588391502eb9b0adcb')},
#  <Recursion on list with id=3107352166664>]
# [{'Agency Name': 'Boston Police Department',
#   'County': 'THOMAS',
#   'Latitude': 30.864606,
#   'Longitude': -83.91982,
#   'ORI': 'GA1360200',
#   '_id': ObjectId('6335e0588391502eb9b0adcc')},
#  <Recursion on list with id=3107354365640>]
# [{'Agency Name': 'Molena Police Department',
#   'County': 'PIKE',
#   'Latitude': 33.090768,
#   'Longitude': -84.386627,
#   'ORI': 'GA1140300',
#   '_id': ObjectId('6335e0588391502eb9b0adcd')},
#  <Recursion on list with id=3107310088520>]
# [{'Agency Name': 'Dunwoody  Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.770661,
#   'Longitude': -84.226343,
#   'ORI': 'GA0447100',
#   '_id': ObjectId('6335e0588391502eb9b0adce')},
#  <Recursion on list with id=3107354352200>]
# [{'Agency Name': "Rockdale County Sheriff's Office",
#   'County': 'ROCKDALE',
#   'Latitude': 33.685886,
#   'Longitude': -84.05896,
#   'ORI': 'GA1220000',
#   '_id': ObjectId('6335e0588391502eb9b0adcf')},
#  <Recursion on list with id=3107354350856>]
# [{'Agency Name': 'Louisville Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810100',
#   '_id': ObjectId('6335e0588391502eb9b0add0')},
#  <Recursion on list with id=3107351660744>]
# [{'Agency Name': 'Savannah Fire and Emergency Services Arson Unit',
#   'County': 'CHATHAM',
#   'Latitude': 32.08216,
#   'Longitude': -81.09664,
#   'ORI': 'GA0252500',
#   '_id': ObjectId('6335e0588391502eb9b0add1')},
#  <Recursion on list with id=3107352845512>]
# [{'Agency Name': 'Garden City Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0250200',
#   '_id': ObjectId('6335e0588391502eb9b0add2')},
#  <Recursion on list with id=3107352165320>]
# [{'Agency Name': "Murray County Sheriff's Office",
#   'County': 'MURRAY',
#   'Latitude': 34.78274,
#   'Longitude': -84.785446,
#   'ORI': 'GA1050000',
#   '_id': ObjectId('6335e0588391502eb9b0add3')},
#  <Recursion on list with id=3107352168200>]
# [{'Agency Name': 'Calhoun Police Department',
#   'County': 'GORDON',
#   'Latitude': 34.50379,
#   'Longitude': -84.95111,
#   'ORI': 'GA0640100',
#   '_id': ObjectId('6335e0588391502eb9b0add4')},
#  <Recursion on list with id=3107352168264>]
# [{'Agency Name': 'Midway Police Department',
#   'County': 'LIBERTY',
#   'Latitude': 31.807296,
#   'Longitude': -81.457864,
#   'ORI': 'GA0890200',
#   '_id': ObjectId('6335e0588391502eb9b0add5')},
#  <Recursion on list with id=3107352166856>]
# [{'Agency Name': 'Euharlee Police Department',
#   'County': 'BARTOW',
#   'Latitude': 34.240917,
#   'Longitude': -84.838188,
#   'ORI': 'GA0080700',
#   '_id': ObjectId('6335e0588391502eb9b0add6')},
#  <Recursion on list with id=3107354183688>]
# [{'Agency Name': 'Sandy Springs Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.925224,
#   'Longitude': -84.359856,
#   'ORI': 'GA0605600',
#   '_id': ObjectId('6335e0588391502eb9b0add7')},
#  <Recursion on list with id=3107327104264>]
# [{'Agency Name': "Haralson County Sheriff's Office",
#   'County': 'HARALSON',
#   'Latitude': 33.795165,
#   'Longitude': -85.220062,
#   'ORI': 'GA0710000',
#   '_id': ObjectId('6335e0588391502eb9b0add8')},
#  <Recursion on list with id=3107354452552>]
# [{'Agency Name': 'Screven Police Department',
#   'County': 'WAYNE',
#   'Latitude': 31.547845,
#   'Longitude': -81.912376,
#   'ORI': 'GA1510200',
#   '_id': ObjectId('6335e0588391502eb9b0add9')},
#  <Recursion on list with id=3107352168328>]
# [{'Agency Name': 'Hiawassee Police Department',
#   'County': 'TOWNS',
#   'Latitude': 34.902662,
#   'Longitude': -83.732215,
#   'ORI': 'GA1390100',
#   '_id': ObjectId('6335e0588391502eb9b0adda')},
#  <Recursion on list with id=3107352165256>]
# [{'Agency Name': 'Madison Police Department',
#   'County': 'MORGAN',
#   'Latitude': 33.593732,
#   'Longitude': -83.492324,
#   'ORI': 'GA1040100',
#   '_id': ObjectId('6335e0588391502eb9b0addb')},
#  <Recursion on list with id=3107352165128>]
# [{'Agency Name': 'Monroe Police Department',
#   'County': 'WALTON',
#   'Latitude': 33.782648,
#   'Longitude': -83.734215,
#   'ORI': 'GA1470100',
#   '_id': ObjectId('6335e0588391502eb9b0addc')},
#  <Recursion on list with id=3107352181704>]
# [{'Agency Name': 'Cecil',
#   'County': 'COOK',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0370400',
#   '_id': ObjectId('6335e0588391502eb9b0addd')},
#  <Recursion on list with id=3107351659208>]
# [{'Agency Name': 'Pembroke Police Department',
#   'County': 'BRYAN',
#   'Latitude': 32.017969,
#   'Longitude': -81.438543,
#   'ORI': 'GA0150100',
#   '_id': ObjectId('6335e0588391502eb9b0adde')},
#  <Recursion on list with id=3107354381064>]
# [{'Agency Name': 'State Patrol: Lawrenceville',
#   'County': 'GWINNETT',
#   'Latitude': 33.959099,
#   'Longitude': -84.022949,
#   'ORI': 'GAGSP3700',
#   '_id': ObjectId('6335e0588391502eb9b0addf')},
#  <Recursion on list with id=3107354365064>]
# [{'Agency Name': 'Richmond County Marshal',
#   'County': 'RICHMOND',
#   'Latitude': 33.361487,
#   'Longitude': -82.074998,
#   'ORI': 'GA1210700',
#   '_id': ObjectId('6335e0588391502eb9b0ade0')},
#  <Recursion on list with id=3107351630728>]
# [{'Agency Name': 'Mountain City Police Department',
#   'County': 'RABUN',
#   'Latitude': 34.883026,
#   'Longitude': -83.404735,
#   'ORI': 'GA1190200',
#   '_id': ObjectId('6335e0588391502eb9b0ade1')},
#  <Recursion on list with id=3107354853192>]
# [{'Agency Name': 'State Patrol: Donalsonville',
#   'County': 'SEMINOLE',
#   'Latitude': 30.933894,
#   'Longitude': -84.867592,
#   'ORI': 'GAGSP1400',
#   '_id': ObjectId('6335e0588391502eb9b0ade2')},
#  <Recursion on list with id=3107354447496>]
# [{'Agency Name': 'Greensboro Police Department',
#   'County': 'GREENE',
#   'Latitude': 33.573967,
#   'Longitude': -83.17531,
#   'ORI': 'GA0660100',
#   '_id': ObjectId('6335e0588391502eb9b0ade3')},
#  <Recursion on list with id=3107354363208>]
# [{'Agency Name': 'Fort Oglethorpe Police Department',
#   'County': 'WALKER; CATOOSA',
#   'Latitude': 34.899393,
#   'Longitude': -85.137353,
#   'ORI': 'GA0230100',
#   '_id': ObjectId('6335e0588391502eb9b0ade4')},
#  <Recursion on list with id=3107354349704>]
# [{'Agency Name': 'Franklin Police Department',
#   'County': 'HEARD',
#   'Latitude': 33.290968,
#   'Longitude': -85.139594,
#   'ORI': 'GA0740100',
#   '_id': ObjectId('6335e0588391502eb9b0ade5')},
#  <Recursion on list with id=3107352727048>]
# [{'Agency Name': 'Cumming Police Department',
#   'County': 'FORSYTH',
#   'Latitude': 34.204327,
#   'Longitude': -84.13951,
#   'ORI': 'GA0580100',
#   '_id': ObjectId('6335e0588391502eb9b0ade6')},
#  <Recursion on list with id=3107354488456>]
# [{'Agency Name': 'Albany Technical College',
#   'County': 'DOUGHERTY',
#   'Latitude': None,
#   'Longitude': None,
#   'ORI': 'GA0471100',
#   '_id': ObjectId('6335e0588391502eb9b0ade7')},
#  <Recursion on list with id=3107351660232>]
# [{'Agency Name': 'Clayton County Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.541374,
#   'Longitude': -84.34508,
#   'ORI': 'GA0310100',
#   '_id': ObjectId('6335e0588391502eb9b0ade8')},
#  <Recursion on list with id=3107354371144>]
# [{'Agency Name': "Calhoun County Sheriff's Office",
#   'County': 'CALHOUN',
#   'Latitude': 31.521279,
#   'Longitude': -84.62629,
#   'ORI': 'GA0190000',
#   '_id': ObjectId('6335e0588391502eb9b0ade9')},
#  <Recursion on list with id=3107310384648>]
# [{'Agency Name': "Worth County Sheriff's Office",
#   'County': 'WORTH',
#   'Latitude': 31.527578,
#   'Longitude': -83.83554,
#   'ORI': 'GA1590000',
#   '_id': ObjectId('6335e0588391502eb9b0adea')},
#  <Recursion on list with id=3107352165768>]
# [{'Agency Name': 'Lookout Mountain Police Department',
#   'County': 'WALKER',
#   'Latitude': 34.978447,
#   'Longitude': -85.35674,
#   'ORI': 'GA1460300',
#   '_id': ObjectId('6335e0588391502eb9b0adeb')},
#  <Recursion on list with id=3107354490952>]
# [{'Agency Name': 'Pendergrass  Police Department',
#   'County': 'JACKSON',
#   'Latitude': 34.134157,
#   'Longitude': -83.565133,
#   'ORI': 'GA0780900',
#   '_id': ObjectId('6335e0588391502eb9b0adec')},
#  <Recursion on list with id=3107310256712>]
# [{'Agency Name': "Pulaski County Sheriff's Office",
#   'County': 'PULASKI',
#   'Latitude': 32.238794,
#   'Longitude': -83.481855,
#   'ORI': 'GA1160000',
#   '_id': ObjectId('6335e0588391502eb9b0aded')},
#  <Recursion on list with id=3107354492232>]
# [{'Agency Name': 'Valdosta State University',
#   'County': 'LOWNDES',
#   'Latitude': 30.813684,
#   'Longitude': -83.264366,
#   'ORI': 'GA0920500',
#   '_id': ObjectId('6335e0588391502eb9b0adee')},
#  <Recursion on list with id=3107104692296>]
# [{'Agency Name': 'Cave Spring Police Department',
#   'County': 'FLOYD',
#   'Latitude': 34.263677,
#   'Longitude': -85.21373,
#   'ORI': 'GA0570300',
#   '_id': ObjectId('6335e0588391502eb9b0adef')},
#  <Recursion on list with id=3107352211144>]
# [{'Agency Name': 'Georgia Institute of Technology',
#   'County': 'FULTON',
#   'Latitude': 33.779533,
#   'Longitude': -84.40235,
#   'ORI': 'GA0601000',
#   '_id': ObjectId('6335e0588391502eb9b0adf0')},
#  <Recursion on list with id=3107354363144>]
# [{'Agency Name': 'Doraville Police Department',
#   'County': 'DEKALB',
#   'Latitude': 33.90096,
#   'Longitude': -84.27897,
#   'ORI': 'GA0440600',
#   '_id': ObjectId('6335e0588391502eb9b0adf1')},
#  <Recursion on list with id=3107354370248>]
# [{'Agency Name': "Tattnall County Sheriff's Office",
#   'County': 'TATTNALL',
#   'Latitude': 32.043768,
#   'Longitude': -82.059208,
#   'ORI': 'GA1320000',
#   '_id': ObjectId('6335e0588391502eb9b0adf2')},
#  <Recursion on list with id=3107352166600>]
# [{'Agency Name': 'Gwinnett County Public Schools',
#   'County': 'GWINNETT',
#   'Latitude': 33.959099,
#   'Longitude': -84.022949,
#   'ORI': 'GA0671000',
#   '_id': ObjectId('6335e0588391502eb9b0adf3')},
#  <Recursion on list with id=3107354484488>]
# [{'Agency Name': 'Temple Police Department',
#   'County': 'CARROLL',
#   'Latitude': 33.582237,
#   'Longitude': -85.080527,
#   'ORI': 'GA0220400',
#   '_id': ObjectId('6335e0588391502eb9b0adf4')},
#  <Recursion on list with id=3107354492552>]
# [{'Agency Name': 'Sylvania Police Department',
#   'County': 'SCREVEN',
#   'Latitude': 32.744751,
#   'Longitude': -81.617585,
#   'ORI': 'GA1240100',
#   '_id': ObjectId('6335e0588391502eb9b0adf5')},
#  <Recursion on list with id=3107354488392>]
# [{'Agency Name': 'Lakeland Police Department',
#   'County': 'LANIER',
#   'Latitude': 31.038197,
#   'Longitude': -83.063164,
#   'ORI': 'GA0860100',
#   '_id': ObjectId('6335e0588391502eb9b0adf6')},
#  <Recursion on list with id=3107354483720>]
# [{'Agency Name': 'Bainbridge Police Department',
#   'County': 'DECATUR',
#   'Latitude': 30.878091,
#   'Longitude': -84.577894,
#   'ORI': 'GA0430100',
#   '_id': ObjectId('6335e0588391502eb9b0adf7')},
#  <Recursion on list with id=3107354365832>]
# [{'Agency Name': 'Irwinton Police Department',
#   'County': 'WILKINSON',
#   'Latitude': 32.804312,
#   'Longitude': -83.175497,
#   'ORI': 'GA1580200',
#   '_id': ObjectId('6335e0588391502eb9b0adf8')},
#  <Recursion on list with id=3107354364872>]
# [{'Agency Name': 'Rockmart Police Department',
#   'County': 'POLK',
#   'Latitude': 33.996015,
#   'Longitude': -85.188338,
#   'ORI': 'GA1150200',
#   '_id': ObjectId('6335e0588391502eb9b0adf9')},
#  <Recursion on list with id=3107354473672>]
# [{'Agency Name': 'Warm Springs Police Department',
#   'County': 'MERIWETHER',
#   'Latitude': 33.03022,
#   'Longitude': -84.663279,
#   'ORI': 'GA0990500',
#   '_id': ObjectId('6335e0588391502eb9b0adfa')},
#  <Recursion on list with id=3107310385032>]
# [{'Agency Name': 'State Patrol: Thomaston',
#   'County': 'UPSON',
#   'Latitude': 32.881837,
#   'Longitude': -84.292281,
#   'ORI': 'GAGSP2600',
#   '_id': ObjectId('6335e0588391502eb9b0adfb')},
#  <Recursion on list with id=3107354483208>]
# [{'Agency Name': 'State Patrol: Cartersville',
#   'County': 'BARTOW',
#   'Latitude': 34.204853,
#   'Longitude': -84.81206,
#   'ORI': 'GAGSP0300',
#   '_id': ObjectId('6335e0588391502eb9b0adfc')},
#  <Recursion on list with id=3107310215816>]
# [{'Agency Name': "Union County Sheriff's Office",
#   'County': 'UNION',
#   'Latitude': 34.83377,
#   'Longitude': -83.989573,
#   'ORI': 'GA1440000',
#   '_id': ObjectId('6335e0588391502eb9b0adfd')},
#  <Recursion on list with id=3107354444488>]
# [{'Agency Name': "Mitchell County Sheriff's Office",
#   'County': 'MITCHELL',
#   'Latitude': 31.228997,
#   'Longitude': -84.192038,
#   'ORI': 'GA1010000',
#   '_id': ObjectId('6335e0588391502eb9b0adfe')},
#  <Recursion on list with id=3107354459848>]
# [{'Agency Name': "Dougherty County Sheriff's Office",
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470000',
#   '_id': ObjectId('6335e0588391502eb9b0adff')},
#  <Recursion on list with id=3107354336136>]
# [{'Agency Name': 'Nelson Police Department',
#   'County': 'CHEROKEE; PICKENS',
#   'Latitude': 34.456625,
#   'Longitude': -84.490263,
#   'ORI': 'GA0280600',
#   '_id': ObjectId('6335e0588391502eb9b0ae00')},
#  <Recursion on list with id=3107354476168>]
# [{'Agency Name': "Baker County Sheriff's Office",
#   'County': 'BAKER',
#   'Latitude': 31.31958,
#   'Longitude': -84.454881,
#   'ORI': 'GA0040000',
#   '_id': ObjectId('6335e0588391502eb9b0ae01')},
#  <Recursion on list with id=3107354333640>]
# [{'Agency Name': 'Gordon State College',
#   'County': 'LAMAR',
#   'Latitude': 33.044018,
#   'Longitude': -84.15348,
#   'ORI': 'GA0850300',
#   '_id': ObjectId('6335e0588391502eb9b0ae02')},
#  <Recursion on list with id=3107354853192>]
# [{'Agency Name': "McDuffie County Sheriff's Office",
#   'County': 'MCDUFFIE',
#   'Latitude': 33.482464,
#   'Longitude': -82.473188,
#   'ORI': 'GA0940000',
#   '_id': ObjectId('6335e0588391502eb9b0ae03')},
#  <Recursion on list with id=3107352166856>]
# [{'Agency Name': 'Newnan Police Department',
#   'County': 'COWETA',
#   'Latitude': 33.352897,
#   'Longitude': -84.762138,
#   'ORI': 'GA0380100',
#   '_id': ObjectId('6335e0588391502eb9b0ae04')},
#  <Recursion on list with id=3107351630728>]
# [{'Agency Name': 'Wesleyan College',
#   'County': 'BIBB',
#   'Latitude': 32.876038,
#   'Longitude': -83.71381,
#   'ORI': 'GA011119E',
#   '_id': ObjectId('6335e0588391502eb9b0ae05')},
#  <Recursion on list with id=3107354183688>]
# [{'Agency Name': "Effingham County Sheriff's Office",
#   'County': 'EFFINGHAM',
# ...
#   '_id': ObjectId('6335e0598391502eb9b0af88')},
#  <Recursion on list with id=3107351659208>]
# [{'Agency Name': "Cherokee County Sheriff's Office",
#   'County': 'CHEROKEE',
#   'Latitude': 34.196648,
#   'Longitude': -84.49234,
#   'ORI': 'GA0280000',
#   '_id': ObjectId('6335e0598391502eb9b0af89')},
#  <Recursion on list with id=3107354493576>]
# [{'Agency Name': 'Cohutta Police Department',
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   'ORI': 'GA1550300',
#   '_id': ObjectId('6335e0598391502eb9b0af8a')},
#  <Recursion on list with id=3107354853192>]
# [{'Agency Name': 'Oak Park Police Department',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   'ORI': 'GA0530600',
#   '_id': ObjectId('6335e0598391502eb9b0af8b')},
#  <Recursion on list with id=3107354361928>]
# [{'Agency Name': 'Mercer University',
#   'County': 'BIBB',
#   'Latitude': 32.82903,
#   'Longitude': -83.648766,
#   'ORI': 'GA011099E',
#   '_id': ObjectId('6335e0598391502eb9b0af8c')},
#  <Recursion on list with id=3107354494984>]
# [{'Agency Name': 'Wrightsville Police Department',
#   'County': 'JOHNSON',
#   'Latitude': 32.72852,
#   'Longitude': -82.731895,
#   'ORI': 'GA0830100',
#   '_id': ObjectId('6335e0598391502eb9b0af8d')},
#  <Recursion on list with id=3107354365768>]
# [{'Agency Name': 'Blakely Police Department',
#   'County': 'EARLY',
#   'Latitude': 31.324191,
#   'Longitude': -84.906723,
#   'ORI': 'GA0490100',
#   '_id': ObjectId('6335e0598391502eb9b0af8e')},
#  <Recursion on list with id=3107354362184>]
# [{'Agency Name': 'Pickens County Board of Education',
#   'County': 'PICKENS',
#   'Latitude': 34.456625,
#   'Longitude': -84.490263,
#   'ORI': 'GA1120300',
#   '_id': ObjectId('6335e0598391502eb9b0af8f')},
#  <Recursion on list with id=3107354361992>]
# [{'Agency Name': 'Henry County Police Department',
#   'County': 'HENRY',
#   'Latitude': 33.452881,
#   'Longitude': -84.15444,
#   'ORI': 'GA0750500',
#   '_id': ObjectId('6335e0598391502eb9b0af90')},
#  <Recursion on list with id=3107354561608>]
# [{'Agency Name': 'Cordele Police Department',
#   'County': 'CRISP',
#   'Latitude': 31.973846,
#   'Longitude': -83.782745,
#   'ORI': 'GA0400100',
#   '_id': ObjectId('6335e0598391502eb9b0af91')},
#  <Recursion on list with id=3107354542280>]
# [{'Agency Name': "Glascock County Sheriff's Office",
#   'County': 'GLASCOCK',
#   'Latitude': 33.227491,
#   'Longitude': -82.606913,
#   'ORI': 'GA0620000',
#   '_id': ObjectId('6335e0598391502eb9b0af92')},
#  <Recursion on list with id=3107354544264>]
# [{'Agency Name': 'Trion Police Department',
#   'County': 'CHATTOOGA',
#   'Latitude': 34.54347,
#   'Longitude': -85.312996,
#   'ORI': 'GA0270200',
#   '_id': ObjectId('6335e0598391502eb9b0af93')},
#  <Recursion on list with id=3107354350856>]
# [{'Agency Name': 'Covington Police Department',
#   'County': 'NEWTON',
#   'Latitude': 33.595737,
#   'Longitude': -83.857635,
#   'ORI': 'GA1070100',
#   '_id': ObjectId('6335e0598391502eb9b0af94')},
#  <Recursion on list with id=3107354327944>]
# [{'Agency Name': 'Georgia Military College',
#   'County': 'BALDWIN',
#   'Latitude': 33.08015,
#   'Longitude': -83.22491,
#   'ORI': 'GA0050400',
#   '_id': ObjectId('6335e0598391502eb9b0af95')},
#  <Recursion on list with id=3107354544008>]
# [{'Agency Name': 'Roswell Police Department',
#   'County': 'FULTON',
#   'Latitude': 34.021626,
#   'Longitude': -84.35973,
#   'ORI': 'GA0600500',
#   '_id': ObjectId('6335e0598391502eb9b0af96')},
#  <Recursion on list with id=3107354562696>]
# [{'Agency Name': 'Hogansville Police Department',
#   'County': 'TROUP',
#   'Latitude': 33.17311,
#   'Longitude': -84.920135,
#   'ORI': 'GA1410100',
#   '_id': ObjectId('6335e0598391502eb9b0af97')},
#  <Recursion on list with id=3107354327112>]
# [{'Agency Name': 'Richland Police Department',
#   'County': 'STEWART',
#   'Latitude': 32.073225,
#   'Longitude': -84.834912,
#   'ORI': 'GA1280200',
#   '_id': ObjectId('6335e0598391502eb9b0af98')},
#  <Recursion on list with id=3107354350536>]
# [{'Agency Name': 'State Patrol: Marietta',
#   'County': 'COBB',
#   'Latitude': 33.93994,
#   'Longitude': -84.574166,
#   'ORI': 'GAGSP0900',
#   '_id': ObjectId('6335e0598391502eb9b0af99')},
#  <Recursion on list with id=3107354444232>]
# [{'Agency Name': 'McCaysville Police Department',
#   'County': 'FANNIN',
#   'Latitude': 34.866497,
#   'Longitude': -84.31744,
#   'ORI': 'GA0550100',
#   '_id': ObjectId('6335e0598391502eb9b0af9a')},
#  <Recursion on list with id=3107352845512>]
# [{'Agency Name': 'Buena Vista Police Department',
#   'County': 'MARION',
#   'Latitude': 32.359538,
#   'Longitude': -84.529561,
#   'ORI': 'GA0980100',
#   '_id': ObjectId('6335e0598391502eb9b0af9b')},
#  <Recursion on list with id=3107354545032>]
# [{'Agency Name': 'Albany-Dougherty Metropolitan Drug Squad',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470600',
#   '_id': ObjectId('6335e0598391502eb9b0af9c')},
#  <Recursion on list with id=3107354352712>]
# [{'Agency Name': 'Suwanee Police Department',
#   'County': 'GWINNETT',
#   'Latitude': 33.959099,
#   'Longitude': -84.022949,
#   'ORI': 'GA0670900',
#   '_id': ObjectId('6335e0598391502eb9b0af9d')},
#  <Recursion on list with id=3107354543944>]
# [{'Agency Name': "Coffee County Sheriff's Office",
#   'County': 'COFFEE',
#   'Latitude': 31.549245,
#   'Longitude': -82.844938,
#   'ORI': 'GA0340000',
#   '_id': ObjectId('6335e0598391502eb9b0af9e')},
#  <Recursion on list with id=3107309278984>]
# [{'Agency Name': "Irwin County Sheriff's Office",
#   'County': 'IRWIN',
#   'Latitude': 31.591131,
#   'Longitude': -83.25055,
#   'ORI': 'GA0770000',
#   '_id': ObjectId('6335e0598391502eb9b0af9f')},
#  <Recursion on list with id=3107354364680>]
# [{'Agency Name': 'Cochran Police Department',
#   'County': 'BLECKLEY',
#   'Latitude': 32.386444,
#   'Longitude': -83.35458,
#   'ORI': 'GA0120100',
#   '_id': ObjectId('6335e0598391502eb9b0afa0')},
#  <Recursion on list with id=3107354393288>]
# [{'Agency Name': "Wilcox County Sheriff's Office",
#   'County': 'WILCOX',
#   'Latitude': 31.962717,
#   'Longitude': -83.438262,
#   'ORI': 'GA1560000',
#   '_id': ObjectId('6335e0598391502eb9b0afa1')},
#  <Recursion on list with id=3107354390792>]
# [{'Agency Name': 'Augusta Technical College',
#   'County': 'RICHMOND',
#   'Latitude': 33.419178,
#   'Longitude': -82.051254,
#   'ORI': 'GA1212100',
#   '_id': ObjectId('6335e0598391502eb9b0afa2')},
#  <Recursion on list with id=3107354390600>]
# [{'Agency Name': 'Georgia World Congress',
#   'County': 'FULTON',
#   'Latitude': 33.759632,
#   'Longitude': -84.382416,
#   'ORI': 'GA0603800',
#   '_id': ObjectId('6335e0598391502eb9b0afa3')},
#  <Recursion on list with id=3107354371464>]
# [{'Agency Name': "Pierce County Sheriff's Office",
#   'County': 'PIERCE',
#   'Latitude': 31.302244,
#   'Longitude': -82.23383,
#   'ORI': 'GA1130000',
#   '_id': ObjectId('6335e0598391502eb9b0afa4')},
#  <Recursion on list with id=3107354496840>]
# [{'Agency Name': 'Andrew College ',
#   'County': 'RANDOLPH',
#   'Latitude': 31.771894,
#   'Longitude': -84.79704,
#   'ORI': 'GA120059E',
#   '_id': ObjectId('6335e0598391502eb9b0afa5')},
#  <Recursion on list with id=3107354372680>]
# [{'Agency Name': 'Danielsville Police Department',
#   'County': 'MADISON',
#   'Latitude': 34.128484,
#   'Longitude': -83.203644,
#   'ORI': 'GA0970300',
#   '_id': ObjectId('6335e0598391502eb9b0afa6')},
#  <Recursion on list with id=3107354391688>]
# [{'Agency Name': "Dade County Sheriff's Office",
#   'County': 'DADE',
#   'Latitude': 34.852424,
#   'Longitude': -85.506201,
#   'ORI': 'GA0410000',
#   '_id': ObjectId('6335e0598391502eb9b0afa7')},
#  <Recursion on list with id=3107354370312>]
# [{'Agency Name': "Barrow County Sheriff's Office",
#   'County': 'BARROW',
#   'Latitude': 33.992009,
#   'Longitude': -83.712303,
#   'ORI': 'GA0070000',
#   '_id': ObjectId('6335e0598391502eb9b0afa8')},
#  <Recursion on list with id=3107354563272>]
# [{'Agency Name': "Jones County Sheriff's Office",
#   'County': 'JONES',
#   'Latitude': 33.020226,
#   'Longitude': -83.562339,
#   'ORI': 'GA0840000',
#   '_id': ObjectId('6335e0598391502eb9b0afa9')},
#  <Recursion on list with id=3107354425928>]
# [{'Agency Name': 'Cobb County Police Department',
#   'County': 'COBB',
#   'Latitude': 33.958862,
#   'Longitude': -84.54633,
#   'ORI': 'GA0330200',
#   '_id': ObjectId('6335e0598391502eb9b0afaa')},
#  <Recursion on list with id=3107354565192>]
# [{'Agency Name': 'McRae Police Department',
#   'County': 'WHEELER; TELFAIR',
#   'Latitude': 31.913639,
#   'Longitude': -82.931062,
#   'ORI': 'GA1340100',
#   '_id': ObjectId('6335e0598391502eb9b0afab')},
#  <Recursion on list with id=3107354362440>]
# [{'Agency Name': 'Snellville Police Department',
#   'County': 'GWINNETT',
#   'Latitude': 33.83367,
#   'Longitude': -84.00958,
#   'ORI': 'GA0670800',
#   '_id': ObjectId('6335e0598391502eb9b0afac')},
#  <Recursion on list with id=3107354565064>]
# [{'Agency Name': 'Warner Robins Police Department',
#   'County': 'PEACH; HOUSTON',
#   'Latitude': 32.458381,
#   'Longitude': -83.662856,
#   'ORI': 'GA0760200',
#   '_id': ObjectId('6335e0598391502eb9b0afad')},
#  <Recursion on list with id=3107354353352>]
# [{'Agency Name': 'Canton Police Department',
#   'County': 'CHEROKEE',
#   'Latitude': 34.23541,
#   'Longitude': -84.490005,
#   'ORI': 'GA0280100',
#   '_id': ObjectId('6335e0598391502eb9b0afae')},
#  <Recursion on list with id=3107354493576>]
# [{'Agency Name': 'State Patrol: Swainsboro',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   'ORI': 'GAGSP1900',
#   '_id': ObjectId('6335e0598391502eb9b0afaf')},
#  <Recursion on list with id=3107354452552>]
# [{'Agency Name': "Randolph County Sheriff's Office",
#   'County': 'RANDOLPH',
#   'Latitude': 31.762651,
#   'Longitude': -84.752311,
#   'ORI': 'GA1200000',
#   '_id': ObjectId('6335e0598391502eb9b0afb0')},
#  <Recursion on list with id=3107351659208>]
# [{'Agency Name': 'Stillmore Police Department',
#   'County': 'EMANUEL',
#   'Latitude': 32.5911,
#   'Longitude': -82.299763,
#   'ORI': 'GA0530500',
#   '_id': ObjectId('6335e0598391502eb9b0afb1')},
#  <Recursion on list with id=3107310088520>]
# [{'Agency Name': 'Tunnel Hill Police Department',
#   'County': 'WHITFIELD',
#   'Latitude': 34.801726,
#   'Longitude': -84.968541,
#   'ORI': 'GA1550200',
#   '_id': ObjectId('6335e0598391502eb9b0afb2')},
#  <Recursion on list with id=3107351660744>]
# [{'Agency Name': 'Adrian Police Department',
#   'County': 'EMANUEL; JOHNSON',
#   'Latitude': 32.689831,
#   'Longitude': -82.661354,
#   'ORI': 'GA0830200',
#   '_id': ObjectId('6335e0598391502eb9b0afb3')},
#  <Recursion on list with id=3107354325640>]
# [{'Agency Name': 'East Ellijay Police Department',
#   'County': 'GILMER',
#   'Latitude': 34.690541,
#   'Longitude': -84.453984,
#   'ORI': 'GA0610300',
#   '_id': ObjectId('6335e0598391502eb9b0afb4')},
#  <Recursion on list with id=3107354454856>]
# [{'Agency Name': 'Locust Grove Police Department',
#   'County': 'HENRY',
#   'Latitude': 33.452881,
#   'Longitude': -84.15444,
#   'ORI': 'GA0750400',
#   '_id': ObjectId('6335e0598391502eb9b0afb5')},
#  <Recursion on list with id=3107354361608>]
# [{'Agency Name': 'Lake City Police Department',
#   'County': 'CLAYTON',
#   'Latitude': 33.60693,
#   'Longitude': -84.34333,
#   'ORI': 'GA0310600',
#   '_id': ObjectId('6335e0598391502eb9b0afb6')},
#  <Recursion on list with id=3107306127304>]
# [{'Agency Name': "Sumter County Sheriff's Office",
#   'County': 'SUMTER',
#   'Latitude': 32.042197,
#   'Longitude': -84.204259,
#   'ORI': 'GA1290000',
#   '_id': ObjectId('6335e0598391502eb9b0afb7')},
#  <Recursion on list with id=3107352165320>]
# [{'Agency Name': "Newton County Sheriff's Office",
#   'County': 'NEWTON',
#   'Latitude': 33.544065,
#   'Longitude': -83.855192,
#   'ORI': 'GA1070000',
#   '_id': ObjectId('6335e0598391502eb9b0afb8')},
#  <Recursion on list with id=3107352168264>]
# [{'Agency Name': 'Georgia College and State University',
#   'County': 'BALDWIN',
#   'Latitude': 33.059504,
#   'Longitude': -83.255452,
#   'ORI': 'GA0050300',
#   '_id': ObjectId('6335e0598391502eb9b0afb9')},
#  <Recursion on list with id=3107354410568>]
# [{'Agency Name': "Fayette County Sheriff's Office",
#   'County': 'FAYETTE',
#   'Latitude': 33.446476,
#   'Longitude': -84.45227,
#   'ORI': 'GA0560000',
#   '_id': ObjectId('6335e0598391502eb9b0afba')},
#  <Recursion on list with id=3107354336264>]
# [{'Agency Name': "Meriwether County Sheriff's Office",
#   'County': 'MERIWETHER',
#   'Latitude': 33.03022,
#   'Longitude': -84.663279,
#   'ORI': 'GA0990000',
#   '_id': ObjectId('6335e0598391502eb9b0afbb')},
#  <Recursion on list with id=3107354393480>]
# [{'Agency Name': 'Fulton County Marshal',
#   'County': 'FULTON',
#   'Latitude': 33.752655,
#   'Longitude': -84.38997,
#   'ORI': 'GA0602700',
#   '_id': ObjectId('6335e0598391502eb9b0afbc')},
#  <Recursion on list with id=3107354365704>]
# [{'Agency Name': 'Alpharetta Police Department',
#   'County': 'FULTON',
#   'Latitude': 33.790034,
#   'Longitude': -84.468182,
#   'ORI': 'GA0600400',
#   '_id': ObjectId('6335e0598391502eb9b0afbd')},
#  <Recursion on list with id=3107354183688>]
# [{'Agency Name': 'Lumpkin Police Department',
#   'County': 'STEWART',
#   'Latitude': 32.073225,
#   'Longitude': -84.834912,
#   'ORI': 'GA1280100',
#   '_id': ObjectId('6335e0598391502eb9b0afbe')},
#  <Recursion on list with id=3107354328648>]
# [{'Agency Name': "Troup County Sheriff's Office",
#   'County': 'TROUP',
#   'Latitude': 32.989746,
#   'Longitude': -85.00395,
#   'ORI': 'GA1410000',
#   '_id': ObjectId('6335e0598391502eb9b0afbf')},
#  <Recursion on list with id=3107354364232>]
# [{'Agency Name': 'Oakwood Police Department',
#   'County': 'HALL',
#   'Latitude': 34.317588,
#   'Longitude': -83.818497,
#   'ORI': 'GA0690400',
#   '_id': ObjectId('6335e0598391502eb9b0afc0')},
#  <Recursion on list with id=3107354352200>]
# [{'Agency Name': "Brantley County Sheriff's Office",
#   'County': 'BRANTLEY',
#   'Latitude': 31.197334,
#   'Longitude': -81.982978,
#   'ORI': 'GA0130000',
#   '_id': ObjectId('6335e0598391502eb9b0afc1')},
#  <Recursion on list with id=3107354394376>]
# [{'Agency Name': 'State Patrol: Madison',
#   'County': 'MORGAN',
#   'Latitude': 33.593732,
#   'Longitude': -83.492324,
#   'ORI': 'GAGSP0800',
#   '_id': ObjectId('6335e0598391502eb9b0afc2')},
#  <Recursion on list with id=3107354363720>]
# [{'Agency Name': 'Douglas Police Department',
#   'County': 'COFFEE',
#   'Latitude': 31.511168,
#   'Longitude': -82.852135,
#   'ORI': 'GA0340100',
#   '_id': ObjectId('6335e0598391502eb9b0afc3')},
#  <Recursion on list with id=3107354352584>]
# [{'Agency Name': 'Dougherty County Board of Education',
#   'County': 'DOUGHERTY',
#   'Latitude': 31.532588,
#   'Longitude': -84.20904,
#   'ORI': 'GA0470500',
#   '_id': ObjectId('6335e0598391502eb9b0afc4')},
#  <Recursion on list with id=3107354410056>]
# [{'Agency Name': "Terrell County Sheriff's Office",
#   'County': 'TERRELL',
#   'Latitude': 31.777191,
#   'Longitude': -84.439446,
#   'ORI': 'GA1350000',
#   '_id': ObjectId('6335e0598391502eb9b0afc5')},
#  <Recursion on list with id=3107352168200>]
# [{'Agency Name': 'Tybee Island Police Department',
#   'County': 'CHATHAM',
#   'Latitude': 31.980523,
#   'Longitude': -81.08519,
#   'ORI': 'GA0250600',
#   '_id': ObjectId('6335e0598391502eb9b0afc6')},
#  <Recursion on list with id=3107354365640>]
# [{'Agency Name': "Lincoln County Sheriff's Office",
#   'County': 'LINCOLN',
#   'Latitude': 33.792151,
#   'Longitude': -82.448299,
#   'ORI': 'GA0900000',
#   '_id': ObjectId('6335e0598391502eb9b0afc7')},
#  <Recursion on list with id=3107354453512>]
# [{'Agency Name': 'Blue Ridge Police Department',
#   'County': 'FANNIN',
#   'Latitude': 34.866226,
#   'Longitude': -84.32594,
#   'ORI': 'GA0550200',
#   '_id': ObjectId('6335e0598391502eb9b0afc8')},
#  <Recursion on list with id=3107354371272>]
# [{'Agency Name': 'Ocilla Police Department',
#   'County': 'IRWIN',
#   'Latitude': 31.591131,
#   'Longitude': -83.25055,
#   'ORI': 'GA0770100',
#   '_id': ObjectId('6335e0598391502eb9b0afc9')},
#  <Recursion on list with id=3107323257032>]
# [{'Agency Name': 'Stapleton Police Department',
#   'County': 'JEFFERSON',
#   'Latitude': 33.051874,
#   'Longitude': -82.41905,
#   'ORI': 'GA0810500',
#   '_id': ObjectId('6335e0598391502eb9b0afca')},
#  <Recursion on list with id=3107354381064>]
# [{'Agency Name': 'Middle Georgia State University',
#   'County': 'BLECKLEY',
#   'Latitude': 32.435403,
#   'Longitude': -83.331717,
#   'ORI': 'GA0120200',
#   '_id': ObjectId('6335e0598391502eb9b0afcb')},
#  <Recursion on list with id=3107354380552>]

# %% [markdown]
# ### Load County Table / Build Dictionary

# %%
countyList = []
countyDF = pd.DataFrame(list(db.destination.find({})))['County']

# split multi-counties into individual
for row in countyDF:

    #split the multi-counties
    counties = row.split('; ')

    for cnty in counties:
        if cnty not in countyList and cnty != '':
            countyList.append(cnty)

# cleanup and store in SQL
countyList.sort()
countyDF = pd.DataFrame(countyList, columns =['county_name'])
countyDF.insert(0, 'countyid', range(1, 1 + len(countyDF)))
countyDF.to_sql(name='County', con=engine, if_exists='replace', index=False)

#put counties in dictionary for lookup
county_dict = dict(zip(countyDF.county_name, countyDF.countyid))
county_dict
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     207         try:
# --> 208             raise exception
#     209         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     207         try:
# --> 208             raise exception
#     209         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10632\3057742853.py in <module>
#      16 countyDF = pd.DataFrame(countyList, columns =['county_name'])
#      17 countyDF.insert(0, 'countyid', range(1, 1 + len(countyDF)))
# ---> 18 countyDF.to_sql(name='County', con=engine, if_exists='replace', index=False)
#      19
#      20 #put counties in dictionary for lookup
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1756             index_label=index_label,
#    1757             schema=schema,
# -> 1758             dtype=dtype,
#    1759         )
#    1760
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     854
#     855     def create(self):
# --> 856         if self.exists():
#     857             if self.if_exists == "fail":
#     858                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in exists(self)
#     838
#     839     def exists(self):
# --> 840         return self.pd_sql.has_table(self.name, self.schema)
#     841
#     842     def sql_schema(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1781             import sqlalchemy as sa
#    1782
# -> 1783             insp = sa.inspect(self.connectable)
#    1784             return insp.has_table(name, schema or self.meta.schema)
#    1785         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3313         """
#    3314
# -> 3315         return self._connection_cls(self, close_with_result=close_with_result)
#    3316
#    3317     @util.deprecated(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3392
#    3393         """
# -> 3394         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3395
#    3396
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3363             if connection is None:
#    3364                 Connection._handle_dbapi_exception_noconnection(
# -> 3365                     e, dialect, self
#    3366                 )
#    3367             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2197         elif should_wrap:
#    2198             util.raise_(
# -> 2199                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2200             )
#    2201         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3359         dialect = self.dialect
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#    3363             if connection is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     664         except Exception as e:
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#     668             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     595     def connect(self, *cargs, **cparams):
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#     599     def create_connect_args(self, url):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### Load Agency Table / Build Dictionary

# %%
agencyList = []
DF_raw = pd.DataFrame(list(db.destination.find({})))[['Agency Name','County','ORI','Latitude','Longitude']]
agencyDF = pd.DataFrame(columns=['agency_name','ori','latitude','longitude'])

for index, row in DF_raw.iterrows():
    if row[0] not in agencyList:
        agencyList.append(row[0])
        agencyDF.loc[len(agencyDF.index)] = [row[0], row[2],  row[3],  row[4]]
        
agencyDF = agencyDF.sort_values(by=['agency_name'])
agencyDF.insert(0, 'agencyid', range(1, 1 + len(agencyDF.index)))
agencyDF.to_sql(name='Agency', con=engine, if_exists='replace', index=False)

#put agencies in dictionary for lookup
agency_dict = dict(zip(agencyDF.agency_name, agencyDF.agencyid))
agency_dict

# %% [markdown]
# ### Load CountyAgency Relationship Table

# %%
DF_raw = pd.DataFrame(list(db.destination.find({})))[['Agency Name','County','ORI','Latitude','Longitude']]
countyagencyDF = pd.DataFrame(columns=['agencyid','countyid'])

for index, row in DF_raw.iterrows():
    
    # split the multi-counties
    if ';' in row.County:
        counties = row.County.split('; ')

        for cnty in counties:
            if cnty != '':
                countyagencyDF.loc[len(countyagencyDF.index)] = [agency_dict.get(row[0]), county_dict.get(cnty)]
    else:
        countyagencyDF.loc[len(countyagencyDF.index)] = [agency_dict.get(row[0]), county_dict.get(row[1])]
        
countyagencyDF = countyagencyDF.sort_values(by=['agencyid','countyid'])
countyagencyDF.insert(0, 'countyagencyid', range(1, 1 + len(countyagencyDF.index)))
countyagencyDF.to_sql(name='CountyAgency', con=engine, if_exists='replace', index=False)
countyagencyDF.head(5)

# %% [markdown]
# ### Load Income Table

# %%
DF_raw = pd.read_csv('data/incomepercapita.csv')
incomeDF = pd.DataFrame(columns=['countyid','percapita_income','data_year'])

for index, row in DF_raw.iterrows():
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[1], 2017]
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[2], 2018]
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[3], 2019]
    incomeDF.loc[len(incomeDF.index)] = [county_dict.get(row[0].replace(' County','').upper()), row[4], 2020]
        
incomeDF = incomeDF.sort_values(by=['countyid','data_year'])
incomeDF.insert(0, 'incomeid', range(1, 1 + len(incomeDF.index)))
incomeDF.to_sql(name='Income', con=engine, if_exists='replace', index=False)
incomeDF.head(5)

# %% [markdown]
# ### Load GA Crimes Table

# %%
crimeDF = pd.read_csv('data/crimes.csv')
crimeDF.to_sql(name= 'Crimes', con= engine, if_exists= 'replace', index= False)
